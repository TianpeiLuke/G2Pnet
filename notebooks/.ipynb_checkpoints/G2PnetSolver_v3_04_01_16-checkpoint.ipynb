# %% [markdown]
# # G$^2$Pnet: The Grassmanian Gaussian Process Network
# We check the implementation of G2PnetSolver (ver 4.) class in ../src/
#
# Created by Tianpei Xie, 04/01/2016
#
# Last Edit 04/01/2016

# %%
# %reset
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import rbf_kernel, pairwise_kernels
import GPy
import GPy.util as gutil

# %matplotlib inline 
plt.close('all')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
Ifsavefig =  True
Ifsavedata = True
trail = 0

# %% [markdown]
# The network generating

# %%
size = 40
color_map = {0:'r', 1:'c', 2:'y'}
#center = np.zeros(2)
#center[1] = 1
center = None

n = 40
m = 0
G0= nx.barbell_graph(n,m) 
#generate the bar-bell graph, which consists of two fully connected component and a path connecting them 

label0 = np.zeros([2*n,1])
label0[n:2*n] = np.ones([n,1])
#### labeling of the cluster
for node in G0.nodes():
    G0.node[node]['category'] = int(label0[node,0])

# %%
####generate the eigenspace of normalized Laplacian
k = 3
nnodes = nx.adjacency_matrix(G0).shape[0]

ncv=max(2*k+1,int(np.sqrt(nnodes)))

eigenvalues,eigenvectors= sp.sparse.linalg.eigsh(nx.laplacian_matrix(G0).asfptype(), k=k, \
                                                which='SM', return_eigenvectors = True, ncv=ncv)
index=np.argsort(eigenvalues)[1:k] # 0 index is zero eigenvalue    
pos_spectral_mat = np.real(eigenvectors[:,index]) #pos_spectral_mat is the spectral location of the nodes
pos_spectral_df = pd.DataFrame(data=pos_spectral_mat, columns=['PX','PY'], dtype=float)
pos_spectral_df['LABEL'] = label0

# %% [markdown]
# The node attributes generating

# %%
T= 2
c = 2*np.pi*0.8
data_np = np.zeros([nnodes, T])
column_name = []
for t in np.arange(1,T+1):
    temp1 = np.multiply(pos_spectral_df['PX'].apply(lambda x: np.exp(-c*t*x)).values, \
                          pos_spectral_df['PY'].apply(lambda y: np.cos(c*t*y)).values)
    data_np[:,t-1] = temp1
    if t == 1:
        column_name = str(t-1)+"_cos"
    else:    
        column_name = [column_name, str(t-1)+"_cos"]

sigma = 0.1        
data_np = np.add(data_np, sigma*np.random.randn(nnodes, T))    
data_df = pd.DataFrame(data=data_np, columns=column_name, dtype=float)
data_df['LABEL'] = label0

# %%
if Ifsavedata:
    nx.write_adjlist(G0, "../data/04_01_2016_experiment"+ str(trail) +".adjlist",delimiter=',')
    nx.write_edgelist(G0, "../data/04_01_2016_experiment" + str(trail) + ".edgelist")

    np.savez("../data/04_01_2016_experiment" + str(trail) + "_data.npz", pos_spectral_mat, data_np, label0)
    data_df.to_csv("../data/04_01_2016_experiment" + str(trail) + "_X.csv", index_label= 'ID')
    pos_spectral_df.to_csv("../data/04_01_2016_experiment" +  str(trail)  + "_U.csv", index_label= 'ID')

# %% [markdown]
# if Ifsavedata:
#     nx.write_adjlist(G0, "../data/experiment_bad_03_31_2016.adjlist",delimiter=',')
#     nx.write_edgelist(G0, "../data/experiment_bad_03_31_2016.edgelist")
#
#     np.savez("../data/experiment_bad_data_03_31_2016.npz", pos_spectral_mat, data_np, label0)
#     data_df.to_csv("../data/experiment_bad_X_03_31_2016.csv", index_label= 'ID')
#     pos_spectral_df.to_csv("../data/experiment_bad_U_03_31_2016.csv", index_label= 'ID')

# %%
X= data_np
U= pos_spectral_mat
nsample, ndim = X.shape
_ , ndim_latent = U.shape

kern = GPy.kern.RBF(2)

# %% [markdown]
# Import from the G2PnetSolver_v4.py

# %%
import sys
import os
dirorg = os.path.dirname(os.getcwd())
sys.path.insert(0, dirorg+"/src/")

# %%
import G2PnetSolver_v4 #G2PnetSolver_v2
#from imp import reload
#reload(G2PnetSolver_v2)

# %%
from G2PnetSolver_v4 import  G2PnetSolver as Solver
from G2PnetSolver_v4 import  Grassmann_update, check_step

# %%
choice = "near"

# %%
np.random.seed(seed=150)

if choice == "random":
    print("Random Initialization")
    Temp = np.random.randn(nsample, nsample)
    Temp_sym = (Temp + Temp.T) / 2 
    _, U_temp = np.linalg.eig(Temp_sym)
    U_test = U_temp[:, np.arange(ndim_latent)]
    U0 = U_test
elif choice == "near":
    print("Initialization in neigborhood.")
    U0 = U
ones = np.ones([nsample,])/np.sqrt(nsample)
eta0 = 0.75
np.random.seed(seed=160)
G_temp = np.random.randn(nsample, ndim_latent) / (np.sqrt(nsample * ndim_latent))
H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(np.column_stack((U0, ones)))),G_temp)
print(str(check_step(H_temp, eta0)))

while not check_step(H_temp, eta0):
    np.random.seed(seed=160)
    G_temp = np.random.randn(nsample, ndim_latent) / np.sqrt(nsample * ndim_latent)
    H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(np.column_stack((U0, ones)))),G_temp)
U_init = Grassmann_update(U0, H_temp, eta=eta0)
# Out:
# Initialization in neigborhood.
# True

# %%
np.dot(U_init.T, np.ones([nsample,]))
# Out:
# array([ -5.36556910e-13,   1.99701367e-14])

# %%
sp.linalg.svdvals(H_temp)*eta0
# Out:
# array([ 0.5225932 ,  0.50828827])

# %% [markdown]
# ### Compute the gradient $\frac{dL}{dU}$
# The loss function is given as negative log-likelihood of Gaussian process
#
# \begin{align}
# \mathcal{L}(\beta, \sigma, \mathbf{U}) &= \frac{pN}{2}\log(2\pi)+\frac{p}{2}\log\det(\mathbf{K}_{\beta, \sigma, \mathbf{U}})+\frac{1}{2}\text{tr}\left(\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{−1}\mathbf{X}\mathbf{X}^T\right) + \frac{\lambda}{2} \|\mathbf{U}\mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2}
# \end{align}
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{K}$
# \begin{align}
# \mathbf{T}&= 2\mathbf{T}_{0} - \text{diag}\left(\mathbf{T}_{0}\right),\\
# \mathbf{T}_{0} &= \frac{1}{2}\left(\mathbf{I} - \mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}\mathbf{X}\mathbf{X}^T/p \right)\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}, \\
# \mathbf{K}_{r,s} &= K_{\sigma}\left(\mathbf{U}_{r,:} , \mathbf{U}_{s,:}\right) + \beta \delta_{r,s}
# \end{align}
#
# For rbf kernel,
# \begin{align}
# \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{Z}}}{\partial \mathbf{U}_{m,j}}
# &= -\frac{l^{2}}{\sigma^2} \exp\left(-\frac{1}{2\sigma^2} \|\mathbf{U}_{m} -  \mathbf{U}_{n}\|^{2} \right)\left[2\left( \mathbf{U}_{m,i} - \mathbf{U}_{n,j} \right)\right]
# \end{align}
#
# The differential of the second norm term
# \begin{align}
# \frac{d}{d\mathbf{U}}\frac{1}{2}\|\mathbf{U} \mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2} &=
# \frac{d}{d\mathbf{U}}\frac{1}{2}\left[\text{tr}\left(\mathbf{U} \mathbf{U}^{T}\right) - \text{tr}\left(\mathbf{U}_{L}\mathbf{U}_{L}^{T}\mathbf{U}\mathbf{U}^{T}\right)\right]\\
# &= \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U}
# \end{align}
#
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{U}$
# \begin{align}
# \frac{\partial\mathcal{L}}{\partial\mathbf{U}} &= \left[\text{tr}\left( \mathbf{T} \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{U}}}{\partial \mathbf{U}_{m,j}} \right)\right]_{m,j} + \lambda \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U},
# \end{align}

# %%
if Ifsavedata:
    U_columns = [str(i) for i in np.arange(ndim_latent)]
    U_df = pd.DataFrame(data = U_init, columns=U_columns, dtype= float)
    if choice == "random":
        U_df['RANDOM'] = np.ones([nsample, 1])
    elif choice == "near":
        U_df['RANDOM'] = np.zeros([nsample, 1])
    
    U_df.to_csv("../data/04_01_16_" + str(trail)  + "_U_init.csv")
    #U_df.to_csv("../data/U_init_bad_03_31_16.csv")

# %%
add_reg = True
lambda_array = np.array([0.01]) #10, 1, 0.001
eta = 0.0001
max_iters = 600
kern_array = [GPy.kern.RBF(2)+ GPy.kern.White(2) for i in np.arange(len(lambda_array))]
kern_grass_array = [GPy.kern.RBF(2)+ GPy.kern.White(2) for i in np.arange(len(lambda_array))]
solver_array = []
hist_nll_eu_array = []
hist_nll_grass_array = []
hist_Hsig_array = []

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 30.0)
plt.style.use('seaborn-white')

for i, lambda_var in enumerate(lambda_array): 
    ax = plt.subplot(5,1,i+1)
    solver = Solver(X=X, U=U_init, kernel=kern_array[i], U_ref= U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_eu, hist_eta, hist_kern_eu = solver.optimize(max_iters = max_iters)
    solver_array.append(solver)
    hist_nll_eu_array.append(hist_nll_eu)
    
    
    solver2 = Solver(X=X, U=U_init, kernel=kern_grass_array[i], U_ref = U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_grass, hist_eta, hist_kern_grass = solver2.optimize(max_iters = max_iters, optimizor = "grad_descent_grass")
    hist_Hsig_array.append(solver2.hist_Hsig)
    
    solver_array.append(solver2)
    hist_nll_grass_array.append(hist_nll_grass)
        
    # %xdel solver
    # %xdel solver2
# Out:
# kernel initialization ...
# negative log-likelihood compute
# [step   0] neg-log-likelihood -515.877061 stepsize 0.0001
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -523.511874 stepsize 0.0001
# [step   2] neg-log-likelihood -519.573047 stepsize 0.0001
# [step   3] neg-log-likelihood -513.288445 stepsize 0.0001
# [step   4] neg-log-likelihood -510.569806 stepsize 0.0001
# [step   5] neg-log-likelihood -517.681905 stepsize 0.0001
# [step   6] neg-log-likelihood -529.619797 stepsize 0.0001
# [step   7] neg-log-likelihood -545.862996 stepsize 0.0001
# [step   8] neg-log-likelihood -563.485319 stepsize 0.0001
# [step   9] neg-log-likelihood -580.294329 stepsize 0.0001
# [step  10] neg-log-likelihood -593.866447 stepsize 0.0001
# [step  11] neg-log-likelihood -606.958703 stepsize 0.0001
# [step  12] neg-log-likelihood -625.250771 stepsize 0.0001
# [step  13] neg-log-likelihood -636.299696 stepsize 0.0001
# [step  14] neg-log-likelihood -651.458937 stepsize 0.0001
# [step  15] neg-log-likelihood -667.668914 stepsize 0.0001
# [step  16] neg-log-likelihood -680.069463 stepsize 0.0001
# [step  17] neg-log-likelihood -697.591641 stepsize 0.0001
# [step  18] neg-log-likelihood -712.926937 stepsize 0.0001
# [step  19] neg-log-likelihood -730.014230 stepsize 0.0001
# [step  20] neg-log-likelihood -744.862564 stepsize 0.0001
# [step  21] neg-log-likelihood -752.760141 stepsize 0.0001
# [step  22] neg-log-likelihood -763.546879 stepsize 0.0001
# [step  23] neg-log-likelihood -775.913276 stepsize 0.0001
# [step  24] neg-log-likelihood -782.084057 stepsize 0.0001
# [step  25] neg-log-likelihood -790.396823 stepsize 0.0001
# [step  26] neg-log-likelihood -799.881806 stepsize 0.0001
# [step  27] neg-log-likelihood -806.625026 stepsize 0.0001
# [step  28] neg-log-likelihood -813.333076 stepsize 0.0001
# [step  29] neg-log-likelihood -821.494551 stepsize 0.0001
# [step  30] neg-log-likelihood -830.006325 stepsize 0.0001
# [step  31] neg-log-likelihood -835.789603 stepsize 0.0001
# [step  32] neg-log-likelihood -842.479175 stepsize 0.0001
# [step  33] neg-log-likelihood -848.544779 stepsize 0.0001
# [step  34] neg-log-likelihood -854.493633 stepsize 0.0001
# [step  35] neg-log-likelihood -861.254100 stepsize 0.0001
# [step  36] neg-log-likelihood -868.601992 stepsize 0.0001
# [step  37] neg-log-likelihood -876.856965 stepsize 0.0001
# [step  38] neg-log-likelihood -884.354453 stepsize 0.0001
# [step  39] neg-log-likelihood -890.723488 stepsize 0.0001
# [step  40] neg-log-likelihood -898.518860 stepsize 0.0001
# [step  41] neg-log-likelihood -905.318768 stepsize 0.0001
# [step  42] neg-log-likelihood -912.951018 stepsize 0.0001
# [step  43] neg-log-likelihood -920.412657 stepsize 0.0001
# [step  44] neg-log-likelihood -929.061835 stepsize 0.0001
# [step  45] neg-log-likelihood -937.348221 stepsize 0.0001
# [step  46] neg-log-likelihood -947.121525 stepsize 0.0001
# [step  47] neg-log-likelihood -956.907624 stepsize 0.0001
# [step  48] neg-log-likelihood -967.227784 stepsize 0.0001
# [step  49] neg-log-likelihood -978.629868 stepsize 0.0001
# [step  50] neg-log-likelihood -986.806402 stepsize 0.0001
# [step  51] neg-log-likelihood -997.102617 stepsize 0.0001
# [step  52] neg-log-likelihood -1006.571517 stepsize 0.0001
# [step  53] neg-log-likelihood -1016.093440 stepsize 0.0001
# [step  54] neg-log-likelihood -1026.425115 stepsize 0.0001
# [step  55] neg-log-likelihood -1039.093726 stepsize 0.0001
# [step  56] neg-log-likelihood -1047.113185 stepsize 0.0001
# [step  57] neg-log-likelihood -1061.035370 stepsize 0.0001
# [step  58] neg-log-likelihood -1071.373374 stepsize 0.0001
# [step  59] neg-log-likelihood -1082.070754 stepsize 0.0001
# [step  60] neg-log-likelihood -1091.787220 stepsize 0.0001
# [step  61] neg-log-likelihood -1103.763778 stepsize 0.0001
# [step  62] neg-log-likelihood -1106.196584 stepsize 0.0001
# [step  63] neg-log-likelihood -1116.560391 stepsize 0.0001
# [step  64] neg-log-likelihood -1125.084348 stepsize 0.0001
# [step  65] neg-log-likelihood -1135.199756 stepsize 0.0001
# [step  66] neg-log-likelihood -1143.302209 stepsize 0.0001
# [step  67] neg-log-likelihood -1151.216796 stepsize 0.0001
# [step  68] neg-log-likelihood -1161.277289 stepsize 0.0001
# [step  69] neg-log-likelihood -1167.801062 stepsize 0.0001
# [step  70] neg-log-likelihood -1175.071649 stepsize 0.0001
# [step  71] neg-log-likelihood -1179.607773 stepsize 0.0001
# [step  72] neg-log-likelihood -1188.669297 stepsize 0.0001
# [step  73] neg-log-likelihood -1194.067791 stepsize 0.0001
# [step  74] neg-log-likelihood -1198.490260 stepsize 0.0001
# [step  75] neg-log-likelihood -1205.117585 stepsize 0.0001
# [step  76] neg-log-likelihood -1206.529150 stepsize 0.0001
# [step  77] neg-log-likelihood -1212.888648 stepsize 0.0001
# [step  78] neg-log-likelihood -1216.233929 stepsize 0.0001
# [step  79] neg-log-likelihood -1220.119663 stepsize 0.0001
# [step  80] neg-log-likelihood -1222.182846 stepsize 0.0001
# [step  81] neg-log-likelihood -1228.082658 stepsize 0.0001
# [step  82] neg-log-likelihood -1230.069416 stepsize 0.0001
# [step  83] neg-log-likelihood -1231.869126 stepsize 0.0001
# [step  84] neg-log-likelihood -1234.750433 stepsize 0.0001
# [step  85] neg-log-likelihood -1240.512635 stepsize 0.0001
# [step  86] neg-log-likelihood -1239.026369 stepsize 0.0001
# [step  87] neg-log-likelihood -1247.410380 stepsize 0.0001
# [step  88] neg-log-likelihood -1247.975175 stepsize 0.0001
# [step  89] neg-log-likelihood -1250.131424 stepsize 0.0001
# [step  90] neg-log-likelihood -1251.429376 stepsize 0.0001
# [step  91] neg-log-likelihood -1254.929702 stepsize 0.0001
# [step  92] neg-log-likelihood -1256.267625 stepsize 0.0001
# [step  93] neg-log-likelihood -1258.242189 stepsize 0.0001
# [step  94] neg-log-likelihood -1261.582121 stepsize 0.0001
# [step  95] neg-log-likelihood -1260.040099 stepsize 0.0001
# [step  96] neg-log-likelihood -1264.449887 stepsize 0.0001
# [step  97] neg-log-likelihood -1266.246803 stepsize 0.0001
# [step  98] neg-log-likelihood -1268.673241 stepsize 0.0001
# [step  99] neg-log-likelihood -1273.184421 stepsize 0.0001
# [step 100] neg-log-likelihood -1271.312037 stepsize 0.0001
# [step 101] neg-log-likelihood -1274.383521 stepsize 0.0001
# [step 102] neg-log-likelihood -1276.648854 stepsize 0.0001
# [step 103] neg-log-likelihood -1281.030058 stepsize 0.0001
# [step 104] neg-log-likelihood -1281.822581 stepsize 0.0001
# [step 105] neg-log-likelihood -1285.754547 stepsize 0.0001
# [step 106] neg-log-likelihood -1291.959645 stepsize 0.0001
# [step 107] neg-log-likelihood -1286.461039 stepsize 0.0001
# [step 108] neg-log-likelihood -1292.744626 stepsize 0.0001
# [step 109] neg-log-likelihood -1293.605647 stepsize 0.0001
# [step 110] neg-log-likelihood -1296.817467 stepsize 0.0001
# [step 111] neg-log-likelihood -1298.991550 stepsize 0.0001
# [step 112] neg-log-likelihood -1302.179396 stepsize 0.0001
# [step 113] neg-log-likelihood -1306.769809 stepsize 0.0001
# [step 114] neg-log-likelihood -1307.285500 stepsize 0.0001
# [step 115] neg-log-likelihood -1311.441358 stepsize 0.0001
# [step 116] neg-log-likelihood -1316.349000 stepsize 0.0001
# [step 117] neg-log-likelihood -1318.652220 stepsize 0.0001
# [step 118] neg-log-likelihood -1321.290168 stepsize 0.0001
# [step 119] neg-log-likelihood -1322.587346 stepsize 0.0001
# [step 120] neg-log-likelihood -1329.710190 stepsize 0.0001
# [step 121] neg-log-likelihood -1332.347190 stepsize 0.0001
# [step 122] neg-log-likelihood -1331.427750 stepsize 0.0001
# [step 123] neg-log-likelihood -1332.338453 stepsize 0.0001
# [step 124] neg-log-likelihood -1339.070387 stepsize 0.0001
# [step 125] neg-log-likelihood -1339.136220 stepsize 0.0001
# [step 126] neg-log-likelihood -1339.474286 stepsize 0.0001
# [step 127] neg-log-likelihood -1344.103419 stepsize 0.0001
# [step 128] neg-log-likelihood -1346.698309 stepsize 0.0001
# [step 129] neg-log-likelihood -1345.283360 stepsize 0.0001
# [step 130] neg-log-likelihood -1348.077261 stepsize 0.0001
# [step 131] neg-log-likelihood -1350.941571 stepsize 0.0001
# [step 132] neg-log-likelihood -1358.053052 stepsize 0.0001
# [step 133] neg-log-likelihood -1356.665467 stepsize 0.0001
# [step 134] neg-log-likelihood -1359.046347 stepsize 0.0001
# [step 135] neg-log-likelihood -1359.483817 stepsize 0.0001
# [step 136] neg-log-likelihood -1365.616282 stepsize 0.0001
# [step 137] neg-log-likelihood -1368.815760 stepsize 0.0001
# [step 138] neg-log-likelihood -1367.228677 stepsize 0.0001
# [step 139] neg-log-likelihood -1375.823778 stepsize 0.0001
# [step 140] neg-log-likelihood -1373.952422 stepsize 0.0001
# [step 141] neg-log-likelihood -1377.691981 stepsize 0.0001
# [step 142] neg-log-likelihood -1376.067301 stepsize 0.0001
# [step 143] neg-log-likelihood -1383.520571 stepsize 0.0001
# [step 144] neg-log-likelihood -1382.809428 stepsize 0.0001
# [step 145] neg-log-likelihood -1385.941850 stepsize 0.0001
# [step 146] neg-log-likelihood -1385.924236 stepsize 0.0001
# [step 147] neg-log-likelihood -1388.725931 stepsize 0.0001
# [step 148] neg-log-likelihood -1389.941635 stepsize 0.0001
# [step 149] neg-log-likelihood -1393.540788 stepsize 0.0001
# [step 150] neg-log-likelihood -1393.730858 stepsize 0.0001
# [step 151] neg-log-likelihood -1396.858676 stepsize 0.0001
# [step 152] neg-log-likelihood -1396.095894 stepsize 0.0001
# [step 153] neg-log-likelihood -1402.788372 stepsize 0.0001
# [step 154] neg-log-likelihood -1400.886171 stepsize 0.0001
# [step 155] neg-log-likelihood -1402.336620 stepsize 0.0001
# [step 156] neg-log-likelihood -1404.566110 stepsize 0.0001
# [step 157] neg-log-likelihood -1404.180558 stepsize 0.0001
# [step 158] neg-log-likelihood -1404.549098 stepsize 0.0001
# [step 159] neg-log-likelihood -1408.833213 stepsize 0.0001
# [step 160] neg-log-likelihood -1409.211107 stepsize 0.0001
# [step 161] neg-log-likelihood -1406.805586 stepsize 0.0001
# [step 162] neg-log-likelihood -1408.905368 stepsize 0.0001
# [step 163] neg-log-likelihood -1410.880727 stepsize 0.0001
# [step 164] neg-log-likelihood -1413.782559 stepsize 0.0001
# [step 165] neg-log-likelihood -1412.551765 stepsize 0.0001
# [step 166] neg-log-likelihood -1411.810815 stepsize 0.0001
# [step 167] neg-log-likelihood -1415.279389 stepsize 0.0001
# [step 168] neg-log-likelihood -1416.527065 stepsize 0.0001
# [step 169] neg-log-likelihood -1416.257523 stepsize 0.0001
# [step 170] neg-log-likelihood -1420.592710 stepsize 0.0001
# [step 171] neg-log-likelihood -1414.598125 stepsize 0.0001
# [step 172] neg-log-likelihood -1421.265809 stepsize 0.0001
# [step 173] neg-log-likelihood -1419.761746 stepsize 0.0001
# [step 174] neg-log-likelihood -1421.226027 stepsize 0.0001
# [step 175] neg-log-likelihood -1421.286724 stepsize 0.0001
# [step 176] neg-log-likelihood -1423.323230 stepsize 0.0001
# [step 177] neg-log-likelihood -1422.495260 stepsize 0.0001
# [step 178] neg-log-likelihood -1423.513189 stepsize 0.0001
# [step 179] neg-log-likelihood -1421.169353 stepsize 0.0001
# [step 180] neg-log-likelihood -1429.709213 stepsize 0.0001
# [step 181] neg-log-likelihood -1425.325782 stepsize 0.0001
# [step 182] neg-log-likelihood -1425.278045 stepsize 0.0001
# [step 183] neg-log-likelihood -1428.444784 stepsize 0.0001
# [step 184] neg-log-likelihood -1423.886715 stepsize 0.0001
# [step 185] neg-log-likelihood -1426.222371 stepsize 0.0001
# [step 186] neg-log-likelihood -1424.466272 stepsize 0.0001
# [step 187] neg-log-likelihood -1427.175872 stepsize 0.0001
# [step 188] neg-log-likelihood -1427.042312 stepsize 0.0001
# [step 189] neg-log-likelihood -1429.734082 stepsize 0.0001
# [step 190] neg-log-likelihood -1427.795901 stepsize 0.0001
# [step 191] neg-log-likelihood -1430.139522 stepsize 0.0001
# [step 192] neg-log-likelihood -1429.483056 stepsize 0.0001
# [step 193] neg-log-likelihood -1429.887196 stepsize 0.0001
# [step 194] neg-log-likelihood -1430.848547 stepsize 0.0001
# [step 195] neg-log-likelihood -1433.228907 stepsize 0.0001
# [step 196] neg-log-likelihood -1431.996508 stepsize 0.0001
# [step 197] neg-log-likelihood -1433.584398 stepsize 0.0001
# [step 198] neg-log-likelihood -1429.926148 stepsize 0.0001
# [step 199] neg-log-likelihood -1435.769470 stepsize 0.0001
# [step 200] neg-log-likelihood -1433.378506 stepsize 0.0001
# [step 201] neg-log-likelihood -1432.460957 stepsize 0.0001
# [step 202] neg-log-likelihood -1433.466492 stepsize 0.0001
# [step 203] neg-log-likelihood -1435.810819 stepsize 0.0001
# [step 204] neg-log-likelihood -1433.519256 stepsize 0.0001
# [step 205] neg-log-likelihood -1434.100330 stepsize 0.0001
# [step 206] neg-log-likelihood -1431.384018 stepsize 0.0001
# [step 207] neg-log-likelihood -1436.311747 stepsize 0.0001
# [step 208] neg-log-likelihood -1433.352705 stepsize 0.0001
# [step 209] neg-log-likelihood -1436.319320 stepsize 0.0001
# [step 210] neg-log-likelihood -1435.123382 stepsize 0.0001
# [step 211] neg-log-likelihood -1435.912543 stepsize 0.0001
# [step 212] neg-log-likelihood -1435.973077 stepsize 0.0001
# [step 213] neg-log-likelihood -1435.454497 stepsize 0.0001
# [step 214] neg-log-likelihood -1435.296726 stepsize 0.0001
# [step 215] neg-log-likelihood -1433.412615 stepsize 0.0001
# [step 216] neg-log-likelihood -1436.101018 stepsize 0.0001
# [step 217] neg-log-likelihood -1436.448709 stepsize 0.0001
# [step 218] neg-log-likelihood -1434.484121 stepsize 0.0001
# [step 219] neg-log-likelihood -1437.082088 stepsize 0.0001
# [step 220] neg-log-likelihood -1433.929940 stepsize 0.0001
# [step 221] neg-log-likelihood -1437.183248 stepsize 0.0001
# [step 222] neg-log-likelihood -1436.038534 stepsize 0.0001
# [step 223] neg-log-likelihood -1440.021389 stepsize 0.0001
# [step 224] neg-log-likelihood -1440.219581 stepsize 0.0001
# [step 225] neg-log-likelihood -1437.556770 stepsize 0.0001
# [step 226] neg-log-likelihood -1440.227654 stepsize 0.0001
# [step 227] neg-log-likelihood -1440.964533 stepsize 0.0001
# [step 228] neg-log-likelihood -1437.916261 stepsize 0.0001
# [step 229] neg-log-likelihood -1439.737488 stepsize 0.0001
# [step 230] neg-log-likelihood -1440.659743 stepsize 0.0001
# [step 231] neg-log-likelihood -1440.734098 stepsize 0.0001
# [step 232] neg-log-likelihood -1443.072016 stepsize 0.0001
# [step 233] neg-log-likelihood -1442.714755 stepsize 0.0001
# [step 234] neg-log-likelihood -1440.091401 stepsize 0.0001
# [step 235] neg-log-likelihood -1441.683015 stepsize 0.0001
# [step 236] neg-log-likelihood -1443.967110 stepsize 0.0001
# [step 237] neg-log-likelihood -1440.422706 stepsize 0.0001
# [step 238] neg-log-likelihood -1442.286063 stepsize 0.0001
# [step 239] neg-log-likelihood -1441.845660 stepsize 0.0001
# [step 240] neg-log-likelihood -1442.902278 stepsize 0.0001
# [step 241] neg-log-likelihood -1445.748002 stepsize 0.0001
# [step 242] neg-log-likelihood -1446.821484 stepsize 0.0001
# [step 243] neg-log-likelihood -1445.415773 stepsize 0.0001
# [step 244] neg-log-likelihood -1441.631206 stepsize 0.0001
# [step 245] neg-log-likelihood -1446.325620 stepsize 0.0001
# [step 246] neg-log-likelihood -1447.817515 stepsize 0.0001
# [step 247] neg-log-likelihood -1446.323072 stepsize 0.0001
# [step 248] neg-log-likelihood -1449.278759 stepsize 0.0001
# [step 249] neg-log-likelihood -1446.874312 stepsize 0.0001
# [step 250] neg-log-likelihood -1447.934044 stepsize 0.0001
# [step 251] neg-log-likelihood -1448.557105 stepsize 0.0001
# [step 252] neg-log-likelihood -1449.335921 stepsize 0.0001
# [step 253] neg-log-likelihood -1448.428994 stepsize 0.0001
# [step 254] neg-log-likelihood -1449.519008 stepsize 0.0001
# [step 255] neg-log-likelihood -1448.509608 stepsize 0.0001
# [step 256] neg-log-likelihood -1452.957599 stepsize 0.0001
# [step 257] neg-log-likelihood -1450.834563 stepsize 0.0001
# [step 258] neg-log-likelihood -1450.648944 stepsize 0.0001
# [step 259] neg-log-likelihood -1454.094662 stepsize 0.0001
# [step 260] neg-log-likelihood -1452.440833 stepsize 0.0001
# [step 261] neg-log-likelihood -1451.343644 stepsize 0.0001
# [step 262] neg-log-likelihood -1452.173979 stepsize 0.0001
# [step 263] neg-log-likelihood -1449.753869 stepsize 0.0001
# [step 264] neg-log-likelihood -1453.376663 stepsize 0.0001
# [step 265] neg-log-likelihood -1453.010771 stepsize 0.0001
# [step 266] neg-log-likelihood -1453.024712 stepsize 0.0001
# [step 267] neg-log-likelihood -1453.214742 stepsize 0.0001
# [step 268] neg-log-likelihood -1454.800171 stepsize 0.0001
# [step 269] neg-log-likelihood -1454.181397 stepsize 0.0001
# [step 270] neg-log-likelihood -1454.652306 stepsize 0.0001
# [step 271] neg-log-likelihood -1456.542382 stepsize 0.0001
# [step 272] neg-log-likelihood -1453.040930 stepsize 0.0001
# [step 273] neg-log-likelihood -1458.996610 stepsize 0.0001
# [step 274] neg-log-likelihood -1454.176673 stepsize 0.0001
# [step 275] neg-log-likelihood -1455.680260 stepsize 0.0001
# [step 276] neg-log-likelihood -1455.961802 stepsize 0.0001
# [step 277] neg-log-likelihood -1456.688487 stepsize 0.0001
# [step 278] neg-log-likelihood -1454.852214 stepsize 0.0001
# [step 279] neg-log-likelihood -1457.085697 stepsize 0.0001
# [step 280] neg-log-likelihood -1456.082955 stepsize 0.0001
# [step 281] neg-log-likelihood -1458.807022 stepsize 0.0001
# [step 282] neg-log-likelihood -1458.159463 stepsize 0.0001
# [step 283] neg-log-likelihood -1458.407774 stepsize 0.0001
# [step 284] neg-log-likelihood -1458.832399 stepsize 0.0001
# [step 285] neg-log-likelihood -1458.081091 stepsize 0.0001
# [step 286] neg-log-likelihood -1459.538431 stepsize 0.0001
# [step 287] neg-log-likelihood -1465.207203 stepsize 0.0001
# [step 288] neg-log-likelihood -1458.541597 stepsize 0.0001
# [step 289] neg-log-likelihood -1461.733633 stepsize 0.0001
# [step 290] neg-log-likelihood -1456.507024 stepsize 0.0001
# [step 291] neg-log-likelihood -1460.688995 stepsize 0.0001
# [step 292] neg-log-likelihood -1460.222443 stepsize 0.0001
# [step 293] neg-log-likelihood -1462.036670 stepsize 0.0001
# [step 294] neg-log-likelihood -1462.419382 stepsize 0.0001
# [step 295] neg-log-likelihood -1463.967516 stepsize 0.0001
# [step 296] neg-log-likelihood -1465.635540 stepsize 0.0001
# [step 297] neg-log-likelihood -1464.802000 stepsize 0.0001
# [step 298] neg-log-likelihood -1459.924710 stepsize 0.0001
# [step 299] neg-log-likelihood -1463.808652 stepsize 0.0001
# [step 300] neg-log-likelihood -1468.145125 stepsize 0.0001
# [step 301] neg-log-likelihood -1464.095054 stepsize 0.0001
# [step 302] neg-log-likelihood -1464.778688 stepsize 0.0001
# [step 303] neg-log-likelihood -1463.767369 stepsize 0.0001
# [step 304] neg-log-likelihood -1464.482836 stepsize 0.0001
# [step 305] neg-log-likelihood -1462.285223 stepsize 0.0001
# [step 306] neg-log-likelihood -1466.090585 stepsize 0.0001
# [step 307] neg-log-likelihood -1464.259758 stepsize 0.0001
# [step 308] neg-log-likelihood -1466.212283 stepsize 0.0001
# [step 309] neg-log-likelihood -1464.103531 stepsize 0.0001
# [step 310] neg-log-likelihood -1465.117817 stepsize 0.0001
# [step 311] neg-log-likelihood -1466.108474 stepsize 0.0001
# [step 312] neg-log-likelihood -1467.334673 stepsize 0.0001
# [step 313] neg-log-likelihood -1466.229103 stepsize 0.0001
# [step 314] neg-log-likelihood -1465.292435 stepsize 0.0001
# [step 315] neg-log-likelihood -1466.535593 stepsize 0.0001
# [step 316] neg-log-likelihood -1468.928140 stepsize 0.0001
# [step 317] neg-log-likelihood -1465.914828 stepsize 0.0001
# [step 318] neg-log-likelihood -1469.845179 stepsize 0.0001
# [step 319] neg-log-likelihood -1469.558238 stepsize 0.0001
# [step 320] neg-log-likelihood -1468.368807 stepsize 0.0001
# [step 321] neg-log-likelihood -1468.415865 stepsize 0.0001
# [step 322] neg-log-likelihood -1470.493423 stepsize 0.0001
# [step 323] neg-log-likelihood -1477.317759 stepsize 0.0001
# [step 324] neg-log-likelihood -1468.776917 stepsize 0.0001
# [step 325] neg-log-likelihood -1470.601682 stepsize 0.0001
# [step 326] neg-log-likelihood -1469.016617 stepsize 0.0001
# [step 327] neg-log-likelihood -1469.674818 stepsize 0.0001
# [step 328] neg-log-likelihood -1472.385624 stepsize 0.0001
# [step 329] neg-log-likelihood -1472.909588 stepsize 0.0001
# [step 330] neg-log-likelihood -1469.637780 stepsize 0.0001
# [step 331] neg-log-likelihood -1474.569361 stepsize 0.0001
# [step 332] neg-log-likelihood -1471.961476 stepsize 0.0001
# [step 333] neg-log-likelihood -1472.467238 stepsize 0.0001
# [step 334] neg-log-likelihood -1474.237812 stepsize 0.0001
# [step 335] neg-log-likelihood -1469.771542 stepsize 0.0001
# [step 336] neg-log-likelihood -1470.836043 stepsize 0.0001
# [step 337] neg-log-likelihood -1473.253614 stepsize 0.0001
# [step 338] neg-log-likelihood -1475.756692 stepsize 0.0001
# [step 339] neg-log-likelihood -1475.235973 stepsize 0.0001
# [step 340] neg-log-likelihood -1472.616144 stepsize 0.0001
# [step 341] neg-log-likelihood -1474.988693 stepsize 0.0001
# [step 342] neg-log-likelihood -1474.238664 stepsize 0.0001
# [step 343] neg-log-likelihood -1475.776014 stepsize 0.0001
# [step 344] neg-log-likelihood -1476.607744 stepsize 0.0001
# [step 345] neg-log-likelihood -1478.035982 stepsize 0.0001
# [step 346] neg-log-likelihood -1475.878309 stepsize 0.0001
# [step 347] neg-log-likelihood -1480.168725 stepsize 0.0001
# [step 348] neg-log-likelihood -1478.669129 stepsize 0.0001
# [step 349] neg-log-likelihood -1477.425470 stepsize 0.0001
# [step 350] neg-log-likelihood -1477.230091 stepsize 0.0001
# [step 351] neg-log-likelihood -1479.177694 stepsize 0.0001
# [step 352] neg-log-likelihood -1474.829190 stepsize 0.0001
# [step 353] neg-log-likelihood -1475.596783 stepsize 0.0001
# [step 354] neg-log-likelihood -1476.460639 stepsize 0.0001
# [step 355] neg-log-likelihood -1479.263510 stepsize 0.0001
# [step 356] neg-log-likelihood -1479.364832 stepsize 0.0001
# [step 357] neg-log-likelihood -1477.738717 stepsize 0.0001
# [step 358] neg-log-likelihood -1479.132640 stepsize 0.0001
# [step 359] neg-log-likelihood -1480.775848 stepsize 0.0001
# [step 360] neg-log-likelihood -1481.446326 stepsize 0.0001
# [step 361] neg-log-likelihood -1480.468303 stepsize 0.0001
# [step 362] neg-log-likelihood -1477.237167 stepsize 0.0001
# [step 363] neg-log-likelihood -1479.233117 stepsize 0.0001
# [step 364] neg-log-likelihood -1482.535398 stepsize 0.0001
# [step 365] neg-log-likelihood -1485.813625 stepsize 0.0001
# [step 366] neg-log-likelihood -1480.858018 stepsize 0.0001
# [step 367] neg-log-likelihood -1479.672870 stepsize 0.0001
# [step 368] neg-log-likelihood -1483.787988 stepsize 0.0001
# [step 369] neg-log-likelihood -1480.748704 stepsize 0.0001
# [step 370] neg-log-likelihood -1482.382234 stepsize 0.0001
# [step 371] neg-log-likelihood -1481.784528 stepsize 0.0001
# [step 372] neg-log-likelihood -1479.366691 stepsize 0.0001
# [step 373] neg-log-likelihood -1482.208161 stepsize 0.0001
# [step 374] neg-log-likelihood -1481.298676 stepsize 0.0001
# [step 375] neg-log-likelihood -1480.523462 stepsize 0.0001
# [step 376] neg-log-likelihood -1480.930082 stepsize 0.0001
# [step 377] neg-log-likelihood -1481.855381 stepsize 0.0001
# [step 378] neg-log-likelihood -1482.175528 stepsize 0.0001
# [step 379] neg-log-likelihood -1484.239598 stepsize 0.0001
# [step 380] neg-log-likelihood -1482.434738 stepsize 0.0001
# [step 381] neg-log-likelihood -1482.147385 stepsize 0.0001
# [step 382] neg-log-likelihood -1482.446781 stepsize 0.0001
# [step 383] neg-log-likelihood -1485.044436 stepsize 0.0001
# [step 384] neg-log-likelihood -1485.432752 stepsize 0.0001
# [step 385] neg-log-likelihood -1481.948234 stepsize 0.0001
# [step 386] neg-log-likelihood -1484.310486 stepsize 0.0001
# [step 387] neg-log-likelihood -1483.431791 stepsize 0.0001
# [step 388] neg-log-likelihood -1484.819462 stepsize 0.0001
# [step 389] neg-log-likelihood -1484.129382 stepsize 0.0001
# [step 390] neg-log-likelihood -1485.128437 stepsize 0.0001
# [step 391] neg-log-likelihood -1483.226545 stepsize 0.0001
# [step 392] neg-log-likelihood -1483.757663 stepsize 0.0001
# [step 393] neg-log-likelihood -1483.941583 stepsize 0.0001
# [step 394] neg-log-likelihood -1489.123142 stepsize 0.0001
# [step 395] neg-log-likelihood -1483.321843 stepsize 0.0001
# [step 396] neg-log-likelihood -1485.469997 stepsize 0.0001
# [step 397] neg-log-likelihood -1486.822420 stepsize 0.0001
# [step 398] neg-log-likelihood -1486.061930 stepsize 0.0001
# [step 399] neg-log-likelihood -1484.736693 stepsize 0.0001
# [step 400] neg-log-likelihood -1481.713188 stepsize 0.0001
# [step 401] neg-log-likelihood -1485.077011 stepsize 0.0001
# [step 402] neg-log-likelihood -1484.730148 stepsize 0.0001
# [step 403] neg-log-likelihood -1483.886888 stepsize 0.0001
# [step 404] neg-log-likelihood -1485.474309 stepsize 0.0001
# [step 405] neg-log-likelihood -1486.296637 stepsize 0.0001
# [step 406] neg-log-likelihood -1487.335055 stepsize 0.0001
# [step 407] neg-log-likelihood -1487.688745 stepsize 0.0001
# [step 408] neg-log-likelihood -1487.845173 stepsize 0.0001
# [step 409] neg-log-likelihood -1482.676140 stepsize 0.0001
# [step 410] neg-log-likelihood -1485.222543 stepsize 0.0001
# [step 411] neg-log-likelihood -1483.892930 stepsize 0.0001
# [step 412] neg-log-likelihood -1485.316494 stepsize 0.0001
# [step 413] neg-log-likelihood -1485.457849 stepsize 0.0001
# [step 414] neg-log-likelihood -1483.285550 stepsize 0.0001
# [step 415] neg-log-likelihood -1484.104261 stepsize 0.0001
# [step 416] neg-log-likelihood -1483.261160 stepsize 0.0001
# [step 417] neg-log-likelihood -1486.493151 stepsize 0.0001
# [step 418] neg-log-likelihood -1485.224058 stepsize 0.0001
# [step 419] neg-log-likelihood -1485.065077 stepsize 0.0001
# [step 420] neg-log-likelihood -1484.017624 stepsize 0.0001
# [step 421] neg-log-likelihood -1485.377425 stepsize 0.0001
# [step 422] neg-log-likelihood -1484.113517 stepsize 0.0001
# [step 423] neg-log-likelihood -1487.909309 stepsize 0.0001
# [step 424] neg-log-likelihood -1485.996780 stepsize 0.0001
# [step 425] neg-log-likelihood -1486.583994 stepsize 0.0001
# [step 426] neg-log-likelihood -1483.972232 stepsize 0.0001
# [step 427] neg-log-likelihood -1484.809780 stepsize 0.0001
# [step 428] neg-log-likelihood -1484.349688 stepsize 0.0001
# [step 429] neg-log-likelihood -1487.253890 stepsize 0.0001
# [step 430] neg-log-likelihood -1484.171218 stepsize 0.0001
# [step 431] neg-log-likelihood -1487.257275 stepsize 0.0001
# [step 432] neg-log-likelihood -1483.735354 stepsize 0.0001
# [step 433] neg-log-likelihood -1485.132154 stepsize 0.0001
# [step 434] neg-log-likelihood -1487.809689 stepsize 0.0001
# [step 435] neg-log-likelihood -1486.783262 stepsize 0.0001
# [step 436] neg-log-likelihood -1486.702776 stepsize 0.0001
# [step 437] neg-log-likelihood -1485.194559 stepsize 0.0001
# [step 438] neg-log-likelihood -1483.931926 stepsize 0.0001
# [step 439] neg-log-likelihood -1485.517231 stepsize 0.0001
# [step 440] neg-log-likelihood -1485.019201 stepsize 0.0001
# [step 441] neg-log-likelihood -1487.395337 stepsize 0.0001
# [step 442] neg-log-likelihood -1486.059793 stepsize 0.0001
# [step 443] neg-log-likelihood -1484.814031 stepsize 0.0001
# [step 444] neg-log-likelihood -1482.358802 stepsize 0.0001
# [step 445] neg-log-likelihood -1485.882479 stepsize 0.0001
# [step 446] neg-log-likelihood -1487.019532 stepsize 0.0001
# [step 447] neg-log-likelihood -1483.742653 stepsize 0.0001
# [step 448] neg-log-likelihood -1482.463580 stepsize 0.0001
# [step 449] neg-log-likelihood -1481.292069 stepsize 0.0001
# [step 450] neg-log-likelihood -1484.759098 stepsize 0.0001
# [step 451] neg-log-likelihood -1484.869897 stepsize 0.0001
# [step 452] neg-log-likelihood -1482.611987 stepsize 0.0001
# [step 453] neg-log-likelihood -1484.561829 stepsize 0.0001
# [step 454] neg-log-likelihood -1483.146272 stepsize 0.0001
# [step 455] neg-log-likelihood -1481.636627 stepsize 0.0001
# [step 456] neg-log-likelihood -1482.426731 stepsize 0.0001
# [step 457] neg-log-likelihood -1484.782357 stepsize 0.0001
# [step 458] neg-log-likelihood -1482.006865 stepsize 0.0001
# [step 459] neg-log-likelihood -1481.573129 stepsize 0.0001
# [step 460] neg-log-likelihood -1480.998558 stepsize 0.0001
# [step 461] neg-log-likelihood -1481.622565 stepsize 0.0001
# [step 462] neg-log-likelihood -1482.626631 stepsize 0.0001
# [step 463] neg-log-likelihood -1482.676490 stepsize 0.0001
# [step 464] neg-log-likelihood -1483.048268 stepsize 0.0001
# [step 465] neg-log-likelihood -1481.047011 stepsize 0.0001
# [step 466] neg-log-likelihood -1482.002451 stepsize 0.0001
# [step 467] neg-log-likelihood -1480.016538 stepsize 0.0001
# [step 468] neg-log-likelihood -1479.557917 stepsize 0.0001
# [step 469] neg-log-likelihood -1478.532796 stepsize 0.0001
# [step 470] neg-log-likelihood -1482.584105 stepsize 0.0001
# [step 471] neg-log-likelihood -1480.469452 stepsize 0.0001
# [step 472] neg-log-likelihood -1480.617920 stepsize 0.0001
# [step 473] neg-log-likelihood -1483.118869 stepsize 0.0001
# [step 474] neg-log-likelihood -1481.351894 stepsize 0.0001
# [step 475] neg-log-likelihood -1478.951098 stepsize 0.0001
# [step 476] neg-log-likelihood -1477.653985 stepsize 0.0001
# [step 477] neg-log-likelihood -1476.991484 stepsize 0.0001
# [step 478] neg-log-likelihood -1476.752836 stepsize 0.0001
# [step 479] neg-log-likelihood -1477.276429 stepsize 0.0001
# [step 480] neg-log-likelihood -1477.147032 stepsize 0.0001
# [step 481] neg-log-likelihood -1476.025178 stepsize 0.0001
# [step 482] neg-log-likelihood -1476.647559 stepsize 0.0001
# [step 483] neg-log-likelihood -1474.723639 stepsize 0.0001
# [step 484] neg-log-likelihood -1473.828708 stepsize 0.0001
# [step 485] neg-log-likelihood -1478.393259 stepsize 0.0001
# [step 486] neg-log-likelihood -1474.368058 stepsize 0.0001
# [step 487] neg-log-likelihood -1475.527120 stepsize 0.0001
# [step 488] neg-log-likelihood -1472.478721 stepsize 0.0001
# [step 489] neg-log-likelihood -1473.288162 stepsize 0.0001
# [step 490] neg-log-likelihood -1474.521033 stepsize 0.0001
# [step 491] neg-log-likelihood -1473.290723 stepsize 0.0001
# [step 492] neg-log-likelihood -1471.238314 stepsize 0.0001
# [step 493] neg-log-likelihood -1473.367931 stepsize 0.0001
# [step 494] neg-log-likelihood -1470.511931 stepsize 0.0001
# [step 495] neg-log-likelihood -1471.610598 stepsize 0.0001
# [step 496] neg-log-likelihood -1470.705023 stepsize 0.0001
# [step 497] neg-log-likelihood -1474.685102 stepsize 0.0001
# [step 498] neg-log-likelihood -1469.010683 stepsize 0.0001
# [step 499] neg-log-likelihood -1465.453834 stepsize 0.0001
# [step 500] neg-log-likelihood -1462.761965 stepsize 0.0001
# [step 501] neg-log-likelihood -1466.506818 stepsize 0.0001
# [step 502] neg-log-likelihood -1464.171589 stepsize 0.0001
# [step 503] neg-log-likelihood -1463.196462 stepsize 0.0001
# [step 504] neg-log-likelihood -1468.333503 stepsize 0.0001
# [step 505] neg-log-likelihood -1462.506327 stepsize 0.0001
# [step 506] neg-log-likelihood -1460.629434 stepsize 0.0001
# [step 507] neg-log-likelihood -1459.814589 stepsize 0.0001
# [step 508] neg-log-likelihood -1460.743160 stepsize 0.0001
# [step 509] neg-log-likelihood -1460.178006 stepsize 0.0001
# [step 510] neg-log-likelihood -1459.000891 stepsize 0.0001
# [step 511] neg-log-likelihood -1456.349396 stepsize 0.0001
# [step 512] neg-log-likelihood -1460.712080 stepsize 0.0001
# [step 513] neg-log-likelihood -1460.085570 stepsize 0.0001
# [step 514] neg-log-likelihood -1455.344479 stepsize 0.0001
# [step 515] neg-log-likelihood -1456.640639 stepsize 0.0001
# [step 516] neg-log-likelihood -1453.931852 stepsize 0.0001
# [step 517] neg-log-likelihood -1452.541893 stepsize 0.0001
# [step 518] neg-log-likelihood -1450.907567 stepsize 0.0001
# [step 519] neg-log-likelihood -1450.385419 stepsize 0.0001
# [step 520] neg-log-likelihood -1451.750173 stepsize 0.0001
# [step 521] neg-log-likelihood -1450.734537 stepsize 0.0001
# [step 522] neg-log-likelihood -1449.700856 stepsize 0.0001
# [step 523] neg-log-likelihood -1446.913873 stepsize 0.0001
# [step 524] neg-log-likelihood -1445.574607 stepsize 0.0001
# [step 525] neg-log-likelihood -1448.310152 stepsize 0.0001
# [step 526] neg-log-likelihood -1444.291888 stepsize 0.0001
# [step 527] neg-log-likelihood -1442.504529 stepsize 0.0001
# [step 528] neg-log-likelihood -1443.245081 stepsize 0.0001
# [step 529] neg-log-likelihood -1439.145508 stepsize 0.0001
# [step 530] neg-log-likelihood -1438.875706 stepsize 0.0001
# [step 531] neg-log-likelihood -1433.513891 stepsize 0.0001
# [step 532] neg-log-likelihood -1432.248998 stepsize 0.0001
# [step 533] neg-log-likelihood -1429.493870 stepsize 0.0001
# [step 534] neg-log-likelihood -1427.758008 stepsize 0.0001
# [step 535] neg-log-likelihood -1427.002807 stepsize 0.0001
# [step 536] neg-log-likelihood -1423.890868 stepsize 0.0001
# [step 537] neg-log-likelihood -1417.706245 stepsize 0.0001
# [step 538] neg-log-likelihood -1417.875259 stepsize 0.0001
# [step 539] neg-log-likelihood -1416.440467 stepsize 0.0001
# [step 540] neg-log-likelihood -1411.341405 stepsize 0.0001
# [step 541] neg-log-likelihood -1408.941316 stepsize 0.0001
# [step 542] neg-log-likelihood -1406.261877 stepsize 0.0001
# [step 543] neg-log-likelihood -1406.564495 stepsize 0.0001
# [step 544] neg-log-likelihood -1397.821407 stepsize 0.0001
# [step 545] neg-log-likelihood -1397.180337 stepsize 0.0001
# [step 546] neg-log-likelihood -1395.730692 stepsize 0.0001
# [step 547] neg-log-likelihood -1389.386300 stepsize 0.0001
# [step 548] neg-log-likelihood -1380.790587 stepsize 0.0001
# [step 549] neg-log-likelihood -1375.430144 stepsize 0.0001
# [step 550] neg-log-likelihood -1370.195858 stepsize 0.0001
# [step 551] neg-log-likelihood -1364.232770 stepsize 0.0001
# [step 552] neg-log-likelihood -1354.864950 stepsize 0.0001
# [step 553] neg-log-likelihood -1346.384060 stepsize 0.0001
# [step 554] neg-log-likelihood -1336.352429 stepsize 0.0001
# [step 555] neg-log-likelihood -1317.634473 stepsize 0.0001
# [step 556] neg-log-likelihood -1293.921787 stepsize 0.0001
# [step 557] neg-log-likelihood -1268.672930 stepsize 0.0001
# [step 558] neg-log-likelihood -1232.019853 stepsize 0.0001
# [step 559] neg-log-likelihood -1202.138451 stepsize 0.0001
# [step 560] neg-log-likelihood -1179.031539 stepsize 0.0001
# [step 561] neg-log-likelihood -1164.372234 stepsize 0.0001
# [step 562] neg-log-likelihood -1150.521615 stepsize 0.0001
# [step 563] neg-log-likelihood -1139.884805 stepsize 0.0001
# [step 564] neg-log-likelihood -1129.827572 stepsize 0.0001
# [step 565] neg-log-likelihood -1118.191079 stepsize 0.0001
# [step 566] neg-log-likelihood -1110.252597 stepsize 0.0001
# [step 567] neg-log-likelihood -1104.566164 stepsize 0.0001
# [step 568] neg-log-likelihood -1094.882008 stepsize 0.0001
# [step 569] neg-log-likelihood -1089.365276 stepsize 0.0001
# [step 570] neg-log-likelihood -1086.790658 stepsize 0.0001
# [step 571] neg-log-likelihood -1078.578057 stepsize 0.0001
# [step 572] neg-log-likelihood -1072.957319 stepsize 0.0001
# [step 573] neg-log-likelihood -1070.142348 stepsize 0.0001
# [step 574] neg-log-likelihood -1061.319369 stepsize 0.0001
# [step 575] neg-log-likelihood -1062.800108 stepsize 0.0001
# [step 576] neg-log-likelihood -1054.981724 stepsize 0.0001
# [step 577] neg-log-likelihood -1055.298998 stepsize 0.0001
# [step 578] neg-log-likelihood -1047.959746 stepsize 0.0001
# [step 579] neg-log-likelihood -1042.060259 stepsize 0.0001
# [step 580] neg-log-likelihood -1039.189631 stepsize 0.0001
# [step 581] neg-log-likelihood -1037.220998 stepsize 0.0001
# [step 582] neg-log-likelihood -1029.799487 stepsize 0.0001
# [step 583] neg-log-likelihood -1032.625363 stepsize 0.0001
# [step 584] neg-log-likelihood -1022.761676 stepsize 0.0001
# [step 585] neg-log-likelihood -1023.280526 stepsize 0.0001
# [step 586] neg-log-likelihood -1018.322742 stepsize 0.0001
# [step 587] neg-log-likelihood -1017.663775 stepsize 0.0001
# [step 588] neg-log-likelihood -1008.663315 stepsize 0.0001
# [step 589] neg-log-likelihood -1005.596566 stepsize 0.0001
# [step 590] neg-log-likelihood -1001.790561 stepsize 0.0001
# [step 591] neg-log-likelihood -999.021566 stepsize 0.0001
# [step 592] neg-log-likelihood -997.320199 stepsize 0.0001
# [step 593] neg-log-likelihood -998.697388 stepsize 0.0001
# [step 594] neg-log-likelihood -992.105546 stepsize 0.0001
# [step 595] neg-log-likelihood -988.747699 stepsize 0.0001
# [step 596] neg-log-likelihood -983.698803 stepsize 0.0001
# [step 597] neg-log-likelihood -979.779955 stepsize 0.0001
# [step 598] neg-log-likelihood -975.838849 stepsize 0.0001
# [step 599] neg-log-likelihood -972.316896 stepsize 0.0001
# kernel initialization ...
# negative log-likelihood compute
# [step   0] neg-log-likelihood -515.877061 stepsize 0.0001
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -523.333919 stepsize 0.0001
# [step   2] neg-log-likelihood -519.385853 stepsize 0.0001
# [step   3] neg-log-likelihood -513.196737 stepsize 0.0001
# [step   4] neg-log-likelihood -510.217788 stepsize 0.0001
# [step   5] neg-log-likelihood -516.860156 stepsize 0.0001
# [step   6] neg-log-likelihood -528.002876 stepsize 0.0001
# [step   7] neg-log-likelihood -543.185933 stepsize 0.0001
# [step   8] neg-log-likelihood -560.147000 stepsize 0.0001
# [step   9] neg-log-likelihood -576.127827 stepsize 0.0001
# [step  10] neg-log-likelihood -590.004994 stepsize 0.0001
# [step  11] neg-log-likelihood -601.427605 stepsize 0.0001
# [step  12] neg-log-likelihood -615.266181 stepsize 0.0001
# [step  13] neg-log-likelihood -629.988066 stepsize 0.0001
# [step  14] neg-log-likelihood -643.161952 stepsize 0.0001
# [step  15] neg-log-likelihood -656.803701 stepsize 0.0001
# [step  16] neg-log-likelihood -671.883775 stepsize 0.0001
# [step  17] neg-log-likelihood -683.571310 stepsize 0.0001
# [step  18] neg-log-likelihood -702.182241 stepsize 0.0001
# [step  19] neg-log-likelihood -712.967878 stepsize 0.0001
# [step  20] neg-log-likelihood -727.724113 stepsize 0.0001
# [step  21] neg-log-likelihood -741.704004 stepsize 0.0001
# [step  22] neg-log-likelihood -748.844436 stepsize 0.0001
# [step  23] neg-log-likelihood -757.914970 stepsize 0.0001
# [step  24] neg-log-likelihood -768.652244 stepsize 0.0001
# [step  25] neg-log-likelihood -779.283041 stepsize 0.0001
# [step  26] neg-log-likelihood -786.444410 stepsize 0.0001
# [step  27] neg-log-likelihood -792.329780 stepsize 0.0001
# [step  28] neg-log-likelihood -796.774758 stepsize 0.0001
# [step  29] neg-log-likelihood -802.309915 stepsize 0.0001
# [step  30] neg-log-likelihood -808.429885 stepsize 0.0001
# [step  31] neg-log-likelihood -815.106075 stepsize 0.0001
# [step  32] neg-log-likelihood -822.583559 stepsize 0.0001
# [step  33] neg-log-likelihood -831.542756 stepsize 0.0001
# [step  34] neg-log-likelihood -835.947790 stepsize 0.0001
# [step  35] neg-log-likelihood -840.493180 stepsize 0.0001
# [step  36] neg-log-likelihood -844.992356 stepsize 0.0001
# [step  37] neg-log-likelihood -850.146398 stepsize 0.0001
# [step  38] neg-log-likelihood -856.017677 stepsize 0.0001
# [step  39] neg-log-likelihood -862.206418 stepsize 0.0001
# [step  40] neg-log-likelihood -868.814425 stepsize 0.0001
# [step  41] neg-log-likelihood -875.523380 stepsize 0.0001
# [step  42] neg-log-likelihood -881.435868 stepsize 0.0001
# [step  43] neg-log-likelihood -887.741111 stepsize 0.0001
# [step  44] neg-log-likelihood -893.802139 stepsize 0.0001
# [step  45] neg-log-likelihood -900.344697 stepsize 0.0001
# [step  46] neg-log-likelihood -906.540328 stepsize 0.0001
# [step  47] neg-log-likelihood -913.394808 stepsize 0.0001
# [step  48] neg-log-likelihood -920.000801 stepsize 0.0001
# [step  49] neg-log-likelihood -927.835236 stepsize 0.0001
# [step  50] neg-log-likelihood -935.536153 stepsize 0.0001
# [step  51] neg-log-likelihood -943.571332 stepsize 0.0001
# [step  52] neg-log-likelihood -952.235044 stepsize 0.0001
# [step  53] neg-log-likelihood -960.335728 stepsize 0.0001
# [step  54] neg-log-likelihood -969.330203 stepsize 0.0001
# [step  55] neg-log-likelihood -980.133309 stepsize 0.0001
# [step  56] neg-log-likelihood -989.479788 stepsize 0.0001
# [step  57] neg-log-likelihood -996.811062 stepsize 0.0001
# [step  58] neg-log-likelihood -1005.109047 stepsize 0.0001
# [step  59] neg-log-likelihood -1014.395285 stepsize 0.0001
# [step  60] neg-log-likelihood -1024.331708 stepsize 0.0001
# [step  61] neg-log-likelihood -1033.956138 stepsize 0.0001
# [step  62] neg-log-likelihood -1042.286629 stepsize 0.0001
# [step  63] neg-log-likelihood -1050.669813 stepsize 0.0001
# [step  64] neg-log-likelihood -1061.722104 stepsize 0.0001
# [step  65] neg-log-likelihood -1068.592847 stepsize 0.0001
# [step  66] neg-log-likelihood -1085.501676 stepsize 0.0001
# [step  67] neg-log-likelihood -1090.547548 stepsize 0.0001
# [step  68] neg-log-likelihood -1098.800544 stepsize 0.0001
# [step  69] neg-log-likelihood -1102.483473 stepsize 0.0001
# [step  70] neg-log-likelihood -1111.557543 stepsize 0.0001
# [step  71] neg-log-likelihood -1123.681177 stepsize 0.0001
# [step  72] neg-log-likelihood -1126.869298 stepsize 0.0001
# [step  73] neg-log-likelihood -1137.269943 stepsize 0.0001
# [step  74] neg-log-likelihood -1140.664656 stepsize 0.0001
# [step  75] neg-log-likelihood -1147.265010 stepsize 0.0001
# [step  76] neg-log-likelihood -1155.394508 stepsize 0.0001
# [step  77] neg-log-likelihood -1163.095273 stepsize 0.0001
# [step  78] neg-log-likelihood -1167.060089 stepsize 0.0001
# [step  79] neg-log-likelihood -1174.065388 stepsize 0.0001
# [step  80] neg-log-likelihood -1180.897741 stepsize 0.0001
# [step  81] neg-log-likelihood -1188.286649 stepsize 0.0001
# [step  82] neg-log-likelihood -1192.894312 stepsize 0.0001
# [step  83] neg-log-likelihood -1196.285477 stepsize 0.0001
# [step  84] neg-log-likelihood -1199.355780 stepsize 0.0001
# [step  85] neg-log-likelihood -1204.951322 stepsize 0.0001
# [step  86] neg-log-likelihood -1207.915002 stepsize 0.0001
# [step  87] neg-log-likelihood -1214.223363 stepsize 0.0001
# [step  88] neg-log-likelihood -1215.037335 stepsize 0.0001
# [step  89] neg-log-likelihood -1219.679890 stepsize 0.0001
# [step  90] neg-log-likelihood -1222.822189 stepsize 0.0001
# [step  91] neg-log-likelihood -1226.969186 stepsize 0.0001
# [step  92] neg-log-likelihood -1228.115670 stepsize 0.0001
# [step  93] neg-log-likelihood -1230.740004 stepsize 0.0001
# [step  94] neg-log-likelihood -1232.668750 stepsize 0.0001
# [step  95] neg-log-likelihood -1234.122139 stepsize 0.0001
# [step  96] neg-log-likelihood -1238.414658 stepsize 0.0001
# [step  97] neg-log-likelihood -1241.531934 stepsize 0.0001
# [step  98] neg-log-likelihood -1243.700774 stepsize 0.0001
# [step  99] neg-log-likelihood -1247.374150 stepsize 0.0001
# [step 100] neg-log-likelihood -1250.317885 stepsize 0.0001
# [step 101] neg-log-likelihood -1250.277225 stepsize 0.0001
# [step 102] neg-log-likelihood -1252.221909 stepsize 0.0001
# [step 103] neg-log-likelihood -1254.819078 stepsize 0.0001
# [step 104] neg-log-likelihood -1257.734513 stepsize 0.0001
# [step 105] neg-log-likelihood -1260.829706 stepsize 0.0001
# [step 106] neg-log-likelihood -1260.150975 stepsize 0.0001
# [step 107] neg-log-likelihood -1262.302937 stepsize 0.0001
# [step 108] neg-log-likelihood -1263.974891 stepsize 0.0001
# [step 109] neg-log-likelihood -1266.253971 stepsize 0.0001
# [step 110] neg-log-likelihood -1267.112659 stepsize 0.0001
# [step 111] neg-log-likelihood -1271.908167 stepsize 0.0001
# [step 112] neg-log-likelihood -1271.072243 stepsize 0.0001
# [step 113] neg-log-likelihood -1275.268109 stepsize 0.0001
# [step 114] neg-log-likelihood -1275.248993 stepsize 0.0001
# [step 115] neg-log-likelihood -1276.374683 stepsize 0.0001
# [step 116] neg-log-likelihood -1280.843746 stepsize 0.0001
# [step 117] neg-log-likelihood -1284.479414 stepsize 0.0001
# [step 118] neg-log-likelihood -1282.691577 stepsize 0.0001
# [step 119] neg-log-likelihood -1285.565679 stepsize 0.0001
# [step 120] neg-log-likelihood -1287.212280 stepsize 0.0001
# [step 121] neg-log-likelihood -1288.497763 stepsize 0.0001
# [step 122] neg-log-likelihood -1290.177290 stepsize 0.0001
# [step 123] neg-log-likelihood -1292.253277 stepsize 0.0001
# [step 124] neg-log-likelihood -1294.230896 stepsize 0.0001
# [step 125] neg-log-likelihood -1299.156001 stepsize 0.0001
# [step 126] neg-log-likelihood -1297.644933 stepsize 0.0001
# [step 127] neg-log-likelihood -1300.000870 stepsize 0.0001
# [step 128] neg-log-likelihood -1303.468283 stepsize 0.0001
# [step 129] neg-log-likelihood -1303.614379 stepsize 0.0001
# [step 130] neg-log-likelihood -1307.877767 stepsize 0.0001
# [step 131] neg-log-likelihood -1307.701313 stepsize 0.0001
# [step 132] neg-log-likelihood -1310.175495 stepsize 0.0001
# [step 133] neg-log-likelihood -1313.203265 stepsize 0.0001
# [step 134] neg-log-likelihood -1315.841609 stepsize 0.0001
# [step 135] neg-log-likelihood -1319.143694 stepsize 0.0001
# [step 136] neg-log-likelihood -1323.374208 stepsize 0.0001
# [step 137] neg-log-likelihood -1324.031352 stepsize 0.0001
# [step 138] neg-log-likelihood -1326.583187 stepsize 0.0001
# [step 139] neg-log-likelihood -1323.179821 stepsize 0.0001
# [step 140] neg-log-likelihood -1325.575004 stepsize 0.0001
# [step 141] neg-log-likelihood -1328.475944 stepsize 0.0001
# [step 142] neg-log-likelihood -1331.505358 stepsize 0.0001
# [step 143] neg-log-likelihood -1332.732766 stepsize 0.0001
# [step 144] neg-log-likelihood -1336.729440 stepsize 0.0001
# [step 145] neg-log-likelihood -1339.871719 stepsize 0.0001
# [step 146] neg-log-likelihood -1336.847906 stepsize 0.0001
# [step 147] neg-log-likelihood -1337.235505 stepsize 0.0001
# [step 148] neg-log-likelihood -1340.137459 stepsize 0.0001
# [step 149] neg-log-likelihood -1341.857733 stepsize 0.0001
# [step 150] neg-log-likelihood -1342.113044 stepsize 0.0001
# [step 151] neg-log-likelihood -1348.512447 stepsize 0.0001
# [step 152] neg-log-likelihood -1351.154170 stepsize 0.0001
# [step 153] neg-log-likelihood -1348.589479 stepsize 0.0001
# [step 154] neg-log-likelihood -1349.028582 stepsize 0.0001
# [step 155] neg-log-likelihood -1350.613554 stepsize 0.0001
# [step 156] neg-log-likelihood -1351.939252 stepsize 0.0001
# [step 157] neg-log-likelihood -1358.773402 stepsize 0.0001
# [step 158] neg-log-likelihood -1356.359656 stepsize 0.0001
# [step 159] neg-log-likelihood -1358.294379 stepsize 0.0001
# [step 160] neg-log-likelihood -1362.158752 stepsize 0.0001
# [step 161] neg-log-likelihood -1362.740445 stepsize 0.0001
# [step 162] neg-log-likelihood -1364.068174 stepsize 0.0001
# [step 163] neg-log-likelihood -1368.213454 stepsize 0.0001
# [step 164] neg-log-likelihood -1371.156955 stepsize 0.0001
# [step 165] neg-log-likelihood -1367.415388 stepsize 0.0001
# [step 166] neg-log-likelihood -1371.803230 stepsize 0.0001
# [step 167] neg-log-likelihood -1379.414693 stepsize 0.0001
# [step 168] neg-log-likelihood -1376.518248 stepsize 0.0001
# [step 169] neg-log-likelihood -1376.913048 stepsize 0.0001
# [step 170] neg-log-likelihood -1377.758391 stepsize 0.0001
# [step 171] neg-log-likelihood -1378.544214 stepsize 0.0001
# [step 172] neg-log-likelihood -1382.155570 stepsize 0.0001
# [step 173] neg-log-likelihood -1383.100194 stepsize 0.0001
# [step 174] neg-log-likelihood -1384.868744 stepsize 0.0001
# [step 175] neg-log-likelihood -1384.514166 stepsize 0.0001
# [step 176] neg-log-likelihood -1387.249772 stepsize 0.0001
# [step 177] neg-log-likelihood -1386.978016 stepsize 0.0001
# [step 178] neg-log-likelihood -1389.926758 stepsize 0.0001
# [step 179] neg-log-likelihood -1395.099838 stepsize 0.0001
# [step 180] neg-log-likelihood -1392.068573 stepsize 0.0001
# [step 181] neg-log-likelihood -1395.223313 stepsize 0.0001
# [step 182] neg-log-likelihood -1396.599457 stepsize 0.0001
# [step 183] neg-log-likelihood -1398.560233 stepsize 0.0001
# [step 184] neg-log-likelihood -1398.093390 stepsize 0.0001
# [step 185] neg-log-likelihood -1400.938379 stepsize 0.0001
# [step 186] neg-log-likelihood -1400.326692 stepsize 0.0001
# [step 187] neg-log-likelihood -1401.043881 stepsize 0.0001
# [step 188] neg-log-likelihood -1403.189899 stepsize 0.0001
# [step 189] neg-log-likelihood -1404.061337 stepsize 0.0001
# [step 190] neg-log-likelihood -1408.306376 stepsize 0.0001
# [step 191] neg-log-likelihood -1407.454102 stepsize 0.0001
# [step 192] neg-log-likelihood -1407.089344 stepsize 0.0001
# [step 193] neg-log-likelihood -1408.845816 stepsize 0.0001
# [step 194] neg-log-likelihood -1407.137640 stepsize 0.0001
# [step 195] neg-log-likelihood -1408.817478 stepsize 0.0001
# [step 196] neg-log-likelihood -1413.295877 stepsize 0.0001
# [step 197] neg-log-likelihood -1409.578173 stepsize 0.0001
# [step 198] neg-log-likelihood -1412.703276 stepsize 0.0001
# [step 199] neg-log-likelihood -1414.782694 stepsize 0.0001
# [step 200] neg-log-likelihood -1417.144543 stepsize 0.0001
# [step 201] neg-log-likelihood -1414.261632 stepsize 0.0001
# [step 202] neg-log-likelihood -1418.139636 stepsize 0.0001
# [step 203] neg-log-likelihood -1419.239120 stepsize 0.0001
# [step 204] neg-log-likelihood -1417.324512 stepsize 0.0001
# [step 205] neg-log-likelihood -1416.811561 stepsize 0.0001
# ...
# [step 329] neg-log-likelihood -1460.675150 stepsize 0.0001
# [step 330] neg-log-likelihood -1460.609070 stepsize 0.0001
# [step 331] neg-log-likelihood -1459.315083 stepsize 0.0001
# [step 332] neg-log-likelihood -1459.131996 stepsize 0.0001
# [step 333] neg-log-likelihood -1458.591285 stepsize 0.0001
# [step 334] neg-log-likelihood -1459.659523 stepsize 0.0001
# [step 335] neg-log-likelihood -1464.357548 stepsize 0.0001
# [step 336] neg-log-likelihood -1460.498176 stepsize 0.0001
# [step 337] neg-log-likelihood -1460.576882 stepsize 0.0001
# [step 338] neg-log-likelihood -1459.710516 stepsize 0.0001
# [step 339] neg-log-likelihood -1462.749046 stepsize 0.0001
# [step 340] neg-log-likelihood -1463.570768 stepsize 0.0001
# [step 341] neg-log-likelihood -1462.215827 stepsize 0.0001
# [step 342] neg-log-likelihood -1463.756252 stepsize 0.0001
# [step 343] neg-log-likelihood -1463.899252 stepsize 0.0001
# [step 344] neg-log-likelihood -1461.177962 stepsize 0.0001
# [step 345] neg-log-likelihood -1463.897709 stepsize 0.0001
# [step 346] neg-log-likelihood -1465.989099 stepsize 0.0001
# [step 347] neg-log-likelihood -1462.960008 stepsize 0.0001
# [step 348] neg-log-likelihood -1465.603873 stepsize 0.0001
# [step 349] neg-log-likelihood -1466.650943 stepsize 0.0001
# [step 350] neg-log-likelihood -1462.313601 stepsize 0.0001
# [step 351] neg-log-likelihood -1462.899760 stepsize 0.0001
# [step 352] neg-log-likelihood -1465.903185 stepsize 0.0001
# [step 353] neg-log-likelihood -1467.529631 stepsize 0.0001
# [step 354] neg-log-likelihood -1465.545778 stepsize 0.0001
# [step 355] neg-log-likelihood -1464.119518 stepsize 0.0001
# [step 356] neg-log-likelihood -1464.931425 stepsize 0.0001
# [step 357] neg-log-likelihood -1466.041337 stepsize 0.0001
# [step 358] neg-log-likelihood -1468.601196 stepsize 0.0001
# [step 359] neg-log-likelihood -1463.609032 stepsize 0.0001
# [step 360] neg-log-likelihood -1467.639762 stepsize 0.0001
# [step 361] neg-log-likelihood -1465.163282 stepsize 0.0001
# [step 362] neg-log-likelihood -1467.826775 stepsize 0.0001
# [step 363] neg-log-likelihood -1467.052540 stepsize 0.0001
# [step 364] neg-log-likelihood -1468.387857 stepsize 0.0001
# [step 365] neg-log-likelihood -1471.107435 stepsize 0.0001
# [step 366] neg-log-likelihood -1469.026669 stepsize 0.0001
# [step 367] neg-log-likelihood -1470.472047 stepsize 0.0001
# [step 368] neg-log-likelihood -1467.331007 stepsize 0.0001
# [step 369] neg-log-likelihood -1470.118085 stepsize 0.0001
# [step 370] neg-log-likelihood -1470.050410 stepsize 0.0001
# [step 371] neg-log-likelihood -1469.197882 stepsize 0.0001
# [step 372] neg-log-likelihood -1469.720056 stepsize 0.0001
# [step 373] neg-log-likelihood -1468.942685 stepsize 0.0001
# [step 374] neg-log-likelihood -1468.742875 stepsize 0.0001
# [step 375] neg-log-likelihood -1472.975814 stepsize 0.0001
# [step 376] neg-log-likelihood -1470.448600 stepsize 0.0001
# [step 377] neg-log-likelihood -1471.519922 stepsize 0.0001
# [step 378] neg-log-likelihood -1474.128954 stepsize 0.0001
# [step 379] neg-log-likelihood -1472.890073 stepsize 0.0001
# [step 380] neg-log-likelihood -1472.982391 stepsize 0.0001
# [step 381] neg-log-likelihood -1475.723784 stepsize 0.0001
# [step 382] neg-log-likelihood -1469.723161 stepsize 0.0001
# [step 383] neg-log-likelihood -1473.734623 stepsize 0.0001
# [step 384] neg-log-likelihood -1472.336582 stepsize 0.0001
# [step 385] neg-log-likelihood -1472.092171 stepsize 0.0001
# [step 386] neg-log-likelihood -1471.806128 stepsize 0.0001
# [step 387] neg-log-likelihood -1473.083125 stepsize 0.0001
# [step 388] neg-log-likelihood -1473.941680 stepsize 0.0001
# [step 389] neg-log-likelihood -1473.422824 stepsize 0.0001
# [step 390] neg-log-likelihood -1471.249610 stepsize 0.0001
# [step 391] neg-log-likelihood -1473.446127 stepsize 0.0001
# [step 392] neg-log-likelihood -1473.870453 stepsize 0.0001
# [step 393] neg-log-likelihood -1474.810815 stepsize 0.0001
# [step 394] neg-log-likelihood -1474.371800 stepsize 0.0001
# [step 395] neg-log-likelihood -1477.584710 stepsize 0.0001
# [step 396] neg-log-likelihood -1477.808662 stepsize 0.0001
# [step 397] neg-log-likelihood -1475.372977 stepsize 0.0001
# [step 398] neg-log-likelihood -1474.786900 stepsize 0.0001
# [step 399] neg-log-likelihood -1473.779182 stepsize 0.0001
# [step 400] neg-log-likelihood -1477.883481 stepsize 0.0001
# [step 401] neg-log-likelihood -1478.174240 stepsize 0.0001
# [step 402] neg-log-likelihood -1478.396150 stepsize 0.0001
# [step 403] neg-log-likelihood -1476.234294 stepsize 0.0001
# [step 404] neg-log-likelihood -1476.397792 stepsize 0.0001
# [step 405] neg-log-likelihood -1475.878047 stepsize 0.0001
# [step 406] neg-log-likelihood -1476.699100 stepsize 0.0001
# [step 407] neg-log-likelihood -1475.916460 stepsize 0.0001
# [step 408] neg-log-likelihood -1476.874974 stepsize 0.0001
# [step 409] neg-log-likelihood -1477.863117 stepsize 0.0001
# [step 410] neg-log-likelihood -1481.593574 stepsize 0.0001
# [step 411] neg-log-likelihood -1478.584750 stepsize 0.0001
# [step 412] neg-log-likelihood -1476.789171 stepsize 0.0001
# [step 413] neg-log-likelihood -1480.256537 stepsize 0.0001
# [step 414] neg-log-likelihood -1478.975539 stepsize 0.0001
# [step 415] neg-log-likelihood -1484.516487 stepsize 0.0001
# [step 416] neg-log-likelihood -1479.948569 stepsize 0.0001
# [step 417] neg-log-likelihood -1480.432086 stepsize 0.0001
# [step 418] neg-log-likelihood -1479.352690 stepsize 0.0001
# [step 419] neg-log-likelihood -1480.746408 stepsize 0.0001
# [step 420] neg-log-likelihood -1478.770507 stepsize 0.0001
# [step 421] neg-log-likelihood -1480.812943 stepsize 0.0001
# [step 422] neg-log-likelihood -1480.140414 stepsize 0.0001
# [step 423] neg-log-likelihood -1481.847241 stepsize 0.0001
# [step 424] neg-log-likelihood -1484.372258 stepsize 0.0001
# [step 425] neg-log-likelihood -1480.944168 stepsize 0.0001
# [step 426] neg-log-likelihood -1481.444966 stepsize 0.0001
# [step 427] neg-log-likelihood -1489.126612 stepsize 0.0001
# [step 428] neg-log-likelihood -1482.370801 stepsize 0.0001
# [step 429] neg-log-likelihood -1482.783173 stepsize 0.0001
# [step 430] neg-log-likelihood -1485.787354 stepsize 0.0001
# [step 431] neg-log-likelihood -1482.437921 stepsize 0.0001
# [step 432] neg-log-likelihood -1484.845936 stepsize 0.0001
# [step 433] neg-log-likelihood -1484.779651 stepsize 0.0001
# [step 434] neg-log-likelihood -1482.493798 stepsize 0.0001
# [step 435] neg-log-likelihood -1482.888881 stepsize 0.0001
# [step 436] neg-log-likelihood -1484.868658 stepsize 0.0001
# [step 437] neg-log-likelihood -1482.904248 stepsize 0.0001
# [step 438] neg-log-likelihood -1487.012220 stepsize 0.0001
# [step 439] neg-log-likelihood -1485.316927 stepsize 0.0001
# [step 440] neg-log-likelihood -1483.038115 stepsize 0.0001
# [step 441] neg-log-likelihood -1480.890678 stepsize 0.0001
# [step 442] neg-log-likelihood -1485.078454 stepsize 0.0001
# [step 443] neg-log-likelihood -1487.211353 stepsize 0.0001
# [step 444] neg-log-likelihood -1483.681857 stepsize 0.0001
# [step 445] neg-log-likelihood -1488.720666 stepsize 0.0001
# [step 446] neg-log-likelihood -1486.874171 stepsize 0.0001
# [step 447] neg-log-likelihood -1486.798217 stepsize 0.0001
# [step 448] neg-log-likelihood -1490.240854 stepsize 0.0001
# [step 449] neg-log-likelihood -1485.772172 stepsize 0.0001
# [step 450] neg-log-likelihood -1485.734089 stepsize 0.0001
# [step 451] neg-log-likelihood -1485.029676 stepsize 0.0001
# [step 452] neg-log-likelihood -1489.504121 stepsize 0.0001
# [step 453] neg-log-likelihood -1488.749405 stepsize 0.0001
# [step 454] neg-log-likelihood -1486.331182 stepsize 0.0001
# [step 455] neg-log-likelihood -1486.612464 stepsize 0.0001
# [step 456] neg-log-likelihood -1487.822627 stepsize 0.0001
# [step 457] neg-log-likelihood -1491.667589 stepsize 0.0001
# [step 458] neg-log-likelihood -1489.489075 stepsize 0.0001
# [step 459] neg-log-likelihood -1489.347503 stepsize 0.0001
# [step 460] neg-log-likelihood -1489.525139 stepsize 0.0001
# [step 461] neg-log-likelihood -1488.529412 stepsize 0.0001
# [step 462] neg-log-likelihood -1488.705560 stepsize 0.0001
# [step 463] neg-log-likelihood -1488.645071 stepsize 0.0001
# [step 464] neg-log-likelihood -1489.303430 stepsize 0.0001
# [step 465] neg-log-likelihood -1488.796230 stepsize 0.0001
# [step 466] neg-log-likelihood -1492.582098 stepsize 0.0001
# [step 467] neg-log-likelihood -1490.489900 stepsize 0.0001
# [step 468] neg-log-likelihood -1489.051225 stepsize 0.0001
# [step 469] neg-log-likelihood -1493.362175 stepsize 0.0001
# [step 470] neg-log-likelihood -1492.188309 stepsize 0.0001
# [step 471] neg-log-likelihood -1490.016393 stepsize 0.0001
# [step 472] neg-log-likelihood -1490.533757 stepsize 0.0001
# [step 473] neg-log-likelihood -1496.650728 stepsize 0.0001
# [step 474] neg-log-likelihood -1492.999286 stepsize 0.0001
# [step 475] neg-log-likelihood -1495.813867 stepsize 0.0001
# [step 476] neg-log-likelihood -1490.550665 stepsize 0.0001
# [step 477] neg-log-likelihood -1493.353434 stepsize 0.0001
# [step 478] neg-log-likelihood -1492.549454 stepsize 0.0001
# [step 479] neg-log-likelihood -1491.862035 stepsize 0.0001
# [step 480] neg-log-likelihood -1492.987706 stepsize 0.0001
# [step 481] neg-log-likelihood -1491.116022 stepsize 0.0001
# [step 482] neg-log-likelihood -1493.292520 stepsize 0.0001
# [step 483] neg-log-likelihood -1491.384899 stepsize 0.0001
# [step 484] neg-log-likelihood -1494.478940 stepsize 0.0001
# [step 485] neg-log-likelihood -1495.196635 stepsize 0.0001
# [step 486] neg-log-likelihood -1493.729924 stepsize 0.0001
# [step 487] neg-log-likelihood -1493.263206 stepsize 0.0001
# [step 488] neg-log-likelihood -1493.254661 stepsize 0.0001
# [step 489] neg-log-likelihood -1495.127185 stepsize 0.0001
# [step 490] neg-log-likelihood -1494.742560 stepsize 0.0001
# [step 491] neg-log-likelihood -1492.529586 stepsize 0.0001
# [step 492] neg-log-likelihood -1497.588442 stepsize 0.0001
# [step 493] neg-log-likelihood -1494.366782 stepsize 0.0001
# [step 494] neg-log-likelihood -1496.016030 stepsize 0.0001
# [step 495] neg-log-likelihood -1495.609127 stepsize 0.0001
# [step 496] neg-log-likelihood -1497.207110 stepsize 0.0001
# [step 497] neg-log-likelihood -1493.916712 stepsize 0.0001
# [step 498] neg-log-likelihood -1494.576251 stepsize 0.0001
# [step 499] neg-log-likelihood -1502.141789 stepsize 0.0001
# [step 500] neg-log-likelihood -1493.141957 stepsize 0.0001
# [step 501] neg-log-likelihood -1500.269903 stepsize 0.0001
# [step 502] neg-log-likelihood -1501.578150 stepsize 0.0001
# [step 503] neg-log-likelihood -1496.469656 stepsize 0.0001
# [step 504] neg-log-likelihood -1501.074051 stepsize 0.0001
# [step 505] neg-log-likelihood -1496.047338 stepsize 0.0001
# [step 506] neg-log-likelihood -1494.067725 stepsize 0.0001
# [step 507] neg-log-likelihood -1497.244541 stepsize 0.0001
# [step 508] neg-log-likelihood -1496.367320 stepsize 0.0001
# [step 509] neg-log-likelihood -1494.275187 stepsize 0.0001
# [step 510] neg-log-likelihood -1498.689643 stepsize 0.0001
# [step 511] neg-log-likelihood -1498.301437 stepsize 0.0001
# [step 512] neg-log-likelihood -1494.355871 stepsize 0.0001
# [step 513] neg-log-likelihood -1496.059131 stepsize 0.0001
# [step 514] neg-log-likelihood -1496.155215 stepsize 0.0001
# [step 515] neg-log-likelihood -1497.308525 stepsize 0.0001
# [step 516] neg-log-likelihood -1496.970961 stepsize 0.0001
# [step 517] neg-log-likelihood -1499.707094 stepsize 0.0001
# [step 518] neg-log-likelihood -1499.603417 stepsize 0.0001
# [step 519] neg-log-likelihood -1496.264079 stepsize 0.0001
# [step 520] neg-log-likelihood -1495.447978 stepsize 0.0001
# [step 521] neg-log-likelihood -1497.879276 stepsize 0.0001
# [step 522] neg-log-likelihood -1498.953686 stepsize 0.0001
# [step 523] neg-log-likelihood -1496.598139 stepsize 0.0001
# [step 524] neg-log-likelihood -1496.656494 stepsize 0.0001
# [step 525] neg-log-likelihood -1502.341036 stepsize 0.0001
# [step 526] neg-log-likelihood -1497.897840 stepsize 0.0001
# [step 527] neg-log-likelihood -1497.260009 stepsize 0.0001
# [step 528] neg-log-likelihood -1498.621551 stepsize 0.0001
# [step 529] neg-log-likelihood -1499.200278 stepsize 0.0001
# [step 530] neg-log-likelihood -1496.791205 stepsize 0.0001
# [step 531] neg-log-likelihood -1500.594613 stepsize 0.0001
# [step 532] neg-log-likelihood -1499.821553 stepsize 0.0001
# [step 533] neg-log-likelihood -1498.480237 stepsize 0.0001
# [step 534] neg-log-likelihood -1498.416718 stepsize 0.0001
# [step 535] neg-log-likelihood -1499.994946 stepsize 0.0001
# [step 536] neg-log-likelihood -1498.893768 stepsize 0.0001
# [step 537] neg-log-likelihood -1499.504949 stepsize 0.0001
# [step 538] neg-log-likelihood -1495.946549 stepsize 0.0001
# [step 539] neg-log-likelihood -1499.413766 stepsize 0.0001
# [step 540] neg-log-likelihood -1497.924931 stepsize 0.0001
# [step 541] neg-log-likelihood -1498.660285 stepsize 0.0001
# [step 542] neg-log-likelihood -1495.841179 stepsize 0.0001
# [step 543] neg-log-likelihood -1497.556407 stepsize 0.0001
# [step 544] neg-log-likelihood -1501.276106 stepsize 0.0001
# [step 545] neg-log-likelihood -1499.815807 stepsize 0.0001
# [step 546] neg-log-likelihood -1496.551216 stepsize 0.0001
# [step 547] neg-log-likelihood -1497.277809 stepsize 0.0001
# [step 548] neg-log-likelihood -1496.943500 stepsize 0.0001
# [step 549] neg-log-likelihood -1499.571929 stepsize 0.0001
# [step 550] neg-log-likelihood -1497.923310 stepsize 0.0001
# [step 551] neg-log-likelihood -1502.250295 stepsize 0.0001
# [step 552] neg-log-likelihood -1498.618201 stepsize 0.0001
# [step 553] neg-log-likelihood -1498.577564 stepsize 0.0001
# [step 554] neg-log-likelihood -1499.723830 stepsize 0.0001
# [step 555] neg-log-likelihood -1496.878077 stepsize 0.0001
# [step 556] neg-log-likelihood -1505.127988 stepsize 0.0001
# [step 557] neg-log-likelihood -1498.840227 stepsize 0.0001
# [step 558] neg-log-likelihood -1499.884739 stepsize 0.0001
# [step 559] neg-log-likelihood -1498.557169 stepsize 0.0001
# [step 560] neg-log-likelihood -1499.410124 stepsize 0.0001
# [step 561] neg-log-likelihood -1500.213736 stepsize 0.0001
# [step 562] neg-log-likelihood -1502.608309 stepsize 0.0001
# [step 563] neg-log-likelihood -1500.180934 stepsize 0.0001
# [step 564] neg-log-likelihood -1497.398134 stepsize 0.0001
# [step 565] neg-log-likelihood -1502.276737 stepsize 0.0001
# [step 566] neg-log-likelihood -1499.015818 stepsize 0.0001
# [step 567] neg-log-likelihood -1498.620792 stepsize 0.0001
# [step 568] neg-log-likelihood -1497.976776 stepsize 0.0001
# [step 569] neg-log-likelihood -1498.070973 stepsize 0.0001
# [step 570] neg-log-likelihood -1497.683273 stepsize 0.0001
# [step 571] neg-log-likelihood -1499.261331 stepsize 0.0001
# [step 572] neg-log-likelihood -1496.447083 stepsize 0.0001
# [step 573] neg-log-likelihood -1499.157623 stepsize 0.0001
# [step 574] neg-log-likelihood -1497.090607 stepsize 0.0001
# [step 575] neg-log-likelihood -1500.887406 stepsize 0.0001
# [step 576] neg-log-likelihood -1497.629211 stepsize 0.0001
# [step 577] neg-log-likelihood -1500.108363 stepsize 0.0001
# [step 578] neg-log-likelihood -1499.090395 stepsize 0.0001
# [step 579] neg-log-likelihood -1496.802240 stepsize 0.0001
# [step 580] neg-log-likelihood -1497.911574 stepsize 0.0001
# [step 581] neg-log-likelihood -1500.464793 stepsize 0.0001
# [step 582] neg-log-likelihood -1500.725959 stepsize 0.0001
# [step 583] neg-log-likelihood -1500.396628 stepsize 0.0001
# [step 584] neg-log-likelihood -1500.113027 stepsize 0.0001
# [step 585] neg-log-likelihood -1499.108033 stepsize 0.0001
# [step 586] neg-log-likelihood -1500.160718 stepsize 0.0001
# [step 587] neg-log-likelihood -1500.441497 stepsize 0.0001
# [step 588] neg-log-likelihood -1497.544536 stepsize 0.0001
# [step 589] neg-log-likelihood -1498.194094 stepsize 0.0001
# [step 590] neg-log-likelihood -1497.716460 stepsize 0.0001
# [step 591] neg-log-likelihood -1500.620002 stepsize 0.0001
# [step 592] neg-log-likelihood -1498.002960 stepsize 0.0001
# [step 593] neg-log-likelihood -1497.994044 stepsize 0.0001
# [step 594] neg-log-likelihood -1497.939879 stepsize 0.0001
# [step 595] neg-log-likelihood -1500.794570 stepsize 0.0001
# [step 596] neg-log-likelihood -1498.768539 stepsize 0.0001
# [step 597] neg-log-likelihood -1497.791807 stepsize 0.0001
# [step 598] neg-log-likelihood -1496.058712 stepsize 0.0001
# [step 599] neg-log-likelihood -1502.613797 stepsize 0.0001

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 6.0*len(lambda_array))
plt.style.use('seaborn-white')

for i in np.arange(len(lambda_array)):
    ax = plt.subplot(len(lambda_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_nll_eu_array[i], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_nll_grass_array[i], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
                             r"Grassmann ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
                             fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f})".format(eta), r"Grassmann ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper center', frameon=True)
    plt.grid(1)
    plt.ylabel('negative log-likelihood', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_01_16_" + str(trail) + "_"
    file_tail = "_nll_iters_Grass_Eu.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %% [markdown]
# These plots show the comparison of learning trajectories for different regularization paramters $\lambda$. We see that the larger $\lambda$, the smoother the curve is. However, it introduces more biases.
# <img src="../figures/03_31_16_nll_iters_Grass_Eu_1_nearReg.png">

# %%
fig= plt.figure(2)
fig.set_size_inches(12.0, 6.0*len(lambda_array))
plt.style.use('seaborn-white')

for i in np.arange(len(lambda_array)):
    ax = plt.subplot(len(lambda_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,0], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,1], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
                             r"2nd singular value ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
                             fontsize = 15, loc='upper right', frameon=True)
    else:    
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:5.4f})".format(eta), r"2nd singular value ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper right', frameon=True)
    plt.grid(1)
    plt.ylabel('singular value', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_01_16_" + str(trail) + "_"
    file_tail = "_sig_iters_Grass_Eu.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
Ifsavefig = True
