# %% [markdown]
# # G$^2$Pnet: The Grassmanian Gaussian Process Network
# We check the implementation of G2PnetSolver (ver 3.) class in ../src/
#
# Created by Tianpei Xie, 03/31/2016
#
# Last Edit 03/31/2016

# %%
# %reset
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import rbf_kernel, pairwise_kernels
import GPy
import GPy.util as gutil

# %matplotlib inline 
plt.close('all')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
Ifsavefig =  False
Ifsavedata = False

# %% [markdown]
# The network generating

# %%
size = 40
color_map = {0:'r', 1:'c', 2:'y'}
#center = np.zeros(2)
#center[1] = 1
center = None

n = 40
m = 0
G0= nx.barbell_graph(n,m) 
#generate the bar-bell graph, which consists of two fully connected component and a path connecting them 

label0 = np.zeros([2*n,1])
label0[n:2*n] = np.ones([n,1])
#### labeling of the cluster
for node in G0.nodes():
    G0.node[node]['category'] = int(label0[node,0])

# %%
####generate the eigenspace of normalized Laplacian
k = 3
nnodes = nx.adjacency_matrix(G0).shape[0]

ncv=max(2*k+1,int(np.sqrt(nnodes)))

eigenvalues,eigenvectors= sp.sparse.linalg.eigsh(nx.laplacian_matrix(G0).asfptype(), k=k, \
                                                which='SM', return_eigenvectors = True, ncv=ncv)
index=np.argsort(eigenvalues)[1:k] # 0 index is zero eigenvalue    
pos_spectral_mat = np.real(eigenvectors[:,index]) #pos_spectral_mat is the spectral location of the nodes
pos_spectral_df = pd.DataFrame(data=pos_spectral_mat, columns=['PX','PY'], dtype=float)
pos_spectral_df['LABEL'] = label0

# %% [markdown]
# The node attributes generating

# %%
T= 2
c = 2*np.pi*0.8
data_np = np.zeros([nnodes, T])
column_name = []
for t in np.arange(1,T+1):
    temp1 = np.multiply(pos_spectral_df['PX'].apply(lambda x: np.exp(-c*t*x)).values, \
                          pos_spectral_df['PY'].apply(lambda y: np.cos(c*t*y)).values)
    data_np[:,t-1] = temp1
    if t == 1:
        column_name = str(t-1)+"_cos"
    else:    
        column_name = [column_name, str(t-1)+"_cos"]

sigma = 0.1        
data_np = np.add(data_np, sigma*np.random.randn(nnodes, T))    
data_df = pd.DataFrame(data=data_np, columns=column_name, dtype=float)
data_df['LABEL'] = label0

# %%
if Ifsavedata:
    nx.write_adjlist(G0, "../data/experiment_03_31_2016.adjlist",delimiter=',')
    nx.write_edgelist(G0, "../data/experiment_03_31_2016.edgelist")

    np.savez("../data/experiment_data_03_31_2016.npz", pos_spectral_mat, data_np, label0)
    data_df.to_csv("../data/experiment_X_03_31_2016.csv", index_label= 'ID')
    pos_spectral_df.to_csv("../data/experiment_U_03_31_2016.csv", index_label= 'ID')

# %% [markdown]
# if Ifsavedata:
#     nx.write_adjlist(G0, "../data/experiment_bad_03_31_2016.adjlist",delimiter=',')
#     nx.write_edgelist(G0, "../data/experiment_bad_03_31_2016.edgelist")
#
#     np.savez("../data/experiment_bad_data_03_31_2016.npz", pos_spectral_mat, data_np, label0)
#     data_df.to_csv("../data/experiment_bad_X_03_31_2016.csv", index_label= 'ID')
#     pos_spectral_df.to_csv("../data/experiment_bad_U_03_31_2016.csv", index_label= 'ID')

# %%
X= data_np
U= pos_spectral_mat
nsample, ndim = X.shape
_ , ndim_latent = U.shape

kern = GPy.kern.RBF(2)

# %% [markdown]
# Import from the G2PnetSolver_v1.py

# %%
import sys
import os
dirorg = os.path.dirname(os.getcwd())
sys.path.insert(0, dirorg+"/src/")

# %%
import G2PnetSolver_v3 #G2PnetSolver_v2
#from imp import reload
#reload(G2PnetSolver_v2)

# %%
from G2PnetSolver_v3 import  G2PnetSolver as Solver
from G2PnetSolver_v3 import  Grassmann_update

# %%
choice = "near"

# %%
np.random.seed(seed=121)

if choice == "random":
    print("Random Initialization")
    Temp = np.random.rand(nsample, nsample)
    Temp_sym = (Temp + Temp.T) / 2 
    _, U_temp = np.linalg.eig(Temp_sym)
    U_test = U_temp[:, np.arange(ndim_latent)]
    U0 = U_test
elif choice == "near":
    print("Initialization in neigborhood.")
    U0 = U

eta0 = 1
G_temp = np.random.rand(nsample, ndim_latent)
H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
U_init = Grassmann_update(U0, H_temp, eta=eta0)
# Out:
# Near optimal.

# %% [markdown]
# ### Compute the gradient $\frac{dL}{dU}$
# The loss function is given as negative log-likelihood of Gaussian process
#
# \begin{align}
# \mathcal{L}(\beta, \sigma, \mathbf{U}) &= \frac{pN}{2}\log(2\pi)+\frac{p}{2}\log\det(\mathbf{K}_{\beta, \sigma, \mathbf{U}})+\frac{1}{2}\text{tr}\left(\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{−1}\mathbf{X}\mathbf{X}^T\right) + \frac{\lambda}{2} \|\mathbf{U}\mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2}
# \end{align}
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{K}$
# \begin{align}
# \mathbf{T}&= 2\mathbf{T}_{0} - \text{diag}\left(\mathbf{T}_{0}\right),\\
# \mathbf{T}_{0} &= \frac{1}{2}\left(\mathbf{I} - \mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}\mathbf{X}\mathbf{X}^T/p \right)\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}, \\
# \mathbf{K}_{r,s} &= K_{\sigma}\left(\mathbf{U}_{r,:} , \mathbf{U}_{s,:}\right) + \beta \delta_{r,s}
# \end{align}
#
# For rbf kernel,
# \begin{align}
# \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{Z}}}{\partial \mathbf{U}_{m,j}}
# &= -\frac{l^{2}}{\sigma^2} \exp\left(-\frac{1}{2\sigma^2} \|\mathbf{U}_{m} -  \mathbf{U}_{n}\|^{2} \right)\left[2\left( \mathbf{U}_{m,i} - \mathbf{U}_{n,j} \right)\right]
# \end{align}
#
# The differential of the second norm term
# \begin{align}
# \frac{d}{d\mathbf{U}}\frac{1}{2}\|\mathbf{U} \mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2} &=
# \frac{d}{d\mathbf{U}}\frac{1}{2}\left[\text{tr}\left(\mathbf{U} \mathbf{U}^{T}\right) - \text{tr}\left(\mathbf{U}_{L}\mathbf{U}_{L}^{T}\mathbf{U}\mathbf{U}^{T}\right)\right]\\
# &= \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U}
# \end{align}
#
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{U}$
# \begin{align}
# \frac{\partial\mathcal{L}}{\partial\mathbf{U}} &= \left[\text{tr}\left( \mathbf{T} \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{U}}}{\partial \mathbf{U}_{m,j}} \right)\right]_{m,j} + \lambda \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U},
# \end{align}

# %%
if Ifsavedata:
    U_columns = [str(i) for i in np.arange(ndim_latent)]
    U_df = pd.DataFrame(data = U_init, columns=U_columns, dtype= float)
    if choice == "random":
        U_df['RANDOM'] = np.ones([nsample, 1])
    elif choice == "near":
        U_df['RANDOM'] = np.zeros([nsample, 1])
    
    U_df.to_csv("../data/U_init_03_31_16.csv")
    #U_df.to_csv("../data/U_init_bad_03_31_16.csv")

# %%
add_reg = True
lambda_array = np.array([10, 1, 0.001])
eta = 0.001
max_iters = 800
kern_array = [GPy.kern.RBF(2) for i in np.arange(len(lambda_array))]
kern_grass_array = [GPy.kern.RBF(2) for i in np.arange(len(lambda_array))]
solver_array = []
hist_nll_eu_array = []
hist_nll_grass_array = []

# %%
trail = 1

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 30.0)
plt.style.use('seaborn-white')

for i, lambda_var in enumerate(lambda_array): 
    ax = plt.subplot(5,1,i+1)
    solver = Solver(X=X, U=U_init, kernel=kern_array[i], U_ref= U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_eu, hist_eta, hist_kern_eu = solver.optimize(max_iters = max_iters)
    solver_array.append(solver)
    hist_nll_eu_array.append(hist_nll_eu)
    
    solver2 = Solver(X=X, U=U_init, kernel=kern_grass_array[i], U_ref = U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_grass, hist_eta, hist_kern_grass = solver2.optimize(max_iters = max_iters, optimizor = "grad_descent_grass")
    
    solver_array.append(solver2)
    hist_nll_grass_array.append(hist_nll_grass)
        
    # %xdel solver
    # %xdel solver2
# Out:
# kernel initialization ...
# negative log-likelihood compute
# [step   0] neg-log-likelihood -1088.061977 stepsize 0.000
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -1097.628539 stepsize 0.000
# [step   2] neg-log-likelihood -1100.116045 stepsize 0.000
# [step   3] neg-log-likelihood -1103.460097 stepsize 0.000
# [step   4] neg-log-likelihood -1109.971325 stepsize 0.000
# [step   5] neg-log-likelihood -1108.257645 stepsize 0.000
# [step   6] neg-log-likelihood -1108.047677 stepsize 0.000
# [step   7] neg-log-likelihood -1108.960913 stepsize 0.000
# [step   8] neg-log-likelihood -1105.720249 stepsize 0.000
# [step   9] neg-log-likelihood -1098.562050 stepsize 0.000
# [step  10] neg-log-likelihood -1093.407810 stepsize 0.000
# [step  11] neg-log-likelihood -1084.918548 stepsize 0.000
# [step  12] neg-log-likelihood -1080.557409 stepsize 0.000
# [step  13] neg-log-likelihood -1058.169991 stepsize 0.000
# [step  14] neg-log-likelihood -1038.344917 stepsize 0.000
# [step  15] neg-log-likelihood -1011.906116 stepsize 0.000
# [step  16] neg-log-likelihood -975.826530 stepsize 0.000
# [step  17] neg-log-likelihood -927.867642 stepsize 0.000
# [step  18] neg-log-likelihood -865.774254 stepsize 0.000
# [step  19] neg-log-likelihood -786.631490 stepsize 0.000
# [step  20] neg-log-likelihood -706.818034 stepsize 0.000
# [step  21] neg-log-likelihood -658.919276 stepsize 0.000
# [step  22] neg-log-likelihood -648.758730 stepsize 0.000
# [step  23] neg-log-likelihood -657.119434 stepsize 0.000
# [step  24] neg-log-likelihood -672.886135 stepsize 0.000
# [step  25] neg-log-likelihood -689.127623 stepsize 0.000
# [step  26] neg-log-likelihood -698.461596 stepsize 0.000
# [step  27] neg-log-likelihood -706.676564 stepsize 0.000
# [step  28] neg-log-likelihood -715.908318 stepsize 0.000
# [step  29] neg-log-likelihood -724.657785 stepsize 0.000
# [step  30] neg-log-likelihood -734.614553 stepsize 0.000
# [step  31] neg-log-likelihood -746.563460 stepsize 0.000
# [step  32] neg-log-likelihood -755.541963 stepsize 0.000
# [step  33] neg-log-likelihood -762.208738 stepsize 0.000
# [step  34] neg-log-likelihood -772.823810 stepsize 0.000
# [step  35] neg-log-likelihood -785.059982 stepsize 0.000
# [step  36] neg-log-likelihood -797.725459 stepsize 0.000
# [step  37] neg-log-likelihood -810.408243 stepsize 0.000
# [step  38] neg-log-likelihood -822.692255 stepsize 0.000
# [step  39] neg-log-likelihood -834.016157 stepsize 0.000
# [step  40] neg-log-likelihood -844.850583 stepsize 0.000
# [step  41] neg-log-likelihood -856.136917 stepsize 0.000
# [step  42] neg-log-likelihood -860.573248 stepsize 0.000
# [step  43] neg-log-likelihood -866.609117 stepsize 0.000
# [step  44] neg-log-likelihood -873.166818 stepsize 0.000
# [step  45] neg-log-likelihood -880.093934 stepsize 0.000
# [step  46] neg-log-likelihood -887.983479 stepsize 0.000
# [step  47] neg-log-likelihood -896.336477 stepsize 0.000
# [step  48] neg-log-likelihood -905.070170 stepsize 0.000
# [step  49] neg-log-likelihood -915.119548 stepsize 0.000
# [step  50] neg-log-likelihood -924.901389 stepsize 0.000
# [step  51] neg-log-likelihood -934.766058 stepsize 0.000
# [step  52] neg-log-likelihood -945.107386 stepsize 0.000
# [step  53] neg-log-likelihood -955.109919 stepsize 0.000
# [step  54] neg-log-likelihood -962.809092 stepsize 0.000
# [step  55] neg-log-likelihood -970.892541 stepsize 0.000
# [step  56] neg-log-likelihood -980.240274 stepsize 0.000
# [step  57] neg-log-likelihood -988.787665 stepsize 0.000
# [step  58] neg-log-likelihood -999.120058 stepsize 0.000
# [step  59] neg-log-likelihood -1010.736978 stepsize 0.000
# [step  60] neg-log-likelihood -1021.764279 stepsize 0.000
# [step  61] neg-log-likelihood -1030.010449 stepsize 0.000
# [step  62] neg-log-likelihood -1039.050432 stepsize 0.000
# [step  63] neg-log-likelihood -1044.885399 stepsize 0.000
# [step  64] neg-log-likelihood -1055.691497 stepsize 0.000
# [step  65] neg-log-likelihood -1070.030682 stepsize 0.000
# [step  66] neg-log-likelihood -1071.879012 stepsize 0.000
# [step  67] neg-log-likelihood -1081.030803 stepsize 0.000
# [step  68] neg-log-likelihood -1084.769417 stepsize 0.000
# [step  69] neg-log-likelihood -1091.809989 stepsize 0.000
# [step  70] neg-log-likelihood -1100.724609 stepsize 0.000
# [step  71] neg-log-likelihood -1107.576688 stepsize 0.000
# [step  72] neg-log-likelihood -1114.066777 stepsize 0.000
# [step  73] neg-log-likelihood -1118.930533 stepsize 0.000
# [step  74] neg-log-likelihood -1125.199681 stepsize 0.000
# [step  75] neg-log-likelihood -1129.840022 stepsize 0.000
# [step  76] neg-log-likelihood -1134.518483 stepsize 0.000
# [step  77] neg-log-likelihood -1137.867807 stepsize 0.000
# [step  78] neg-log-likelihood -1145.389322 stepsize 0.000
# [step  79] neg-log-likelihood -1148.199691 stepsize 0.000
# [step  80] neg-log-likelihood -1154.507806 stepsize 0.000
# [step  81] neg-log-likelihood -1155.042343 stepsize 0.000
# [step  82] neg-log-likelihood -1160.548839 stepsize 0.000
# [step  83] neg-log-likelihood -1162.421691 stepsize 0.000
# [step  84] neg-log-likelihood -1169.072703 stepsize 0.000
# [step  85] neg-log-likelihood -1169.747399 stepsize 0.000
# [step  86] neg-log-likelihood -1172.892430 stepsize 0.000
# [step  87] neg-log-likelihood -1180.115775 stepsize 0.000
# [step  88] neg-log-likelihood -1178.815642 stepsize 0.000
# [step  89] neg-log-likelihood -1178.435439 stepsize 0.000
# [step  90] neg-log-likelihood -1182.352991 stepsize 0.000
# [step  91] neg-log-likelihood -1183.242289 stepsize 0.000
# [step  92] neg-log-likelihood -1186.551035 stepsize 0.000
# [step  93] neg-log-likelihood -1186.745673 stepsize 0.000
# [step  94] neg-log-likelihood -1186.189155 stepsize 0.000
# [step  95] neg-log-likelihood -1188.864858 stepsize 0.000
# [step  96] neg-log-likelihood -1190.801174 stepsize 0.000
# [step  97] neg-log-likelihood -1190.190790 stepsize 0.000
# [step  98] neg-log-likelihood -1192.276694 stepsize 0.000
# [step  99] neg-log-likelihood -1192.661435 stepsize 0.000
# [step 100] neg-log-likelihood -1194.939290 stepsize 0.000
# [step 101] neg-log-likelihood -1194.845104 stepsize 0.000
# [step 102] neg-log-likelihood -1195.603899 stepsize 0.000
# [step 103] neg-log-likelihood -1192.635186 stepsize 0.000
# [step 104] neg-log-likelihood -1190.576098 stepsize 0.000
# [step 105] neg-log-likelihood -1189.865549 stepsize 0.000
# [step 106] neg-log-likelihood -1190.806736 stepsize 0.000
# [step 107] neg-log-likelihood -1190.160352 stepsize 0.000
# [step 108] neg-log-likelihood -1186.272939 stepsize 0.000
# [step 109] neg-log-likelihood -1187.095509 stepsize 0.000
# [step 110] neg-log-likelihood -1182.132276 stepsize 0.000
# [step 111] neg-log-likelihood -1182.944366 stepsize 0.000
# [step 112] neg-log-likelihood -1179.304656 stepsize 0.000
# [step 113] neg-log-likelihood -1180.055867 stepsize 0.000
# [step 114] neg-log-likelihood -1176.892428 stepsize 0.000
# [step 115] neg-log-likelihood -1177.269477 stepsize 0.000
# [step 116] neg-log-likelihood -1172.237732 stepsize 0.000
# [step 117] neg-log-likelihood -1172.678099 stepsize 0.000
# [step 118] neg-log-likelihood -1170.868367 stepsize 0.000
# [step 119] neg-log-likelihood -1169.907809 stepsize 0.000
# [step 120] neg-log-likelihood -1167.843145 stepsize 0.000
# [step 121] neg-log-likelihood -1168.661247 stepsize 0.000
# [step 122] neg-log-likelihood -1171.044546 stepsize 0.000
# [step 123] neg-log-likelihood -1165.964360 stepsize 0.000
# [step 124] neg-log-likelihood -1165.311809 stepsize 0.000
# [step 125] neg-log-likelihood -1165.779706 stepsize 0.000
# [step 126] neg-log-likelihood -1162.442071 stepsize 0.000
# [step 127] neg-log-likelihood -1162.939541 stepsize 0.000
# [step 128] neg-log-likelihood -1158.177380 stepsize 0.000
# [step 129] neg-log-likelihood -1159.811270 stepsize 0.000
# [step 130] neg-log-likelihood -1158.916589 stepsize 0.000
# [step 131] neg-log-likelihood -1158.783849 stepsize 0.000
# [step 132] neg-log-likelihood -1159.947444 stepsize 0.000
# [step 133] neg-log-likelihood -1159.398149 stepsize 0.000
# [step 134] neg-log-likelihood -1159.001098 stepsize 0.000
# [step 135] neg-log-likelihood -1158.924102 stepsize 0.000
# [step 136] neg-log-likelihood -1159.922987 stepsize 0.000
# [step 137] neg-log-likelihood -1155.912993 stepsize 0.000
# [step 138] neg-log-likelihood -1158.093938 stepsize 0.000
# [step 139] neg-log-likelihood -1155.960907 stepsize 0.000
# [step 140] neg-log-likelihood -1151.687511 stepsize 0.000
# [step 141] neg-log-likelihood -1150.852976 stepsize 0.000
# [step 142] neg-log-likelihood -1151.577722 stepsize 0.000
# [step 143] neg-log-likelihood -1145.015632 stepsize 0.000
# [step 144] neg-log-likelihood -1143.865715 stepsize 0.000
# [step 145] neg-log-likelihood -1145.593211 stepsize 0.000
# [step 146] neg-log-likelihood -1140.968517 stepsize 0.000
# [step 147] neg-log-likelihood -1139.221626 stepsize 0.000
# [step 148] neg-log-likelihood -1140.525198 stepsize 0.000
# [step 149] neg-log-likelihood -1141.323774 stepsize 0.000
# [step 150] neg-log-likelihood -1137.408418 stepsize 0.000
# [step 151] neg-log-likelihood -1138.173675 stepsize 0.000
# [step 152] neg-log-likelihood -1137.304488 stepsize 0.000
# [step 153] neg-log-likelihood -1129.272372 stepsize 0.000
# [step 154] neg-log-likelihood -1124.868502 stepsize 0.000
# [step 155] neg-log-likelihood -1121.496877 stepsize 0.000
# [step 156] neg-log-likelihood -1117.013563 stepsize 0.000
# [step 157] neg-log-likelihood -1111.269118 stepsize 0.000
# [step 158] neg-log-likelihood -1110.102292 stepsize 0.000
# [step 159] neg-log-likelihood -1101.185924 stepsize 0.000
# [step 160] neg-log-likelihood -1097.416027 stepsize 0.000
# [step 161] neg-log-likelihood -1096.119390 stepsize 0.000
# [step 162] neg-log-likelihood -1085.970670 stepsize 0.000
# [step 163] neg-log-likelihood -1081.164790 stepsize 0.000
# [step 164] neg-log-likelihood -1081.375354 stepsize 0.000
# [step 165] neg-log-likelihood -1075.715947 stepsize 0.000
# [step 166] neg-log-likelihood -1075.690390 stepsize 0.000
# [step 167] neg-log-likelihood -1073.265415 stepsize 0.000
# [step 168] neg-log-likelihood -1073.239411 stepsize 0.000
# [step 169] neg-log-likelihood -1069.627864 stepsize 0.000
# [step 170] neg-log-likelihood -1062.960126 stepsize 0.000
# [step 171] neg-log-likelihood -1063.599056 stepsize 0.000
# [step 172] neg-log-likelihood -1060.429703 stepsize 0.000
# [step 173] neg-log-likelihood -1058.416271 stepsize 0.000
# [step 174] neg-log-likelihood -1054.900153 stepsize 0.000
# [step 175] neg-log-likelihood -1055.689800 stepsize 0.000
# [step 176] neg-log-likelihood -1053.479390 stepsize 0.000
# [step 177] neg-log-likelihood -1052.183826 stepsize 0.000
# [step 178] neg-log-likelihood -1049.596490 stepsize 0.000
# [step 179] neg-log-likelihood -1046.566132 stepsize 0.000
# [step 180] neg-log-likelihood -1048.826788 stepsize 0.000
# [step 181] neg-log-likelihood -1045.332789 stepsize 0.000
# [step 182] neg-log-likelihood -1043.604053 stepsize 0.000
# [step 183] neg-log-likelihood -1043.364903 stepsize 0.000
# [step 184] neg-log-likelihood -1041.776015 stepsize 0.000
# [step 185] neg-log-likelihood -1043.810328 stepsize 0.000
# [step 186] neg-log-likelihood -1041.336426 stepsize 0.000
# [step 187] neg-log-likelihood -1043.665644 stepsize 0.000
# [step 188] neg-log-likelihood -1035.228682 stepsize 0.000
# [step 189] neg-log-likelihood -1034.284415 stepsize 0.000
# [step 190] neg-log-likelihood -1031.443028 stepsize 0.000
# [step 191] neg-log-likelihood -1033.614338 stepsize 0.000
# [step 192] neg-log-likelihood -1035.263800 stepsize 0.000
# [step 193] neg-log-likelihood -1029.306545 stepsize 0.000
# [step 194] neg-log-likelihood -1026.332009 stepsize 0.000
# [step 195] neg-log-likelihood -1027.490227 stepsize 0.000
# [step 196] neg-log-likelihood -1026.112814 stepsize 0.000
# [step 197] neg-log-likelihood -1024.156145 stepsize 0.000
# [step 198] neg-log-likelihood -1020.129396 stepsize 0.000
# [step 199] neg-log-likelihood -1019.216420 stepsize 0.000
# [step 200] neg-log-likelihood -1019.644205 stepsize 0.000
# [step 201] neg-log-likelihood -1012.072408 stepsize 0.000
# [step 202] neg-log-likelihood -1010.194621 stepsize 0.000
# [step 203] neg-log-likelihood -1009.299003 stepsize 0.000
# [step 204] neg-log-likelihood -1003.669408 stepsize 0.000
# [step 205] neg-log-likelihood -1001.992361 stepsize 0.000
# [step 206] neg-log-likelihood -996.127239 stepsize 0.000
# [step 207] neg-log-likelihood -988.598731 stepsize 0.000
# [step 208] neg-log-likelihood -988.060396 stepsize 0.000
# [step 209] neg-log-likelihood -977.438975 stepsize 0.000
# [step 210] neg-log-likelihood -976.812988 stepsize 0.000
# [step 211] neg-log-likelihood -970.192830 stepsize 0.000
# [step 212] neg-log-likelihood -960.824984 stepsize 0.000
# [step 213] neg-log-likelihood -959.697673 stepsize 0.000
# [step 214] neg-log-likelihood -947.226663 stepsize 0.000
# [step 215] neg-log-likelihood -943.862599 stepsize 0.000
# [step 216] neg-log-likelihood -940.189154 stepsize 0.000
# [step 217] neg-log-likelihood -934.508378 stepsize 0.000
# [step 218] neg-log-likelihood -926.228703 stepsize 0.000
# [step 219] neg-log-likelihood -921.022959 stepsize 0.000
# [step 220] neg-log-likelihood -917.546729 stepsize 0.000
# [step 221] neg-log-likelihood -911.733523 stepsize 0.000
# [step 222] neg-log-likelihood -904.518913 stepsize 0.000
# [step 223] neg-log-likelihood -895.679574 stepsize 0.000
# [step 224] neg-log-likelihood -891.081840 stepsize 0.000
# [step 225] neg-log-likelihood -884.758163 stepsize 0.000
# [step 226] neg-log-likelihood -879.689071 stepsize 0.000
# [step 227] neg-log-likelihood -874.212890 stepsize 0.000
# [step 228] neg-log-likelihood -869.038859 stepsize 0.000
# [step 229] neg-log-likelihood -866.512555 stepsize 0.000
# [step 230] neg-log-likelihood -863.753403 stepsize 0.000
# [step 231] neg-log-likelihood -861.808613 stepsize 0.000
# [step 232] neg-log-likelihood -862.058410 stepsize 0.000
# [step 233] neg-log-likelihood -865.016391 stepsize 0.000
# [step 234] neg-log-likelihood -872.911370 stepsize 0.000
# [step 235] neg-log-likelihood -882.432422 stepsize 0.000
# [step 236] neg-log-likelihood -898.184627 stepsize 0.000
# [step 237] neg-log-likelihood -920.606090 stepsize 0.000
# [step 238] neg-log-likelihood -943.757469 stepsize 0.000
# [step 239] neg-log-likelihood -959.326944 stepsize 0.000
# [step 240] neg-log-likelihood -970.555716 stepsize 0.000
# [step 241] neg-log-likelihood -984.150601 stepsize 0.000
# [step 242] neg-log-likelihood -991.287678 stepsize 0.000
# [step 243] neg-log-likelihood -995.787097 stepsize 0.000
# [step 244] neg-log-likelihood -1003.974311 stepsize 0.000
# [step 245] neg-log-likelihood -1009.426332 stepsize 0.000
# [step 246] neg-log-likelihood -1012.822724 stepsize 0.000
# [step 247] neg-log-likelihood -1016.426665 stepsize 0.000
# [step 248] neg-log-likelihood -1019.135133 stepsize 0.000
# [step 249] neg-log-likelihood -1022.387346 stepsize 0.000
# [step 250] neg-log-likelihood -1024.446319 stepsize 0.000
# [step 251] neg-log-likelihood -1023.886573 stepsize 0.000
# [step 252] neg-log-likelihood -1026.075757 stepsize 0.000
# [step 253] neg-log-likelihood -1030.999145 stepsize 0.000
# [step 254] neg-log-likelihood -1031.151468 stepsize 0.000
# [step 255] neg-log-likelihood -1034.806234 stepsize 0.000
# [step 256] neg-log-likelihood -1038.483027 stepsize 0.000
# [step 257] neg-log-likelihood -1038.314669 stepsize 0.000
# [step 258] neg-log-likelihood -1044.520581 stepsize 0.000
# [step 259] neg-log-likelihood -1046.228380 stepsize 0.000
# [step 260] neg-log-likelihood -1049.077745 stepsize 0.000
# [step 261] neg-log-likelihood -1050.902665 stepsize 0.000
# [step 262] neg-log-likelihood -1052.663720 stepsize 0.000
# [step 263] neg-log-likelihood -1058.403090 stepsize 0.000
# [step 264] neg-log-likelihood -1060.456058 stepsize 0.000
# [step 265] neg-log-likelihood -1063.134645 stepsize 0.000
# [step 266] neg-log-likelihood -1068.641516 stepsize 0.000
# [step 267] neg-log-likelihood -1071.857100 stepsize 0.000
# [step 268] neg-log-likelihood -1073.408213 stepsize 0.000
# [step 269] neg-log-likelihood -1074.448499 stepsize 0.000
# [step 270] neg-log-likelihood -1079.055896 stepsize 0.000
# [step 271] neg-log-likelihood -1083.408857 stepsize 0.000
# [step 272] neg-log-likelihood -1088.563376 stepsize 0.000
# [step 273] neg-log-likelihood -1088.609865 stepsize 0.000
# [step 274] neg-log-likelihood -1095.552423 stepsize 0.000
# [step 275] neg-log-likelihood -1093.834427 stepsize 0.000
# [step 276] neg-log-likelihood -1101.002873 stepsize 0.000
# [step 277] neg-log-likelihood -1105.751215 stepsize 0.000
# [step 278] neg-log-likelihood -1108.313649 stepsize 0.000
# [step 279] neg-log-likelihood -1110.059086 stepsize 0.000
# [step 280] neg-log-likelihood -1111.151481 stepsize 0.000
# [step 281] neg-log-likelihood -1116.399518 stepsize 0.000
# [step 282] neg-log-likelihood -1119.089472 stepsize 0.000
# [step 283] neg-log-likelihood -1124.513131 stepsize 0.000
# [step 284] neg-log-likelihood -1126.760959 stepsize 0.000
# [step 285] neg-log-likelihood -1125.362162 stepsize 0.000
# [step 286] neg-log-likelihood -1132.243608 stepsize 0.000
# [step 287] neg-log-likelihood -1131.218006 stepsize 0.000
# [step 288] neg-log-likelihood -1134.486306 stepsize 0.000
# [step 289] neg-log-likelihood -1138.257361 stepsize 0.000
# [step 290] neg-log-likelihood -1143.137377 stepsize 0.000
# [step 291] neg-log-likelihood -1141.738204 stepsize 0.000
# [step 292] neg-log-likelihood -1145.084352 stepsize 0.000
# [step 293] neg-log-likelihood -1146.623173 stepsize 0.000
# [step 294] neg-log-likelihood -1149.164255 stepsize 0.000
# [step 295] neg-log-likelihood -1151.579924 stepsize 0.000
# [step 296] neg-log-likelihood -1151.970537 stepsize 0.000
# [step 297] neg-log-likelihood -1155.061844 stepsize 0.000
# [step 298] neg-log-likelihood -1153.899202 stepsize 0.000
# [step 299] neg-log-likelihood -1157.696591 stepsize 0.000
# [step 300] neg-log-likelihood -1160.197182 stepsize 0.000
# [step 301] neg-log-likelihood -1159.196612 stepsize 0.000
# [step 302] neg-log-likelihood -1165.744550 stepsize 0.000
# [step 303] neg-log-likelihood -1161.674180 stepsize 0.000
# [step 304] neg-log-likelihood -1162.018056 stepsize 0.000
# [step 305] neg-log-likelihood -1162.178093 stepsize 0.000
# [step 306] neg-log-likelihood -1165.961165 stepsize 0.000
# [step 307] neg-log-likelihood -1165.215727 stepsize 0.000
# [step 308] neg-log-likelihood -1168.437923 stepsize 0.000
# [step 309] neg-log-likelihood -1167.626362 stepsize 0.000
# [step 310] neg-log-likelihood -1167.380763 stepsize 0.000
# [step 311] neg-log-likelihood -1173.954915 stepsize 0.000
# [step 312] neg-log-likelihood -1168.706272 stepsize 0.000
# [step 313] neg-log-likelihood -1171.059160 stepsize 0.000
# [step 314] neg-log-likelihood -1173.423746 stepsize 0.000
# [step 315] neg-log-likelihood -1175.121901 stepsize 0.000
# [step 316] neg-log-likelihood -1174.166063 stepsize 0.000
# [step 317] neg-log-likelihood -1179.388556 stepsize 0.000
# [step 318] neg-log-likelihood -1176.889972 stepsize 0.000
# [step 319] neg-log-likelihood -1177.668594 stepsize 0.000
# [step 320] neg-log-likelihood -1178.528011 stepsize 0.000
# [step 321] neg-log-likelihood -1179.880660 stepsize 0.000
# [step 322] neg-log-likelihood -1181.162258 stepsize 0.000
# [step 323] neg-log-likelihood -1178.891345 stepsize 0.000
# [step 324] neg-log-likelihood -1181.190416 stepsize 0.000
# [step 325] neg-log-likelihood -1181.510015 stepsize 0.000
# [step 326] neg-log-likelihood -1185.109993 stepsize 0.000
# [step 327] neg-log-likelihood -1184.586880 stepsize 0.000
# [step 328] neg-log-likelihood -1184.947297 stepsize 0.000
# [step 329] neg-log-likelihood -1183.873632 stepsize 0.000
# [step 330] neg-log-likelihood -1184.839428 stepsize 0.000
# [step 331] neg-log-likelihood -1190.202852 stepsize 0.000
# [step 332] neg-log-likelihood -1189.532745 stepsize 0.000
# [step 333] neg-log-likelihood -1186.255139 stepsize 0.000
# [step 334] neg-log-likelihood -1186.648130 stepsize 0.000
# [step 335] neg-log-likelihood -1186.746685 stepsize 0.000
# [step 336] neg-log-likelihood -1192.648961 stepsize 0.000
# [step 337] neg-log-likelihood -1190.424471 stepsize 0.000
# [step 338] neg-log-likelihood -1190.349046 stepsize 0.000
# [step 339] neg-log-likelihood -1190.961532 stepsize 0.000
# [step 340] neg-log-likelihood -1192.840182 stepsize 0.000
# [step 341] neg-log-likelihood -1194.970932 stepsize 0.000
# [step 342] neg-log-likelihood -1190.328482 stepsize 0.000
# [step 343] neg-log-likelihood -1192.622499 stepsize 0.000
# [step 344] neg-log-likelihood -1193.306800 stepsize 0.000
# [step 345] neg-log-likelihood -1194.976919 stepsize 0.000
# [step 346] neg-log-likelihood -1195.890176 stepsize 0.000
# [step 347] neg-log-likelihood -1196.079560 stepsize 0.000
# [step 348] neg-log-likelihood -1191.530370 stepsize 0.000
# [step 349] neg-log-likelihood -1196.063666 stepsize 0.000
# [step 350] neg-log-likelihood -1196.774660 stepsize 0.000
# [step 351] neg-log-likelihood -1193.995651 stepsize 0.000
# [step 352] neg-log-likelihood -1198.869148 stepsize 0.000
# [step 353] neg-log-likelihood -1197.229966 stepsize 0.000
# [step 354] neg-log-likelihood -1194.952589 stepsize 0.000
# [step 355] neg-log-likelihood -1206.333698 stepsize 0.000
# [step 356] neg-log-likelihood -1200.188666 stepsize 0.000
# [step 357] neg-log-likelihood -1196.070542 stepsize 0.000
# [step 358] neg-log-likelihood -1201.494623 stepsize 0.000
# [step 359] neg-log-likelihood -1198.307035 stepsize 0.000
# [step 360] neg-log-likelihood -1201.483588 stepsize 0.000
# [step 361] neg-log-likelihood -1201.050311 stepsize 0.000
# [step 362] neg-log-likelihood -1204.180338 stepsize 0.000
# [step 363] neg-log-likelihood -1202.051772 stepsize 0.000
# [step 364] neg-log-likelihood -1202.442544 stepsize 0.000
# [step 365] neg-log-likelihood -1199.372134 stepsize 0.000
# [step 366] neg-log-likelihood -1197.036035 stepsize 0.000
# [step 367] neg-log-likelihood -1197.570451 stepsize 0.000
# [step 368] neg-log-likelihood -1198.602260 stepsize 0.000
# [step 369] neg-log-likelihood -1200.591969 stepsize 0.000
# [step 370] neg-log-likelihood -1201.305791 stepsize 0.000
# [step 371] neg-log-likelihood -1200.244695 stepsize 0.000
# [step 372] neg-log-likelihood -1199.783054 stepsize 0.000
# [step 373] neg-log-likelihood -1203.386511 stepsize 0.000
# [step 374] neg-log-likelihood -1200.784730 stepsize 0.000
# [step 375] neg-log-likelihood -1203.356118 stepsize 0.000
# [step 376] neg-log-likelihood -1200.302547 stepsize 0.000
# [step 377] neg-log-likelihood -1200.716957 stepsize 0.000
# [step 378] neg-log-likelihood -1204.474753 stepsize 0.000
# [step 379] neg-log-likelihood -1201.411103 stepsize 0.000
# [step 380] neg-log-likelihood -1205.019001 stepsize 0.000
# [step 381] neg-log-likelihood -1205.687272 stepsize 0.000
# [step 382] neg-log-likelihood -1199.100799 stepsize 0.000
# [step 383] neg-log-likelihood -1198.331056 stepsize 0.000
# [step 384] neg-log-likelihood -1201.554421 stepsize 0.000
# [step 385] neg-log-likelihood -1201.665027 stepsize 0.000
# [step 386] neg-log-likelihood -1201.222833 stepsize 0.000
# [step 387] neg-log-likelihood -1201.073469 stepsize 0.000
# [step 388] neg-log-likelihood -1198.885473 stepsize 0.000
# [step 389] neg-log-likelihood -1202.399075 stepsize 0.000
# [step 390] neg-log-likelihood -1199.856824 stepsize 0.000
# [step 391] neg-log-likelihood -1201.439216 stepsize 0.000
# [step 392] neg-log-likelihood -1202.770332 stepsize 0.000
# [step 393] neg-log-likelihood -1198.283066 stepsize 0.000
# [step 394] neg-log-likelihood -1204.796497 stepsize 0.000
# [step 395] neg-log-likelihood -1198.104049 stepsize 0.000
# [step 396] neg-log-likelihood -1198.728403 stepsize 0.000
# [step 397] neg-log-likelihood -1202.388813 stepsize 0.000
# [step 398] neg-log-likelihood -1195.934449 stepsize 0.000
# [step 399] neg-log-likelihood -1201.162984 stepsize 0.000
# [step 400] neg-log-likelihood -1202.524295 stepsize 0.000
# [step 401] neg-log-likelihood -1202.027597 stepsize 0.000
# [step 402] neg-log-likelihood -1197.074412 stepsize 0.000
# [step 403] neg-log-likelihood -1199.759645 stepsize 0.000
# [step 404] neg-log-likelihood -1199.228055 stepsize 0.000
# [step 405] neg-log-likelihood -1200.096357 stepsize 0.000
# [step 406] neg-log-likelihood -1201.696422 stepsize 0.000
# [step 407] neg-log-likelihood -1195.452124 stepsize 0.000
# [step 408] neg-log-likelihood -1197.703109 stepsize 0.000
# [step 409] neg-log-likelihood -1199.694714 stepsize 0.000
# [step 410] neg-log-likelihood -1200.520453 stepsize 0.000
# [step 411] neg-log-likelihood -1197.980823 stepsize 0.000
# [step 412] neg-log-likelihood -1195.697877 stepsize 0.000
# [step 413] neg-log-likelihood -1196.389437 stepsize 0.000
# [step 414] neg-log-likelihood -1196.724663 stepsize 0.000
# [step 415] neg-log-likelihood -1197.041492 stepsize 0.000
# [step 416] neg-log-likelihood -1194.396402 stepsize 0.000
# [step 417] neg-log-likelihood -1195.365607 stepsize 0.000
# [step 418] neg-log-likelihood -1198.118630 stepsize 0.000
# [step 419] neg-log-likelihood -1196.232732 stepsize 0.000
# [step 420] neg-log-likelihood -1196.304339 stepsize 0.000
# [step 421] neg-log-likelihood -1193.035302 stepsize 0.000
# [step 422] neg-log-likelihood -1192.771636 stepsize 0.000
# [step 423] neg-log-likelihood -1191.982231 stepsize 0.000
# [step 424] neg-log-likelihood -1192.834350 stepsize 0.000
# [step 425] neg-log-likelihood -1196.470020 stepsize 0.000
# [step 426] neg-log-likelihood -1195.451805 stepsize 0.000
# [step 427] neg-log-likelihood -1193.468570 stepsize 0.000
# [step 428] neg-log-likelihood -1193.550211 stepsize 0.000
# [step 429] neg-log-likelihood -1194.709727 stepsize 0.000
# [step 430] neg-log-likelihood -1194.520767 stepsize 0.000
# [step 431] neg-log-likelihood -1195.838993 stepsize 0.000
# [step 432] neg-log-likelihood -1191.741283 stepsize 0.000
# [step 433] neg-log-likelihood -1188.588723 stepsize 0.000
# [step 434] neg-log-likelihood -1196.476413 stepsize 0.000
# [step 435] neg-log-likelihood -1194.805751 stepsize 0.000
# [step 436] neg-log-likelihood -1191.466761 stepsize 0.000
# [step 437] neg-log-likelihood -1190.616650 stepsize 0.000
# [step 438] neg-log-likelihood -1194.493932 stepsize 0.000
# [step 439] neg-log-likelihood -1191.293985 stepsize 0.000
# [step 440] neg-log-likelihood -1191.066520 stepsize 0.000
# [step 441] neg-log-likelihood -1188.466720 stepsize 0.000
# [step 442] neg-log-likelihood -1192.001707 stepsize 0.000
# [step 443] neg-log-likelihood -1191.079887 stepsize 0.000
# [step 444] neg-log-likelihood -1187.475734 stepsize 0.000
# [step 445] neg-log-likelihood -1188.058905 stepsize 0.000
# [step 446] neg-log-likelihood -1188.363987 stepsize 0.000
# [step 447] neg-log-likelihood -1191.862216 stepsize 0.000
# [step 448] neg-log-likelihood -1188.315544 stepsize 0.000
# [step 449] neg-log-likelihood -1189.955088 stepsize 0.000
# [step 450] neg-log-likelihood -1191.583650 stepsize 0.000
# [step 451] neg-log-likelihood -1190.710861 stepsize 0.000
# [step 452] neg-log-likelihood -1187.111819 stepsize 0.000
# [step 453] neg-log-likelihood -1192.818420 stepsize 0.000
# [step 454] neg-log-likelihood -1186.452697 stepsize 0.000
# [step 455] neg-log-likelihood -1192.849168 stepsize 0.000
# [step 456] neg-log-likelihood -1192.511938 stepsize 0.000
# [step 457] neg-log-likelihood -1188.801691 stepsize 0.000
# [step 458] neg-log-likelihood -1192.309225 stepsize 0.000
# [step 459] neg-log-likelihood -1188.387668 stepsize 0.000
# [step 460] neg-log-likelihood -1191.974745 stepsize 0.000
# [step 461] neg-log-likelihood -1189.067255 stepsize 0.000
# [step 462] neg-log-likelihood -1187.345916 stepsize 0.000
# [step 463] neg-log-likelihood -1187.089536 stepsize 0.000
# [step 464] neg-log-likelihood -1187.576210 stepsize 0.000
# [step 465] neg-log-likelihood -1187.738404 stepsize 0.000
# [step 466] neg-log-likelihood -1186.641553 stepsize 0.000
# [step 467] neg-log-likelihood -1188.275045 stepsize 0.000
# [step 468] neg-log-likelihood -1194.234986 stepsize 0.000
# [step 469] neg-log-likelihood -1185.652322 stepsize 0.000
# [step 470] neg-log-likelihood -1185.698755 stepsize 0.000
# [step 471] neg-log-likelihood -1189.233065 stepsize 0.000
# [step 472] neg-log-likelihood -1186.152802 stepsize 0.000
# [step 473] neg-log-likelihood -1185.506338 stepsize 0.000
# [step 474] neg-log-likelihood -1188.874215 stepsize 0.000
# [step 475] neg-log-likelihood -1186.294542 stepsize 0.000
# [step 476] neg-log-likelihood -1185.014459 stepsize 0.000
# [step 477] neg-log-likelihood -1181.826602 stepsize 0.000
# [step 478] neg-log-likelihood -1184.721073 stepsize 0.000
# [step 479] neg-log-likelihood -1186.241132 stepsize 0.000
# [step 480] neg-log-likelihood -1183.654256 stepsize 0.000
# [step 481] neg-log-likelihood -1178.503005 stepsize 0.000
# [step 482] neg-log-likelihood -1184.537435 stepsize 0.000
# [step 483] neg-log-likelihood -1182.925481 stepsize 0.000
# [step 484] neg-log-likelihood -1180.746233 stepsize 0.000
# [step 485] neg-log-likelihood -1181.975522 stepsize 0.000
# [step 486] neg-log-likelihood -1183.620282 stepsize 0.000
# [step 487] neg-log-likelihood -1181.475756 stepsize 0.000
# [step 488] neg-log-likelihood -1182.964561 stepsize 0.000
# [step 489] neg-log-likelihood -1183.239113 stepsize 0.000
# [step 490] neg-log-likelihood -1175.951945 stepsize 0.000
# [step 491] neg-log-likelihood -1175.541598 stepsize 0.000
# [step 492] neg-log-likelihood -1178.871921 stepsize 0.000
# [step 493] neg-log-likelihood -1174.425494 stepsize 0.000
# [step 494] neg-log-likelihood -1175.606854 stepsize 0.000
# [step 495] neg-log-likelihood -1176.485746 stepsize 0.000
# [step 496] neg-log-likelihood -1174.834527 stepsize 0.000
# [step 497] neg-log-likelihood -1175.632679 stepsize 0.000
# [step 498] neg-log-likelihood -1176.970740 stepsize 0.000
# [step 499] neg-log-likelihood -1171.789513 stepsize 0.000
# [step 500] neg-log-likelihood -1164.993339 stepsize 0.000
# [step 501] neg-log-likelihood -1165.979675 stepsize 0.000
# [step 502] neg-log-likelihood -1164.315996 stepsize 0.000
# [step 503] neg-log-likelihood -1163.936926 stepsize 0.000
# [step 504] neg-log-likelihood -1167.222818 stepsize 0.000
# [step 505] neg-log-likelihood -1168.233430 stepsize 0.000
# [step 506] neg-log-likelihood -1163.097499 stepsize 0.000
# [step 507] neg-log-likelihood -1161.841399 stepsize 0.000
# [step 508] neg-log-likelihood -1161.976925 stepsize 0.000
# [step 509] neg-log-likelihood -1159.199854 stepsize 0.000
# [step 510] neg-log-likelihood -1154.633091 stepsize 0.000
# [step 511] neg-log-likelihood -1151.134013 stepsize 0.000
# [step 512] neg-log-likelihood -1149.241740 stepsize 0.000
# [step 513] neg-log-likelihood -1140.069681 stepsize 0.000
# [step 514] neg-log-likelihood -1136.325986 stepsize 0.000
# [step 515] neg-log-likelihood -1131.456585 stepsize 0.000
# [step 516] neg-log-likelihood -1128.582035 stepsize 0.000
# [step 517] neg-log-likelihood -1120.569407 stepsize 0.000
# [step 518] neg-log-likelihood -1116.536789 stepsize 0.000
# [step 519] neg-log-likelihood -1109.372125 stepsize 0.000
# [step 520] neg-log-likelihood -1098.434411 stepsize 0.000
# [step 521] neg-log-likelihood -1086.217694 stepsize 0.000
# [step 522] neg-log-likelihood -1082.523433 stepsize 0.000
# [step 523] neg-log-likelihood -1062.534895 stepsize 0.000
# [step 524] neg-log-likelihood -1049.025419 stepsize 0.000
# [step 525] neg-log-likelihood -1027.047946 stepsize 0.000
# [step 526] neg-log-likelihood -1004.437044 stepsize 0.000
# [step 527] neg-log-likelihood -976.352759 stepsize 0.000
# [step 528] neg-log-likelihood -930.286761 stepsize 0.000
# [step 529] neg-log-likelihood -842.845214 stepsize 0.000
# [step 530] neg-log-likelihood -824.361971 stepsize 0.000
# [step 531] neg-log-likelihood -880.769847 stepsize 0.000
# [step 532] neg-log-likelihood -981.416442 stepsize 0.000
# [step 533] neg-log-likelihood -1011.933004 stepsize 0.000
# [step 534] neg-log-likelihood -1044.422692 stepsize 0.000
# [step 535] neg-log-likelihood -1084.244479 stepsize 0.000
# [step 536] neg-log-likelihood -1116.549475 stepsize 0.000
# [step 537] neg-log-likelihood -1139.807052 stepsize 0.000
# [step 538] neg-log-likelihood -1154.794840 stepsize 0.000
# [step 539] neg-log-likelihood -1172.975455 stepsize 0.000
# [step 540] neg-log-likelihood -1185.821627 stepsize 0.000
# [step 541] neg-log-likelihood -1200.742667 stepsize 0.000
# [step 542] neg-log-likelihood -1204.787865 stepsize 0.000
# [step 543] neg-log-likelihood -1214.004318 stepsize 0.000
# [step 544] neg-log-likelihood -1213.230308 stepsize 0.000
# [step 545] neg-log-likelihood -1217.590319 stepsize 0.000
# [step 546] neg-log-likelihood -1219.658987 stepsize 0.000
# [step 547] neg-log-likelihood -1226.723804 stepsize 0.000
# [step 548] neg-log-likelihood -1226.645333 stepsize 0.000
# [step 549] neg-log-likelihood -1233.565658 stepsize 0.000
# [step 550] neg-log-likelihood -1232.000970 stepsize 0.000
# [step 551] neg-log-likelihood -1235.195004 stepsize 0.000
# [step 552] neg-log-likelihood -1239.210527 stepsize 0.000
# [step 553] neg-log-likelihood -1240.685324 stepsize 0.000
# [step 554] neg-log-likelihood -1240.173028 stepsize 0.000
# [step 555] neg-log-likelihood -1243.128758 stepsize 0.000
# [step 556] neg-log-likelihood -1243.038972 stepsize 0.000
# [step 557] neg-log-likelihood -1246.792323 stepsize 0.000
# [step 558] neg-log-likelihood -1252.063662 stepsize 0.000
# [step 559] neg-log-likelihood -1248.697964 stepsize 0.000
# [step 560] neg-log-likelihood -1250.980309 stepsize 0.000
# [step 561] neg-log-likelihood -1253.201517 stepsize 0.000
# [step 562] neg-log-likelihood -1252.534183 stepsize 0.000
# [step 563] neg-log-likelihood -1253.153636 stepsize 0.000
# [step 564] neg-log-likelihood -1256.269660 stepsize 0.000
# [step 565] neg-log-likelihood -1257.518218 stepsize 0.000
# [step 566] neg-log-likelihood -1260.291271 stepsize 0.000
# [step 567] neg-log-likelihood -1254.925668 stepsize 0.000
# [step 568] neg-log-likelihood -1262.530626 stepsize 0.000
# [step 569] neg-log-likelihood -1260.543224 stepsize 0.000
# [step 570] neg-log-likelihood -1260.764880 stepsize 0.000
# [step 571] neg-log-likelihood -1263.014580 stepsize 0.000
# [step 572] neg-log-likelihood -1260.294258 stepsize 0.000
# [step 573] neg-log-likelihood -1269.175603 stepsize 0.000
# [step 574] neg-log-likelihood -1267.233100 stepsize 0.000
# [step 575] neg-log-likelihood -1264.742764 stepsize 0.000
# [step 576] neg-log-likelihood -1268.099773 stepsize 0.000
# [step 577] neg-log-likelihood -1263.245324 stepsize 0.000
# [step 578] neg-log-likelihood -1259.223741 stepsize 0.000
# [step 579] neg-log-likelihood -1262.743212 stepsize 0.000
# [step 580] neg-log-likelihood -1261.468374 stepsize 0.000
# [step 581] neg-log-likelihood -1260.913651 stepsize 0.000
# [step 582] neg-log-likelihood -1257.553060 stepsize 0.000
# [step 583] neg-log-likelihood -1259.049183 stepsize 0.000
# [step 584] neg-log-likelihood -1260.244786 stepsize 0.000
# [step 585] neg-log-likelihood -1253.842751 stepsize 0.000
# [step 586] neg-log-likelihood -1256.017282 stepsize 0.000
# [step 587] neg-log-likelihood -1251.446163 stepsize 0.000
# [step 588] neg-log-likelihood -1249.803600 stepsize 0.000
# [step 589] neg-log-likelihood -1251.945496 stepsize 0.000
# [step 590] neg-log-likelihood -1248.941008 stepsize 0.000
# [step 591] neg-log-likelihood -1248.366865 stepsize 0.000
# [step 592] neg-log-likelihood -1245.158014 stepsize 0.000
# [step 593] neg-log-likelihood -1247.194676 stepsize 0.000
# [step 594] neg-log-likelihood -1241.926534 stepsize 0.000
# [step 595] neg-log-likelihood -1240.287432 stepsize 0.000
# [step 596] neg-log-likelihood -1241.192399 stepsize 0.000
# [step 597] neg-log-likelihood -1236.162660 stepsize 0.000
# [step 598] neg-log-likelihood -1235.303421 stepsize 0.000
# [step 599] neg-log-likelihood -1232.132269 stepsize 0.000
# [step 600] neg-log-likelihood -1230.436193 stepsize 0.000
# [step 601] neg-log-likelihood -1228.056180 stepsize 0.000
# [step 602] neg-log-likelihood -1221.952176 stepsize 0.000
# [step 603] neg-log-likelihood -1217.641306 stepsize 0.000
# [step 604] neg-log-likelihood -1212.459509 stepsize 0.000
# [step 605] neg-log-likelihood -1208.726179 stepsize 0.000
# [step 606] neg-log-likelihood -1205.641199 stepsize 0.000
# [step 607] neg-log-likelihood -1198.542031 stepsize 0.000
# [step 608] neg-log-likelihood -1191.803702 stepsize 0.000
# [step 609] neg-log-likelihood -1186.563939 stepsize 0.000
# [step 610] neg-log-likelihood -1179.089144 stepsize 0.000
# [step 611] neg-log-likelihood -1177.015420 stepsize 0.000
# [step 612] neg-log-likelihood -1167.132943 stepsize 0.000
# [step 613] neg-log-likelihood -1158.886119 stepsize 0.000
# [step 614] neg-log-likelihood -1149.830042 stepsize 0.000
# [step 615] neg-log-likelihood -1135.213985 stepsize 0.000
# [step 616] neg-log-likelihood -1120.623464 stepsize 0.000
# [step 617] neg-log-likelihood -1111.391752 stepsize 0.000
# [step 618] neg-log-likelihood -1094.157547 stepsize 0.000
# [step 619] neg-log-likelihood -1080.537649 stepsize 0.000
# [step 620] neg-log-likelihood -1065.392312 stepsize 0.000
# [step 621] neg-log-likelihood -1051.503513 stepsize 0.000
# [step 622] neg-log-likelihood -1039.627047 stepsize 0.000
# [step 623] neg-log-likelihood -1034.105388 stepsize 0.000
# [step 624] neg-log-likelihood -1026.147531 stepsize 0.000
# [step 625] neg-log-likelihood -1017.867095 stepsize 0.000
# [step 626] neg-log-likelihood -1013.238288 stepsize 0.000
# [step 627] neg-log-likelihood -1013.566959 stepsize 0.000
# [step 628] neg-log-likelihood -1022.070829 stepsize 0.000
# [step 629] neg-log-likelihood -1016.406459 stepsize 0.000
# [step 630] neg-log-likelihood -1020.637475 stepsize 0.000
# [step 631] neg-log-likelihood -1025.139925 stepsize 0.000
# [step 632] neg-log-likelihood -1032.755657 stepsize 0.000
# [step 633] neg-log-likelihood -1034.116561 stepsize 0.000
# [step 634] neg-log-likelihood -1047.702269 stepsize 0.000
# [step 635] neg-log-likelihood -1065.616099 stepsize 0.000
# [step 636] neg-log-likelihood -1089.542547 stepsize 0.000
# [step 637] neg-log-likelihood -1107.239768 stepsize 0.000
# [step 638] neg-log-likelihood -1128.789643 stepsize 0.000
# [step 639] neg-log-likelihood -1148.456958 stepsize 0.000
# [step 640] neg-log-likelihood -1165.289706 stepsize 0.000
# [step 641] neg-log-likelihood -1189.597583 stepsize 0.000
# [step 642] neg-log-likelihood -1200.215886 stepsize 0.000
# [step 643] neg-log-likelihood -1232.399146 stepsize 0.000
# [step 644] neg-log-likelihood -1244.806115 stepsize 0.000
# [step 645] neg-log-likelihood -1290.195108 stepsize 0.000
# [step 646] neg-log-likelihood -1284.138694 stepsize 0.000
# [step 647] neg-log-likelihood -1302.440406 stepsize 0.000
# [step 648] neg-log-likelihood -1309.647407 stepsize 0.000
# [step 649] neg-log-likelihood -1322.906677 stepsize 0.000
# [step 650] neg-log-likelihood -1324.914180 stepsize 0.000
# [step 651] neg-log-likelihood -1334.713037 stepsize 0.000
# [step 652] neg-log-likelihood -1341.453337 stepsize 0.000
# [step 653] neg-log-likelihood -1345.539861 stepsize 0.000
# [step 654] neg-log-likelihood -1351.481857 stepsize 0.000
# [step 655] neg-log-likelihood -1357.289596 stepsize 0.000
# [step 656] neg-log-likelihood -1360.096283 stepsize 0.000
# [step 657] neg-log-likelihood -1359.746318 stepsize 0.000
# [step 658] neg-log-likelihood -1360.912543 stepsize 0.000
# [step 659] neg-log-likelihood -1364.673503 stepsize 0.000
# [step 660] neg-log-likelihood -1371.529759 stepsize 0.000
# [step 661] neg-log-likelihood -1367.055945 stepsize 0.000
# [step 662] neg-log-likelihood -1367.776157 stepsize 0.000
# [step 663] neg-log-likelihood -1372.348131 stepsize 0.000
# [step 664] neg-log-likelihood -1372.462553 stepsize 0.000
# [step 665] neg-log-likelihood -1368.944987 stepsize 0.000
# [step 666] neg-log-likelihood -1375.120182 stepsize 0.000
# [step 667] neg-log-likelihood -1369.591381 stepsize 0.000
# [step 668] neg-log-likelihood -1374.221390 stepsize 0.000
# [step 669] neg-log-likelihood -1372.101180 stepsize 0.000
# [step 670] neg-log-likelihood -1370.804264 stepsize 0.000
# [step 671] neg-log-likelihood -1373.382504 stepsize 0.000
# [step 672] neg-log-likelihood -1371.161375 stepsize 0.000
# [step 673] neg-log-likelihood -1372.792109 stepsize 0.000
# [step 674] neg-log-likelihood -1368.614886 stepsize 0.000
# [step 675] neg-log-likelihood -1366.435722 stepsize 0.000
# [step 676] neg-log-likelihood -1369.478759 stepsize 0.000
# [step 677] neg-log-likelihood -1363.927337 stepsize 0.000
# [step 678] neg-log-likelihood -1365.036447 stepsize 0.000
# [step 679] neg-log-likelihood -1367.837502 stepsize 0.000
# [step 680] neg-log-likelihood -1364.790697 stepsize 0.000
# [step 681] neg-log-likelihood -1367.848479 stepsize 0.000
# [step 682] neg-log-likelihood -1363.560952 stepsize 0.000
# [step 683] neg-log-likelihood -1362.687885 stepsize 0.000
# [step 684] neg-log-likelihood -1363.706221 stepsize 0.000
# [step 685] neg-log-likelihood -1365.828110 stepsize 0.000
# [step 686] neg-log-likelihood -1361.455713 stepsize 0.000
# [step 687] neg-log-likelihood -1359.556869 stepsize 0.000
# [step 688] neg-log-likelihood -1360.244316 stepsize 0.000
# [step 689] neg-log-likelihood -1359.466124 stepsize 0.000
# [step 690] neg-log-likelihood -1366.349570 stepsize 0.000
# [step 691] neg-log-likelihood -1359.328050 stepsize 0.000
# [step 692] neg-log-likelihood -1359.685362 stepsize 0.000
# [step 693] neg-log-likelihood -1358.365670 stepsize 0.000
# [step 694] neg-log-likelihood -1357.997790 stepsize 0.000
# [step 695] neg-log-likelihood -1362.609546 stepsize 0.000
# [step 696] neg-log-likelihood -1360.280336 stepsize 0.000
# [step 697] neg-log-likelihood -1356.981068 stepsize 0.000
# [step 698] neg-log-likelihood -1356.368103 stepsize 0.000
# [step 699] neg-log-likelihood -1356.988477 stepsize 0.000
# [step 700] neg-log-likelihood -1355.535566 stepsize 0.000
# [step 701] neg-log-likelihood -1357.818561 stepsize 0.000
# [step 702] neg-log-likelihood -1358.446022 stepsize 0.000
# [step 703] neg-log-likelihood -1354.156882 stepsize 0.000
# [step 704] neg-log-likelihood -1351.860372 stepsize 0.000
# [step 705] neg-log-likelihood -1351.608575 stepsize 0.000
# [step 706] neg-log-likelihood -1346.746104 stepsize 0.000
# [step 707] neg-log-likelihood -1351.257236 stepsize 0.000
# [step 708] neg-log-likelihood -1340.719125 stepsize 0.000
# [step 709] neg-log-likelihood -1339.562431 stepsize 0.000
# [step 710] neg-log-likelihood -1339.625474 stepsize 0.000
# [step 711] neg-log-likelihood -1334.907654 stepsize 0.000
# [step 712] neg-log-likelihood -1337.526956 stepsize 0.000
# [step 713] neg-log-likelihood -1332.786665 stepsize 0.000
# [step 714] neg-log-likelihood -1333.793030 stepsize 0.000
# [step 715] neg-log-likelihood -1325.780880 stepsize 0.000
# [step 716] neg-log-likelihood -1325.815285 stepsize 0.000
# [step 717] neg-log-likelihood -1317.724543 stepsize 0.000
# [step 718] neg-log-likelihood -1311.931497 stepsize 0.000
# [step 719] neg-log-likelihood -1310.382330 stepsize 0.000
# [step 720] neg-log-likelihood -1298.587802 stepsize 0.000
# [step 721] neg-log-likelihood -1290.798125 stepsize 0.000
# [step 722] neg-log-likelihood -1268.828581 stepsize 0.000
# [step 723] neg-log-likelihood -1252.968925 stepsize 0.000
# [step 724] neg-log-likelihood -1236.448906 stepsize 0.000
# [step 725] neg-log-likelihood -1213.255765 stepsize 0.000
# [step 726] neg-log-likelihood -1186.704286 stepsize 0.000
# [step 727] neg-log-likelihood -1153.611127 stepsize 0.000
# [step 728] neg-log-likelihood -1127.458896 stepsize 0.000
# [step 729] neg-log-likelihood -1107.268031 stepsize 0.000
# [step 730] neg-log-likelihood -1089.087507 stepsize 0.000
# [step 731] neg-log-likelihood -1074.608263 stepsize 0.000
# [step 732] neg-log-likelihood -1055.106969 stepsize 0.000
# [step 733] neg-log-likelihood -1034.702519 stepsize 0.000
# [step 734] neg-log-likelihood -1001.629378 stepsize 0.000
# [step 735] neg-log-likelihood -965.473314 stepsize 0.000
# [step 736] neg-log-likelihood -906.807704 stepsize 0.000
# [step 737] neg-log-likelihood -855.530781 stepsize 0.000
# [step 738] neg-log-likelihood -604.980944 stepsize 0.000
# [step 739] neg-log-likelihood -1386.278126 stepsize 0.000
# [step 740] neg-log-likelihood -1385.014641 stepsize 0.000
# [step 741] neg-log-likelihood -1371.886640 stepsize 0.000
# [step 742] neg-log-likelihood -1417.322343 stepsize 0.000
# [step 743] neg-log-likelihood -1422.139877 stepsize 0.000
# [step 744] neg-log-likelihood -1454.326378 stepsize 0.000
# [step 745] neg-log-likelihood -1463.746589 stepsize 0.000
# [step 746] neg-log-likelihood -1484.508726 stepsize 0.000
# [step 747] neg-log-likelihood -1497.391347 stepsize 0.000
# [step 748] neg-log-likelihood -1506.697873 stepsize 0.000
# [step 749] neg-log-likelihood -1519.286501 stepsize 0.000
# [step 750] neg-log-likelihood -1527.519717 stepsize 0.000
# [step 751] neg-log-likelihood -1535.002359 stepsize 0.000
# [step 752] neg-log-likelihood -1537.236905 stepsize 0.000
# [step 753] neg-log-likelihood -1543.297649 stepsize 0.000
# [step 754] neg-log-likelihood -1546.694413 stepsize 0.000
# [step 755] neg-log-likelihood -1546.027455 stepsize 0.000
# [step 756] neg-log-likelihood -1549.299836 stepsize 0.000
# [step 757] neg-log-likelihood -1556.030087 stepsize 0.000
# [step 758] neg-log-likelihood -1555.073134 stepsize 0.000
# [step 759] neg-log-likelihood -1551.196107 stepsize 0.000
# [step 760] neg-log-likelihood -1551.951783 stepsize 0.000
# [step 761] neg-log-likelihood -1555.682180 stepsize 0.000
# [step 762] neg-log-likelihood -1554.656051 stepsize 0.000
# [step 763] neg-log-likelihood -1554.523816 stepsize 0.000
# [step 764] neg-log-likelihood -1555.812803 stepsize 0.000
# [step 765] neg-log-likelihood -1553.833619 stepsize 0.000
# [step 766] neg-log-likelihood -1557.779457 stepsize 0.000
# [step 767] neg-log-likelihood -1560.627757 stepsize 0.000
# [step 768] neg-log-likelihood -1553.285609 stepsize 0.000
# [step 769] neg-log-likelihood -1553.606038 stepsize 0.000
# [step 770] neg-log-likelihood -1553.945170 stepsize 0.000
# [step 771] neg-log-likelihood -1553.401442 stepsize 0.000
# [step 772] neg-log-likelihood -1551.000596 stepsize 0.000
# [step 773] neg-log-likelihood -1551.733006 stepsize 0.000
# [step 774] neg-log-likelihood -1554.809705 stepsize 0.000
# [step 775] neg-log-likelihood -1558.230194 stepsize 0.000
# [step 776] neg-log-likelihood -1549.727501 stepsize 0.000
# [step 777] neg-log-likelihood -1550.911437 stepsize 0.000
# [step 778] neg-log-likelihood -1551.481970 stepsize 0.000
# [step 779] neg-log-likelihood -1548.608641 stepsize 0.000
# [step 780] neg-log-likelihood -1541.184160 stepsize 0.000
# [step 781] neg-log-likelihood -1543.203190 stepsize 0.000
# [step 782] neg-log-likelihood -1543.138217 stepsize 0.000
# [step 783] neg-log-likelihood -1539.764231 stepsize 0.000
# [step 784] neg-log-likelihood -1532.442464 stepsize 0.000
# [step 785] neg-log-likelihood -1528.460673 stepsize 0.000
# [step 786] neg-log-likelihood -1528.760444 stepsize 0.000
# [step 787] neg-log-likelihood -1523.646626 stepsize 0.000
# [step 788] neg-log-likelihood -1521.586654 stepsize 0.000
# [step 789] neg-log-likelihood -1514.317212 stepsize 0.000
# [step 790] neg-log-likelihood -1508.418467 stepsize 0.000
# [step 791] neg-log-likelihood -1494.023877 stepsize 0.000
# [step 792] neg-log-likelihood -1477.628607 stepsize 0.000
# [step 793] neg-log-likelihood -1451.969120 stepsize 0.000
# [step 794] neg-log-likelihood -1410.389672 stepsize 0.000
# [step 795] neg-log-likelihood -1363.202750 stepsize 0.000
# [step 796] neg-log-likelihood -1311.436316 stepsize 0.000
# [step 797] neg-log-likelihood -1264.553114 stepsize 0.000
# [step 798] neg-log-likelihood -1230.522775 stepsize 0.000
# [step 799] neg-log-likelihood -1200.717354 stepsize 0.000
# [step 800] neg-log-likelihood -1163.157257 stepsize 0.000
# [step 801] neg-log-likelihood -1117.711713 stepsize 0.000
# [step 802] neg-log-likelihood -1031.532118 stepsize 0.000
# [step 803] neg-log-likelihood -913.989486 stepsize 0.000
# [step 804] neg-log-likelihood -1604.045868 stepsize 0.000
# [step 805] neg-log-likelihood -1366.519896 stepsize 0.000
# [step 806] neg-log-likelihood -1364.562304 stepsize 0.000
# [step 807] neg-log-likelihood -1515.915537 stepsize 0.000
# [step 808] neg-log-likelihood -1554.314391 stepsize 0.000
# [step 809] neg-log-likelihood -1566.616223 stepsize 0.000
# [step 810] neg-log-likelihood -1563.995733 stepsize 0.000
# [step 811] neg-log-likelihood -1549.699877 stepsize 0.000
# [step 812] neg-log-likelihood -1537.792769 stepsize 0.000
# [step 813] neg-log-likelihood -1519.900418 stepsize 0.000
# [step 814] neg-log-likelihood -1477.203713 stepsize 0.000
# [step 815] neg-log-likelihood -1434.615012 stepsize 0.000
# [step 816] neg-log-likelihood -1395.818146 stepsize 0.000
# [step 817] neg-log-likelihood -1353.191740 stepsize 0.000
# [step 818] neg-log-likelihood -1302.062845 stepsize 0.000
# [step 819] neg-log-likelihood -1241.893064 stepsize 0.000
# [step 820] neg-log-likelihood -1148.417868 stepsize 0.000
# [step 821] neg-log-likelihood -1040.323800 stepsize 0.000
# [step 822] neg-log-likelihood -870.355745 stepsize 0.000
# [step 823] neg-log-likelihood -1539.672836 stepsize 0.000
# ...
# [step 725] neg-log-likelihood -1321.610829 stepsize 0.000
# [step 726] neg-log-likelihood -1322.429809 stepsize 0.000
# [step 727] neg-log-likelihood -1317.163091 stepsize 0.000
# [step 728] neg-log-likelihood -1319.232129 stepsize 0.000
# [step 729] neg-log-likelihood -1318.591864 stepsize 0.000
# [step 730] neg-log-likelihood -1317.188574 stepsize 0.000
# [step 731] neg-log-likelihood -1315.928250 stepsize 0.000
# [step 732] neg-log-likelihood -1308.395098 stepsize 0.000
# [step 733] neg-log-likelihood -1307.933953 stepsize 0.000
# [step 734] neg-log-likelihood -1311.729932 stepsize 0.000
# [step 735] neg-log-likelihood -1305.057466 stepsize 0.000
# [step 736] neg-log-likelihood -1308.709697 stepsize 0.000
# [step 737] neg-log-likelihood -1298.489003 stepsize 0.000
# [step 738] neg-log-likelihood -1293.349319 stepsize 0.000
# [step 739] neg-log-likelihood -1287.004334 stepsize 0.000
# [step 740] neg-log-likelihood -1285.360556 stepsize 0.000
# [step 741] neg-log-likelihood -1273.695867 stepsize 0.000
# [step 742] neg-log-likelihood -1249.061271 stepsize 0.000
# [step 743] neg-log-likelihood -1218.020039 stepsize 0.000
# [step 744] neg-log-likelihood -1185.194455 stepsize 0.000
# [step 745] neg-log-likelihood -1175.619698 stepsize 0.000
# [step 746] neg-log-likelihood -1156.654607 stepsize 0.000
# [step 747] neg-log-likelihood -1144.792202 stepsize 0.000
# [step 748] neg-log-likelihood -1148.825490 stepsize 0.000
# [step 749] neg-log-likelihood -1129.105288 stepsize 0.000
# [step 750] neg-log-likelihood -1124.170791 stepsize 0.000
# [step 751] neg-log-likelihood -1048.766825 stepsize 0.000
# [step 752] neg-log-likelihood -1210.125812 stepsize 0.000
# [step 753] neg-log-likelihood -1343.445606 stepsize 0.000
# [step 754] neg-log-likelihood -1392.022739 stepsize 0.000
# [step 755] neg-log-likelihood -1391.636205 stepsize 0.000
# [step 756] neg-log-likelihood -1405.451573 stepsize 0.000
# [step 757] neg-log-likelihood -1412.212824 stepsize 0.000
# [step 758] neg-log-likelihood -1416.753102 stepsize 0.000
# [step 759] neg-log-likelihood -1418.937851 stepsize 0.000
# [step 760] neg-log-likelihood -1424.675162 stepsize 0.000
# [step 761] neg-log-likelihood -1422.368878 stepsize 0.000
# [step 762] neg-log-likelihood -1426.173430 stepsize 0.000
# [step 763] neg-log-likelihood -1422.152560 stepsize 0.000
# [step 764] neg-log-likelihood -1418.309459 stepsize 0.000
# [step 765] neg-log-likelihood -1418.799338 stepsize 0.000
# [step 766] neg-log-likelihood -1412.811222 stepsize 0.000
# [step 767] neg-log-likelihood -1408.585437 stepsize 0.000
# [step 768] neg-log-likelihood -1409.514140 stepsize 0.000
# [step 769] neg-log-likelihood -1406.019203 stepsize 0.000
# [step 770] neg-log-likelihood -1403.365617 stepsize 0.000
# [step 771] neg-log-likelihood -1398.647284 stepsize 0.000
# [step 772] neg-log-likelihood -1397.720790 stepsize 0.000
# [step 773] neg-log-likelihood -1389.463142 stepsize 0.000
# [step 774] neg-log-likelihood -1387.383933 stepsize 0.000
# [step 775] neg-log-likelihood -1385.524775 stepsize 0.000
# [step 776] neg-log-likelihood -1381.708037 stepsize 0.000
# [step 777] neg-log-likelihood -1378.405992 stepsize 0.000
# [step 778] neg-log-likelihood -1372.899115 stepsize 0.000
# [step 779] neg-log-likelihood -1366.492857 stepsize 0.000
# [step 780] neg-log-likelihood -1367.833661 stepsize 0.000
# [step 781] neg-log-likelihood -1365.776968 stepsize 0.000
# [step 782] neg-log-likelihood -1357.743601 stepsize 0.000
# [step 783] neg-log-likelihood -1350.835047 stepsize 0.000
# [step 784] neg-log-likelihood -1345.658598 stepsize 0.000
# [step 785] neg-log-likelihood -1338.770460 stepsize 0.000
# [step 786] neg-log-likelihood -1335.541916 stepsize 0.000
# [step 787] neg-log-likelihood -1324.231627 stepsize 0.000
# [step 788] neg-log-likelihood -1313.453161 stepsize 0.000
# [step 789] neg-log-likelihood -1305.988873 stepsize 0.000
# [step 790] neg-log-likelihood -1252.285678 stepsize 0.000
# [step 791] neg-log-likelihood -1209.631086 stepsize 0.000
# [step 792] neg-log-likelihood -1182.113857 stepsize 0.000
# [step 793] neg-log-likelihood -1159.090195 stepsize 0.000
# [step 794] neg-log-likelihood -1147.291004 stepsize 0.000
# [step 795] neg-log-likelihood -1131.436077 stepsize 0.000
# [step 796] neg-log-likelihood -1123.425562 stepsize 0.000
# [step 797] neg-log-likelihood -1118.585577 stepsize 0.000
# [step 798] neg-log-likelihood -1088.010477 stepsize 0.000
# [step 799] neg-log-likelihood -1032.605868 stepsize 0.000
# [step 800] neg-log-likelihood -1352.802322 stepsize 0.000
# [step 801] neg-log-likelihood -1284.458868 stepsize 0.000
# [step 802] neg-log-likelihood -1340.503697 stepsize 0.000
# [step 803] neg-log-likelihood -1332.771591 stepsize 0.000
# [step 804] neg-log-likelihood -1339.472652 stepsize 0.000
# [step 805] neg-log-likelihood -1351.010304 stepsize 0.000
# [step 806] neg-log-likelihood -1351.434565 stepsize 0.000
# [step 807] neg-log-likelihood -1356.626126 stepsize 0.000
# [step 808] neg-log-likelihood -1371.733290 stepsize 0.000
# [step 809] neg-log-likelihood -1375.122565 stepsize 0.000
# [step 810] neg-log-likelihood -1383.647379 stepsize 0.000
# [step 811] neg-log-likelihood -1384.449262 stepsize 0.000
# [step 812] neg-log-likelihood -1388.385919 stepsize 0.000
# [step 813] neg-log-likelihood -1399.272856 stepsize 0.000
# [step 814] neg-log-likelihood -1392.036933 stepsize 0.000
# [step 815] neg-log-likelihood -1384.291455 stepsize 0.000
# [step 816] neg-log-likelihood -1385.118220 stepsize 0.000
# [step 817] neg-log-likelihood -1385.892662 stepsize 0.000
# [step 818] neg-log-likelihood -1387.145357 stepsize 0.000
# [step 819] neg-log-likelihood -1378.482107 stepsize 0.000
# [step 820] neg-log-likelihood -1376.118077 stepsize 0.000
# [step 821] neg-log-likelihood -1376.222585 stepsize 0.000
# [step 822] neg-log-likelihood -1371.889128 stepsize 0.000
# [step 823] neg-log-likelihood -1364.236692 stepsize 0.000
# [step 824] neg-log-likelihood -1361.554034 stepsize 0.000
# [step 825] neg-log-likelihood -1356.914504 stepsize 0.000
# [step 826] neg-log-likelihood -1351.838451 stepsize 0.000
# [step 827] neg-log-likelihood -1342.934111 stepsize 0.000
# [step 828] neg-log-likelihood -1338.626734 stepsize 0.000
# [step 829] neg-log-likelihood -1333.070035 stepsize 0.000
# [step 830] neg-log-likelihood -1316.152852 stepsize 0.000
# [step 831] neg-log-likelihood -1302.823347 stepsize 0.000
# [step 832] neg-log-likelihood -1279.544147 stepsize 0.000
# [step 833] neg-log-likelihood -1219.936540 stepsize 0.000
# [step 834] neg-log-likelihood -1182.271651 stepsize 0.000
# [step 835] neg-log-likelihood -1162.246790 stepsize 0.000
# [step 836] neg-log-likelihood -1147.720208 stepsize 0.000
# [step 837] neg-log-likelihood -1131.624302 stepsize 0.000
# [step 838] neg-log-likelihood -1127.511459 stepsize 0.000
# [step 839] neg-log-likelihood -1126.670295 stepsize 0.000
# [step 840] neg-log-likelihood -1132.227410 stepsize 0.000
# [step 841] neg-log-likelihood -1105.161999 stepsize 0.000
# [step 842] neg-log-likelihood -1090.511745 stepsize 0.000
# [step 843] neg-log-likelihood -907.463606 stepsize 0.000
# [step 844] neg-log-likelihood -1314.961339 stepsize 0.000
# [step 845] neg-log-likelihood -1390.239094 stepsize 0.000
# [step 846] neg-log-likelihood -1393.444536 stepsize 0.000
# [step 847] neg-log-likelihood -1386.920164 stepsize 0.000
# [step 848] neg-log-likelihood -1391.778712 stepsize 0.000
# [step 849] neg-log-likelihood -1387.023783 stepsize 0.000
# [step 850] neg-log-likelihood -1388.285221 stepsize 0.000
# [step 851] neg-log-likelihood -1385.712844 stepsize 0.000
# [step 852] neg-log-likelihood -1386.730197 stepsize 0.000
# [step 853] neg-log-likelihood -1382.877681 stepsize 0.000
# [step 854] neg-log-likelihood -1392.099969 stepsize 0.000
# [step 855] neg-log-likelihood -1386.005830 stepsize 0.000
# [step 856] neg-log-likelihood -1390.002303 stepsize 0.000
# [step 857] neg-log-likelihood -1385.968292 stepsize 0.000
# [step 858] neg-log-likelihood -1382.810131 stepsize 0.000
# [step 859] neg-log-likelihood -1391.726588 stepsize 0.000
# [step 860] neg-log-likelihood -1384.959354 stepsize 0.000
# [step 861] neg-log-likelihood -1381.406504 stepsize 0.000
# [step 862] neg-log-likelihood -1378.197274 stepsize 0.000
# [step 863] neg-log-likelihood -1368.234292 stepsize 0.000
# [step 864] neg-log-likelihood -1370.208482 stepsize 0.000
# [step 865] neg-log-likelihood -1365.695393 stepsize 0.000
# [step 866] neg-log-likelihood -1356.594454 stepsize 0.000
# [step 867] neg-log-likelihood -1351.404548 stepsize 0.000
# [step 868] neg-log-likelihood -1347.201202 stepsize 0.000
# [step 869] neg-log-likelihood -1341.192928 stepsize 0.000
# [step 870] neg-log-likelihood -1340.358139 stepsize 0.000
# [step 871] neg-log-likelihood -1336.173704 stepsize 0.000
# [step 872] neg-log-likelihood -1329.811963 stepsize 0.000
# [step 873] neg-log-likelihood -1321.853231 stepsize 0.000
# [step 874] neg-log-likelihood -1310.768155 stepsize 0.000
# [step 875] neg-log-likelihood -1304.357890 stepsize 0.000
# [step 876] neg-log-likelihood -1293.222217 stepsize 0.000
# [step 877] neg-log-likelihood -1277.913760 stepsize 0.000
# [step 878] neg-log-likelihood -1256.120636 stepsize 0.000
# [step 879] neg-log-likelihood -1227.486901 stepsize 0.000
# [step 880] neg-log-likelihood -1184.178381 stepsize 0.000
# [step 881] neg-log-likelihood -1142.096535 stepsize 0.000
# [step 882] neg-log-likelihood -1119.895127 stepsize 0.000
# [step 883] neg-log-likelihood -1106.035832 stepsize 0.000
# [step 884] neg-log-likelihood -1093.919797 stepsize 0.000
# [step 885] neg-log-likelihood -1081.625740 stepsize 0.000
# [step 886] neg-log-likelihood -1082.151263 stepsize 0.000
# [step 887] neg-log-likelihood -1060.895407 stepsize 0.000
# [step 888] neg-log-likelihood -1010.271161 stepsize 0.000
# [step 889] neg-log-likelihood -1053.325380 stepsize 0.000
# [step 890] neg-log-likelihood -1400.109564 stepsize 0.000
# [step 891] neg-log-likelihood -1400.436484 stepsize 0.000
# [step 892] neg-log-likelihood -1410.448894 stepsize 0.000
# [step 893] neg-log-likelihood -1420.085775 stepsize 0.000
# [step 894] neg-log-likelihood -1417.461381 stepsize 0.000
# [step 895] neg-log-likelihood -1421.160265 stepsize 0.000
# [step 896] neg-log-likelihood -1424.295759 stepsize 0.000
# [step 897] neg-log-likelihood -1425.980054 stepsize 0.000
# [step 898] neg-log-likelihood -1423.065172 stepsize 0.000
# [step 899] neg-log-likelihood -1423.519830 stepsize 0.000
# [step 900] neg-log-likelihood -1426.474609 stepsize 0.000
# [step 901] neg-log-likelihood -1425.538605 stepsize 0.000
# [step 902] neg-log-likelihood -1428.650218 stepsize 0.000
# [step 903] neg-log-likelihood -1429.983137 stepsize 0.000
# [step 904] neg-log-likelihood -1427.719711 stepsize 0.000
# [step 905] neg-log-likelihood -1426.239216 stepsize 0.000
# [step 906] neg-log-likelihood -1424.303077 stepsize 0.000
# [step 907] neg-log-likelihood -1423.759763 stepsize 0.000
# [step 908] neg-log-likelihood -1423.931535 stepsize 0.000
# [step 909] neg-log-likelihood -1419.670571 stepsize 0.000
# [step 910] neg-log-likelihood -1427.268099 stepsize 0.000
# [step 911] neg-log-likelihood -1426.667655 stepsize 0.000
# [step 912] neg-log-likelihood -1419.808732 stepsize 0.000
# [step 913] neg-log-likelihood -1419.052676 stepsize 0.000
# [step 914] neg-log-likelihood -1416.511350 stepsize 0.000
# [step 915] neg-log-likelihood -1419.857048 stepsize 0.000
# [step 916] neg-log-likelihood -1414.104933 stepsize 0.000
# [step 917] neg-log-likelihood -1414.757190 stepsize 0.000
# [step 918] neg-log-likelihood -1408.633396 stepsize 0.000
# [step 919] neg-log-likelihood -1409.189157 stepsize 0.000
# [step 920] neg-log-likelihood -1405.272567 stepsize 0.000
# [step 921] neg-log-likelihood -1402.072273 stepsize 0.000
# [step 922] neg-log-likelihood -1389.283078 stepsize 0.000
# [step 923] neg-log-likelihood -1389.963207 stepsize 0.000
# [step 924] neg-log-likelihood -1380.047996 stepsize 0.000
# [step 925] neg-log-likelihood -1377.117486 stepsize 0.000
# [step 926] neg-log-likelihood -1378.468552 stepsize 0.000
# [step 927] neg-log-likelihood -1370.207864 stepsize 0.000
# [step 928] neg-log-likelihood -1361.325000 stepsize 0.000
# [step 929] neg-log-likelihood -1354.080999 stepsize 0.000
# [step 930] neg-log-likelihood -1345.978909 stepsize 0.000
# [step 931] neg-log-likelihood -1336.374005 stepsize 0.000
# [step 932] neg-log-likelihood -1324.492058 stepsize 0.000
# [step 933] neg-log-likelihood -1300.343265 stepsize 0.000
# [step 934] neg-log-likelihood -1245.527624 stepsize 0.000
# [step 935] neg-log-likelihood -1201.803109 stepsize 0.000
# [step 936] neg-log-likelihood -1174.722398 stepsize 0.000
# [step 937] neg-log-likelihood -1149.796087 stepsize 0.000
# [step 938] neg-log-likelihood -1497.668923 stepsize 0.000
# [step 939] neg-log-likelihood -1426.932907 stepsize 0.000
# [step 940] neg-log-likelihood -1380.185016 stepsize 0.000
# [step 941] neg-log-likelihood -1413.774614 stepsize 0.000
# [step 942] neg-log-likelihood -1419.340574 stepsize 0.000
# [step 943] neg-log-likelihood -1428.658080 stepsize 0.000
# [step 944] neg-log-likelihood -1436.025994 stepsize 0.000
# [step 945] neg-log-likelihood -1426.020930 stepsize 0.000
# [step 946] neg-log-likelihood -1427.470311 stepsize 0.000
# [step 947] neg-log-likelihood -1427.019077 stepsize 0.000
# [step 948] neg-log-likelihood -1428.032111 stepsize 0.000
# [step 949] neg-log-likelihood -1420.047533 stepsize 0.000
# [step 950] neg-log-likelihood -1416.880008 stepsize 0.000
# [step 951] neg-log-likelihood -1415.389623 stepsize 0.000
# [step 952] neg-log-likelihood -1410.267168 stepsize 0.000
# [step 953] neg-log-likelihood -1406.705124 stepsize 0.000
# [step 954] neg-log-likelihood -1402.848132 stepsize 0.000
# [step 955] neg-log-likelihood -1393.184049 stepsize 0.000
# [step 956] neg-log-likelihood -1397.309907 stepsize 0.000
# [step 957] neg-log-likelihood -1381.162180 stepsize 0.000
# [step 958] neg-log-likelihood -1386.070705 stepsize 0.000
# [step 959] neg-log-likelihood -1370.160609 stepsize 0.000
# [step 960] neg-log-likelihood -1365.721180 stepsize 0.000
# [step 961] neg-log-likelihood -1361.792568 stepsize 0.000
# [step 962] neg-log-likelihood -1345.659792 stepsize 0.000
# [step 963] neg-log-likelihood -1341.517677 stepsize 0.000
# [step 964] neg-log-likelihood -1332.915664 stepsize 0.000
# [step 965] neg-log-likelihood -1198.209540 stepsize 0.000
# [step 966] neg-log-likelihood -1183.705541 stepsize 0.000
# [step 967] neg-log-likelihood -1031.335554 stepsize 0.000
# [step 968] neg-log-likelihood -1378.626404 stepsize 0.000
# [step 969] neg-log-likelihood -1376.697790 stepsize 0.000
# [step 970] neg-log-likelihood -1395.119440 stepsize 0.000
# [step 971] neg-log-likelihood -1417.445171 stepsize 0.000
# [step 972] neg-log-likelihood -1423.686269 stepsize 0.000
# [step 973] neg-log-likelihood -1428.791543 stepsize 0.000
# [step 974] neg-log-likelihood -1427.254653 stepsize 0.000
# [step 975] neg-log-likelihood -1421.633035 stepsize 0.000
# [step 976] neg-log-likelihood -1411.283163 stepsize 0.000
# [step 977] neg-log-likelihood -1386.781629 stepsize 0.000
# [step 978] neg-log-likelihood -1331.684335 stepsize 0.000
# [step 979] neg-log-likelihood -1277.032884 stepsize 0.000
# [step 980] neg-log-likelihood -1246.173293 stepsize 0.000
# [step 981] neg-log-likelihood -1237.833102 stepsize 0.000
# [step 982] neg-log-likelihood -1231.968430 stepsize 0.000
# [step 983] neg-log-likelihood -1238.787897 stepsize 0.000
# [step 984] neg-log-likelihood -1240.053650 stepsize 0.000
# [step 985] neg-log-likelihood -1241.621670 stepsize 0.000
# [step 986] neg-log-likelihood -1276.341886 stepsize 0.000
# [step 987] neg-log-likelihood -1298.418079 stepsize 0.000
# [step 988] neg-log-likelihood -1465.811685 stepsize 0.000
# [step 989] neg-log-likelihood -1373.885972 stepsize 0.000
# [step 990] neg-log-likelihood -1282.726229 stepsize 0.000
# [step 991] neg-log-likelihood -1269.463534 stepsize 0.000
# [step 992] neg-log-likelihood -1294.781263 stepsize 0.000
# [step 993] neg-log-likelihood -1320.975126 stepsize 0.000
# [step 994] neg-log-likelihood -1336.323522 stepsize 0.000
# [step 995] neg-log-likelihood -1350.684975 stepsize 0.000
# [step 996] neg-log-likelihood -1357.681648 stepsize 0.000
# [step 997] neg-log-likelihood -1361.128925 stepsize 0.000
# [step 998] neg-log-likelihood -1358.322236 stepsize 0.000
# [step 999] neg-log-likelihood -1359.783185 stepsize 0.000

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 6.0*len(lambda_array))
plt.style.use('seaborn-white')

for i in np.arange(len(lambda_array)):
    ax = plt.subplot(len(lambda_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_nll_eu_array[i], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_nll_grass_array[i], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
                             r"Grassmann ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
                             fontsize = 15, loc='upper right', frameon=True)
    else:    
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f})".format(eta), r"Grassmann ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper right', frameon=True)
    plt.grid(1)
    plt.ylabel('negative log-likelihood', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/nll_iters_Grass_Eu_" + str(trail) + "_"
    file_tail = "_03_31_16.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %% [markdown]
# These plots show the comparison of learning trajectories for different regularization paramters $\lambda$. We see that the larger $\lambda$, the smoother the curve is. However, it introduces more biases.
# <img src="../figures/nll_iters_Grass_Eu_1_nearReg_03_31_16.png">
