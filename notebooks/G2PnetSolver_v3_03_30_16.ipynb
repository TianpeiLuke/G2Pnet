# %% [markdown]
# We check the implementation of G2PnetSovler class in ../src/
#
# Created by Tianpei Xie, 03/30/2016
#
# Last Edit 03/31/2016

# %%
# %reset
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import rbf_kernel, pairwise_kernels
import GPy
import GPy.util as gutil

# %matplotlib inline 
plt.close('all')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# /Applications/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
Ifsavefig =  False
Ifsavedata = False

# %% [markdown]
# The network generating

# %%
size = 40
color_map = {0:'r', 1:'c', 2:'y'}
#center = np.zeros(2)
#center[1] = 1
center = None

n = 40
m = 0
G0= nx.barbell_graph(n,m) 
#generate the bar-bell graph, which consists of two fully connected component and a path connecting them 

label0 = np.zeros([2*n,1])
label0[n:2*n] = np.ones([n,1])
#### labeling of the cluster
for node in G0.nodes():
    G0.node[node]['category'] = int(label0[node,0])

# %%
####generate the eigenspace of normalized Laplacian
k = 3
nnodes = nx.adjacency_matrix(G0).shape[0]

ncv=max(2*k+1,int(np.sqrt(nnodes)))

eigenvalues,eigenvectors= sp.sparse.linalg.eigsh(nx.laplacian_matrix(G0).asfptype(), k=k, \
                                                which='SM', return_eigenvectors = True, ncv=ncv)
index=np.argsort(eigenvalues)[1:k] # 0 index is zero eigenvalue    
pos_spectral_mat = np.real(eigenvectors[:,index]) #pos_spectral_mat is the spectral location of the nodes
pos_spectral_df = pd.DataFrame(data=pos_spectral_mat, columns=['PX','PY'], dtype=float)
pos_spectral_df['LABEL'] = label0

# %% [markdown]
# The node attributes generating

# %%
T= 2
c = 2*np.pi*0.8
data_np = np.zeros([nnodes, T])
column_name = []
for t in np.arange(1,T+1):
    temp1 = np.multiply(pos_spectral_df['PX'].apply(lambda x: np.exp(-c*t*x)).values, \
                          pos_spectral_df['PY'].apply(lambda y: np.cos(c*t*y)).values)
    data_np[:,t-1] = temp1
    if t == 1:
        column_name = str(t-1)+"_cos"
    else:    
        column_name = [column_name, str(t-1)+"_cos"]

sigma = 0.1        
data_np = np.add(data_np, sigma*np.random.randn(nnodes, T))    
data_df = pd.DataFrame(data=data_np, columns=column_name, dtype=float)
data_df['LABEL'] = label0

# %%
if Ifsavedata:
    nx.write_adjlist(G0, "../data/experiment_03_31_2016.adjlist",delimiter=',')
    nx.write_edgelist(G0, "../data/experiment_03_31_2016.edgelist")

    np.savez("../data/experiment_data_03_31_2016.npz", pos_spectral_mat, data_np, label0)
    data_df.to_csv("../data/experiment_X_03_31_2016.csv", index_label= 'ID')
    pos_spectral_df.to_csv("../data/experiment_U_03_31_2016.csv", index_label= 'ID')

# %% [markdown]
# if Ifsavedata:
#     nx.write_adjlist(G0, "../data/experiment_bad_03_31_2016.adjlist",delimiter=',')
#     nx.write_edgelist(G0, "../data/experiment_bad_03_31_2016.edgelist")
#
#     np.savez("../data/experiment_bad_data_03_31_2016.npz", pos_spectral_mat, data_np, label0)
#     data_df.to_csv("../data/experiment_bad_X_03_31_2016.csv", index_label= 'ID')
#     pos_spectral_df.to_csv("../data/experiment_bad_U_03_31_2016.csv", index_label= 'ID')

# %%
X= data_np
U= pos_spectral_mat
nsample, ndim = X.shape
_ , ndim_latent = U.shape

kern = GPy.kern.RBF(2)

# %% [markdown]
# Import from the G2PnetSolver_v1.py

# %%
import sys
import os
dirorg = os.path.dirname(os.getcwd())
sys.path.insert(0, dirorg+"/src/")

# %%
import G2PnetSolver_v3 #G2PnetSolver_v2
#from imp import reload
#reload(G2PnetSolver_v2)

# %% [markdown]
# from G2PnetSolver_v2 import  G2PnetSolver as Solver
# from G2PnetSolver_v2 import  Grassmann_update

# %%
from G2PnetSolver_v3 import  G2PnetSolver as Solver
from G2PnetSolver_v3 import  Grassmann_update

# %%
choice = "near"

# %%
np.random.seed(seed=121)

if choice == "random":
    print("Random")
    Temp = np.random.rand(nsample, nsample)
    Temp_sym = (Temp + Temp.T) / 2 
    _, U_temp = np.linalg.eig(Temp_sym)
    U_test = U_temp[:, np.arange(ndim_latent)]
    U0 = U_test
elif choice == "near":
    print("Near optimal.")
    U0 = U

eta0 = 1
G_temp = np.random.rand(nsample, ndim_latent)
H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
U_init = Grassmann_update(U0, H_temp, eta=eta0)
# Out:
# Near optimal.

# %% [markdown]
# ### Compute the gradient $\frac{dL}{dU}$
# The loss function is given as negative log-likelihood of Gaussian process
#
# \begin{align}
# \mathcal{L}(\beta, \sigma, \mathbf{U}) &= \frac{pN}{2}\log(2\pi)+\frac{p}{2}\log\det(\mathbf{K}_{\beta, \sigma, \mathbf{U}})+\frac{1}{2}\text{tr}\left(\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{−1}\mathbf{X}\mathbf{X}^T\right) + \frac{\lambda}{2} \|\mathbf{U}\mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2}
# \end{align}
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{K}$
# \begin{align}
# \mathbf{T}&= 2\mathbf{T}_{0} - \text{diag}\left(\mathbf{T}_{0}\right),\\
# \mathbf{T}_{0} &= \frac{1}{2}\left(\mathbf{I} - \mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}\mathbf{X}\mathbf{X}^T/p \right)\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}, \\
# \mathbf{K}_{r,s} &= K_{\sigma}\left(\mathbf{U}_{r,:} , \mathbf{U}_{s,:}\right) + \beta \delta_{r,s}
# \end{align}
#
# For rbf kernel,
# \begin{align}
# \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{Z}}}{\partial \mathbf{U}_{m,j}}
# &= -\frac{l^{2}}{\sigma^2} \exp\left(-\frac{1}{2\sigma^2} \|\mathbf{U}_{m} -  \mathbf{U}_{n}\|^{2} \right)\left[2\left( \mathbf{U}_{m,i} - \mathbf{U}_{n,j} \right)\right]
# \end{align}
#
# The differential of the second norm term
# \begin{align}
# \frac{d}{d\mathbf{U}}\frac{1}{2}\|\mathbf{U} \mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2} &=
# \frac{d}{d\mathbf{U}}\frac{1}{2}\left[\text{tr}\left(\mathbf{U} \mathbf{U}^{T}\right) - \text{tr}\left(\mathbf{U}_{L}\mathbf{U}_{L}^{T}\mathbf{U}\mathbf{U}^{T}\right)\right]\\
# &= \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U}
# \end{align}
#
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{U}$
# \begin{align}
# \frac{\partial\mathcal{L}}{\partial\mathbf{U}} &= \left[\text{tr}\left( \mathbf{T} \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{U}}}{\partial \mathbf{U}_{m,j}} \right)\right]_{m,j} + \lambda \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U},
# \end{align}

# %%
if Ifsavedata:
    U_columns = [str(i) for i in np.arange(ndim_latent)]
    U_df = pd.DataFrame(data = U_init, columns=U_columns, dtype= float)
    if choice == "random":
        U_df['RANDOM'] = np.ones([nsample, 1])
    elif choice == "near":
        U_df['RANDOM'] = np.zeros([nsample, 1])
    
    U_df.to_csv("../data/U_init_03_31_16.csv")
    #U_df.to_csv("../data/U_init_bad_03_31_16.csv")

# %%
add_reg = True
lambda_var = 100

# %%
eta = 0.0001
kern = GPy.kern.RBF(2) 
solver = Solver(X=X, U=U_init, kernel=kern, U_ref= U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
# Out:
# kernel initialization ...
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i     f              |g|
#     00s03  006   1.813233e+02   7.753113e+02
#     00s11  015   1.746346e+02   2.772941e-02
#     00s12  017   1.746343e+02   7.771249e-08
#     00s12  018   1.746343e+02   7.771249e-08
# Runtime:     00s12
# Optimization status: Converged
#
# negative log-likelihood compute

# %%
max_iters = 2000
hist_nll_eu, hist_eta, hist_kern_eu = solver.optimize(max_iters = max_iters)
# Out:
# [step   0] neg-log-likelihood -1127.396971 stepsize 0.000
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -1130.420426 stepsize 0.000
# [step   2] neg-log-likelihood -1132.463422 stepsize 0.000
# [step   3] neg-log-likelihood -1133.044027 stepsize 0.000
# [step   4] neg-log-likelihood -1131.612097 stepsize 0.000
# [step   5] neg-log-likelihood -1127.688896 stepsize 0.000
# [step   6] neg-log-likelihood -1125.553043 stepsize 0.000
# [step   7] neg-log-likelihood -1120.858502 stepsize 0.000
# [step   8] neg-log-likelihood -1102.422996 stepsize 0.000
# [step   9] neg-log-likelihood -1085.564385 stepsize 0.000
# [step  10] neg-log-likelihood -1061.812017 stepsize 0.000
# [step  11] neg-log-likelihood -1023.869242 stepsize 0.000
# [step  12] neg-log-likelihood -948.466780 stepsize 0.000
# [step  13] neg-log-likelihood -825.429255 stepsize 0.000
# [step  14] neg-log-likelihood -735.688083 stepsize 0.000
# [step  15] neg-log-likelihood -700.497978 stepsize 0.000
# [step  16] neg-log-likelihood -704.008567 stepsize 0.000
# [step  17] neg-log-likelihood -718.064099 stepsize 0.000
# [step  18] neg-log-likelihood -729.615523 stepsize 0.000
# [step  19] neg-log-likelihood -745.298217 stepsize 0.000
# [step  20] neg-log-likelihood -760.834817 stepsize 0.000
# [step  21] neg-log-likelihood -778.796991 stepsize 0.000
# [step  22] neg-log-likelihood -802.010044 stepsize 0.000
# [step  23] neg-log-likelihood -832.493262 stepsize 0.000
# [step  24] neg-log-likelihood -863.228250 stepsize 0.000
# [step  25] neg-log-likelihood -888.924944 stepsize 0.000
# [step  26] neg-log-likelihood -913.080990 stepsize 0.000
# [step  27] neg-log-likelihood -935.939585 stepsize 0.000
# [step  28] neg-log-likelihood -956.781401 stepsize 0.000
# [step  29] neg-log-likelihood -974.502817 stepsize 0.000
# [step  30] neg-log-likelihood -993.227741 stepsize 0.000
# [step  31] neg-log-likelihood -1005.352336 stepsize 0.000
# [step  32] neg-log-likelihood -1017.638413 stepsize 0.000
# [step  33] neg-log-likelihood -1032.615467 stepsize 0.000
# [step  34] neg-log-likelihood -1039.766227 stepsize 0.000
# [step  35] neg-log-likelihood -1052.349297 stepsize 0.000
# [step  36] neg-log-likelihood -1062.656672 stepsize 0.000
# [step  37] neg-log-likelihood -1068.100976 stepsize 0.000
# [step  38] neg-log-likelihood -1074.592110 stepsize 0.000
# [step  39] neg-log-likelihood -1080.453922 stepsize 0.000
# [step  40] neg-log-likelihood -1086.600352 stepsize 0.000
# [step  41] neg-log-likelihood -1091.580244 stepsize 0.000
# [step  42] neg-log-likelihood -1095.942252 stepsize 0.000
# [step  43] neg-log-likelihood -1102.938211 stepsize 0.000
# [step  44] neg-log-likelihood -1107.718731 stepsize 0.000
# [step  45] neg-log-likelihood -1111.502668 stepsize 0.000
# [step  46] neg-log-likelihood -1116.039724 stepsize 0.000
# [step  47] neg-log-likelihood -1121.945620 stepsize 0.000
# [step  48] neg-log-likelihood -1131.717133 stepsize 0.000
# [step  49] neg-log-likelihood -1134.447149 stepsize 0.000
# [step  50] neg-log-likelihood -1143.531152 stepsize 0.000
# [step  51] neg-log-likelihood -1144.128753 stepsize 0.000
# [step  52] neg-log-likelihood -1152.051195 stepsize 0.000
# [step  53] neg-log-likelihood -1156.368107 stepsize 0.000
# [step  54] neg-log-likelihood -1159.883302 stepsize 0.000
# [step  55] neg-log-likelihood -1170.615361 stepsize 0.000
# [step  56] neg-log-likelihood -1171.441646 stepsize 0.000
# [step  57] neg-log-likelihood -1180.250501 stepsize 0.000
# [step  58] neg-log-likelihood -1182.782568 stepsize 0.000
# [step  59] neg-log-likelihood -1188.494532 stepsize 0.000
# [step  60] neg-log-likelihood -1191.026761 stepsize 0.000
# [step  61] neg-log-likelihood -1195.703687 stepsize 0.000
# [step  62] neg-log-likelihood -1199.060451 stepsize 0.000
# [step  63] neg-log-likelihood -1201.144240 stepsize 0.000
# [step  64] neg-log-likelihood -1205.394526 stepsize 0.000
# [step  65] neg-log-likelihood -1204.258666 stepsize 0.000
# [step  66] neg-log-likelihood -1212.421679 stepsize 0.000
# [step  67] neg-log-likelihood -1214.057876 stepsize 0.000
# [step  68] neg-log-likelihood -1216.130792 stepsize 0.000
# [step  69] neg-log-likelihood -1222.811583 stepsize 0.000
# [step  70] neg-log-likelihood -1220.596604 stepsize 0.000
# [step  71] neg-log-likelihood -1224.789046 stepsize 0.000
# [step  72] neg-log-likelihood -1235.327786 stepsize 0.000
# [step  73] neg-log-likelihood -1234.047859 stepsize 0.000
# [step  74] neg-log-likelihood -1239.417841 stepsize 0.000
# [step  75] neg-log-likelihood -1241.563942 stepsize 0.000
# [step  76] neg-log-likelihood -1245.996069 stepsize 0.000
# [step  77] neg-log-likelihood -1249.361262 stepsize 0.000
# [step  78] neg-log-likelihood -1252.329381 stepsize 0.000
# [step  79] neg-log-likelihood -1253.429608 stepsize 0.000
# [step  80] neg-log-likelihood -1260.830893 stepsize 0.000
# [step  81] neg-log-likelihood -1262.342762 stepsize 0.000
# [step  82] neg-log-likelihood -1267.342883 stepsize 0.000
# [step  83] neg-log-likelihood -1267.735571 stepsize 0.000
# [step  84] neg-log-likelihood -1268.317900 stepsize 0.000
# [step  85] neg-log-likelihood -1273.342921 stepsize 0.000
# [step  86] neg-log-likelihood -1278.060678 stepsize 0.000
# [step  87] neg-log-likelihood -1281.144146 stepsize 0.000
# [step  88] neg-log-likelihood -1287.094255 stepsize 0.000
# [step  89] neg-log-likelihood -1289.887773 stepsize 0.000
# [step  90] neg-log-likelihood -1292.343052 stepsize 0.000
# [step  91] neg-log-likelihood -1297.307109 stepsize 0.000
# [step  92] neg-log-likelihood -1304.218239 stepsize 0.000
# [step  93] neg-log-likelihood -1305.428080 stepsize 0.000
# [step  94] neg-log-likelihood -1307.099505 stepsize 0.000
# [step  95] neg-log-likelihood -1309.504359 stepsize 0.000
# [step  96] neg-log-likelihood -1313.261385 stepsize 0.000
# [step  97] neg-log-likelihood -1318.636375 stepsize 0.000
# [step  98] neg-log-likelihood -1323.142722 stepsize 0.000
# [step  99] neg-log-likelihood -1325.651694 stepsize 0.000
# [step 100] neg-log-likelihood -1332.001696 stepsize 0.000
# [step 101] neg-log-likelihood -1335.118938 stepsize 0.000
# [step 102] neg-log-likelihood -1338.550124 stepsize 0.000
# [step 103] neg-log-likelihood -1341.598052 stepsize 0.000
# [step 104] neg-log-likelihood -1347.027515 stepsize 0.000
# [step 105] neg-log-likelihood -1348.662084 stepsize 0.000
# [step 106] neg-log-likelihood -1355.137171 stepsize 0.000
# [step 107] neg-log-likelihood -1356.963147 stepsize 0.000
# [step 108] neg-log-likelihood -1361.381551 stepsize 0.000
# [step 109] neg-log-likelihood -1364.914940 stepsize 0.000
# [step 110] neg-log-likelihood -1368.826410 stepsize 0.000
# [step 111] neg-log-likelihood -1370.300416 stepsize 0.000
# [step 112] neg-log-likelihood -1376.232046 stepsize 0.000
# [step 113] neg-log-likelihood -1380.002132 stepsize 0.000
# [step 114] neg-log-likelihood -1385.786046 stepsize 0.000
# [step 115] neg-log-likelihood -1387.885335 stepsize 0.000
# [step 116] neg-log-likelihood -1391.912490 stepsize 0.000
# [step 117] neg-log-likelihood -1394.651043 stepsize 0.000
# [step 118] neg-log-likelihood -1395.452200 stepsize 0.000
# [step 119] neg-log-likelihood -1403.144883 stepsize 0.000
# [step 120] neg-log-likelihood -1406.451984 stepsize 0.000
# [step 121] neg-log-likelihood -1407.861956 stepsize 0.000
# [step 122] neg-log-likelihood -1412.221566 stepsize 0.000
# [step 123] neg-log-likelihood -1416.455775 stepsize 0.000
# [step 124] neg-log-likelihood -1417.372122 stepsize 0.000
# [step 125] neg-log-likelihood -1423.817992 stepsize 0.000
# [step 126] neg-log-likelihood -1426.647715 stepsize 0.000
# [step 127] neg-log-likelihood -1429.890641 stepsize 0.000
# [step 128] neg-log-likelihood -1435.014458 stepsize 0.000
# [step 129] neg-log-likelihood -1438.500332 stepsize 0.000
# [step 130] neg-log-likelihood -1436.619037 stepsize 0.000
# [step 131] neg-log-likelihood -1440.668950 stepsize 0.000
# [step 132] neg-log-likelihood -1439.964638 stepsize 0.000
# [step 133] neg-log-likelihood -1443.360353 stepsize 0.000
# [step 134] neg-log-likelihood -1444.716685 stepsize 0.000
# [step 135] neg-log-likelihood -1445.087971 stepsize 0.000
# [step 136] neg-log-likelihood -1449.530258 stepsize 0.000
# [step 137] neg-log-likelihood -1448.384517 stepsize 0.000
# [step 138] neg-log-likelihood -1450.747684 stepsize 0.000
# [step 139] neg-log-likelihood -1449.515014 stepsize 0.000
# [step 140] neg-log-likelihood -1452.164195 stepsize 0.000
# [step 141] neg-log-likelihood -1454.561271 stepsize 0.000
# [step 142] neg-log-likelihood -1452.915648 stepsize 0.000
# [step 143] neg-log-likelihood -1453.772016 stepsize 0.000
# [step 144] neg-log-likelihood -1458.224922 stepsize 0.000
# [step 145] neg-log-likelihood -1458.094035 stepsize 0.000
# [step 146] neg-log-likelihood -1457.294239 stepsize 0.000
# [step 147] neg-log-likelihood -1459.853627 stepsize 0.000
# [step 148] neg-log-likelihood -1464.582623 stepsize 0.000
# [step 149] neg-log-likelihood -1462.455620 stepsize 0.000
# [step 150] neg-log-likelihood -1465.288215 stepsize 0.000
# [step 151] neg-log-likelihood -1464.433407 stepsize 0.000
# [step 152] neg-log-likelihood -1465.948401 stepsize 0.000
# [step 153] neg-log-likelihood -1465.730507 stepsize 0.000
# [step 154] neg-log-likelihood -1467.375373 stepsize 0.000
# [step 155] neg-log-likelihood -1472.260831 stepsize 0.000
# [step 156] neg-log-likelihood -1470.856827 stepsize 0.000
# [step 157] neg-log-likelihood -1475.604620 stepsize 0.000
# [step 158] neg-log-likelihood -1473.780444 stepsize 0.000
# [step 159] neg-log-likelihood -1478.273682 stepsize 0.000
# [step 160] neg-log-likelihood -1477.452322 stepsize 0.000
# [step 161] neg-log-likelihood -1476.450683 stepsize 0.000
# [step 162] neg-log-likelihood -1478.619355 stepsize 0.000
# [step 163] neg-log-likelihood -1481.835614 stepsize 0.000
# [step 164] neg-log-likelihood -1477.658572 stepsize 0.000
# [step 165] neg-log-likelihood -1482.947280 stepsize 0.000
# [step 166] neg-log-likelihood -1484.134012 stepsize 0.000
# [step 167] neg-log-likelihood -1482.943277 stepsize 0.000
# [step 168] neg-log-likelihood -1482.062641 stepsize 0.000
# [step 169] neg-log-likelihood -1484.665716 stepsize 0.000
# [step 170] neg-log-likelihood -1487.190807 stepsize 0.000
# [step 171] neg-log-likelihood -1484.991736 stepsize 0.000
# [step 172] neg-log-likelihood -1484.779843 stepsize 0.000
# [step 173] neg-log-likelihood -1487.877370 stepsize 0.000
# [step 174] neg-log-likelihood -1487.296060 stepsize 0.000
# [step 175] neg-log-likelihood -1491.733399 stepsize 0.000
# [step 176] neg-log-likelihood -1489.719626 stepsize 0.000
# [step 177] neg-log-likelihood -1492.079134 stepsize 0.000
# [step 178] neg-log-likelihood -1493.627944 stepsize 0.000
# [step 179] neg-log-likelihood -1491.972840 stepsize 0.000
# [step 180] neg-log-likelihood -1488.626976 stepsize 0.000
# [step 181] neg-log-likelihood -1498.473397 stepsize 0.000
# [step 182] neg-log-likelihood -1492.568555 stepsize 0.000
# [step 183] neg-log-likelihood -1490.892224 stepsize 0.000
# [step 184] neg-log-likelihood -1489.714531 stepsize 0.000
# [step 185] neg-log-likelihood -1494.309773 stepsize 0.000
# [step 186] neg-log-likelihood -1491.291034 stepsize 0.000
# [step 187] neg-log-likelihood -1494.189614 stepsize 0.000
# [step 188] neg-log-likelihood -1494.749625 stepsize 0.000
# [step 189] neg-log-likelihood -1491.334745 stepsize 0.000
# [step 190] neg-log-likelihood -1491.251973 stepsize 0.000
# [step 191] neg-log-likelihood -1493.611398 stepsize 0.000
# [step 192] neg-log-likelihood -1494.324775 stepsize 0.000
# [step 193] neg-log-likelihood -1493.019010 stepsize 0.000
# [step 194] neg-log-likelihood -1492.941280 stepsize 0.000
# [step 195] neg-log-likelihood -1494.703466 stepsize 0.000
# [step 196] neg-log-likelihood -1493.094555 stepsize 0.000
# [step 197] neg-log-likelihood -1497.898374 stepsize 0.000
# [step 198] neg-log-likelihood -1497.515546 stepsize 0.000
# [step 199] neg-log-likelihood -1497.500909 stepsize 0.000
# [step 200] neg-log-likelihood -1495.973909 stepsize 0.000
# [step 201] neg-log-likelihood -1499.804318 stepsize 0.000
# [step 202] neg-log-likelihood -1498.476777 stepsize 0.000
# [step 203] neg-log-likelihood -1498.769660 stepsize 0.000
# [step 204] neg-log-likelihood -1496.862524 stepsize 0.000
# [step 205] neg-log-likelihood -1501.406427 stepsize 0.000
# [step 206] neg-log-likelihood -1499.178405 stepsize 0.000
# [step 207] neg-log-likelihood -1498.781015 stepsize 0.000
# [step 208] neg-log-likelihood -1502.819562 stepsize 0.000
# [step 209] neg-log-likelihood -1501.941440 stepsize 0.000
# [step 210] neg-log-likelihood -1498.794345 stepsize 0.000
# [step 211] neg-log-likelihood -1498.527330 stepsize 0.000
# [step 212] neg-log-likelihood -1499.426122 stepsize 0.000
# [step 213] neg-log-likelihood -1499.207345 stepsize 0.000
# [step 214] neg-log-likelihood -1500.681401 stepsize 0.000
# [step 215] neg-log-likelihood -1501.992854 stepsize 0.000
# [step 216] neg-log-likelihood -1498.578558 stepsize 0.000
# [step 217] neg-log-likelihood -1502.574782 stepsize 0.000
# [step 218] neg-log-likelihood -1500.782352 stepsize 0.000
# [step 219] neg-log-likelihood -1504.199350 stepsize 0.000
# [step 220] neg-log-likelihood -1498.103225 stepsize 0.000
# [step 221] neg-log-likelihood -1499.015279 stepsize 0.000
# [step 222] neg-log-likelihood -1501.065820 stepsize 0.000
# [step 223] neg-log-likelihood -1502.031369 stepsize 0.000
# [step 224] neg-log-likelihood -1498.931613 stepsize 0.000
# [step 225] neg-log-likelihood -1501.670147 stepsize 0.000
# [step 226] neg-log-likelihood -1506.558037 stepsize 0.000
# [step 227] neg-log-likelihood -1501.684368 stepsize 0.000
# [step 228] neg-log-likelihood -1502.990254 stepsize 0.000
# [step 229] neg-log-likelihood -1503.335476 stepsize 0.000
# [step 230] neg-log-likelihood -1502.277498 stepsize 0.000
# [step 231] neg-log-likelihood -1503.090580 stepsize 0.000
# [step 232] neg-log-likelihood -1503.113418 stepsize 0.000
# [step 233] neg-log-likelihood -1504.225405 stepsize 0.000
# [step 234] neg-log-likelihood -1507.800647 stepsize 0.000
# [step 235] neg-log-likelihood -1505.172275 stepsize 0.000
# [step 236] neg-log-likelihood -1501.703320 stepsize 0.000
# [step 237] neg-log-likelihood -1505.838380 stepsize 0.000
# [step 238] neg-log-likelihood -1504.816158 stepsize 0.000
# [step 239] neg-log-likelihood -1504.539943 stepsize 0.000
# [step 240] neg-log-likelihood -1504.715286 stepsize 0.000
# [step 241] neg-log-likelihood -1505.296241 stepsize 0.000
# [step 242] neg-log-likelihood -1503.621387 stepsize 0.000
# [step 243] neg-log-likelihood -1504.651946 stepsize 0.000
# [step 244] neg-log-likelihood -1512.874047 stepsize 0.000
# [step 245] neg-log-likelihood -1503.417211 stepsize 0.000
# [step 246] neg-log-likelihood -1502.624691 stepsize 0.000
# [step 247] neg-log-likelihood -1502.181345 stepsize 0.000
# [step 248] neg-log-likelihood -1499.819786 stepsize 0.000
# [step 249] neg-log-likelihood -1502.916230 stepsize 0.000
# [step 250] neg-log-likelihood -1502.583279 stepsize 0.000
# [step 251] neg-log-likelihood -1500.447026 stepsize 0.000
# [step 252] neg-log-likelihood -1500.815398 stepsize 0.000
# [step 253] neg-log-likelihood -1499.279390 stepsize 0.000
# [step 254] neg-log-likelihood -1503.007483 stepsize 0.000
# [step 255] neg-log-likelihood -1502.747388 stepsize 0.000
# [step 256] neg-log-likelihood -1505.611159 stepsize 0.000
# [step 257] neg-log-likelihood -1501.238823 stepsize 0.000
# [step 258] neg-log-likelihood -1502.253260 stepsize 0.000
# [step 259] neg-log-likelihood -1501.731688 stepsize 0.000
# [step 260] neg-log-likelihood -1501.465072 stepsize 0.000
# [step 261] neg-log-likelihood -1501.900995 stepsize 0.000
# [step 262] neg-log-likelihood -1502.589093 stepsize 0.000
# [step 263] neg-log-likelihood -1500.562148 stepsize 0.000
# [step 264] neg-log-likelihood -1499.477390 stepsize 0.000
# [step 265] neg-log-likelihood -1500.676309 stepsize 0.000
# [step 266] neg-log-likelihood -1505.212102 stepsize 0.000
# [step 267] neg-log-likelihood -1502.200598 stepsize 0.000
# [step 268] neg-log-likelihood -1501.957089 stepsize 0.000
# [step 269] neg-log-likelihood -1502.548741 stepsize 0.000
# [step 270] neg-log-likelihood -1504.737942 stepsize 0.000
# [step 271] neg-log-likelihood -1502.283298 stepsize 0.000
# [step 272] neg-log-likelihood -1503.022794 stepsize 0.000
# [step 273] neg-log-likelihood -1501.373766 stepsize 0.000
# [step 274] neg-log-likelihood -1496.453508 stepsize 0.000
# [step 275] neg-log-likelihood -1502.096858 stepsize 0.000
# [step 276] neg-log-likelihood -1501.269940 stepsize 0.000
# [step 277] neg-log-likelihood -1499.988712 stepsize 0.000
# [step 278] neg-log-likelihood -1499.079271 stepsize 0.000
# [step 279] neg-log-likelihood -1501.471705 stepsize 0.000
# [step 280] neg-log-likelihood -1499.216436 stepsize 0.000
# [step 281] neg-log-likelihood -1504.177094 stepsize 0.000
# [step 282] neg-log-likelihood -1498.725272 stepsize 0.000
# [step 283] neg-log-likelihood -1500.042159 stepsize 0.000
# [step 284] neg-log-likelihood -1501.914091 stepsize 0.000
# [step 285] neg-log-likelihood -1503.613233 stepsize 0.000
# [step 286] neg-log-likelihood -1503.593566 stepsize 0.000
# [step 287] neg-log-likelihood -1495.106689 stepsize 0.000
# [step 288] neg-log-likelihood -1499.017109 stepsize 0.000
# [step 289] neg-log-likelihood -1500.788751 stepsize 0.000
# [step 290] neg-log-likelihood -1498.636417 stepsize 0.000
# [step 291] neg-log-likelihood -1500.416086 stepsize 0.000
# [step 292] neg-log-likelihood -1494.921066 stepsize 0.000
# [step 293] neg-log-likelihood -1501.806691 stepsize 0.000
# [step 294] neg-log-likelihood -1498.268466 stepsize 0.000
# [step 295] neg-log-likelihood -1496.939874 stepsize 0.000
# [step 296] neg-log-likelihood -1492.481949 stepsize 0.000
# [step 297] neg-log-likelihood -1497.872403 stepsize 0.000
# [step 298] neg-log-likelihood -1492.745971 stepsize 0.000
# [step 299] neg-log-likelihood -1495.843901 stepsize 0.000
# [step 300] neg-log-likelihood -1496.743478 stepsize 0.000
# [step 301] neg-log-likelihood -1495.814006 stepsize 0.000
# [step 302] neg-log-likelihood -1492.514285 stepsize 0.000
# [step 303] neg-log-likelihood -1493.591489 stepsize 0.000
# [step 304] neg-log-likelihood -1492.553531 stepsize 0.000
# [step 305] neg-log-likelihood -1492.215505 stepsize 0.000
# [step 306] neg-log-likelihood -1492.168326 stepsize 0.000
# [step 307] neg-log-likelihood -1492.352402 stepsize 0.000
# [step 308] neg-log-likelihood -1493.121871 stepsize 0.000
# [step 309] neg-log-likelihood -1492.571752 stepsize 0.000
# [step 310] neg-log-likelihood -1491.289070 stepsize 0.000
# [step 311] neg-log-likelihood -1487.274581 stepsize 0.000
# [step 312] neg-log-likelihood -1489.144421 stepsize 0.000
# [step 313] neg-log-likelihood -1487.294125 stepsize 0.000
# [step 314] neg-log-likelihood -1489.130193 stepsize 0.000
# [step 315] neg-log-likelihood -1486.870918 stepsize 0.000
# [step 316] neg-log-likelihood -1489.409060 stepsize 0.000
# [step 317] neg-log-likelihood -1486.946559 stepsize 0.000
# [step 318] neg-log-likelihood -1484.715050 stepsize 0.000
# [step 319] neg-log-likelihood -1486.097236 stepsize 0.000
# [step 320] neg-log-likelihood -1484.450611 stepsize 0.000
# [step 321] neg-log-likelihood -1486.823971 stepsize 0.000
# [step 322] neg-log-likelihood -1484.356557 stepsize 0.000
# [step 323] neg-log-likelihood -1482.476820 stepsize 0.000
# [step 324] neg-log-likelihood -1479.693552 stepsize 0.000
# [step 325] neg-log-likelihood -1484.379531 stepsize 0.000
# [step 326] neg-log-likelihood -1481.088854 stepsize 0.000
# [step 327] neg-log-likelihood -1477.649002 stepsize 0.000
# [step 328] neg-log-likelihood -1479.346657 stepsize 0.000
# [step 329] neg-log-likelihood -1477.517212 stepsize 0.000
# [step 330] neg-log-likelihood -1479.994140 stepsize 0.000
# [step 331] neg-log-likelihood -1480.476126 stepsize 0.000
# [step 332] neg-log-likelihood -1476.153717 stepsize 0.000
# [step 333] neg-log-likelihood -1475.447226 stepsize 0.000
# [step 334] neg-log-likelihood -1475.330548 stepsize 0.000
# [step 335] neg-log-likelihood -1474.538604 stepsize 0.000
# [step 336] neg-log-likelihood -1472.995265 stepsize 0.000
# [step 337] neg-log-likelihood -1475.925820 stepsize 0.000
# [step 338] neg-log-likelihood -1474.500426 stepsize 0.000
# [step 339] neg-log-likelihood -1467.277896 stepsize 0.000
# [step 340] neg-log-likelihood -1472.210265 stepsize 0.000
# [step 341] neg-log-likelihood -1468.144596 stepsize 0.000
# [step 342] neg-log-likelihood -1473.084548 stepsize 0.000
# [step 343] neg-log-likelihood -1472.069197 stepsize 0.000
# [step 344] neg-log-likelihood -1468.663239 stepsize 0.000
# [step 345] neg-log-likelihood -1467.583971 stepsize 0.000
# [step 346] neg-log-likelihood -1467.606211 stepsize 0.000
# [step 347] neg-log-likelihood -1465.497016 stepsize 0.000
# [step 348] neg-log-likelihood -1464.159080 stepsize 0.000
# [step 349] neg-log-likelihood -1463.713291 stepsize 0.000
# [step 350] neg-log-likelihood -1461.920840 stepsize 0.000
# [step 351] neg-log-likelihood -1468.065449 stepsize 0.000
# [step 352] neg-log-likelihood -1463.474193 stepsize 0.000
# [step 353] neg-log-likelihood -1462.649105 stepsize 0.000
# [step 354] neg-log-likelihood -1460.811049 stepsize 0.000
# [step 355] neg-log-likelihood -1461.414561 stepsize 0.000
# [step 356] neg-log-likelihood -1458.532690 stepsize 0.000
# [step 357] neg-log-likelihood -1458.064852 stepsize 0.000
# [step 358] neg-log-likelihood -1457.390965 stepsize 0.000
# [step 359] neg-log-likelihood -1459.688443 stepsize 0.000
# [step 360] neg-log-likelihood -1455.671029 stepsize 0.000
# [step 361] neg-log-likelihood -1453.473512 stepsize 0.000
# [step 362] neg-log-likelihood -1457.798757 stepsize 0.000
# [step 363] neg-log-likelihood -1458.543715 stepsize 0.000
# [step 364] neg-log-likelihood -1455.412360 stepsize 0.000
# [step 365] neg-log-likelihood -1450.402346 stepsize 0.000
# [step 366] neg-log-likelihood -1450.018389 stepsize 0.000
# [step 367] neg-log-likelihood -1447.786765 stepsize 0.000
# [step 368] neg-log-likelihood -1451.372059 stepsize 0.000
# [step 369] neg-log-likelihood -1448.446455 stepsize 0.000
# [step 370] neg-log-likelihood -1448.158745 stepsize 0.000
# [step 371] neg-log-likelihood -1447.788900 stepsize 0.000
# [step 372] neg-log-likelihood -1443.819722 stepsize 0.000
# [step 373] neg-log-likelihood -1442.831349 stepsize 0.000
# [step 374] neg-log-likelihood -1444.568180 stepsize 0.000
# [step 375] neg-log-likelihood -1441.905452 stepsize 0.000
# [step 376] neg-log-likelihood -1439.373146 stepsize 0.000
# [step 377] neg-log-likelihood -1440.530347 stepsize 0.000
# [step 378] neg-log-likelihood -1443.927717 stepsize 0.000
# [step 379] neg-log-likelihood -1432.923189 stepsize 0.000
# [step 380] neg-log-likelihood -1437.342622 stepsize 0.000
# [step 381] neg-log-likelihood -1437.023425 stepsize 0.000
# [step 382] neg-log-likelihood -1433.639304 stepsize 0.000
# [step 383] neg-log-likelihood -1434.241110 stepsize 0.000
# [step 384] neg-log-likelihood -1432.352524 stepsize 0.000
# [step 385] neg-log-likelihood -1429.179809 stepsize 0.000
# [step 386] neg-log-likelihood -1428.241883 stepsize 0.000
# [step 387] neg-log-likelihood -1427.710705 stepsize 0.000
# [step 388] neg-log-likelihood -1424.795257 stepsize 0.000
# [step 389] neg-log-likelihood -1427.387001 stepsize 0.000
# [step 390] neg-log-likelihood -1422.291248 stepsize 0.000
# [step 391] neg-log-likelihood -1418.110341 stepsize 0.000
# [step 392] neg-log-likelihood -1419.358368 stepsize 0.000
# [step 393] neg-log-likelihood -1425.222030 stepsize 0.000
# [step 394] neg-log-likelihood -1420.689993 stepsize 0.000
# [step 395] neg-log-likelihood -1416.649341 stepsize 0.000
# [step 396] neg-log-likelihood -1420.564317 stepsize 0.000
# [step 397] neg-log-likelihood -1414.324656 stepsize 0.000
# [step 398] neg-log-likelihood -1414.420705 stepsize 0.000
# [step 399] neg-log-likelihood -1414.280046 stepsize 0.000
# [step 400] neg-log-likelihood -1413.518354 stepsize 0.000
# [step 401] neg-log-likelihood -1413.485357 stepsize 0.000
# [step 402] neg-log-likelihood -1409.137236 stepsize 0.000
# [step 403] neg-log-likelihood -1411.790411 stepsize 0.000
# [step 404] neg-log-likelihood -1409.891889 stepsize 0.000
# [step 405] neg-log-likelihood -1407.734515 stepsize 0.000
# [step 406] neg-log-likelihood -1406.510303 stepsize 0.000
# [step 407] neg-log-likelihood -1407.015445 stepsize 0.000
# [step 408] neg-log-likelihood -1407.043887 stepsize 0.000
# [step 409] neg-log-likelihood -1402.464313 stepsize 0.000
# [step 410] neg-log-likelihood -1406.126384 stepsize 0.000
# [step 411] neg-log-likelihood -1409.683594 stepsize 0.000
# [step 412] neg-log-likelihood -1406.417386 stepsize 0.000
# [step 413] neg-log-likelihood -1403.479625 stepsize 0.000
# [step 414] neg-log-likelihood -1405.138271 stepsize 0.000
# [step 415] neg-log-likelihood -1401.537068 stepsize 0.000
# [step 416] neg-log-likelihood -1405.186363 stepsize 0.000
# [step 417] neg-log-likelihood -1398.812456 stepsize 0.000
# [step 418] neg-log-likelihood -1403.441070 stepsize 0.000
# [step 419] neg-log-likelihood -1399.926862 stepsize 0.000
# [step 420] neg-log-likelihood -1404.308219 stepsize 0.000
# [step 421] neg-log-likelihood -1399.830799 stepsize 0.000
# [step 422] neg-log-likelihood -1403.695089 stepsize 0.000
# [step 423] neg-log-likelihood -1398.899534 stepsize 0.000
# [step 424] neg-log-likelihood -1401.584319 stepsize 0.000
# [step 425] neg-log-likelihood -1399.668756 stepsize 0.000
# [step 426] neg-log-likelihood -1397.253497 stepsize 0.000
# [step 427] neg-log-likelihood -1399.555608 stepsize 0.000
# [step 428] neg-log-likelihood -1403.103575 stepsize 0.000
# [step 429] neg-log-likelihood -1400.342314 stepsize 0.000
# [step 430] neg-log-likelihood -1398.220136 stepsize 0.000
# [step 431] neg-log-likelihood -1398.143558 stepsize 0.000
# [step 432] neg-log-likelihood -1400.329200 stepsize 0.000
# [step 433] neg-log-likelihood -1393.230724 stepsize 0.000
# [step 434] neg-log-likelihood -1390.813267 stepsize 0.000
# [step 435] neg-log-likelihood -1394.436546 stepsize 0.000
# [step 436] neg-log-likelihood -1390.531964 stepsize 0.000
# [step 437] neg-log-likelihood -1387.571425 stepsize 0.000
# [step 438] neg-log-likelihood -1385.240866 stepsize 0.000
# [step 439] neg-log-likelihood -1387.770044 stepsize 0.000
# [step 440] neg-log-likelihood -1383.477572 stepsize 0.000
# [step 441] neg-log-likelihood -1379.649441 stepsize 0.000
# [step 442] neg-log-likelihood -1374.245657 stepsize 0.000
# [step 443] neg-log-likelihood -1372.626459 stepsize 0.000
# [step 444] neg-log-likelihood -1367.890065 stepsize 0.000
# [step 445] neg-log-likelihood -1361.523604 stepsize 0.000
# [step 446] neg-log-likelihood -1358.946917 stepsize 0.000
# [step 447] neg-log-likelihood -1355.569229 stepsize 0.000
# [step 448] neg-log-likelihood -1345.243367 stepsize 0.000
# [step 449] neg-log-likelihood -1334.801424 stepsize 0.000
# [step 450] neg-log-likelihood -1322.232213 stepsize 0.000
# [step 451] neg-log-likelihood -1305.334878 stepsize 0.000
# [step 452] neg-log-likelihood -1275.448779 stepsize 0.000
# [step 453] neg-log-likelihood -1232.918334 stepsize 0.000
# [step 454] neg-log-likelihood -1127.589953 stepsize 0.000
# [step 455] neg-log-likelihood -1001.325516 stepsize 0.000
# [step 456] neg-log-likelihood -981.570635 stepsize 0.000
# [step 457] neg-log-likelihood -1068.879213 stepsize 0.000
# [step 458] neg-log-likelihood -1151.864035 stepsize 0.000
# [step 459] neg-log-likelihood -1387.082989 stepsize 0.000
# [step 460] neg-log-likelihood -1425.858767 stepsize 0.000
# [step 461] neg-log-likelihood -1522.477825 stepsize 0.000
# [step 462] neg-log-likelihood -1526.232357 stepsize 0.000
# [step 463] neg-log-likelihood -1549.024950 stepsize 0.000
# [step 464] neg-log-likelihood -1542.794046 stepsize 0.000
# [step 465] neg-log-likelihood -1545.798643 stepsize 0.000
# [step 466] neg-log-likelihood -1533.097939 stepsize 0.000
# [step 467] neg-log-likelihood -1527.008492 stepsize 0.000
# [step 468] neg-log-likelihood -1523.988070 stepsize 0.000
# [step 469] neg-log-likelihood -1516.534884 stepsize 0.000
# [step 470] neg-log-likelihood -1518.276174 stepsize 0.000
# [step 471] neg-log-likelihood -1502.513411 stepsize 0.000
# [step 472] neg-log-likelihood -1490.944376 stepsize 0.000
# [step 473] neg-log-likelihood -1482.756238 stepsize 0.000
# [step 474] neg-log-likelihood -1471.341368 stepsize 0.000
# [step 475] neg-log-likelihood -1448.841516 stepsize 0.000
# [step 476] neg-log-likelihood -1436.727810 stepsize 0.000
# [step 477] neg-log-likelihood -1403.901962 stepsize 0.000
# [step 478] neg-log-likelihood -1349.261668 stepsize 0.000
# [step 479] neg-log-likelihood -1248.753257 stepsize 0.000
# [step 480] neg-log-likelihood -1085.478794 stepsize 0.000
# [step 481] neg-log-likelihood -1481.714828 stepsize 0.000
# [step 482] neg-log-likelihood -1455.996177 stepsize 0.000
# [step 483] neg-log-likelihood -1388.931070 stepsize 0.000
# [step 484] neg-log-likelihood -1460.652472 stepsize 0.000
# [step 485] neg-log-likelihood -1457.540786 stepsize 0.000
# [step 486] neg-log-likelihood -1461.353271 stepsize 0.000
# [step 487] neg-log-likelihood -1463.490256 stepsize 0.000
# [step 488] neg-log-likelihood -1456.893872 stepsize 0.000
# [step 489] neg-log-likelihood -1435.395543 stepsize 0.000
# [step 490] neg-log-likelihood -1399.626831 stepsize 0.000
# [step 491] neg-log-likelihood -1320.603575 stepsize 0.000
# [step 492] neg-log-likelihood -1165.831348 stepsize 0.000
# [step 493] neg-log-likelihood -1460.221307 stepsize 0.000
# [step 494] neg-log-likelihood -1491.416012 stepsize 0.000
# [step 495] neg-log-likelihood -1540.356805 stepsize 0.000
# [step 496] neg-log-likelihood -1574.022847 stepsize 0.000
# [step 497] neg-log-likelihood -1591.937578 stepsize 0.000
# [step 498] neg-log-likelihood -1579.793479 stepsize 0.000
# [step 499] neg-log-likelihood -1572.484748 stepsize 0.000
# [step 500] neg-log-likelihood -1543.488529 stepsize 0.000
# [step 501] neg-log-likelihood -1446.590199 stepsize 0.000
# [step 502] neg-log-likelihood -1201.673833 stepsize 0.000
# [step 503] neg-log-likelihood -1076.007524 stepsize 0.000
# [step 504] neg-log-likelihood -1020.024777 stepsize 0.000
# [step 505] neg-log-likelihood -1535.610443 stepsize 0.000
# [step 506] neg-log-likelihood -1252.220859 stepsize 0.000
# [step 507] neg-log-likelihood -1337.236174 stepsize 0.000
# [step 508] neg-log-likelihood -1247.098049 stepsize 0.000
# [step 509] neg-log-likelihood -1373.208867 stepsize 0.000
# [step 510] neg-log-likelihood -1442.600972 stepsize 0.000
# [step 511] neg-log-likelihood -1419.266128 stepsize 0.000
# [step 512] neg-log-likelihood -1394.079334 stepsize 0.000
# [step 513] neg-log-likelihood -1360.945884 stepsize 0.000
# [step 514] neg-log-likelihood -1092.134712 stepsize 0.000
# [step 515] neg-log-likelihood -1222.895587 stepsize 0.000
# [step 516] neg-log-likelihood -1407.921068 stepsize 0.000
# [step 517] neg-log-likelihood -1448.919990 stepsize 0.000
# [step 518] neg-log-likelihood -1508.476004 stepsize 0.000
# [step 519] neg-log-likelihood -1464.024157 stepsize 0.000
# [step 520] neg-log-likelihood -1352.074716 stepsize 0.000
# [step 521] neg-log-likelihood -1348.572446 stepsize 0.000
# [step 522] neg-log-likelihood -1216.117251 stepsize 0.000
# [step 523] neg-log-likelihood -1371.182769 stepsize 0.000
# [step 524] neg-log-likelihood -1333.841706 stepsize 0.000
# [step 525] neg-log-likelihood -1450.461637 stepsize 0.000
# [step 526] neg-log-likelihood -1587.982016 stepsize 0.000
# [step 527] neg-log-likelihood -1616.005593 stepsize 0.000
# [step 528] neg-log-likelihood -1628.581039 stepsize 0.000
# [step 529] neg-log-likelihood -1618.348662 stepsize 0.000
# [step 530] neg-log-likelihood -1602.996803 stepsize 0.000
# [step 531] neg-log-likelihood -1561.477441 stepsize 0.000
# [step 532] neg-log-likelihood -1460.768712 stepsize 0.000
# [step 533] neg-log-likelihood -1408.430140 stepsize 0.000
# [step 534] neg-log-likelihood -1339.380101 stepsize 0.000
# [step 535] neg-log-likelihood -1424.764205 stepsize 0.000
# [step 536] neg-log-likelihood -1347.165594 stepsize 0.000
# [step 537] neg-log-likelihood -1445.199858 stepsize 0.000
# [step 538] neg-log-likelihood -1098.053937 stepsize 0.000
# [step 539] neg-log-likelihood -1482.130350 stepsize 0.000
# [step 540] neg-log-likelihood -1360.735328 stepsize 0.000
# [step 541] neg-log-likelihood -1407.292510 stepsize 0.000
# [step 542] neg-log-likelihood -1600.744423 stepsize 0.000
# [step 543] neg-log-likelihood -1633.710267 stepsize 0.000
# [step 544] neg-log-likelihood -1615.314407 stepsize 0.000
# [step 545] neg-log-likelihood -1596.522159 stepsize 0.000
# [step 546] neg-log-likelihood -1568.362163 stepsize 0.000
# [step 547] neg-log-likelihood -1530.893063 stepsize 0.000
# [step 548] neg-log-likelihood -1463.314415 stepsize 0.000
# [step 549] neg-log-likelihood -1286.102466 stepsize 0.000
# [step 550] neg-log-likelihood -1641.033128 stepsize 0.000
# [step 551] neg-log-likelihood -1696.216677 stepsize 0.000
# [step 552] neg-log-likelihood -1671.468212 stepsize 0.000
# [step 553] neg-log-likelihood -1508.673951 stepsize 0.000
# [step 554] neg-log-likelihood -1467.473178 stepsize 0.000
# [step 555] neg-log-likelihood -1434.678749 stepsize 0.000
# [step 556] neg-log-likelihood -1411.768270 stepsize 0.000
# [step 557] neg-log-likelihood -1394.399459 stepsize 0.000
# [step 558] neg-log-likelihood -1354.088694 stepsize 0.000
# [step 559] neg-log-likelihood -1306.113071 stepsize 0.000
# [step 560] neg-log-likelihood -1315.355326 stepsize 0.000
# [step 561] neg-log-likelihood -1603.182737 stepsize 0.000
# [step 562] neg-log-likelihood -1259.979604 stepsize 0.000
# [step 563] neg-log-likelihood -1680.141573 stepsize 0.000
# [step 564] neg-log-likelihood -1537.523169 stepsize 0.000
# [step 565] neg-log-likelihood -1530.919559 stepsize 0.000
# [step 566] neg-log-likelihood -1453.989317 stepsize 0.000
# [step 567] neg-log-likelihood -1283.162969 stepsize 0.000
# [step 568] neg-log-likelihood -1175.479523 stepsize 0.000
# [step 569] neg-log-likelihood -1537.288337 stepsize 0.000
# [step 570] neg-log-likelihood -1467.242309 stepsize 0.000
# [step 571] neg-log-likelihood -1487.049743 stepsize 0.000
# [step 572] neg-log-likelihood -1616.050072 stepsize 0.000
# [step 573] neg-log-likelihood -1633.342835 stepsize 0.000
# [step 574] neg-log-likelihood -1647.429663 stepsize 0.000
# [step 575] neg-log-likelihood -1632.149424 stepsize 0.000
# [step 576] neg-log-likelihood -1606.256468 stepsize 0.000
# [step 577] neg-log-likelihood -1577.771482 stepsize 0.000
# [step 578] neg-log-likelihood -1530.278972 stepsize 0.000
# [step 579] neg-log-likelihood -1457.674009 stepsize 0.000
# [step 580] neg-log-likelihood -1208.934203 stepsize 0.000
# [step 581] neg-log-likelihood -1758.261438 stepsize 0.000
# [step 582] neg-log-likelihood -1233.427397 stepsize 0.000
# [step 583] neg-log-likelihood -963.376768 stepsize 0.000
# [step 584] neg-log-likelihood -1347.447188 stepsize 0.000
# [step 585] neg-log-likelihood -1386.319317 stepsize 0.000
# [step 586] neg-log-likelihood -1247.982711 stepsize 0.000
# [step 587] neg-log-likelihood -1545.893278 stepsize 0.000
# [step 588] neg-log-likelihood -1474.534677 stepsize 0.000
# [step 589] neg-log-likelihood -1572.961531 stepsize 0.000
# [step 590] neg-log-likelihood -1615.133327 stepsize 0.000
# [step 591] neg-log-likelihood -1610.349065 stepsize 0.000
# [step 592] neg-log-likelihood -1600.829253 stepsize 0.000
# [step 593] neg-log-likelihood -1592.276129 stepsize 0.000
# [step 594] neg-log-likelihood -1582.602023 stepsize 0.000
# [step 595] neg-log-likelihood -1574.802005 stepsize 0.000
# [step 596] neg-log-likelihood -1558.154708 stepsize 0.000
# [step 597] neg-log-likelihood -1541.497838 stepsize 0.000
# [step 598] neg-log-likelihood -1511.965508 stepsize 0.000
# [step 599] neg-log-likelihood -1481.577404 stepsize 0.000
# [step 600] neg-log-likelihood -1435.214601 stepsize 0.000
# [step 601] neg-log-likelihood -1385.306339 stepsize 0.000
# [step 602] neg-log-likelihood -1325.160069 stepsize 0.000
# [step 603] neg-log-likelihood -1026.477817 stepsize 0.000
# [step 604] neg-log-likelihood -929.126318 stepsize 0.000
# [step 605] neg-log-likelihood -944.499051 stepsize 0.000
# [step 606] neg-log-likelihood -1435.849247 stepsize 0.000
# [step 607] neg-log-likelihood -1311.761441 stepsize 0.000
# [step 608] neg-log-likelihood -1407.600584 stepsize 0.000
# [step 609] neg-log-likelihood -1312.046619 stepsize 0.000
# [step 610] neg-log-likelihood -1132.225857 stepsize 0.000
# [step 611] neg-log-likelihood -1394.729080 stepsize 0.000
# [step 612] neg-log-likelihood -1441.788370 stepsize 0.000
# [step 613] neg-log-likelihood -1467.021158 stepsize 0.000
# [step 614] neg-log-likelihood -1463.964590 stepsize 0.000
# [step 615] neg-log-likelihood -1460.785016 stepsize 0.000
# [step 616] neg-log-likelihood -1431.334098 stepsize 0.000
# [step 617] neg-log-likelihood -1398.199746 stepsize 0.000
# [step 618] neg-log-likelihood -1238.059126 stepsize 0.000
# [step 619] neg-log-likelihood -1311.454834 stepsize 0.000
# [step 620] neg-log-likelihood -1655.725235 stepsize 0.000
# [step 621] neg-log-likelihood -1670.577754 stepsize 0.000
# [step 622] neg-log-likelihood -1677.523783 stepsize 0.000
# [step 623] neg-log-likelihood -1676.147017 stepsize 0.000
# [step 624] neg-log-likelihood -1677.299551 stepsize 0.000
# [step 625] neg-log-likelihood -1684.158355 stepsize 0.000
# [step 626] neg-log-likelihood -1689.831657 stepsize 0.000
# [step 627] neg-log-likelihood -1688.433446 stepsize 0.000

# %%
kern_grass = GPy.kern.RBF(2) 
solver2 = Solver(X=X, U=U_init, kernel=kern_grass, U_ref = U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
hist_nll_grass, hist_eta, hist_kern_grass = solver2.optimize(max_iters = max_iters, optimizor = "grad_descent_grass")

# %%
trail = 4

# %%
fig= plt.figure(4)
fig.set_size_inches(10.0, 6.0)
plt.style.use('seaborn-white')
ax = plt.axes()
h1, = plt.plot(np.arange(max_iters), hist_nll_eu, 'b')
h2, = plt.plot(np.arange(max_iters), hist_nll_grass, 'r')
if add_reg:
    ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                         r"Grassmann ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
          fontsize = 15, loc='upper right', frameon=True)
else:    
    ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f})".format(eta), r"Grassmann ($\eta$ = {0:5.4f})".format(eta)], \
          fontsize = 15, loc='upper right', frameon=True)
plt.grid(1)
plt.ylabel('negative log-likelihood', fontsize = 15)
plt.xlabel('iterations', fontsize = 15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show
if Ifsavefig:
    file_org = "../figures/nll_iters_Grass_Eu_" + str(trail) + "_"
    file_tail = "_03_31_16.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
solver.add_reg

# %%
# %xdel solver
# %xdel solver2

# %% [markdown]
# Ifsavefig = True
# add_reg = False
# from imp import reload
# reload(G2PnetSolver_v3)
# from G2PnetSolver_v3 import  G2PnetSolver as Solver
# from G2PnetSolver_v3 import  Grassmann_update
