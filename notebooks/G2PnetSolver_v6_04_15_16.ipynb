# %% [markdown]
# # G$^2$Pnet: The Grassmanian Gaussian Process Network
# We check the implementation of G2PnetSolver (ver 6.) with conjugate gradient descent class in ../src/
#
# Created by Tianpei Xie, 04/13/2016
#
# Last Edit 04/14/2016

# %%
# %reset
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import rbf_kernel, pairwise_kernels
import GPy
import GPy.util as gutil

# %matplotlib inline 
plt.close('all')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
Ifsavefig =  True
Ifsavedata = False #True
trial = 3

# %%
G=nx.read_adjlist("../data/04_01_2016_experiment8.adjlist")

# %% [markdown]
# size = 40
# color_map = {0:'r', 1:'c', 2:'y'}
# #center = np.zeros(2)
# #center[1] = 1
# center = None
#
# n = 40
# m = 0
# G0= nx.barbell_graph(n,m)
# #generate the bar-bell graph, which consists of two fully connected component and a path connecting them
#
# label0 = np.zeros([2*n,1])
# label0[n:2*n] = np.ones([n,1])
# #### labeling of the cluster
# for node in G0.nodes():
#     G0.node[node]['category'] = int(label0[node,0])

# %%
data_df = pd.read_csv("../data/04_01_2016_experiment8_X.csv", index_col = 'ID')
spectral_df = pd.read_csv("../data/04_01_2016_experiment8_U.csv", index_col ='ID')
U_init_pd = pd.read_csv("../data/04_01_16_8_U_init.csv", index_col = 0)

# %%
X = data_df.loc[:,['0_cos','1_cos']].values
U = spectral_df.loc[:,['PX','PY']].values
labels = data_df.loc[:,'LABEL'].values
U_init = U_init_pd.loc[:,['0','1']].values

# %%
nsample, ndim = X.shape
_ , ndim_latent = U.shape

# %%
import sys
import os
dirorg = os.path.dirname(os.getcwd())
sys.path.insert(0, dirorg+"/src/")

# %%
import G2PnetSolver_v6 #G2PnetSolver_v2
#from imp import reload
#reload(G2PnetSolver_v2)

# %%
from G2PnetSolver_v6 import  G2PnetSolver as Solver
from G2PnetSolver_v6 import  Grassmann_update, check_step

# %%
choice = "near"
IfGen = False

# %%
if IfGen:
    np.random.seed(seed=150)

    if choice == "random":
        print("Random Initialization")
        Temp = np.random.randn(nsample, nsample)
        Temp_sym = (Temp + Temp.T) / 2 
        _, U_temp = np.linalg.eig(Temp_sym)
        U_test = U_temp[:, np.arange(ndim_latent)]
        U0 = U_test
    elif choice == "near":
        print("Initialization in neigborhood.")
        U0 = U

    eta0 = 0.75
    np.random.seed(seed=160)
    G_temp = np.random.randn(nsample, ndim_latent) / (np.sqrt(nsample * ndim_latent))
    H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
    print(str(check_step(H_temp, eta0)))
    while not check_step(H_temp, eta0):
        np.random.seed(seed=160)
        G_temp = np.random.randn(nsample, ndim_latent) / np.sqrt(nsample * ndim_latent)
        H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
    U_init = Grassmann_update(U0, H_temp, eta=eta0)

# %%
if Ifsavedata:
    U_columns = [str(i) for i in np.arange(ndim_latent)]
    U_df = pd.DataFrame(data = U_init, columns=U_columns, dtype= float)
    if choice == "random":
        U_df['RANDOM'] = np.ones([nsample, 1])
    elif choice == "near":
        U_df['RANDOM'] = np.zeros([nsample, 1])
    
    U_df.to_csv("../data/04_15_16_" + str(trial)  + "_U_init.csv")

# %%
add_reg = True
max_iters = 600
eta_array = np.array([1e-3, 2e-3, 5e-3])
kern_array = [GPy.kern.RBF(2) + GPy.kern.White(2) for i in np.arange(len(eta_array))]
kern_grass_array = [GPy.kern.RBF(2)+ GPy.kern.White(2)  for i in np.arange(len(eta_array))]
kern_conjugate_grass_array = [GPy.kern.RBF(2)+ GPy.kern.White(2) for i in np.arange(len(eta_array))]
noise_interval = np.array([0.24,0.25])

# %%
solver_array = []
hist_nll_eu_array = []
hist_nll_grass_array = []
hist_nll_conjugate_grass_array = []
hist_Hsig_array = []
hist_Hsig_conjugate_array = []
hist_Gnorm_array = []
hist_Gnorm_conjugate_array = []
hist_gamma_array = []
hist_deltaG_array = []
hist_condK_array = []
hist_condK_grass_array = []
hist_condK_conjugate_array = []
hist_cond2K_array = []
hist_cond2K_grass_array = []
hist_cond2K_conjugate_array = []
hist_kern_eu_array = []
hist_kern_grass_array = []
hist_kern_grass2_array = []

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 30.0)
plt.style.use('seaborn-white')
lambda_var = 1


for i, eta in enumerate(eta_array): 
    ax = plt.subplot(5,1,i+1)
    solver = Solver(X=X, U=U_init, kernel=kern_array[i], U_ref= U, \
                    noise_interval = noise_interval, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_eu, hist_eta, hist_kern_eu, hist_Hsig_eu = solver.optimize(max_iters = max_iters, optimizor = "gd")
    solver_array.append(solver)
    hist_cond2K_array.append(solver.hist_cond_dK)
    hist_condK_array.append(solver.hist_cond_K)
    hist_nll_eu_array.append(hist_nll_eu)
    hist_kern_eu_array.append(hist_kern_eu)
    
    
    solver2 = Solver(X=X, U=U_init, kernel=kern_grass_array[i], U_ref = U, \
                     noise_interval = noise_interval, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_grass, hist_eta, hist_kern_grass, hist_Hsig_grass = \
                      solver2.optimize(max_iters = max_iters, optimizor = "gd_grass")
    hist_Hsig_array.append(hist_Hsig_grass)
    hist_Gnorm_array.append(solver2.hist_G_norm)
    hist_cond2K_grass_array.append(solver2.hist_cond_dK)
    hist_condK_grass_array.append(solver2.hist_cond_K)
    
    solver_array.append(solver2)
    hist_nll_grass_array.append(hist_nll_grass)
    hist_kern_grass_array.append(hist_kern_grass)
    
    solver3 = Solver(X=X, U=U_init, kernel=kern_conjugate_grass_array[i], U_ref = U, \
                     noise_interval = noise_interval, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_grass2, hist_eta2, hist_kern_grass2, hist_Hsig_grass2 = \
                      solver3.optimize(max_iters = max_iters, optimizor = "cg_grass")
    hist_Hsig_conjugate_array.append(hist_Hsig_grass2)    
    hist_Gnorm_conjugate_array.append(solver3.hist_G_norm)   
    hist_deltaG_array.append(solver3.hist_delta_G)
    hist_gamma_array.append(solver3.hist_gamma)
    hist_cond2K_conjugate_array.append(solver3.hist_cond_dK)
    hist_condK_conjugate_array.append(solver3.hist_cond_K)

    solver_array.append(solver3)
    hist_nll_conjugate_grass_array.append(hist_nll_grass2)
    hist_kern_grass2_array.append(hist_kern_grass2)
    
    # %xdel solver
    # %xdel solver2
    # %xdel solver3
# Out:
# kernel initialization ...
# Warning: changing parameters to satisfy constraints
# negative log-likelihood compute
# [step   0] neg-log-likelihood 89.749048 stepsize 0.0010
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood 87.947483 stepsize 0.0010
# [step   2] neg-log-likelihood 86.837805 stepsize 0.0010
# [step   3] neg-log-likelihood 86.464888 stepsize 0.0010
# [step   4] neg-log-likelihood 86.156739 stepsize 0.0010
# [step   5] neg-log-likelihood 85.694697 stepsize 0.0010
# [step   6] neg-log-likelihood 85.111121 stepsize 0.0010
# [step   7] neg-log-likelihood 84.494724 stepsize 0.0010
# [step   8] neg-log-likelihood 83.900513 stepsize 0.0010
# [step   9] neg-log-likelihood 83.354214 stepsize 0.0010
# [step  10] neg-log-likelihood 82.868171 stepsize 0.0010
# [step  11] neg-log-likelihood 82.444817 stepsize 0.0010
# [step  12] neg-log-likelihood 82.078412 stepsize 0.0010
# [step  13] neg-log-likelihood 81.758877 stepsize 0.0010
# [step  14] neg-log-likelihood 81.475970 stepsize 0.0010
# [step  15] neg-log-likelihood 81.221495 stepsize 0.0010
# [step  16] neg-log-likelihood 80.989661 stepsize 0.0010
# [step  17] neg-log-likelihood 80.776625 stepsize 0.0010
# [step  18] neg-log-likelihood 80.579925 stepsize 0.0010
# [step  19] neg-log-likelihood 80.397970 stepsize 0.0010
# [step  20] neg-log-likelihood 80.229638 stepsize 0.0010
# [step  21] neg-log-likelihood 80.074007 stepsize 0.0010
# [step  22] neg-log-likelihood 79.930180 stepsize 0.0010
# [step  23] neg-log-likelihood 79.797218 stepsize 0.0010
# [step  24] neg-log-likelihood 79.674134 stepsize 0.0010
# [step  25] neg-log-likelihood 79.559932 stepsize 0.0010
# [step  26] neg-log-likelihood 79.453643 stepsize 0.0010
# [step  27] neg-log-likelihood 79.354369 stepsize 0.0010
# [step  28] neg-log-likelihood 79.261307 stepsize 0.0010
# [step  29] neg-log-likelihood 79.173753 stepsize 0.0010
# [step  30] neg-log-likelihood 79.091104 stepsize 0.0010
# [step  31] neg-log-likelihood 79.012847 stepsize 0.0010
# [step  32] neg-log-likelihood 78.938545 stepsize 0.0010
# [step  33] neg-log-likelihood 78.867832 stepsize 0.0010
# [step  34] neg-log-likelihood 78.800393 stepsize 0.0010
# [step  35] neg-log-likelihood 78.735961 stepsize 0.0010
# [step  36] neg-log-likelihood 78.674310 stepsize 0.0010
# [step  37] neg-log-likelihood 78.615244 stepsize 0.0010
# [step  38] neg-log-likelihood 78.558599 stepsize 0.0010
# [step  39] neg-log-likelihood 78.504231 stepsize 0.0010
# [step  40] neg-log-likelihood 78.452016 stepsize 0.0010
# [step  41] neg-log-likelihood 78.401848 stepsize 0.0010
# [step  42] neg-log-likelihood 78.353629 stepsize 0.0010
# [step  43] neg-log-likelihood 78.307272 stepsize 0.0010
# [step  44] neg-log-likelihood 78.262697 stepsize 0.0010
# [step  45] neg-log-likelihood 78.219828 stepsize 0.0010
# [step  46] neg-log-likelihood 78.178591 stepsize 0.0010
# [step  47] neg-log-likelihood 78.138914 stepsize 0.0010
# [step  48] neg-log-likelihood 78.100726 stepsize 0.0010
# [step  49] neg-log-likelihood 78.063953 stepsize 0.0010
# [step  50] neg-log-likelihood 78.028442 stepsize 0.0010
# [step  51] neg-log-likelihood 77.994283 stepsize 0.0010
# [step  52] neg-log-likelihood 77.961323 stepsize 0.0010
# [step  53] neg-log-likelihood 77.929491 stepsize 0.0010
# [step  54] neg-log-likelihood 77.898713 stepsize 0.0010
# [step  55] neg-log-likelihood 77.868915 stepsize 0.0010
# [step  56] neg-log-likelihood 77.840091 stepsize 0.0010
# [step  57] neg-log-likelihood 77.811990 stepsize 0.0010
# [step  58] neg-log-likelihood 77.784794 stepsize 0.0010
# [step  59] neg-log-likelihood 77.758179 stepsize 0.0010
# [step  60] neg-log-likelihood 77.732296 stepsize 0.0010
# [step  61] neg-log-likelihood 77.706968 stepsize 0.0010
# [step  62] neg-log-likelihood 77.682230 stepsize 0.0010
# [step  63] neg-log-likelihood 77.657945 stepsize 0.0010
# [step  64] neg-log-likelihood 77.634052 stepsize 0.0010
# [step  65] neg-log-likelihood 77.610517 stepsize 0.0010
# [step  66] neg-log-likelihood 77.587265 stepsize 0.0010
# [step  67] neg-log-likelihood 77.564323 stepsize 0.0010
# [step  68] neg-log-likelihood 77.541440 stepsize 0.0010
# [step  69] neg-log-likelihood 77.518943 stepsize 0.0010
# [step  70] neg-log-likelihood 77.496232 stepsize 0.0010
# [step  71] neg-log-likelihood 77.471469 stepsize 0.0010
# [step  72] neg-log-likelihood 77.451593 stepsize 0.0010
# [step  73] neg-log-likelihood 77.428291 stepsize 0.0010
# [step  74] neg-log-likelihood 77.405722 stepsize 0.0010
# [step  75] neg-log-likelihood 77.383779 stepsize 0.0010
# [step  76] neg-log-likelihood 77.362299 stepsize 0.0010
# [step  77] neg-log-likelihood 77.341095 stepsize 0.0010
# [step  78] neg-log-likelihood 77.315632 stepsize 0.0010
# [step  79] neg-log-likelihood 77.292552 stepsize 0.0010
# [step  80] neg-log-likelihood 77.269397 stepsize 0.0010
# [step  81] neg-log-likelihood 77.246067 stepsize 0.0010
# [step  82] neg-log-likelihood 77.222691 stepsize 0.0010
# [step  83] neg-log-likelihood 77.199343 stepsize 0.0010
# [step  84] neg-log-likelihood 77.176120 stepsize 0.0010
# [step  85] neg-log-likelihood 77.153424 stepsize 0.0010
# [step  86] neg-log-likelihood 77.130865 stepsize 0.0010
# [step  87] neg-log-likelihood 77.108786 stepsize 0.0010
# [step  88] neg-log-likelihood 77.087339 stepsize 0.0010
# [step  89] neg-log-likelihood 77.066525 stepsize 0.0010
# [step  90] neg-log-likelihood 77.046451 stepsize 0.0010
# [step  91] neg-log-likelihood 77.027212 stepsize 0.0010
# [step  92] neg-log-likelihood 77.008861 stepsize 0.0010
# [step  93] neg-log-likelihood 76.991695 stepsize 0.0010
# [step  94] neg-log-likelihood 76.975170 stepsize 0.0010
# [step  95] neg-log-likelihood 76.959462 stepsize 0.0010
# [step  96] neg-log-likelihood 76.944494 stepsize 0.0010
# [step  97] neg-log-likelihood 76.930184 stepsize 0.0010
# [step  98] neg-log-likelihood 76.916223 stepsize 0.0010
# [step  99] neg-log-likelihood 76.903029 stepsize 0.0010
# [step 100] neg-log-likelihood 76.890262 stepsize 0.0010
# [step 101] neg-log-likelihood 76.882164 stepsize 0.0010
# [step 102] neg-log-likelihood 76.865703 stepsize 0.0010
# [step 103] neg-log-likelihood 76.856433 stepsize 0.0010
# [step 104] neg-log-likelihood 76.842258 stepsize 0.0010
# [step 105] neg-log-likelihood 76.831835 stepsize 0.0010
# [step 106] neg-log-likelihood 76.820881 stepsize 0.0010
# [step 107] neg-log-likelihood 76.809462 stepsize 0.0010
# [step 108] neg-log-likelihood 76.797655 stepsize 0.0010
# [step 109] neg-log-likelihood 76.785545 stepsize 0.0010
# [step 110] neg-log-likelihood 76.779241 stepsize 0.0010
# [step 111] neg-log-likelihood 76.766617 stepsize 0.0010
# [step 112] neg-log-likelihood 76.761272 stepsize 0.0010
# [step 113] neg-log-likelihood 76.748427 stepsize 0.0010
# [step 114] neg-log-likelihood 76.745118 stepsize 0.0010
# [step 115] neg-log-likelihood 76.737897 stepsize 0.0010
# [step 116] neg-log-likelihood 76.731114 stepsize 0.0010
# [step 117] neg-log-likelihood 76.724826 stepsize 0.0010
# [step 118] neg-log-likelihood 76.719259 stepsize 0.0010
# [step 119] neg-log-likelihood 76.713896 stepsize 0.0010
# [step 120] neg-log-likelihood 76.709147 stepsize 0.0010
# [step 121] neg-log-likelihood 76.705076 stepsize 0.0010
# [step 122] neg-log-likelihood 76.701534 stepsize 0.0010
# [step 123] neg-log-likelihood 76.698738 stepsize 0.0010
# [step 124] neg-log-likelihood 76.696285 stepsize 0.0010
# [step 125] neg-log-likelihood 76.694540 stepsize 0.0010
# [step 126] neg-log-likelihood 76.693510 stepsize 0.0010
# [step 127] neg-log-likelihood 76.693182 stepsize 0.0010
# [step 128] neg-log-likelihood 76.693587 stepsize 0.0010
# [step 129] neg-log-likelihood 76.694764 stepsize 0.0010
# [step 130] neg-log-likelihood 76.696723 stepsize 0.0010
# [step 131] neg-log-likelihood 76.699614 stepsize 0.0010
# [step 132] neg-log-likelihood 76.703359 stepsize 0.0010
# [step 133] neg-log-likelihood 76.708099 stepsize 0.0010
# [step 134] neg-log-likelihood 76.713827 stepsize 0.0010
# [step 135] neg-log-likelihood 76.720599 stepsize 0.0010
# [step 136] neg-log-likelihood 76.728521 stepsize 0.0010
# [step 137] neg-log-likelihood 76.737641 stepsize 0.0010
# [step 138] neg-log-likelihood 76.747998 stepsize 0.0010
# [step 139] neg-log-likelihood 76.759652 stepsize 0.0010
# [step 140] neg-log-likelihood 76.772666 stepsize 0.0010
# [step 141] neg-log-likelihood 76.787104 stepsize 0.0010
# [step 142] neg-log-likelihood 76.803026 stepsize 0.0010
# [step 143] neg-log-likelihood 76.820493 stepsize 0.0010
# [step 144] neg-log-likelihood 76.839535 stepsize 0.0010
# [step 145] neg-log-likelihood 76.860306 stepsize 0.0010
# [step 146] neg-log-likelihood 76.882780 stepsize 0.0010
# [step 147] neg-log-likelihood 76.907073 stepsize 0.0010
# [step 148] neg-log-likelihood 76.933192 stepsize 0.0010
# [step 149] neg-log-likelihood 76.961216 stepsize 0.0010
# [step 150] neg-log-likelihood 76.991204 stepsize 0.0010
# [step 151] neg-log-likelihood 77.023217 stepsize 0.0010
# [step 152] neg-log-likelihood 77.057312 stepsize 0.0010
# [step 153] neg-log-likelihood 77.093551 stepsize 0.0010
# [step 154] neg-log-likelihood 77.131994 stepsize 0.0010
# [step 155] neg-log-likelihood 77.172700 stepsize 0.0010
# [step 156] neg-log-likelihood 77.215697 stepsize 0.0010
# [step 157] neg-log-likelihood 77.261129 stepsize 0.0010
# [step 158] neg-log-likelihood 77.309012 stepsize 0.0010
# [step 159] neg-log-likelihood 77.359415 stepsize 0.0010
# [step 160] neg-log-likelihood 77.412407 stepsize 0.0010
# [step 161] neg-log-likelihood 77.468058 stepsize 0.0010
# [step 162] neg-log-likelihood 77.526443 stepsize 0.0010
# [step 163] neg-log-likelihood 77.587633 stepsize 0.0010
# [step 164] neg-log-likelihood 77.651707 stepsize 0.0010
# [step 165] neg-log-likelihood 77.718742 stepsize 0.0010
# [step 166] neg-log-likelihood 77.788816 stepsize 0.0010
# [step 167] neg-log-likelihood 77.862048 stepsize 0.0010
# [step 168] neg-log-likelihood 77.938459 stepsize 0.0010
# [step 169] neg-log-likelihood 78.018156 stepsize 0.0010
# [step 170] neg-log-likelihood 78.101219 stepsize 0.0010
# [step 171] neg-log-likelihood 78.187728 stepsize 0.0010
# [step 172] neg-log-likelihood 78.277760 stepsize 0.0010
# [step 173] neg-log-likelihood 78.371387 stepsize 0.0010
# [step 174] neg-log-likelihood 78.468676 stepsize 0.0010
# [step 175] neg-log-likelihood 78.569688 stepsize 0.0010
# [step 176] neg-log-likelihood 78.674477 stepsize 0.0010
# [step 177] neg-log-likelihood 78.783087 stepsize 0.0010
# [step 178] neg-log-likelihood 78.895550 stepsize 0.0010
# [step 179] neg-log-likelihood 79.011887 stepsize 0.0010
# [step 180] neg-log-likelihood 79.132118 stepsize 0.0010
# [step 181] neg-log-likelihood 79.256252 stepsize 0.0010
# [step 182] neg-log-likelihood 79.384237 stepsize 0.0010
# [step 183] neg-log-likelihood 79.516098 stepsize 0.0010
# [step 184] neg-log-likelihood 79.651629 stepsize 0.0010
# [step 185] neg-log-likelihood 79.790818 stepsize 0.0010
# [step 186] neg-log-likelihood 79.933686 stepsize 0.0010
# [step 187] neg-log-likelihood 80.080026 stepsize 0.0010
# [step 188] neg-log-likelihood 80.229643 stepsize 0.0010
# [step 189] neg-log-likelihood 80.382428 stepsize 0.0010
# [step 190] neg-log-likelihood 80.538249 stepsize 0.0010
# [step 191] neg-log-likelihood 80.691422 stepsize 0.0010
# [step 192] neg-log-likelihood 80.851345 stepsize 0.0010
# [step 193] neg-log-likelihood 81.018306 stepsize 0.0010
# [step 194] neg-log-likelihood 81.191563 stepsize 0.0010
# [step 195] neg-log-likelihood 81.355662 stepsize 0.0010
# [step 196] neg-log-likelihood 81.525421 stepsize 0.0010
# [step 197] neg-log-likelihood 81.697221 stepsize 0.0010
# [step 198] neg-log-likelihood 81.870158 stepsize 0.0010
# [step 199] neg-log-likelihood 82.044208 stepsize 0.0010
# [step 200] neg-log-likelihood 82.220018 stepsize 0.0010
# [step 201] neg-log-likelihood 82.397141 stepsize 0.0010
# [step 202] neg-log-likelihood 82.575418 stepsize 0.0010
# [step 203] neg-log-likelihood 82.753936 stepsize 0.0010
# [step 204] neg-log-likelihood 82.930448 stepsize 0.0010
# [step 205] neg-log-likelihood 83.099210 stepsize 0.0010
# [step 206] neg-log-likelihood 83.248097 stepsize 0.0010
# [step 207] neg-log-likelihood 83.355266 stepsize 0.0010
# [step 208] neg-log-likelihood 83.388552 stepsize 0.0010
# [step 209] neg-log-likelihood 83.311351 stepsize 0.0010
# [step 210] neg-log-likelihood 83.090926 stepsize 0.0010
# [step 211] neg-log-likelihood 82.694367 stepsize 0.0010
# [step 212] neg-log-likelihood 82.065357 stepsize 0.0010
# [step 213] neg-log-likelihood 81.107997 stepsize 0.0010
# [step 214] neg-log-likelihood 79.785487 stepsize 0.0010
# [step 215] neg-log-likelihood 78.357136 stepsize 0.0010
# [step 216] neg-log-likelihood 77.216178 stepsize 0.0010
# [step 217] neg-log-likelihood 76.504736 stepsize 0.0010
# [step 218] neg-log-likelihood 76.129120 stepsize 0.0010
# [step 219] neg-log-likelihood 75.950079 stepsize 0.0010
# [step 220] neg-log-likelihood 75.874763 stepsize 0.0010
# [step 221] neg-log-likelihood 75.855126 stepsize 0.0010
# [step 222] neg-log-likelihood 75.867094 stepsize 0.0010
# [step 223] neg-log-likelihood 75.901260 stepsize 0.0010
# [step 224] neg-log-likelihood 75.955979 stepsize 0.0010
# [step 225] neg-log-likelihood 76.037940 stepsize 0.0010
# [step 226] neg-log-likelihood 76.163805 stepsize 0.0010
# [step 227] neg-log-likelihood 76.373099 stepsize 0.0010
# [step 228] neg-log-likelihood 76.759015 stepsize 0.0010
# [step 229] neg-log-likelihood 77.677875 stepsize 0.0010
# [step 230] neg-log-likelihood 81.781706 stepsize 0.0010
# [step 231] neg-log-likelihood 86.768125 stepsize 0.0010
# [step 232] neg-log-likelihood 87.439483 stepsize 0.0010
# [step 233] neg-log-likelihood 88.983385 stepsize 0.0010
# [step 234] neg-log-likelihood 94.287244 stepsize 0.0010
# [step 235] neg-log-likelihood 82.435207 stepsize 0.0010
# [step 236] neg-log-likelihood 79.556627 stepsize 0.0010
# [step 237] neg-log-likelihood 79.762121 stepsize 0.0010
# [step 238] neg-log-likelihood 79.923505 stepsize 0.0010
# [step 239] neg-log-likelihood 80.067601 stepsize 0.0010
# [step 240] neg-log-likelihood 80.206755 stepsize 0.0010
# [step 241] neg-log-likelihood 80.346391 stepsize 0.0010
# [step 242] neg-log-likelihood 80.485658 stepsize 0.0010
# [step 243] neg-log-likelihood 80.640999 stepsize 0.0010
# [step 244] neg-log-likelihood 80.831685 stepsize 0.0010
# [step 245] neg-log-likelihood 81.084110 stepsize 0.0010
# [step 246] neg-log-likelihood 81.414739 stepsize 0.0010
# [step 247] neg-log-likelihood 81.838560 stepsize 0.0010
# [step 248] neg-log-likelihood 82.345777 stepsize 0.0010
# [step 249] neg-log-likelihood 82.955362 stepsize 0.0010
# [step 250] neg-log-likelihood 83.683830 stepsize 0.0010
# [step 251] neg-log-likelihood 84.959910 stepsize 0.0010
# [step 252] neg-log-likelihood 87.034100 stepsize 0.0010
# [step 253] neg-log-likelihood 99.330745 stepsize 0.0010
# [step 254] neg-log-likelihood 81.364992 stepsize 0.0010
# [step 255] neg-log-likelihood 79.551588 stepsize 0.0010
# [step 256] neg-log-likelihood 79.219119 stepsize 0.0010
# [step 257] neg-log-likelihood 79.085760 stepsize 0.0010
# [step 258] neg-log-likelihood 79.208963 stepsize 0.0010
# [step 259] neg-log-likelihood 79.409793 stepsize 0.0010
# [step 260] neg-log-likelihood 79.634543 stepsize 0.0010
# [step 261] neg-log-likelihood 79.869862 stepsize 0.0010
# [step 262] neg-log-likelihood 80.113120 stepsize 0.0010
# [step 263] neg-log-likelihood 80.365980 stepsize 0.0010
# [step 264] neg-log-likelihood 80.633411 stepsize 0.0010
# [step 265] neg-log-likelihood 80.919113 stepsize 0.0010
# [step 266] neg-log-likelihood 81.226313 stepsize 0.0010
# [step 267] neg-log-likelihood 81.555707 stepsize 0.0010
# [step 268] neg-log-likelihood 81.906766 stepsize 0.0010
# [step 269] neg-log-likelihood 82.278215 stepsize 0.0010
# [step 270] neg-log-likelihood 82.668494 stepsize 0.0010
# [step 271] neg-log-likelihood 83.076032 stepsize 0.0010
# [step 272] neg-log-likelihood 83.499448 stepsize 0.0010
# [step 273] neg-log-likelihood 83.937796 stepsize 0.0010
# [step 274] neg-log-likelihood 84.390839 stepsize 0.0010
# [step 275] neg-log-likelihood 84.858475 stepsize 0.0010
# [step 276] neg-log-likelihood 85.341435 stepsize 0.0010
# [step 277] neg-log-likelihood 85.841825 stepsize 0.0010
# [step 278] neg-log-likelihood 86.362417 stepsize 0.0010
# [step 279] neg-log-likelihood 86.907308 stepsize 0.0010
# [step 280] neg-log-likelihood 87.482122 stepsize 0.0010
# [step 281] neg-log-likelihood 88.094191 stepsize 0.0010
# [step 282] neg-log-likelihood 88.752393 stepsize 0.0010
# [step 283] neg-log-likelihood 89.467145 stepsize 0.0010
# [step 284] neg-log-likelihood 90.247611 stepsize 0.0010
# [step 285] neg-log-likelihood 91.098781 stepsize 0.0010
# [step 286] neg-log-likelihood 92.019756 stepsize 0.0010
# [step 287] neg-log-likelihood 93.006157 stepsize 0.0010
# [step 288] neg-log-likelihood 94.055658 stepsize 0.0010
# [step 289] neg-log-likelihood 95.172342 stepsize 0.0010
# [step 290] neg-log-likelihood 96.372209 stepsize 0.0010
# [step 291] neg-log-likelihood 97.693497 stepsize 0.0010
# [step 292] neg-log-likelihood 99.228132 stepsize 0.0010
# [step 293] neg-log-likelihood 101.245599 stepsize 0.0010
# [step 294] neg-log-likelihood 106.814198 stepsize 0.0010
# [step 295] neg-log-likelihood 100.428477 stepsize 0.0010
# [step 296] neg-log-likelihood 92.307562 stepsize 0.0010
# [step 297] neg-log-likelihood 76.123440 stepsize 0.0010
# [step 298] neg-log-likelihood 76.269157 stepsize 0.0010
# [step 299] neg-log-likelihood 76.511221 stepsize 0.0010
# [step 300] neg-log-likelihood 76.719894 stepsize 0.0010
# [step 301] neg-log-likelihood 76.839837 stepsize 0.0010
# [step 302] neg-log-likelihood 76.911888 stepsize 0.0010
# [step 303] neg-log-likelihood 77.009611 stepsize 0.0010
# [step 304] neg-log-likelihood 77.151047 stepsize 0.0010
# [step 305] neg-log-likelihood 77.317048 stepsize 0.0010
# [step 306] neg-log-likelihood 77.492629 stepsize 0.0010
# [step 307] neg-log-likelihood 77.671380 stepsize 0.0010
# [step 308] neg-log-likelihood 77.851456 stepsize 0.0010
# [step 309] neg-log-likelihood 78.032939 stepsize 0.0010
# [step 310] neg-log-likelihood 78.216619 stepsize 0.0010
# [step 311] neg-log-likelihood 78.403397 stepsize 0.0010
# [step 312] neg-log-likelihood 78.593808 stepsize 0.0010
# [step 313] neg-log-likelihood 78.788646 stepsize 0.0010
# [step 314] neg-log-likelihood 78.988243 stepsize 0.0010
# [step 315] neg-log-likelihood 79.192851 stepsize 0.0010
# [step 316] neg-log-likelihood 79.402604 stepsize 0.0010
# [step 317] neg-log-likelihood 79.617557 stepsize 0.0010
# [step 318] neg-log-likelihood 79.837582 stepsize 0.0010
# [step 319] neg-log-likelihood 80.062945 stepsize 0.0010
# [step 320] neg-log-likelihood 80.293651 stepsize 0.0010
# [step 321] neg-log-likelihood 80.529415 stepsize 0.0010
# [step 322] neg-log-likelihood 80.770467 stepsize 0.0010
# [step 323] neg-log-likelihood 81.016957 stepsize 0.0010
# [step 324] neg-log-likelihood 81.269134 stepsize 0.0010
# [step 325] neg-log-likelihood 81.527137 stepsize 0.0010
# [step 326] neg-log-likelihood 81.791028 stepsize 0.0010
# [step 327] neg-log-likelihood 82.061476 stepsize 0.0010
# [step 328] neg-log-likelihood 82.338789 stepsize 0.0010
# [step 329] neg-log-likelihood 82.623476 stepsize 0.0010
# [step 330] neg-log-likelihood 82.916124 stepsize 0.0010
# [step 331] neg-log-likelihood 83.217403 stepsize 0.0010
# [step 332] neg-log-likelihood 83.528062 stepsize 0.0010
# [step 333] neg-log-likelihood 83.848925 stepsize 0.0010
# [step 334] neg-log-likelihood 84.180878 stepsize 0.0010
# [step 335] neg-log-likelihood 84.524685 stepsize 0.0010
# [step 336] neg-log-likelihood 84.881607 stepsize 0.0010
# [step 337] neg-log-likelihood 85.252411 stepsize 0.0010
# [step 338] neg-log-likelihood 85.637964 stepsize 0.0010
# [step 339] neg-log-likelihood 86.039005 stepsize 0.0010
# [step 340] neg-log-likelihood 86.456185 stepsize 0.0010
# [step 341] neg-log-likelihood 86.889839 stepsize 0.0010
# [step 342] neg-log-likelihood 87.340844 stepsize 0.0010
# [step 343] neg-log-likelihood 87.809590 stepsize 0.0010
# [step 344] neg-log-likelihood 88.296932 stepsize 0.0010
# [step 345] neg-log-likelihood 88.803944 stepsize 0.0010
# [step 346] neg-log-likelihood 89.333022 stepsize 0.0010
# [step 347] neg-log-likelihood 89.887579 stepsize 0.0010
# [step 348] neg-log-likelihood 90.473726 stepsize 0.0010
# [step 349] neg-log-likelihood 91.102236 stepsize 0.0010
# [step 350] neg-log-likelihood 91.792831 stepsize 0.0010
# [step 351] neg-log-likelihood 92.586823 stepsize 0.0010
# [step 352] neg-log-likelihood 93.583041 stepsize 0.0010
# [step 353] neg-log-likelihood 95.020521 stepsize 0.0010
# [step 354] neg-log-likelihood 97.067014 stepsize 0.0010
# [step 355] neg-log-likelihood 99.613193 stepsize 0.0010
# [step 356] neg-log-likelihood 102.924154 stepsize 0.0010
# [step 357] neg-log-likelihood 105.946519 stepsize 0.0010
# [step 358] neg-log-likelihood 105.242062 stepsize 0.0010
# [step 359] neg-log-likelihood 95.506714 stepsize 0.0010
# [step 360] neg-log-likelihood 95.059407 stepsize 0.0010
# [step 361] neg-log-likelihood 93.030534 stepsize 0.0010
# [step 362] neg-log-likelihood 91.507544 stepsize 0.0010
# [step 363] neg-log-likelihood 90.841511 stepsize 0.0010
# [step 364] neg-log-likelihood 90.218355 stepsize 0.0010
# [step 365] neg-log-likelihood 88.034384 stepsize 0.0010
# [step 366] neg-log-likelihood 84.116799 stepsize 0.0010
# [step 367] neg-log-likelihood 83.983109 stepsize 0.0010
# [step 368] neg-log-likelihood 84.229229 stepsize 0.0010
# [step 369] neg-log-likelihood 84.499812 stepsize 0.0010
# [step 370] neg-log-likelihood 84.745528 stepsize 0.0010
# [step 371] neg-log-likelihood 84.942362 stepsize 0.0010
# [step 372] neg-log-likelihood 85.054925 stepsize 0.0010
# [step 373] neg-log-likelihood 85.031523 stepsize 0.0010
# [step 374] neg-log-likelihood 84.843137 stepsize 0.0010
# [step 375] neg-log-likelihood 84.607966 stepsize 0.0010
# [step 376] neg-log-likelihood 84.691760 stepsize 0.0010
# [step 377] neg-log-likelihood 85.463792 stepsize 0.0010
# [step 378] neg-log-likelihood 86.673327 stepsize 0.0010
# [step 379] neg-log-likelihood 87.803247 stepsize 0.0010
# [step 380] neg-log-likelihood 88.979418 stepsize 0.0010
# [step 381] neg-log-likelihood 90.183984 stepsize 0.0010
# [step 382] neg-log-likelihood 91.315389 stepsize 0.0010
# [step 383] neg-log-likelihood 92.309515 stepsize 0.0010
# [step 384] neg-log-likelihood 93.185758 stepsize 0.0010
# [step 385] neg-log-likelihood 94.037153 stepsize 0.0010
# [step 386] neg-log-likelihood 95.059151 stepsize 0.0010
# [step 387] neg-log-likelihood 96.502161 stepsize 0.0010
# [step 388] neg-log-likelihood 98.176040 stepsize 0.0010
# [step 389] neg-log-likelihood 99.707429 stepsize 0.0010
# [step 390] neg-log-likelihood 100.929445 stepsize 0.0010
# [step 391] neg-log-likelihood 101.591341 stepsize 0.0010
# [step 392] neg-log-likelihood 102.528831 stepsize 0.0010
# [step 393] neg-log-likelihood 99.727333 stepsize 0.0010
# [step 394] neg-log-likelihood 99.582784 stepsize 0.0010
# [step 395] neg-log-likelihood 90.159895 stepsize 0.0010
# [step 396] neg-log-likelihood 89.208402 stepsize 0.0010
# [step 397] neg-log-likelihood 97.705957 stepsize 0.0010
# [step 398] neg-log-likelihood 88.493545 stepsize 0.0010
# [step 399] neg-log-likelihood 90.254186 stepsize 0.0010
# [step 400] neg-log-likelihood 91.831319 stepsize 0.0010
# [step 401] neg-log-likelihood 94.178183 stepsize 0.0010
# [step 402] neg-log-likelihood 96.355087 stepsize 0.0010
# [step 403] neg-log-likelihood 99.294193 stepsize 0.0010
# [step 404] neg-log-likelihood 99.833510 stepsize 0.0010
# [step 405] neg-log-likelihood 99.660301 stepsize 0.0010
# [step 406] neg-log-likelihood 102.820716 stepsize 0.0010
# [step 407] neg-log-likelihood 105.806072 stepsize 0.0010
# [step 408] neg-log-likelihood 87.959580 stepsize 0.0010
# [step 409] neg-log-likelihood 86.738217 stepsize 0.0010
# [step 410] neg-log-likelihood 87.276605 stepsize 0.0010
# [step 411] neg-log-likelihood 73.358545 stepsize 0.0010
# [step 412] neg-log-likelihood 74.234876 stepsize 0.0010
# [step 413] neg-log-likelihood 74.840533 stepsize 0.0010
# [step 414] neg-log-likelihood 74.984240 stepsize 0.0010
# [step 415] neg-log-likelihood 74.893114 stepsize 0.0010
# [step 416] neg-log-likelihood 74.796091 stepsize 0.0010
# [step 417] neg-log-likelihood 74.748762 stepsize 0.0010
# [step 418] neg-log-likelihood 74.748078 stepsize 0.0010
# [step 419] neg-log-likelihood 74.783324 stepsize 0.0010
# [step 420] neg-log-likelihood 74.853447 stepsize 0.0010
# [step 421] neg-log-likelihood 74.983548 stepsize 0.0010
# [step 422] neg-log-likelihood 75.259547 stepsize 0.0010
# [step 423] neg-log-likelihood 75.894914 stepsize 0.0010
# [step 424] neg-log-likelihood 77.045013 stepsize 0.0010
# [step 425] neg-log-likelihood 78.442927 stepsize 0.0010
# [step 426] neg-log-likelihood 80.108124 stepsize 0.0010
# [step 427] neg-log-likelihood 82.811512 stepsize 0.0010
# [step 428] neg-log-likelihood 84.748544 stepsize 0.0010
# [step 429] neg-log-likelihood 92.149172 stepsize 0.0010
# [step 430] neg-log-likelihood 71.490026 stepsize 0.0010
# [step 431] neg-log-likelihood 80.578495 stepsize 0.0010
# [step 432] neg-log-likelihood 80.519760 stepsize 0.0010
# [step 433] neg-log-likelihood 80.644292 stepsize 0.0010
# [step 434] neg-log-likelihood 81.041451 stepsize 0.0010
# [step 435] neg-log-likelihood 81.408596 stepsize 0.0010
# [step 436] neg-log-likelihood 81.452436 stepsize 0.0010
# [step 437] neg-log-likelihood 77.004236 stepsize 0.0010
# [step 438] neg-log-likelihood 77.027470 stepsize 0.0010
# [step 439] neg-log-likelihood 77.085038 stepsize 0.0010
# [step 440] neg-log-likelihood 77.270560 stepsize 0.0010
# [step 441] neg-log-likelihood 82.288951 stepsize 0.0010
# [step 442] neg-log-likelihood 82.785694 stepsize 0.0010
# [step 443] neg-log-likelihood 83.431840 stepsize 0.0010
# [step 444] neg-log-likelihood 84.050143 stepsize 0.0010
# [step 445] neg-log-likelihood 84.559181 stepsize 0.0010
# [step 446] neg-log-likelihood 84.908952 stepsize 0.0010
# [step 447] neg-log-likelihood 85.233509 stepsize 0.0010
# [step 448] neg-log-likelihood 84.444619 stepsize 0.0010
# [step 449] neg-log-likelihood 83.002864 stepsize 0.0010
# [step 450] neg-log-likelihood 83.355531 stepsize 0.0010
# [step 451] neg-log-likelihood 84.662561 stepsize 0.0010
# [step 452] neg-log-likelihood 87.705521 stepsize 0.0010
# [step 453] neg-log-likelihood 87.092956 stepsize 0.0010
# [step 454] neg-log-likelihood 91.090242 stepsize 0.0010
# [step 455] neg-log-likelihood 76.122934 stepsize 0.0010
# [step 456] neg-log-likelihood 80.444474 stepsize 0.0010
# [step 457] neg-log-likelihood 78.601580 stepsize 0.0010
# [step 458] neg-log-likelihood 77.275856 stepsize 0.0010
# [step 459] neg-log-likelihood 76.798303 stepsize 0.0010
# [step 460] neg-log-likelihood 76.737881 stepsize 0.0010
# [step 461] neg-log-likelihood 76.787773 stepsize 0.0010
# [step 462] neg-log-likelihood 76.870426 stepsize 0.0010
# [step 463] neg-log-likelihood 76.971368 stepsize 0.0010
# [step 464] neg-log-likelihood 77.091361 stepsize 0.0010
# [step 465] neg-log-likelihood 77.234056 stepsize 0.0010
# [step 466] neg-log-likelihood 77.401489 stepsize 0.0010
# [step 467] neg-log-likelihood 77.592919 stepsize 0.0010
# [step 468] neg-log-likelihood 77.805465 stepsize 0.0010
# [step 469] neg-log-likelihood 78.035169 stepsize 0.0010
# [step 470] neg-log-likelihood 78.277533 stepsize 0.0010
# [step 471] neg-log-likelihood 78.528747 stepsize 0.0010
# [step 472] neg-log-likelihood 78.785982 stepsize 0.0010
# [step 473] neg-log-likelihood 79.046863 stepsize 0.0010
# [step 474] neg-log-likelihood 79.309832 stepsize 0.0010
# [step 475] neg-log-likelihood 79.573992 stepsize 0.0010
# [step 476] neg-log-likelihood 79.839138 stepsize 0.0010
# [step 477] neg-log-likelihood 80.104843 stepsize 0.0010
# [step 478] neg-log-likelihood 80.372110 stepsize 0.0010
# [step 479] neg-log-likelihood 80.641838 stepsize 0.0010
# [step 480] neg-log-likelihood 80.914723 stepsize 0.0010
# [step 481] neg-log-likelihood 81.193217 stepsize 0.0010
# [step 482] neg-log-likelihood 81.479712 stepsize 0.0010
# [step 483] neg-log-likelihood 81.777417 stepsize 0.0010
# [step 484] neg-log-likelihood 82.053601 stepsize 0.0010
# [step 485] neg-log-likelihood 82.427625 stepsize 0.0010
# [step 486] neg-log-likelihood 82.766690 stepsize 0.0010
# [step 487] neg-log-likelihood 83.139430 stepsize 0.0010
# [step 488] neg-log-likelihood 83.589329 stepsize 0.0010
# [step 489] neg-log-likelihood 84.007823 stepsize 0.0010
# [step 490] neg-log-likelihood 84.432577 stepsize 0.0010
# [step 491] neg-log-likelihood 84.855260 stepsize 0.0010
# [step 492] neg-log-likelihood 85.248986 stepsize 0.0010
# [step 493] neg-log-likelihood 85.549851 stepsize 0.0010
# [step 494] neg-log-likelihood 85.696281 stepsize 0.0010
# [step 495] neg-log-likelihood 85.092644 stepsize 0.0010
# [step 496] neg-log-likelihood 84.069866 stepsize 0.0010
# [step 497] neg-log-likelihood 87.545535 stepsize 0.0010
# [step 498] neg-log-likelihood 84.845873 stepsize 0.0010
# [step 499] neg-log-likelihood 84.738327 stepsize 0.0010
# [step 500] neg-log-likelihood 85.283864 stepsize 0.0010
# [step 501] neg-log-likelihood 85.496111 stepsize 0.0010
# [step 502] neg-log-likelihood 85.581388 stepsize 0.0010
# [step 503] neg-log-likelihood 87.114601 stepsize 0.0010
# [step 504] neg-log-likelihood 87.557646 stepsize 0.0010
# [step 505] neg-log-likelihood 78.590203 stepsize 0.0010
# [step 506] neg-log-likelihood 78.635357 stepsize 0.0010
# [step 507] neg-log-likelihood 78.255924 stepsize 0.0010
# [step 508] neg-log-likelihood 78.168806 stepsize 0.0010
# [step 509] neg-log-likelihood 78.247977 stepsize 0.0010
# [step 510] neg-log-likelihood 78.309986 stepsize 0.0010
# [step 511] neg-log-likelihood 78.421904 stepsize 0.0010
# [step 512] neg-log-likelihood 78.560234 stepsize 0.0010
# [step 513] neg-log-likelihood 78.718890 stepsize 0.0010
# [step 514] neg-log-likelihood 78.906996 stepsize 0.0010
# [step 515] neg-log-likelihood 79.140181 stepsize 0.0010
# [step 516] neg-log-likelihood 79.426438 stepsize 0.0010
# [step 517] neg-log-likelihood 79.772447 stepsize 0.0010
# [step 518] neg-log-likelihood 80.189814 stepsize 0.0010
# [step 519] neg-log-likelihood 80.693113 stepsize 0.0010
# [step 520] neg-log-likelihood 81.298930 stepsize 0.0010
# [step 521] neg-log-likelihood 82.024672 stepsize 0.0010
# [step 522] neg-log-likelihood 82.880755 stepsize 0.0010
# [step 523] neg-log-likelihood 83.859498 stepsize 0.0010
# [step 524] neg-log-likelihood 84.923159 stepsize 0.0010
# [step 525] neg-log-likelihood 86.013200 stepsize 0.0010
# [step 526] neg-log-likelihood 87.071786 stepsize 0.0010
# [step 527] neg-log-likelihood 88.060944 stepsize 0.0010
# [step 528] neg-log-likelihood 88.959089 stepsize 0.0010
# [step 529] neg-log-likelihood 89.744142 stepsize 0.0010
# [step 530] neg-log-likelihood 90.374805 stepsize 0.0010
# [step 531] neg-log-likelihood 90.830087 stepsize 0.0010
# [step 532] neg-log-likelihood 91.181683 stepsize 0.0010
# [step 533] neg-log-likelihood 91.374419 stepsize 0.0010
# [step 534] neg-log-likelihood 90.977177 stepsize 0.0010
# [step 535] neg-log-likelihood 87.968307 stepsize 0.0010
# [step 536] neg-log-likelihood 81.822803 stepsize 0.0010
# [step 537] neg-log-likelihood 75.410246 stepsize 0.0010
# [step 538] neg-log-likelihood 75.060419 stepsize 0.0010
# [step 539] neg-log-likelihood 75.419274 stepsize 0.0010
# [step 540] neg-log-likelihood 75.725727 stepsize 0.0010
# [step 541] neg-log-likelihood 76.012742 stepsize 0.0010
# [step 542] neg-log-likelihood 76.291776 stepsize 0.0010
# [step 543] neg-log-likelihood 76.567112 stepsize 0.0010
# [step 544] neg-log-likelihood 76.841164 stepsize 0.0010
# [step 545] neg-log-likelihood 77.115309 stepsize 0.0010
# [step 546] neg-log-likelihood 77.390790 stepsize 0.0010
# [step 547] neg-log-likelihood 77.668647 stepsize 0.0010
# [step 548] neg-log-likelihood 77.950514 stepsize 0.0010
# [step 549] neg-log-likelihood 78.238254 stepsize 0.0010
# [step 550] neg-log-likelihood 78.534590 stepsize 0.0010
# [step 551] neg-log-likelihood 78.843766 stepsize 0.0010
# [step 552] neg-log-likelihood 79.173052 stepsize 0.0010
# [step 553] neg-log-likelihood 79.535599 stepsize 0.0010
# [step 554] neg-log-likelihood 79.969122 stepsize 0.0010
# [step 555] neg-log-likelihood 80.514394 stepsize 0.0010
# [step 556] neg-log-likelihood 81.322850 stepsize 0.0010
# [step 557] neg-log-likelihood 82.264629 stepsize 0.0010
# [step 558] neg-log-likelihood 83.127060 stepsize 0.0010
# [step 559] neg-log-likelihood 83.872135 stepsize 0.0010
# [step 560] neg-log-likelihood 84.512235 stepsize 0.0010
# [step 561] neg-log-likelihood 85.066568 stepsize 0.0010
# [step 562] neg-log-likelihood 85.552265 stepsize 0.0010
# [step 563] neg-log-likelihood 85.983121 stepsize 0.0010
# [step 564] neg-log-likelihood 86.369104 stepsize 0.0010
# [step 565] neg-log-likelihood 86.716559 stepsize 0.0010
# [step 566] neg-log-likelihood 87.030042 stepsize 0.0010
# [step 567] neg-log-likelihood 87.311643 stepsize 0.0010
# [step 568] neg-log-likelihood 87.562741 stepsize 0.0010
# [step 569] neg-log-likelihood 87.782925 stepsize 0.0010
# [step 570] neg-log-likelihood 87.969751 stepsize 0.0010
# [step 571] neg-log-likelihood 88.128961 stepsize 0.0010
# [step 572] neg-log-likelihood 88.187859 stepsize 0.0010
# [step 573] neg-log-likelihood 87.891583 stepsize 0.0010
# [step 574] neg-log-likelihood 86.599592 stepsize 0.0010
# [step 575] neg-log-likelihood 88.245880 stepsize 0.0010
# [step 576] neg-log-likelihood 86.951284 stepsize 0.0010
# [step 577] neg-log-likelihood 90.154567 stepsize 0.0010
# [step 578] neg-log-likelihood 86.838101 stepsize 0.0010
# [step 579] neg-log-likelihood 83.296236 stepsize 0.0010
# [step 580] neg-log-likelihood 79.283990 stepsize 0.0010
# [step 581] neg-log-likelihood 76.694034 stepsize 0.0010
# [step 582] neg-log-likelihood 79.109022 stepsize 0.0010
# [step 583] neg-log-likelihood 80.535486 stepsize 0.0010
# [step 584] neg-log-likelihood 80.633228 stepsize 0.0010
# [step 585] neg-log-likelihood 80.711460 stepsize 0.0010
# [step 586] neg-log-likelihood 80.824067 stepsize 0.0010
# [step 587] neg-log-likelihood 80.964579 stepsize 0.0010
# [step 588] neg-log-likelihood 81.114552 stepsize 0.0010
# [step 589] neg-log-likelihood 81.278248 stepsize 0.0010
# [step 590] neg-log-likelihood 81.452567 stepsize 0.0010
# [step 591] neg-log-likelihood 81.637540 stepsize 0.0010
# [step 592] neg-log-likelihood 81.830505 stepsize 0.0010
# [step 593] neg-log-likelihood 82.032313 stepsize 0.0010
# [step 594] neg-log-likelihood 82.242394 stepsize 0.0010
# [step 595] neg-log-likelihood 82.461805 stepsize 0.0010
# [step 596] neg-log-likelihood 82.689944 stepsize 0.0010
# [step 597] neg-log-likelihood 82.923334 stepsize 0.0010
# [step 598] neg-log-likelihood 83.156968 stepsize 0.0010
# [step 599] neg-log-likelihood 83.339104 stepsize 0.0010
# kernel initialization ...
# Warning: changing parameters to satisfy constraints
# negative log-likelihood compute
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   0] neg-log-likelihood 89.749048 stepsize 0.0010
# [step   1] neg-log-likelihood 87.952679 stepsize 0.0010
# [step   2] neg-log-likelihood 86.896086 stepsize 0.0010
# [step   3] neg-log-likelihood 86.530769 stepsize 0.0010
# [step   4] neg-log-likelihood 86.264061 stepsize 0.0010
# [step   5] neg-log-likelihood 85.877392 stepsize 0.0010
# [step   6] neg-log-likelihood 85.381565 stepsize 0.0010
# [step   7] neg-log-likelihood 84.846099 stepsize 0.0010
# [step   8] neg-log-likelihood 84.317753 stepsize 0.0010
# [step   9] neg-log-likelihood 83.818563 stepsize 0.0010
# [step  10] neg-log-likelihood 83.359764 stepsize 0.0010
# [step  11] neg-log-likelihood 82.947022 stepsize 0.0010
# [step  12] neg-log-likelihood 82.580945 stepsize 0.0010
# [step  13] neg-log-likelihood 82.257822 stepsize 0.0010
# [step  14] neg-log-likelihood 81.971524 stepsize 0.0010
# [step  15] neg-log-likelihood 81.715575 stepsize 0.0010
# [step  16] neg-log-likelihood 81.484347 stepsize 0.0010
# [step  17] neg-log-likelihood 81.273437 stepsize 0.0010
# [step  18] neg-log-likelihood 81.079595 stepsize 0.0010
# [step  19] neg-log-likelihood 80.900496 stepsize 0.0010
# [step  20] neg-log-likelihood 80.734484 stepsize 0.0010
# [step  21] neg-log-likelihood 80.580367 stepsize 0.0010
# [step  22] neg-log-likelihood 80.437236 stepsize 0.0010
# [step  23] neg-log-likelihood 80.304340 stepsize 0.0010
# [step  24] neg-log-likelihood 80.181002 stepsize 0.0010
# [step  25] neg-log-likelihood 80.066568 stepsize 0.0010
# [step  26] neg-log-likelihood 79.960388 stepsize 0.0010
# [step  27] neg-log-likelihood 79.861808 stepsize 0.0010
# [step  28] neg-log-likelihood 79.770175 stepsize 0.0010
# [step  29] neg-log-likelihood 79.684856 stepsize 0.0010
# [step  30] neg-log-likelihood 79.605246 stepsize 0.0010
# [step  31] neg-log-likelihood 79.530777 stepsize 0.0010
# [step  32] neg-log-likelihood 79.460931 stepsize 0.0010
# [step  33] neg-log-likelihood 79.395238 stepsize 0.0010
# [step  34] neg-log-likelihood 79.333279 stepsize 0.0010
# [step  35] neg-log-likelihood 79.274681 stepsize 0.0010
# [step  36] neg-log-likelihood 79.219117 stepsize 0.0010
# [step  37] neg-log-likelihood 79.166300 stepsize 0.0010
# [step  38] neg-log-likelihood 79.115977 stepsize 0.0010
# [step  39] neg-log-likelihood 79.067924 stepsize 0.0010
# [step  40] neg-log-likelihood 79.021946 stepsize 0.0010
# [step  41] neg-log-likelihood 78.977868 stepsize 0.0010
# [step  42] neg-log-likelihood 78.935536 stepsize 0.0010
# [step  43] neg-log-likelihood 78.894812 stepsize 0.0010
# [step  44] neg-log-likelihood 78.855572 stepsize 0.0010
# [step  45] neg-log-likelihood 78.817706 stepsize 0.0010
# [step  46] neg-log-likelihood 78.781113 stepsize 0.0010
# [step  47] neg-log-likelihood 78.745702 stepsize 0.0010
# [step  48] neg-log-likelihood 78.711390 stepsize 0.0010
# [step  49] neg-log-likelihood 78.678102 stepsize 0.0010
# [step  50] neg-log-likelihood 78.645769 stepsize 0.0010
# [step  51] neg-log-likelihood 78.614325 stepsize 0.0010
# [step  52] neg-log-likelihood 78.583712 stepsize 0.0010
# [step  53] neg-log-likelihood 78.553874 stepsize 0.0010
# [step  54] neg-log-likelihood 78.524758 stepsize 0.0010
# [step  55] neg-log-likelihood 78.496318 stepsize 0.0010
# [step  56] neg-log-likelihood 78.468505 stepsize 0.0010
# [step  57] neg-log-likelihood 78.441276 stepsize 0.0010
# [step  58] neg-log-likelihood 78.414589 stepsize 0.0010
# [step  59] neg-log-likelihood 78.388405 stepsize 0.0010
# [step  60] neg-log-likelihood 78.362684 stepsize 0.0010
# [step  61] neg-log-likelihood 78.337392 stepsize 0.0010
# [step  62] neg-log-likelihood 78.312491 stepsize 0.0010
# [step  63] neg-log-likelihood 78.287949 stepsize 0.0010
# [step  64] neg-log-likelihood 78.263734 stepsize 0.0010
# [step  65] neg-log-likelihood 78.239817 stepsize 0.0010
# [step  66] neg-log-likelihood 78.216167 stepsize 0.0010
# [step  67] neg-log-likelihood 78.192760 stepsize 0.0010
# [step  68] neg-log-likelihood 78.169570 stepsize 0.0010
# [step  69] neg-log-likelihood 78.146576 stepsize 0.0010
# [step  70] neg-log-likelihood 78.123756 stepsize 0.0010
# [step  71] neg-log-likelihood 78.101092 stepsize 0.0010
# [step  72] neg-log-likelihood 78.078570 stepsize 0.0010
# [step  73] neg-log-likelihood 78.056174 stepsize 0.0010
# [step  74] neg-log-likelihood 78.033895 stepsize 0.0010
# [step  75] neg-log-likelihood 78.011723 stepsize 0.0010
# [step  76] neg-log-likelihood 77.989650 stepsize 0.0010
# [step  77] neg-log-likelihood 77.967672 stepsize 0.0010
# [step  78] neg-log-likelihood 77.945786 stepsize 0.0010
# [step  79] neg-log-likelihood 77.923990 stepsize 0.0010
# [step  80] neg-log-likelihood 77.902283 stepsize 0.0010
# [step  81] neg-log-likelihood 77.880667 stepsize 0.0010
# [step  82] neg-log-likelihood 77.859144 stepsize 0.0010
# [step  83] neg-log-likelihood 77.837716 stepsize 0.0010
# [step  84] neg-log-likelihood 77.816388 stepsize 0.0010
# [step  85] neg-log-likelihood 77.795111 stepsize 0.0010
# [step  86] neg-log-likelihood 77.774006 stepsize 0.0010
# [step  87] neg-log-likelihood 77.753009 stepsize 0.0010
# [step  88] neg-log-likelihood 77.732125 stepsize 0.0010
# [step  89] neg-log-likelihood 77.711356 stepsize 0.0010
# [step  90] neg-log-likelihood 77.690706 stepsize 0.0010
# [step  91] neg-log-likelihood 77.670179 stepsize 0.0010
# [step  92] neg-log-likelihood 77.649562 stepsize 0.0010
# [step  93] neg-log-likelihood 77.629337 stepsize 0.0010
# [step  94] neg-log-likelihood 77.609257 stepsize 0.0010
# [step  95] neg-log-likelihood 77.589287 stepsize 0.0010
# [step  96] neg-log-likelihood 77.566795 stepsize 0.0010
# [step  97] neg-log-likelihood 77.549618 stepsize 0.0010
# [step  98] neg-log-likelihood 77.530014 stepsize 0.0010
# [step  99] neg-log-likelihood 77.510513 stepsize 0.0010
# [step 100] neg-log-likelihood 77.489990 stepsize 0.0010
# [step 101] neg-log-likelihood 77.469751 stepsize 0.0010
# [step 102] neg-log-likelihood 77.449825 stepsize 0.0010
# [step 103] neg-log-likelihood 77.433295 stepsize 0.0010
# [step 104] neg-log-likelihood 77.414346 stepsize 0.0010
# [step 105] neg-log-likelihood 77.395470 stepsize 0.0010
# [step 106] neg-log-likelihood 77.376873 stepsize 0.0010
# [step 107] neg-log-likelihood 77.358473 stepsize 0.0010
# [step 108] neg-log-likelihood 77.340211 stepsize 0.0010
# [step 109] neg-log-likelihood 77.322027 stepsize 0.0010
# [step 110] neg-log-likelihood 77.303881 stepsize 0.0010
# [step 111] neg-log-likelihood 77.285771 stepsize 0.0010
# [step 112] neg-log-likelihood 77.268377 stepsize 0.0010
# [step 113] neg-log-likelihood 77.250875 stepsize 0.0010
# [step 114] neg-log-likelihood 77.230824 stepsize 0.0010
# [step 115] neg-log-likelihood 77.213530 stepsize 0.0010
# [step 116] neg-log-likelihood 77.196676 stepsize 0.0010
# [step 117] neg-log-likelihood 77.177281 stepsize 0.0010
# [step 118] neg-log-likelihood 77.160721 stepsize 0.0010
# [step 119] neg-log-likelihood 77.143958 stepsize 0.0010
# [step 120] neg-log-likelihood 77.124251 stepsize 0.0010
# [step 121] neg-log-likelihood 77.108081 stepsize 0.0010
# [step 122] neg-log-likelihood 77.091553 stepsize 0.0010
# [step 123] neg-log-likelihood 77.071971 stepsize 0.0010
# [step 124] neg-log-likelihood 77.056098 stepsize 0.0010
# [step 125] neg-log-likelihood 77.039806 stepsize 0.0010
# [step 126] neg-log-likelihood 77.020491 stepsize 0.0010
# [step 127] neg-log-likelihood 77.004918 stepsize 0.0010
# [step 128] neg-log-likelihood 76.986774 stepsize 0.0010
# [step 129] neg-log-likelihood 76.971358 stepsize 0.0010
# [step 130] neg-log-likelihood 76.953481 stepsize 0.0010
# [step 131] neg-log-likelihood 76.938369 stepsize 0.0010
# [step 132] neg-log-likelihood 76.920826 stepsize 0.0010
# [step 133] neg-log-likelihood 76.906080 stepsize 0.0010
# [step 134] neg-log-likelihood 76.888950 stepsize 0.0010
# [step 135] neg-log-likelihood 76.874636 stepsize 0.0010
# [step 136] neg-log-likelihood 76.860703 stepsize 0.0010
# [step 137] neg-log-likelihood 76.846656 stepsize 0.0010
# [step 138] neg-log-likelihood 76.828261 stepsize 0.0010
# [step 139] neg-log-likelihood 76.815450 stepsize 0.0010
# [step 140] neg-log-likelihood 76.802877 stepsize 0.0010
# [step 141] neg-log-likelihood 76.786045 stepsize 0.0010
# [step 142] neg-log-likelihood 76.774404 stepsize 0.0010
# [step 143] neg-log-likelihood 76.762961 stepsize 0.0010
# [step 144] neg-log-likelihood 76.747227 stepsize 0.0010
# [step 145] neg-log-likelihood 76.735143 stepsize 0.0010
# [step 146] neg-log-likelihood 76.725852 stepsize 0.0010
# [step 147] neg-log-likelihood 76.712432 stepsize 0.0010
# [step 148] neg-log-likelihood 76.704088 stepsize 0.0010
# [step 149] neg-log-likelihood 76.691551 stepsize 0.0010
# [step 150] neg-log-likelihood 76.684524 stepsize 0.0010
# [step 151] neg-log-likelihood 76.677955 stepsize 0.0010
# [step 152] neg-log-likelihood 76.664645 stepsize 0.0010
# [step 153] neg-log-likelihood 76.659308 stepsize 0.0010
# [step 154] neg-log-likelihood 76.649206 stepsize 0.0010
# [step 155] neg-log-likelihood 76.645116 stepsize 0.0010
# [step 156] neg-log-likelihood 76.636047 stepsize 0.0010
# [step 157] neg-log-likelihood 76.633077 stepsize 0.0010
# [step 158] neg-log-likelihood 76.624988 stepsize 0.0010
# [step 159] neg-log-likelihood 76.623073 stepsize 0.0010
# [step 160] neg-log-likelihood 76.615665 stepsize 0.0010
# [step 161] neg-log-likelihood 76.614926 stepsize 0.0010
# [step 162] neg-log-likelihood 76.608598 stepsize 0.0010
# [step 163] neg-log-likelihood 76.608650 stepsize 0.0010
# [step 164] neg-log-likelihood 76.603289 stepsize 0.0010
# [step 165] neg-log-likelihood 76.601127 stepsize 0.0010
# [step 166] neg-log-likelihood 76.599413 stepsize 0.0010
# [step 167] neg-log-likelihood 76.598126 stepsize 0.0010
# [step 168] neg-log-likelihood 76.597132 stepsize 0.0010
# [step 169] neg-log-likelihood 76.596500 stepsize 0.0010
# [step 170] neg-log-likelihood 76.596153 stepsize 0.0010
# [step 171] neg-log-likelihood 76.596165 stepsize 0.0010
# [step 172] neg-log-likelihood 76.598946 stepsize 0.0010
# [step 173] neg-log-likelihood 76.597018 stepsize 0.0010
# [step 174] neg-log-likelihood 76.600201 stepsize 0.0010
# [step 175] neg-log-likelihood 76.598811 stepsize 0.0010
# [step 176] neg-log-likelihood 76.602553 stepsize 0.0010
# [step 177] neg-log-likelihood 76.601792 stepsize 0.0010
# [step 178] neg-log-likelihood 76.605798 stepsize 0.0010
# [step 179] neg-log-likelihood 76.605538 stepsize 0.0010
# [step 180] neg-log-likelihood 76.610106 stepsize 0.0010
# [step 181] neg-log-likelihood 76.610327 stepsize 0.0010
# [step 182] neg-log-likelihood 76.615347 stepsize 0.0010
# [step 183] neg-log-likelihood 76.616056 stepsize 0.0010
# [step 184] neg-log-likelihood 76.621563 stepsize 0.0010
# [step 185] neg-log-likelihood 76.622745 stepsize 0.0010
# [step 186] neg-log-likelihood 76.628772 stepsize 0.0010
# [step 187] neg-log-likelihood 76.630440 stepsize 0.0010
# [step 188] neg-log-likelihood 76.637035 stepsize 0.0010
# [step 189] neg-log-likelihood 76.639198 stepsize 0.0010
# [step 190] neg-log-likelihood 76.646505 stepsize 0.0010
# [step 191] neg-log-likelihood 76.649091 stepsize 0.0010
# [step 192] neg-log-likelihood 76.657087 stepsize 0.0010
# [step 193] neg-log-likelihood 76.660196 stepsize 0.0010
# [step 194] neg-log-likelihood 76.668956 stepsize 0.0010
# [step 195] neg-log-likelihood 76.672603 stepsize 0.0010
# [step 196] neg-log-likelihood 76.682203 stepsize 0.0010
# [step 197] neg-log-likelihood 76.686410 stepsize 0.0010
# [step 198] neg-log-likelihood 76.696924 stepsize 0.0010
# [step 199] neg-log-likelihood 76.701718 stepsize 0.0010
# [step 200] neg-log-likelihood 76.709972 stepsize 0.0010
# [step 201] neg-log-likelihood 76.718619 stepsize 0.0010
# [step 202] neg-log-likelihood 76.727696 stepsize 0.0010
# [step 203] neg-log-likelihood 76.737216 stepsize 0.0010
# [step 204] neg-log-likelihood 76.747193 stepsize 0.0010
# [step 205] neg-log-likelihood 76.757642 stepsize 0.0010
# [step 206] neg-log-likelihood 76.768575 stepsize 0.0010
# [step 207] neg-log-likelihood 76.780007 stepsize 0.0010
# [step 208] neg-log-likelihood 76.791951 stepsize 0.0010
# [step 209] neg-log-likelihood 76.804421 stepsize 0.0010
# [step 210] neg-log-likelihood 76.817429 stepsize 0.0010
# [step 211] neg-log-likelihood 76.830988 stepsize 0.0010
# [step 212] neg-log-likelihood 76.845110 stepsize 0.0010
# [step 213] neg-log-likelihood 76.859806 stepsize 0.0010
# [step 214] neg-log-likelihood 76.875088 stepsize 0.0010
# [step 215] neg-log-likelihood 76.890966 stepsize 0.0010
# [step 216] neg-log-likelihood 76.907449 stepsize 0.0010
# [step 217] neg-log-likelihood 76.924546 stepsize 0.0010
# [step 218] neg-log-likelihood 76.942264 stepsize 0.0010
# [step 219] neg-log-likelihood 76.960609 stepsize 0.0010
# [step 220] neg-log-likelihood 76.979586 stepsize 0.0010
# [step 221] neg-log-likelihood 76.999200 stepsize 0.0010
# [step 222] neg-log-likelihood 77.019451 stepsize 0.0010
# [step 223] neg-log-likelihood 77.040340 stepsize 0.0010
# [step 224] neg-log-likelihood 77.061864 stepsize 0.0010
# [step 225] neg-log-likelihood 77.084022 stepsize 0.0010
# [step 226] neg-log-likelihood 77.106806 stepsize 0.0010
# [step 227] neg-log-likelihood 77.130208 stepsize 0.0010
# [step 228] neg-log-likelihood 77.154218 stepsize 0.0010
# [step 229] neg-log-likelihood 77.178822 stepsize 0.0010
# [step 230] neg-log-likelihood 77.204006 stepsize 0.0010
# [step 231] neg-log-likelihood 77.229749 stepsize 0.0010
# [step 232] neg-log-likelihood 77.256032 stepsize 0.0010
# [step 233] neg-log-likelihood 77.282829 stepsize 0.0010
# [step 234] neg-log-likelihood 77.310113 stepsize 0.0010
# [step 235] neg-log-likelihood 77.337853 stepsize 0.0010
# [step 236] neg-log-likelihood 77.366017 stepsize 0.0010
# [step 237] neg-log-likelihood 77.394568 stepsize 0.0010
# [step 238] neg-log-likelihood 77.423466 stepsize 0.0010
# [step 239] neg-log-likelihood 77.452669 stepsize 0.0010
# [step 240] neg-log-likelihood 77.482132 stepsize 0.0010
# [step 241] neg-log-likelihood 77.511808 stepsize 0.0010
# [step 242] neg-log-likelihood 77.541645 stepsize 0.0010
# [step 243] neg-log-likelihood 77.571592 stepsize 0.0010
# [step 244] neg-log-likelihood 77.601594 stepsize 0.0010
# ...
# [step 317] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 318] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 319] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 320] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 321] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 322] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 323] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 324] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 325] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 326] neg-log-likelihood 238.733614 stepsize 0.0050
# [step 327] neg-log-likelihood 85.208467 stepsize 0.0050
# [step 328] neg-log-likelihood 92.456726 stepsize 0.0050
# [step 329] neg-log-likelihood 103.251577 stepsize 0.0050
# [step 330] neg-log-likelihood 88.350001 stepsize 0.0050
# [step 331] neg-log-likelihood 165.583725 stepsize 0.0050
# [step 332] neg-log-likelihood 215.903075 stepsize 0.0050
# [step 333] neg-log-likelihood 101.901918 stepsize 0.0050
# [step 334] neg-log-likelihood 103.549968 stepsize 0.0050
# [step 335] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 336] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 337] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 338] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 339] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 340] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 341] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 342] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 343] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 344] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 345] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 346] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 347] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 348] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 349] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 350] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 351] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 352] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 353] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 354] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 355] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 356] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 357] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 358] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 359] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 360] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 361] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 362] neg-log-likelihood 239.818040 stepsize 0.0050
# [step 363] neg-log-likelihood 191.693521 stepsize 0.0050
# [step 364] neg-log-likelihood 177.294215 stepsize 0.0050
# [step 365] neg-log-likelihood 206.636633 stepsize 0.0050
# [step 366] neg-log-likelihood 85.031344 stepsize 0.0050
# [step 367] neg-log-likelihood 239.817925 stepsize 0.0050
# [step 368] neg-log-likelihood 238.523773 stepsize 0.0050
# [step 369] neg-log-likelihood 88.215913 stepsize 0.0050
# [step 370] neg-log-likelihood 68.616798 stepsize 0.0050
# [step 371] neg-log-likelihood 93.196716 stepsize 0.0050
# [step 372] neg-log-likelihood 239.818039 stepsize 0.0050
# [step 373] neg-log-likelihood 85.666657 stepsize 0.0050
# [step 374] neg-log-likelihood 210.012071 stepsize 0.0050
# [step 375] neg-log-likelihood 96.563451 stepsize 0.0050
# [step 376] neg-log-likelihood 93.630234 stepsize 0.0050
# [step 377] neg-log-likelihood 188.745112 stepsize 0.0050
# [step 378] neg-log-likelihood 133.891644 stepsize 0.0050
# [step 379] neg-log-likelihood 107.581151 stepsize 0.0050
# [step 380] neg-log-likelihood 97.138747 stepsize 0.0050
# [step 381] neg-log-likelihood 226.266306 stepsize 0.0050
# [step 382] neg-log-likelihood 152.009462 stepsize 0.0050
# [step 383] neg-log-likelihood 159.075772 stepsize 0.0050
# [step 384] neg-log-likelihood 205.840210 stepsize 0.0050
# [step 385] neg-log-likelihood 144.795176 stepsize 0.0050
# [step 386] neg-log-likelihood 201.814252 stepsize 0.0050
# [step 387] neg-log-likelihood 199.135430 stepsize 0.0050
# [step 388] neg-log-likelihood 168.002564 stepsize 0.0050
# [step 389] neg-log-likelihood 203.364369 stepsize 0.0050
# [step 390] neg-log-likelihood 111.732158 stepsize 0.0050
# [step 391] neg-log-likelihood 89.440810 stepsize 0.0050
# [step 392] neg-log-likelihood 88.952232 stepsize 0.0050
# [step 393] neg-log-likelihood 87.567052 stepsize 0.0050
# [step 394] neg-log-likelihood 239.818037 stepsize 0.0050
# [step 395] neg-log-likelihood 239.818037 stepsize 0.0050
# [step 396] neg-log-likelihood 114.303264 stepsize 0.0050
# [step 397] neg-log-likelihood 82.923914 stepsize 0.0050
# [step 398] neg-log-likelihood 88.672098 stepsize 0.0050
# [step 399] neg-log-likelihood 98.180597 stepsize 0.0050
# [step 400] neg-log-likelihood 91.477808 stepsize 0.0050
# [step 401] neg-log-likelihood 143.866734 stepsize 0.0050
# [step 402] neg-log-likelihood 227.270909 stepsize 0.0050
# [step 403] neg-log-likelihood 89.205673 stepsize 0.0050
# [step 404] neg-log-likelihood 85.259775 stepsize 0.0050
# [step 405] neg-log-likelihood 102.349134 stepsize 0.0050
# [step 406] neg-log-likelihood 68.015629 stepsize 0.0050
# [step 407] neg-log-likelihood 214.256769 stepsize 0.0050
# [step 408] neg-log-likelihood 82.198680 stepsize 0.0050
# [step 409] neg-log-likelihood 90.653733 stepsize 0.0050
# [step 410] neg-log-likelihood 100.359315 stepsize 0.0050
# [step 411] neg-log-likelihood 100.186359 stepsize 0.0050
# [step 412] neg-log-likelihood 85.939838 stepsize 0.0050
# [step 413] neg-log-likelihood 84.642604 stepsize 0.0050
# [step 414] neg-log-likelihood 81.129600 stepsize 0.0050
# [step 415] neg-log-likelihood 86.103348 stepsize 0.0050
# [step 416] neg-log-likelihood 92.597593 stepsize 0.0050
# [step 417] neg-log-likelihood 106.129716 stepsize 0.0050
# [step 418] neg-log-likelihood 207.028690 stepsize 0.0050
# [step 419] neg-log-likelihood 88.577963 stepsize 0.0050
# [step 420] neg-log-likelihood 83.285739 stepsize 0.0050
# [step 421] neg-log-likelihood 156.559673 stepsize 0.0050
# [step 422] neg-log-likelihood 93.534230 stepsize 0.0050
# [step 423] neg-log-likelihood 112.625809 stepsize 0.0050
# [step 424] neg-log-likelihood 219.212447 stepsize 0.0050
# [step 425] neg-log-likelihood 109.579338 stepsize 0.0050
# [step 426] neg-log-likelihood 120.621668 stepsize 0.0050
# [step 427] neg-log-likelihood 88.347121 stepsize 0.0050
# [step 428] neg-log-likelihood 128.070723 stepsize 0.0050
# [step 429] neg-log-likelihood 239.818041 stepsize 0.0050
# [step 430] neg-log-likelihood 109.663640 stepsize 0.0050
# [step 431] neg-log-likelihood 168.429650 stepsize 0.0050
# [step 432] neg-log-likelihood 224.782227 stepsize 0.0050
# [step 433] neg-log-likelihood 202.570282 stepsize 0.0050
# [step 434] neg-log-likelihood 198.584848 stepsize 0.0050
# [step 435] neg-log-likelihood 236.352632 stepsize 0.0050
# [step 436] neg-log-likelihood 80.262286 stepsize 0.0050
# [step 437] neg-log-likelihood 110.642248 stepsize 0.0050
# [step 438] neg-log-likelihood 176.571223 stepsize 0.0050
# [step 439] neg-log-likelihood 117.883366 stepsize 0.0050
# [step 440] neg-log-likelihood 188.269824 stepsize 0.0050
# [step 441] neg-log-likelihood 197.206042 stepsize 0.0050
# [step 442] neg-log-likelihood 99.334542 stepsize 0.0050
# [step 443] neg-log-likelihood 108.256659 stepsize 0.0050
# [step 444] neg-log-likelihood 185.860143 stepsize 0.0050
# [step 445] neg-log-likelihood 234.267263 stepsize 0.0050
# [step 446] neg-log-likelihood 99.071945 stepsize 0.0050
# [step 447] neg-log-likelihood 78.422909 stepsize 0.0050
# [step 448] neg-log-likelihood 85.080360 stepsize 0.0050
# [step 449] neg-log-likelihood 80.405586 stepsize 0.0050
# [step 450] neg-log-likelihood 145.599146 stepsize 0.0050
# [step 451] neg-log-likelihood 181.153691 stepsize 0.0050
# [step 452] neg-log-likelihood 90.099305 stepsize 0.0050
# [step 453] neg-log-likelihood 86.016498 stepsize 0.0050
# [step 454] neg-log-likelihood 156.912902 stepsize 0.0050
# [step 455] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 456] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 457] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 458] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 459] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 460] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 461] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 462] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 463] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 464] neg-log-likelihood 239.818038 stepsize 0.0050
# [step 465] neg-log-likelihood 239.668045 stepsize 0.0050
# [step 466] neg-log-likelihood 84.775389 stepsize 0.0050
# [step 467] neg-log-likelihood 98.038009 stepsize 0.0050
# [step 468] neg-log-likelihood 80.582885 stepsize 0.0050
# [step 469] neg-log-likelihood 78.284894 stepsize 0.0050
# [step 470] neg-log-likelihood 77.580812 stepsize 0.0050
# [step 471] neg-log-likelihood 77.411621 stepsize 0.0050
# [step 472] neg-log-likelihood 77.256754 stepsize 0.0050
# [step 473] neg-log-likelihood 77.140669 stepsize 0.0050
# [step 474] neg-log-likelihood 77.047736 stepsize 0.0050
# [step 475] neg-log-likelihood 76.974013 stepsize 0.0050
# [step 476] neg-log-likelihood 76.917890 stepsize 0.0050
# [step 477] neg-log-likelihood 76.878431 stepsize 0.0050
# [step 478] neg-log-likelihood 76.854418 stepsize 0.0050
# [step 479] neg-log-likelihood 76.844202 stepsize 0.0050
# [step 480] neg-log-likelihood 76.845540 stepsize 0.0050
# [step 481] neg-log-likelihood 76.855945 stepsize 0.0050
# [step 482] neg-log-likelihood 76.874061 stepsize 0.0050
# [step 483] neg-log-likelihood 76.897548 stepsize 0.0050
# [step 484] neg-log-likelihood 76.925333 stepsize 0.0050
# [step 485] neg-log-likelihood 76.956429 stepsize 0.0050
# [step 486] neg-log-likelihood 76.990025 stepsize 0.0050
# [step 487] neg-log-likelihood 77.025383 stepsize 0.0050
# [step 488] neg-log-likelihood 77.061762 stepsize 0.0050
# [step 489] neg-log-likelihood 77.098373 stepsize 0.0050
# [step 490] neg-log-likelihood 77.134335 stepsize 0.0050
# [step 491] neg-log-likelihood 77.168642 stepsize 0.0050
# [step 492] neg-log-likelihood 77.200109 stepsize 0.0050
# [step 493] neg-log-likelihood 77.227399 stepsize 0.0050
# [step 494] neg-log-likelihood 77.248756 stepsize 0.0050
# [step 495] neg-log-likelihood 77.262144 stepsize 0.0050
# [step 496] neg-log-likelihood 77.265263 stepsize 0.0050
# [step 497] neg-log-likelihood 77.255797 stepsize 0.0050
# [step 498] neg-log-likelihood 77.231795 stepsize 0.0050
# [step 499] neg-log-likelihood 77.193490 stepsize 0.0050
# [step 500] neg-log-likelihood 77.144093 stepsize 0.0050
# [step 501] neg-log-likelihood 77.090836 stepsize 0.0050
# [step 502] neg-log-likelihood 77.044256 stepsize 0.0050
# [step 503] neg-log-likelihood 77.015521 stepsize 0.0050
# [step 504] neg-log-likelihood 77.012994 stepsize 0.0050
# [step 505] neg-log-likelihood 77.042668 stepsize 0.0050
# [step 506] neg-log-likelihood 77.107080 stepsize 0.0050
# [step 507] neg-log-likelihood 77.207338 stepsize 0.0050
# [step 508] neg-log-likelihood 77.342953 stepsize 0.0050
# [step 509] neg-log-likelihood 77.512307 stepsize 0.0050
# [step 510] neg-log-likelihood 77.712972 stepsize 0.0050
# [step 511] neg-log-likelihood 77.941955 stepsize 0.0050
# [step 512] neg-log-likelihood 78.195521 stepsize 0.0050
# [step 513] neg-log-likelihood 78.469118 stepsize 0.0050
# [step 514] neg-log-likelihood 78.756369 stepsize 0.0050
# [step 515] neg-log-likelihood 79.045114 stepsize 0.0050
# [step 516] neg-log-likelihood 79.310988 stepsize 0.0050
# [step 517] neg-log-likelihood 79.500679 stepsize 0.0050
# [step 518] neg-log-likelihood 79.502025 stepsize 0.0050
# [step 519] neg-log-likelihood 79.120794 stepsize 0.0050
# [step 520] neg-log-likelihood 78.175231 stepsize 0.0050
# [step 521] neg-log-likelihood 76.773825 stepsize 0.0050
# [step 522] neg-log-likelihood 75.563248 stepsize 0.0050
# [step 523] neg-log-likelihood 74.946569 stepsize 0.0050
# [step 524] neg-log-likelihood 74.638284 stepsize 0.0050
# [step 525] neg-log-likelihood 74.373210 stepsize 0.0050
# [step 526] neg-log-likelihood 74.065821 stepsize 0.0050
# [step 527] neg-log-likelihood 73.764724 stepsize 0.0050
# [step 528] neg-log-likelihood 73.542893 stepsize 0.0050
# [step 529] neg-log-likelihood 73.406913 stepsize 0.0050
# [step 530] neg-log-likelihood 73.323499 stepsize 0.0050
# [step 531] neg-log-likelihood 73.293507 stepsize 0.0050
# [step 532] neg-log-likelihood 73.283348 stepsize 0.0050
# [step 533] neg-log-likelihood 73.315348 stepsize 0.0050
# [step 534] neg-log-likelihood 73.372394 stepsize 0.0050
# [step 535] neg-log-likelihood 73.471577 stepsize 0.0050
# [step 536] neg-log-likelihood 73.610548 stepsize 0.0050
# [step 537] neg-log-likelihood 73.806617 stepsize 0.0050
# [step 538] neg-log-likelihood 74.069653 stepsize 0.0050
# [step 539] neg-log-likelihood 74.420871 stepsize 0.0050
# [step 540] neg-log-likelihood 74.880502 stepsize 0.0050
# [step 541] neg-log-likelihood 75.464158 stepsize 0.0050
# [step 542] neg-log-likelihood 76.151571 stepsize 0.0050
# [step 543] neg-log-likelihood 76.868371 stepsize 0.0050
# [step 544] neg-log-likelihood 77.527358 stepsize 0.0050
# [step 545] neg-log-likelihood 78.158691 stepsize 0.0050
# [step 546] neg-log-likelihood 78.933842 stepsize 0.0050
# [step 547] neg-log-likelihood 81.135803 stepsize 0.0050
# [step 548] neg-log-likelihood 99.764702 stepsize 0.0050
# [step 549] neg-log-likelihood 80.725088 stepsize 0.0050
# [step 550] neg-log-likelihood 83.348210 stepsize 0.0050
# [step 551] neg-log-likelihood 73.462638 stepsize 0.0050
# [step 552] neg-log-likelihood 73.472996 stepsize 0.0050
# [step 553] neg-log-likelihood 73.478237 stepsize 0.0050
# [step 554] neg-log-likelihood 73.479863 stepsize 0.0050
# [step 555] neg-log-likelihood 73.479374 stepsize 0.0050
# [step 556] neg-log-likelihood 73.478272 stepsize 0.0050
# [step 557] neg-log-likelihood 73.477323 stepsize 0.0050
# [step 558] neg-log-likelihood 73.477250 stepsize 0.0050
# [step 559] neg-log-likelihood 73.478500 stepsize 0.0050
# [step 560] neg-log-likelihood 73.481320 stepsize 0.0050
# [step 561] neg-log-likelihood 73.485795 stepsize 0.0050
# [step 562] neg-log-likelihood 73.492119 stepsize 0.0050
# [step 563] neg-log-likelihood 73.500328 stepsize 0.0050
# [step 564] neg-log-likelihood 73.510136 stepsize 0.0050
# [step 565] neg-log-likelihood 73.521733 stepsize 0.0050
# [step 566] neg-log-likelihood 73.534948 stepsize 0.0050
# [step 567] neg-log-likelihood 73.549694 stepsize 0.0050
# [step 568] neg-log-likelihood 73.565878 stepsize 0.0050
# [step 569] neg-log-likelihood 73.583408 stepsize 0.0050
# [step 570] neg-log-likelihood 73.602264 stepsize 0.0050
# [step 571] neg-log-likelihood 73.622170 stepsize 0.0050
# [step 572] neg-log-likelihood 73.643213 stepsize 0.0050
# [step 573] neg-log-likelihood 73.665259 stepsize 0.0050
# [step 574] neg-log-likelihood 73.688234 stepsize 0.0050
# [step 575] neg-log-likelihood 73.712079 stepsize 0.0050
# [step 576] neg-log-likelihood 73.736741 stepsize 0.0050
# [step 577] neg-log-likelihood 73.762230 stepsize 0.0050
# [step 578] neg-log-likelihood 73.788384 stepsize 0.0050
# [step 579] neg-log-likelihood 73.815242 stepsize 0.0050
# [step 580] neg-log-likelihood 73.842780 stepsize 0.0050
# [step 581] neg-log-likelihood 73.870991 stepsize 0.0050
# [step 582] neg-log-likelihood 73.899868 stepsize 0.0050
# [step 583] neg-log-likelihood 73.929404 stepsize 0.0050
# [step 584] neg-log-likelihood 73.959601 stepsize 0.0050
# [step 585] neg-log-likelihood 73.990476 stepsize 0.0050
# [step 586] neg-log-likelihood 74.022054 stepsize 0.0050
# [step 587] neg-log-likelihood 74.054363 stepsize 0.0050
# [step 588] neg-log-likelihood 74.083386 stepsize 0.0050
# [step 589] neg-log-likelihood 74.121331 stepsize 0.0050
# [step 590] neg-log-likelihood 74.154239 stepsize 0.0050
# [step 591] neg-log-likelihood 74.189232 stepsize 0.0050
# [step 592] neg-log-likelihood 74.226297 stepsize 0.0050
# [step 593] neg-log-likelihood 74.265518 stepsize 0.0050
# [step 594] neg-log-likelihood 74.306652 stepsize 0.0050
# [step 595] neg-log-likelihood 74.344745 stepsize 0.0050
# [step 596] neg-log-likelihood 74.390259 stepsize 0.0050
# [step 597] neg-log-likelihood 74.428467 stepsize 0.0050
# [step 598] neg-log-likelihood 74.472476 stepsize 0.0050
# [step 599] neg-log-likelihood 74.518240 stepsize 0.0050

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_nll_eu_array[i], '--g')
    h2, = plt.plot(np.arange(max_iters), hist_nll_grass_array[i], '-b', linewidth=3.0)
    h3, = plt.plot(np.arange(max_iters), hist_nll_conjugate_grass_array[i], '-r', linewidth=3.0)

    if add_reg:
        ax.legend([h1, h2, h3], [r"Euclid-GD ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                                 r"Grass-GD ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                                 r"Grass-CG ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                                 fontsize = 15, loc='center left', frameon=True)
    else:    
        ax.legend([h1, h2, h3], [r"Euclid-GD ($\eta$ = {0:6.5f})".format(eta), r"Grass-GD ($\eta$ = {0:6.5f})".format(eta), \
                                 r"Grass-CG ($\eta$ = {0:6.5f})".format(eta)], \
                             fontsize = 15, loc='upper left', frameon=True)
    plt.grid(1)
    plt.ylabel('negative log-likelihood', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    #ax.set_ylim([60, 120])
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_nll_iters_GrassCG_GD_EuGD.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
fig= plt.figure(2)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,0], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,1], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"(Grass-GD) 1st singular value ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                             r"(Grass-GD) 2nd singular value ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:6.5f})".format(eta), r"2nd singular value ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper center', frameon=True)
    plt.grid(1)
    plt.ylabel('singular value', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_sig_iters_Grass_GD.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
fig= plt.figure(3)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_Hsig_conjugate_array[i][:,0], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_Hsig_conjugate_array[i][:,1], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"(Grass-CG) 1st singular value ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                             r"(Grass-CG) 2nd singular value ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:6.5f})".format(eta), r"2nd singular value ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper center', frameon=True)
    plt.grid(1)
    plt.ylabel('singular value', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_sig_iters_Grass_CG.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
fig= plt.figure(4)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_Gnorm_array[i], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_Gnorm_conjugate_array[i], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"(Grass-GD) G-norm ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                             r"(Grass-CG) G-norm ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"(Grass-GD) G-norm ($\eta$ = {0:6.5f})".format(eta), r"(Grass-CG) G-norm ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper center', frameon=True)
    plt.grid(1)
    plt.ylabel('norm value', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_sig_iters_Gnorm_GDCG.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
len(hist_gamma_array[i])
# Out:
# 600

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    h1, = plt.semilogy(np.arange(max_iters), hist_condK_array[i], '--g')
    h2, = plt.semilogy(np.arange(max_iters), hist_condK_grass_array[i], '-b', linewidth=3.0)
    h3, = plt.semilogy(np.arange(max_iters), hist_condK_conjugate_array[i], '-r', linewidth=3.0)

    if add_reg:
         ax.legend([h1, h2, h3], [r"Euclid-GD ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                                  r"Grass-GD ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                                  r"Grass-CG ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='upper left', frameon=True)
    else:    
        ax.legend([h1, h2, h3], [r"Euclid-GD ($\eta$ = {0:6.5f})".format(eta), r"Grass-GD ($\eta$ = {0:6.5f})".format(eta), \
                                 r"Grass-CG ($\eta$ = {0:6.5f})".format(eta)], \
                             fontsize = 15, loc='upper left', frameon=True)
    plt.grid(1)
    plt.ylabel('condition number of K', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_nll_iters_condK.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    h1, = plt.semilogy(np.arange(max_iters), hist_cond2K_array[i], '--g')
    h2, = plt.semilogy(np.arange(max_iters), hist_cond2K_grass_array[i], '-b', linewidth=3.0)
    h3, = plt.semilogy(np.arange(max_iters), hist_cond2K_conjugate_array[i], '-r', linewidth=3.0)

    if add_reg:
         ax.legend([h1, h2, h3], [r"Euclid-GD ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                                  r"Grass-GD ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                                  r"Grass-CG ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='upper center', frameon=True)
        #ax.legend([h3], [r"Conjugate Grassmann ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
        #                     fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2, h3], [r"Euclid-GD ($\eta$ = {0:6.5f})".format(eta), r"Grass-GD ($\eta$ = {0:6.5f})".format(eta), \
                                 r"Grass-CG ($\eta$ = {0:6.5f})".format(eta)], \
                             fontsize = 15, loc='upper center', frameon=True)
    plt.grid(1)
    plt.ylabel('condition number of dL/dK', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_nll_iters_cond2K.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
fig= plt.figure(5)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    #h1, = plt.plot(np.arange(max_iters), hist_Gnorm_array[i], 'b')
    h1, = plt.plot(np.arange(max_iters), hist_gamma_array[i], 'r')
    if add_reg:
        ax.legend([h1], [r"(Grass-CG) $\gamma$ ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='center', frameon=True)
        #ax.legend([h1, h2], [r"(Grass-GD) G-norm ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
        #                     r"(Grass-CG) G-norm ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
        #                     fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"(Grass-GD) G-norm ($\eta$ = {0:6.5f})".format(eta), r"(Grass-CG) G-norm ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='lower center', frameon=True)
    plt.grid(1)
    plt.ylabel(r"$\gamma$", fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_sig_iters_gamma_CG.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
fig= plt.figure(6)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    #h1, = plt.plot(np.arange(max_iters), hist_Gnorm_array[i], 'b')
    h1, = plt.plot(np.arange(max_iters), hist_deltaG_array[i], 'r')
    if add_reg:
        ax.legend([h1], [r"(Grass-CG) $<G - \tau G, G>$ ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='lower center', frameon=True)
        #ax.legend([h1, h2], [r"(Grass-GD) G-norm ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
        #                     r"(Grass-CG) G-norm ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
        #                     fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"(Grass-GD) G-norm ($\eta$ = {0:6.5f})".format(eta), r"(Grass-CG) G-norm ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='lower center', frameon=True)
    plt.grid(1)
    plt.ylabel(r"$\Delta G$", fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_sig_iters_dG_CG.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
fig= plt.figure(6)
fig.set_size_inches(12.0, 6.0*len(eta_array))
plt.style.use('seaborn-white')

for i, eta in enumerate(eta_array):
    ax = plt.subplot(len(eta_array),1,i+1)
    #h1, = plt.plot(np.arange(max_iters), hist_Gnorm_array[i], 'b')
    h1, = plt.plot(np.arange(max_iters), hist_kern_grass_array[i][:,2], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_kern_grass2_array[i][:,2], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"(Grass-GD) $\beta$ ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var), \
                             r"(Grass-CG) $\beta$ ($\eta$ = {0:6.5f}, $\lambda$ = {1:5.3f})".format(eta, lambda_var)], \
                             fontsize = 15, loc='lower center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"(Grass-GD) $\beta$ ($\eta$ = {0:6.5f})".format(eta), r"(Grass-CG) $\beta$ ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='lower center', frameon=True)
    plt.grid(1)
    plt.ylabel(r"$\beta$ noise variance", fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    ax.set_ylim([0,noise_interval[1]])
plt.show    
if Ifsavefig:
    file_org = "../figures/04_15_16_" + str(trial) + "_"
    file_tail = "_sig_iters_beta.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )
