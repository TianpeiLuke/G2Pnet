# %% [markdown]
# # G$^2$Pnet: The Grassmanian Gaussian Process Network
# We check the implementation of G2PnetSolver (ver 4.) class in ../src/
#
# Created by Tianpei Xie, 04/02/2016
#
# Last Edit 04/02/2016

# %%
# %reset
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.metrics.pairwise import rbf_kernel, pairwise_kernels
import GPy
import GPy.util as gutil

# %matplotlib inline 
plt.close('all')
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
Ifsavefig =  False
Ifsavedata = False
trail = 13

# %% [markdown]
# The network generating

# %%
size = 40
color_map = {0:'r', 1:'c', 2:'y'}
#center = np.zeros(2)
#center[1] = 1
center = None

n = 40
m = 0
G0= nx.barbell_graph(n,m) 
#generate the bar-bell graph, which consists of two fully connected component and a path connecting them 

label0 = np.zeros([2*n,1])
label0[n:2*n] = np.ones([n,1])
#### labeling of the cluster
for node in G0.nodes():
    G0.node[node]['category'] = int(label0[node,0])

# %%
####generate the eigenspace of normalized Laplacian
k = 3
nnodes = nx.adjacency_matrix(G0).shape[0]

ncv=max(2*k+1,int(np.sqrt(nnodes)))

eigenvalues,eigenvectors= sp.sparse.linalg.eigsh(nx.laplacian_matrix(G0).asfptype(), k=k, \
                                                which='SM', return_eigenvectors = True, ncv=ncv)
index=np.argsort(eigenvalues)[1:k] # 0 index is zero eigenvalue    
pos_spectral_mat = np.real(eigenvectors[:,index]) #pos_spectral_mat is the spectral location of the nodes
pos_spectral_df = pd.DataFrame(data=pos_spectral_mat, columns=['PX','PY'], dtype=float)
pos_spectral_df['LABEL'] = label0

# %% [markdown]
# The node attributes generating

# %%
T= 2
c = 2*np.pi*0.8
data_np = np.zeros([nnodes, T])
column_name = []
for t in np.arange(1,T+1):
    temp1 = np.multiply(pos_spectral_df['PX'].apply(lambda x: np.exp(-c*t*x)).values, \
                          pos_spectral_df['PY'].apply(lambda y: np.cos(c*t*y)).values)
    data_np[:,t-1] = temp1
    if t == 1:
        column_name = str(t-1)+"_cos"
    else:    
        column_name = [column_name, str(t-1)+"_cos"]

sigma = 0.1        
data_np = np.add(data_np, sigma*np.random.randn(nnodes, T))    
data_df = pd.DataFrame(data=data_np, columns=column_name, dtype=float)
data_df['LABEL'] = label0

# %%
if Ifsavedata:
    nx.write_adjlist(G0, "../data/04_01_2016_experiment"+ str(trail) +".adjlist",delimiter=',')
    nx.write_edgelist(G0, "../data/04_01_2016_experiment" + str(trail) + ".edgelist")

    np.savez("../data/04_01_2016_experiment" + str(trail) + "_data.npz", pos_spectral_mat, data_np, label0)
    data_df.to_csv("../data/04_01_2016_experiment" + str(trail) + "_X.csv", index_label= 'ID')
    pos_spectral_df.to_csv("../data/04_01_2016_experiment" +  str(trail)  + "_U.csv", index_label= 'ID')

# %% [markdown]
# if Ifsavedata:
#     nx.write_adjlist(G0, "../data/experiment_bad_03_31_2016.adjlist",delimiter=',')
#     nx.write_edgelist(G0, "../data/experiment_bad_03_31_2016.edgelist")
#
#     np.savez("../data/experiment_bad_data_03_31_2016.npz", pos_spectral_mat, data_np, label0)
#     data_df.to_csv("../data/experiment_bad_X_03_31_2016.csv", index_label= 'ID')
#     pos_spectral_df.to_csv("../data/experiment_bad_U_03_31_2016.csv", index_label= 'ID')

# %%
X= data_np
U= pos_spectral_mat
nsample, ndim = X.shape
_ , ndim_latent = U.shape

kern = GPy.kern.RBF(2)

# %% [markdown]
# Import from the G2PnetSolver_v4.py

# %%
import sys
import os
dirorg = os.path.dirname(os.getcwd())
sys.path.insert(0, dirorg+"/src/")

# %%
import G2PnetSolver_v4 #G2PnetSolver_v2
#from imp import reload
#reload(G2PnetSolver_v2)

# %%
from G2PnetSolver_v4 import  G2PnetSolver as Solver
from G2PnetSolver_v4 import  Grassmann_update, check_step

# %%
choice = "near"

# %%
np.random.seed(seed=150)

if choice == "random":
    print("Random Initialization")
    Temp = np.random.randn(nsample, nsample)
    Temp_sym = (Temp + Temp.T) / 2 
    _, U_temp = np.linalg.eig(Temp_sym)
    U_test = U_temp[:, np.arange(ndim_latent)]
    U0 = U_test
elif choice == "near":
    print("Initialization in neigborhood.")
    U0 = U

eta0 = 0.75
np.random.seed(seed=160)
G_temp = np.random.randn(nsample, ndim_latent) / (np.sqrt(nsample * ndim_latent))
H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
print(str(check_step(H_temp, eta0)))
while not check_step(H_temp, eta0):
    np.random.seed(seed=160)
    G_temp = np.random.randn(nsample, ndim_latent) / np.sqrt(nsample * ndim_latent)
    H_temp = -np.dot((np.eye(nsample) - gutil.linalg.tdot(U0)),G_temp)
U_init = Grassmann_update(U0, H_temp, eta=eta0)
# Out:
# Initialization in neigborhood.
# True

# %%
sp.linalg.svdvals(H_temp)*eta0
# Out:
# array([ 0.52292797,  0.50843383])

# %% [markdown]
# ### Compute the gradient $\frac{dL}{dU}$
# The loss function is given as negative log-likelihood of Gaussian process
#
# \begin{align}
# \mathcal{L}(\beta, \sigma, \mathbf{U}) &= \frac{pN}{2}\log(2\pi)+\frac{p}{2}\log\det(\mathbf{K}_{\beta, \sigma, \mathbf{U}})+\frac{1}{2}\text{tr}\left(\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{−1}\mathbf{X}\mathbf{X}^T\right) + \frac{\lambda}{2} \|\mathbf{U}\mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2}
# \end{align}
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{K}$
# \begin{align}
# \mathbf{T}&= 2\mathbf{T}_{0} - \text{diag}\left(\mathbf{T}_{0}\right),\\
# \mathbf{T}_{0} &= \frac{1}{2}\left(\mathbf{I} - \mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}\mathbf{X}\mathbf{X}^T/p \right)\mathbf{K}_{\beta, \sigma, \mathbf{U}}^{-1}, \\
# \mathbf{K}_{r,s} &= K_{\sigma}\left(\mathbf{U}_{r,:} , \mathbf{U}_{s,:}\right) + \beta \delta_{r,s}
# \end{align}
#
# For rbf kernel,
# \begin{align}
# \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{Z}}}{\partial \mathbf{U}_{m,j}}
# &= -\frac{l^{2}}{\sigma^2} \exp\left(-\frac{1}{2\sigma^2} \|\mathbf{U}_{m} -  \mathbf{U}_{n}\|^{2} \right)\left[2\left( \mathbf{U}_{m,i} - \mathbf{U}_{n,j} \right)\right]
# \end{align}
#
# The differential of the second norm term
# \begin{align}
# \frac{d}{d\mathbf{U}}\frac{1}{2}\|\mathbf{U} \mathbf{U}^{T} -  \mathbf{U}_{L}\mathbf{U}_{L}^{T}\|_{F}^{2} &=
# \frac{d}{d\mathbf{U}}\frac{1}{2}\left[\text{tr}\left(\mathbf{U} \mathbf{U}^{T}\right) - \text{tr}\left(\mathbf{U}_{L}\mathbf{U}_{L}^{T}\mathbf{U}\mathbf{U}^{T}\right)\right]\\
# &= \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U}
# \end{align}
#
# The partial differential of $\mathcal{L}$ with respect to $\mathbf{U}$
# \begin{align}
# \frac{\partial\mathcal{L}}{\partial\mathbf{U}} &= \left[\text{tr}\left( \mathbf{T} \frac{\partial \mathbf{K}_{\beta, \sigma, \mathbf{U}}}{\partial \mathbf{U}_{m,j}} \right)\right]_{m,j} + \lambda \left(\mathbf{I} - \mathbf{U}_{L}\mathbf{U}_{L}^{T}\right)\mathbf{U},
# \end{align}

# %%
if Ifsavedata:
    U_columns = [str(i) for i in np.arange(ndim_latent)]
    U_df = pd.DataFrame(data = U_init, columns=U_columns, dtype= float)
    if choice == "random":
        U_df['RANDOM'] = np.ones([nsample, 1])
    elif choice == "near":
        U_df['RANDOM'] = np.zeros([nsample, 1])
    
    U_df.to_csv("../data/04_01_16_" + str(trail)  + "_U_init.csv")
    #U_df.to_csv("../data/U_init_bad_03_31_16.csv")

# %%
add_reg = True
lambda_array = np.array([0.01]) #10, 1, 0.001
eta = 0.0001
max_iters = 600
kern_array = [GPy.kern.RBF(2) for i in np.arange(len(lambda_array))]
kern_grass_array = [GPy.kern.RBF(2) for i in np.arange(len(lambda_array))]
solver_array = []
hist_nll_eu_array = []
hist_nll_grass_array = []
hist_Hsig_array = []

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 30.0)
plt.style.use('seaborn-white')

for i, lambda_var in enumerate(lambda_array): 
    ax = plt.subplot(5,1,i+1)
    solver = Solver(X=X, U=U_init, kernel=kern_array[i], U_ref= U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_eu, hist_eta, hist_kern_eu = solver.optimize(max_iters = max_iters)
    solver_array.append(solver)
    hist_nll_eu_array.append(hist_nll_eu)
    
    
    solver2 = Solver(X=X, U=U_init, kernel=kern_grass_array[i], U_ref = U, add_reg = add_reg, lambda_var = lambda_var, eta=eta)
    hist_nll_grass, hist_eta, hist_kern_grass = solver2.optimize(max_iters = max_iters, optimizor = "grad_descent_grass")
    hist_Hsig_array.append(solver2.hist_Hsig)
    
    solver_array.append(solver2)
    hist_nll_grass_array.append(hist_nll_grass)
        
    # %xdel solver
    # %xdel solver2
# Out:
# kernel initialization ...
# negative log-likelihood compute
# [step   0] neg-log-likelihood -550.491901 stepsize 0.0001
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -561.462565 stepsize 0.0001
# [step   2] neg-log-likelihood -558.126426 stepsize 0.0001
# [step   3] neg-log-likelihood -545.376209 stepsize 0.0001
# [step   4] neg-log-likelihood -534.956017 stepsize 0.0001
# [step   5] neg-log-likelihood -533.016631 stepsize 0.0001
# [step   6] neg-log-likelihood -540.269325 stepsize 0.0001
# [step   7] neg-log-likelihood -554.545476 stepsize 0.0001
# [step   8] neg-log-likelihood -571.111556 stepsize 0.0001
# [step   9] neg-log-likelihood -586.027725 stepsize 0.0001
# [step  10] neg-log-likelihood -601.717398 stepsize 0.0001
# [step  11] neg-log-likelihood -618.110439 stepsize 0.0001
# [step  12] neg-log-likelihood -632.556720 stepsize 0.0001
# [step  13] neg-log-likelihood -646.960222 stepsize 0.0001
# [step  14] neg-log-likelihood -659.668374 stepsize 0.0001
# [step  15] neg-log-likelihood -675.610187 stepsize 0.0001
# [step  16] neg-log-likelihood -694.084568 stepsize 0.0001
# [step  17] neg-log-likelihood -713.884436 stepsize 0.0001
# [step  18] neg-log-likelihood -734.883323 stepsize 0.0001
# [step  19] neg-log-likelihood -749.740625 stepsize 0.0001
# [step  20] neg-log-likelihood -765.544400 stepsize 0.0001
# [step  21] neg-log-likelihood -779.207528 stepsize 0.0001
# [step  22] neg-log-likelihood -792.291421 stepsize 0.0001
# [step  23] neg-log-likelihood -805.364824 stepsize 0.0001
# [step  24] neg-log-likelihood -818.494053 stepsize 0.0001
# [step  25] neg-log-likelihood -831.792464 stepsize 0.0001
# [step  26] neg-log-likelihood -845.403718 stepsize 0.0001
# [step  27] neg-log-likelihood -859.502880 stepsize 0.0001
# [step  28] neg-log-likelihood -875.059986 stepsize 0.0001
# [step  29] neg-log-likelihood -888.910695 stepsize 0.0001
# [step  30] neg-log-likelihood -900.440997 stepsize 0.0001
# [step  31] neg-log-likelihood -913.178980 stepsize 0.0001
# [step  32] neg-log-likelihood -926.852448 stepsize 0.0001
# [step  33] neg-log-likelihood -939.835979 stepsize 0.0001
# [step  34] neg-log-likelihood -951.312957 stepsize 0.0001
# [step  35] neg-log-likelihood -962.510877 stepsize 0.0001
# [step  36] neg-log-likelihood -974.173126 stepsize 0.0001
# [step  37] neg-log-likelihood -982.461381 stepsize 0.0001
# [step  38] neg-log-likelihood -994.305793 stepsize 0.0001
# [step  39] neg-log-likelihood -1003.904374 stepsize 0.0001
# [step  40] neg-log-likelihood -1013.508434 stepsize 0.0001
# [step  41] neg-log-likelihood -1023.096979 stepsize 0.0001
# [step  42] neg-log-likelihood -1032.839490 stepsize 0.0001
# [step  43] neg-log-likelihood -1044.951512 stepsize 0.0001
# [step  44] neg-log-likelihood -1053.209105 stepsize 0.0001
# [step  45] neg-log-likelihood -1063.414390 stepsize 0.0001
# [step  46] neg-log-likelihood -1073.189656 stepsize 0.0001
# [step  47] neg-log-likelihood -1082.983770 stepsize 0.0001
# [step  48] neg-log-likelihood -1089.561834 stepsize 0.0001
# [step  49] neg-log-likelihood -1094.193240 stepsize 0.0001
# [step  50] neg-log-likelihood -1101.607062 stepsize 0.0001
# [step  51] neg-log-likelihood -1109.207440 stepsize 0.0001
# [step  52] neg-log-likelihood -1113.591313 stepsize 0.0001
# [step  53] neg-log-likelihood -1121.606405 stepsize 0.0001
# [step  54] neg-log-likelihood -1128.148351 stepsize 0.0001
# [step  55] neg-log-likelihood -1130.469180 stepsize 0.0001
# [step  56] neg-log-likelihood -1134.749048 stepsize 0.0001
# [step  57] neg-log-likelihood -1142.288720 stepsize 0.0001
# [step  58] neg-log-likelihood -1146.704938 stepsize 0.0001
# [step  59] neg-log-likelihood -1150.297075 stepsize 0.0001
# [step  60] neg-log-likelihood -1156.673233 stepsize 0.0001
# [step  61] neg-log-likelihood -1160.014546 stepsize 0.0001
# [step  62] neg-log-likelihood -1161.951940 stepsize 0.0001
# [step  63] neg-log-likelihood -1168.643956 stepsize 0.0001
# [step  64] neg-log-likelihood -1172.073547 stepsize 0.0001
# [step  65] neg-log-likelihood -1180.417258 stepsize 0.0001
# [step  66] neg-log-likelihood -1180.528848 stepsize 0.0001
# [step  67] neg-log-likelihood -1184.966288 stepsize 0.0001
# [step  68] neg-log-likelihood -1188.146565 stepsize 0.0001
# [step  69] neg-log-likelihood -1192.696344 stepsize 0.0001
# [step  70] neg-log-likelihood -1194.920310 stepsize 0.0001
# [step  71] neg-log-likelihood -1197.204217 stepsize 0.0001
# [step  72] neg-log-likelihood -1200.267439 stepsize 0.0001
# [step  73] neg-log-likelihood -1200.806782 stepsize 0.0001
# [step  74] neg-log-likelihood -1203.046443 stepsize 0.0001
# [step  75] neg-log-likelihood -1206.129609 stepsize 0.0001
# [step  76] neg-log-likelihood -1203.884214 stepsize 0.0001
# [step  77] neg-log-likelihood -1206.989447 stepsize 0.0001
# [step  78] neg-log-likelihood -1213.080586 stepsize 0.0001
# [step  79] neg-log-likelihood -1209.795628 stepsize 0.0001
# [step  80] neg-log-likelihood -1212.376032 stepsize 0.0001
# [step  81] neg-log-likelihood -1212.951585 stepsize 0.0001
# [step  82] neg-log-likelihood -1213.564544 stepsize 0.0001
# [step  83] neg-log-likelihood -1216.299090 stepsize 0.0001
# [step  84] neg-log-likelihood -1216.461683 stepsize 0.0001
# [step  85] neg-log-likelihood -1216.574742 stepsize 0.0001
# [step  86] neg-log-likelihood -1214.979249 stepsize 0.0001
# [step  87] neg-log-likelihood -1216.435691 stepsize 0.0001
# [step  88] neg-log-likelihood -1219.215927 stepsize 0.0001
# [step  89] neg-log-likelihood -1219.562014 stepsize 0.0001
# [step  90] neg-log-likelihood -1220.610529 stepsize 0.0001
# [step  91] neg-log-likelihood -1219.638806 stepsize 0.0001
# [step  92] neg-log-likelihood -1223.163454 stepsize 0.0001
# [step  93] neg-log-likelihood -1229.223162 stepsize 0.0001
# [step  94] neg-log-likelihood -1225.008190 stepsize 0.0001
# [step  95] neg-log-likelihood -1223.890799 stepsize 0.0001
# [step  96] neg-log-likelihood -1226.976285 stepsize 0.0001
# [step  97] neg-log-likelihood -1227.115002 stepsize 0.0001
# [step  98] neg-log-likelihood -1227.865847 stepsize 0.0001
# [step  99] neg-log-likelihood -1229.229834 stepsize 0.0001
# [step 100] neg-log-likelihood -1229.925095 stepsize 0.0001
# [step 101] neg-log-likelihood -1231.862620 stepsize 0.0001
# [step 102] neg-log-likelihood -1230.912155 stepsize 0.0001
# [step 103] neg-log-likelihood -1227.322976 stepsize 0.0001
# [step 104] neg-log-likelihood -1232.434097 stepsize 0.0001
# [step 105] neg-log-likelihood -1231.886556 stepsize 0.0001
# [step 106] neg-log-likelihood -1233.413966 stepsize 0.0001
# [step 107] neg-log-likelihood -1231.788087 stepsize 0.0001
# [step 108] neg-log-likelihood -1235.357635 stepsize 0.0001
# [step 109] neg-log-likelihood -1234.236175 stepsize 0.0001
# [step 110] neg-log-likelihood -1233.702499 stepsize 0.0001
# [step 111] neg-log-likelihood -1235.980035 stepsize 0.0001
# [step 112] neg-log-likelihood -1239.338062 stepsize 0.0001
# [step 113] neg-log-likelihood -1237.142858 stepsize 0.0001
# [step 114] neg-log-likelihood -1237.471785 stepsize 0.0001
# [step 115] neg-log-likelihood -1239.990155 stepsize 0.0001
# [step 116] neg-log-likelihood -1240.167271 stepsize 0.0001
# [step 117] neg-log-likelihood -1238.748134 stepsize 0.0001
# [step 118] neg-log-likelihood -1242.478047 stepsize 0.0001
# [step 119] neg-log-likelihood -1243.734100 stepsize 0.0001
# [step 120] neg-log-likelihood -1242.556160 stepsize 0.0001
# [step 121] neg-log-likelihood -1240.758161 stepsize 0.0001
# [step 122] neg-log-likelihood -1241.511443 stepsize 0.0001
# [step 123] neg-log-likelihood -1244.185758 stepsize 0.0001
# [step 124] neg-log-likelihood -1241.592273 stepsize 0.0001
# [step 125] neg-log-likelihood -1240.408036 stepsize 0.0001
# [step 126] neg-log-likelihood -1241.081380 stepsize 0.0001
# [step 127] neg-log-likelihood -1244.587731 stepsize 0.0001
# [step 128] neg-log-likelihood -1245.241005 stepsize 0.0001
# [step 129] neg-log-likelihood -1244.036240 stepsize 0.0001
# [step 130] neg-log-likelihood -1243.690589 stepsize 0.0001
# [step 131] neg-log-likelihood -1248.681379 stepsize 0.0001
# [step 132] neg-log-likelihood -1251.101677 stepsize 0.0001
# [step 133] neg-log-likelihood -1248.940632 stepsize 0.0001
# [step 134] neg-log-likelihood -1252.838098 stepsize 0.0001
# [step 135] neg-log-likelihood -1253.738109 stepsize 0.0001
# [step 136] neg-log-likelihood -1255.932544 stepsize 0.0001
# [step 137] neg-log-likelihood -1256.976267 stepsize 0.0001
# [step 138] neg-log-likelihood -1261.186182 stepsize 0.0001
# [step 139] neg-log-likelihood -1267.393448 stepsize 0.0001
# [step 140] neg-log-likelihood -1266.784055 stepsize 0.0001
# [step 141] neg-log-likelihood -1270.323569 stepsize 0.0001
# [step 142] neg-log-likelihood -1275.246186 stepsize 0.0001
# [step 143] neg-log-likelihood -1278.137912 stepsize 0.0001
# [step 144] neg-log-likelihood -1278.191464 stepsize 0.0001
# [step 145] neg-log-likelihood -1283.244777 stepsize 0.0001
# [step 146] neg-log-likelihood -1285.088179 stepsize 0.0001
# [step 147] neg-log-likelihood -1290.580281 stepsize 0.0001
# [step 148] neg-log-likelihood -1291.609432 stepsize 0.0001
# [step 149] neg-log-likelihood -1294.545544 stepsize 0.0001
# [step 150] neg-log-likelihood -1298.180579 stepsize 0.0001
# [step 151] neg-log-likelihood -1302.048785 stepsize 0.0001
# [step 152] neg-log-likelihood -1305.601881 stepsize 0.0001
# [step 153] neg-log-likelihood -1305.360974 stepsize 0.0001
# [step 154] neg-log-likelihood -1308.157463 stepsize 0.0001
# [step 155] neg-log-likelihood -1313.566863 stepsize 0.0001
# [step 156] neg-log-likelihood -1318.592611 stepsize 0.0001
# [step 157] neg-log-likelihood -1322.846971 stepsize 0.0001
# [step 158] neg-log-likelihood -1330.552693 stepsize 0.0001
# [step 159] neg-log-likelihood -1326.008102 stepsize 0.0001
# [step 160] neg-log-likelihood -1330.792682 stepsize 0.0001
# [step 161] neg-log-likelihood -1334.294834 stepsize 0.0001
# [step 162] neg-log-likelihood -1332.453879 stepsize 0.0001
# [step 163] neg-log-likelihood -1337.309392 stepsize 0.0001
# [step 164] neg-log-likelihood -1334.874679 stepsize 0.0001
# [step 165] neg-log-likelihood -1335.883299 stepsize 0.0001
# [step 166] neg-log-likelihood -1338.723413 stepsize 0.0001
# [step 167] neg-log-likelihood -1338.631413 stepsize 0.0001
# [step 168] neg-log-likelihood -1339.481389 stepsize 0.0001
# [step 169] neg-log-likelihood -1341.353583 stepsize 0.0001
# [step 170] neg-log-likelihood -1339.429878 stepsize 0.0001
# [step 171] neg-log-likelihood -1342.564107 stepsize 0.0001
# [step 172] neg-log-likelihood -1343.826871 stepsize 0.0001
# [step 173] neg-log-likelihood -1346.433405 stepsize 0.0001
# [step 174] neg-log-likelihood -1347.354192 stepsize 0.0001
# [step 175] neg-log-likelihood -1348.868288 stepsize 0.0001
# [step 176] neg-log-likelihood -1349.517159 stepsize 0.0001
# [step 177] neg-log-likelihood -1349.714382 stepsize 0.0001
# [step 178] neg-log-likelihood -1352.075821 stepsize 0.0001
# [step 179] neg-log-likelihood -1353.883027 stepsize 0.0001
# [step 180] neg-log-likelihood -1351.599693 stepsize 0.0001
# [step 181] neg-log-likelihood -1354.760291 stepsize 0.0001
# [step 182] neg-log-likelihood -1357.343733 stepsize 0.0001
# [step 183] neg-log-likelihood -1360.503675 stepsize 0.0001
# [step 184] neg-log-likelihood -1358.636031 stepsize 0.0001
# [step 185] neg-log-likelihood -1358.509433 stepsize 0.0001
# [step 186] neg-log-likelihood -1359.967930 stepsize 0.0001
# [step 187] neg-log-likelihood -1363.376138 stepsize 0.0001
# [step 188] neg-log-likelihood -1362.761216 stepsize 0.0001
# [step 189] neg-log-likelihood -1362.920817 stepsize 0.0001
# [step 190] neg-log-likelihood -1366.314909 stepsize 0.0001
# [step 191] neg-log-likelihood -1368.412199 stepsize 0.0001
# [step 192] neg-log-likelihood -1367.261579 stepsize 0.0001
# [step 193] neg-log-likelihood -1365.775597 stepsize 0.0001
# [step 194] neg-log-likelihood -1370.180170 stepsize 0.0001
# [step 195] neg-log-likelihood -1369.649798 stepsize 0.0001
# [step 196] neg-log-likelihood -1372.049175 stepsize 0.0001
# [step 197] neg-log-likelihood -1370.805575 stepsize 0.0001
# [step 198] neg-log-likelihood -1371.292692 stepsize 0.0001
# [step 199] neg-log-likelihood -1373.564361 stepsize 0.0001
# [step 200] neg-log-likelihood -1370.666923 stepsize 0.0001
# [step 201] neg-log-likelihood -1371.581033 stepsize 0.0001
# [step 202] neg-log-likelihood -1376.452642 stepsize 0.0001
# [step 203] neg-log-likelihood -1373.843711 stepsize 0.0001
# [step 204] neg-log-likelihood -1378.431911 stepsize 0.0001
# [step 205] neg-log-likelihood -1378.878839 stepsize 0.0001
# [step 206] neg-log-likelihood -1378.528089 stepsize 0.0001
# [step 207] neg-log-likelihood -1383.570506 stepsize 0.0001
# [step 208] neg-log-likelihood -1378.740308 stepsize 0.0001
# [step 209] neg-log-likelihood -1380.857366 stepsize 0.0001
# [step 210] neg-log-likelihood -1382.043386 stepsize 0.0001
# [step 211] neg-log-likelihood -1382.075263 stepsize 0.0001
# [step 212] neg-log-likelihood -1384.819360 stepsize 0.0001
# [step 213] neg-log-likelihood -1384.125637 stepsize 0.0001
# [step 214] neg-log-likelihood -1383.794217 stepsize 0.0001
# [step 215] neg-log-likelihood -1383.508537 stepsize 0.0001
# [step 216] neg-log-likelihood -1386.581649 stepsize 0.0001
# [step 217] neg-log-likelihood -1387.467930 stepsize 0.0001
# [step 218] neg-log-likelihood -1386.614058 stepsize 0.0001
# [step 219] neg-log-likelihood -1389.650665 stepsize 0.0001
# [step 220] neg-log-likelihood -1390.975952 stepsize 0.0001
# [step 221] neg-log-likelihood -1387.662231 stepsize 0.0001
# [step 222] neg-log-likelihood -1390.913326 stepsize 0.0001
# [step 223] neg-log-likelihood -1391.992123 stepsize 0.0001
# [step 224] neg-log-likelihood -1392.629858 stepsize 0.0001
# [step 225] neg-log-likelihood -1392.302113 stepsize 0.0001
# [step 226] neg-log-likelihood -1395.070828 stepsize 0.0001
# [step 227] neg-log-likelihood -1394.199857 stepsize 0.0001
# [step 228] neg-log-likelihood -1395.821388 stepsize 0.0001
# [step 229] neg-log-likelihood -1397.187710 stepsize 0.0001
# [step 230] neg-log-likelihood -1396.957686 stepsize 0.0001
# [step 231] neg-log-likelihood -1398.680996 stepsize 0.0001
# [step 232] neg-log-likelihood -1396.486438 stepsize 0.0001
# [step 233] neg-log-likelihood -1398.505636 stepsize 0.0001
# [step 234] neg-log-likelihood -1399.298791 stepsize 0.0001
# [step 235] neg-log-likelihood -1401.245553 stepsize 0.0001
# [step 236] neg-log-likelihood -1401.787437 stepsize 0.0001
# [step 237] neg-log-likelihood -1402.386611 stepsize 0.0001
# [step 238] neg-log-likelihood -1406.456177 stepsize 0.0001
# [step 239] neg-log-likelihood -1404.961175 stepsize 0.0001
# [step 240] neg-log-likelihood -1408.513123 stepsize 0.0001
# [step 241] neg-log-likelihood -1405.122958 stepsize 0.0001
# [step 242] neg-log-likelihood -1405.664357 stepsize 0.0001
# [step 243] neg-log-likelihood -1409.247120 stepsize 0.0001
# [step 244] neg-log-likelihood -1413.302639 stepsize 0.0001
# [step 245] neg-log-likelihood -1410.275413 stepsize 0.0001
# [step 246] neg-log-likelihood -1410.085649 stepsize 0.0001
# [step 247] neg-log-likelihood -1412.848295 stepsize 0.0001
# [step 248] neg-log-likelihood -1410.673926 stepsize 0.0001
# [step 249] neg-log-likelihood -1413.461163 stepsize 0.0001
# [step 250] neg-log-likelihood -1415.230354 stepsize 0.0001
# [step 251] neg-log-likelihood -1413.241086 stepsize 0.0001
# [step 252] neg-log-likelihood -1414.422397 stepsize 0.0001
# [step 253] neg-log-likelihood -1417.043788 stepsize 0.0001
# [step 254] neg-log-likelihood -1416.013153 stepsize 0.0001
# [step 255] neg-log-likelihood -1415.633614 stepsize 0.0001
# [step 256] neg-log-likelihood -1416.447457 stepsize 0.0001
# [step 257] neg-log-likelihood -1416.262250 stepsize 0.0001
# [step 258] neg-log-likelihood -1421.499874 stepsize 0.0001
# [step 259] neg-log-likelihood -1415.772649 stepsize 0.0001
# [step 260] neg-log-likelihood -1419.519926 stepsize 0.0001
# [step 261] neg-log-likelihood -1419.319744 stepsize 0.0001
# [step 262] neg-log-likelihood -1419.795333 stepsize 0.0001
# [step 263] neg-log-likelihood -1425.336354 stepsize 0.0001
# [step 264] neg-log-likelihood -1419.344639 stepsize 0.0001
# [step 265] neg-log-likelihood -1420.163840 stepsize 0.0001
# [step 266] neg-log-likelihood -1422.456443 stepsize 0.0001
# [step 267] neg-log-likelihood -1426.714032 stepsize 0.0001
# [step 268] neg-log-likelihood -1419.874286 stepsize 0.0001
# [step 269] neg-log-likelihood -1420.565123 stepsize 0.0001
# [step 270] neg-log-likelihood -1421.364690 stepsize 0.0001
# [step 271] neg-log-likelihood -1424.422417 stepsize 0.0001
# [step 272] neg-log-likelihood -1422.785134 stepsize 0.0001
# [step 273] neg-log-likelihood -1422.931984 stepsize 0.0001
# [step 274] neg-log-likelihood -1422.729834 stepsize 0.0001
# [step 275] neg-log-likelihood -1425.682783 stepsize 0.0001
# [step 276] neg-log-likelihood -1425.364294 stepsize 0.0001
# [step 277] neg-log-likelihood -1424.218954 stepsize 0.0001
# [step 278] neg-log-likelihood -1429.100824 stepsize 0.0001
# [step 279] neg-log-likelihood -1425.724069 stepsize 0.0001
# [step 280] neg-log-likelihood -1426.238575 stepsize 0.0001
# [step 281] neg-log-likelihood -1426.012677 stepsize 0.0001
# [step 282] neg-log-likelihood -1427.311205 stepsize 0.0001
# [step 283] neg-log-likelihood -1427.539302 stepsize 0.0001
# [step 284] neg-log-likelihood -1428.588837 stepsize 0.0001
# [step 285] neg-log-likelihood -1427.694030 stepsize 0.0001
# [step 286] neg-log-likelihood -1430.200075 stepsize 0.0001
# [step 287] neg-log-likelihood -1429.641641 stepsize 0.0001
# [step 288] neg-log-likelihood -1431.714248 stepsize 0.0001
# [step 289] neg-log-likelihood -1429.702027 stepsize 0.0001
# [step 290] neg-log-likelihood -1432.210800 stepsize 0.0001
# [step 291] neg-log-likelihood -1432.926315 stepsize 0.0001
# [step 292] neg-log-likelihood -1435.824318 stepsize 0.0001
# [step 293] neg-log-likelihood -1433.531185 stepsize 0.0001
# [step 294] neg-log-likelihood -1431.881584 stepsize 0.0001
# [step 295] neg-log-likelihood -1432.323608 stepsize 0.0001
# [step 296] neg-log-likelihood -1431.651703 stepsize 0.0001
# [step 297] neg-log-likelihood -1433.461390 stepsize 0.0001
# [step 298] neg-log-likelihood -1432.839849 stepsize 0.0001
# [step 299] neg-log-likelihood -1434.854643 stepsize 0.0001
# [step 300] neg-log-likelihood -1435.363726 stepsize 0.0001
# [step 301] neg-log-likelihood -1435.534836 stepsize 0.0001
# [step 302] neg-log-likelihood -1439.365668 stepsize 0.0001
# [step 303] neg-log-likelihood -1434.746844 stepsize 0.0001
# [step 304] neg-log-likelihood -1438.848191 stepsize 0.0001
# [step 305] neg-log-likelihood -1439.020308 stepsize 0.0001
# [step 306] neg-log-likelihood -1437.593161 stepsize 0.0001
# [step 307] neg-log-likelihood -1436.139591 stepsize 0.0001
# [step 308] neg-log-likelihood -1440.355183 stepsize 0.0001
# [step 309] neg-log-likelihood -1441.403423 stepsize 0.0001
# [step 310] neg-log-likelihood -1434.955956 stepsize 0.0001
# [step 311] neg-log-likelihood -1438.716041 stepsize 0.0001
# [step 312] neg-log-likelihood -1438.562631 stepsize 0.0001
# [step 313] neg-log-likelihood -1438.103738 stepsize 0.0001
# [step 314] neg-log-likelihood -1442.499786 stepsize 0.0001
# [step 315] neg-log-likelihood -1439.416668 stepsize 0.0001
# [step 316] neg-log-likelihood -1440.512919 stepsize 0.0001
# [step 317] neg-log-likelihood -1439.886749 stepsize 0.0001
# [step 318] neg-log-likelihood -1441.817742 stepsize 0.0001
# [step 319] neg-log-likelihood -1437.272381 stepsize 0.0001
# [step 320] neg-log-likelihood -1437.664049 stepsize 0.0001
# [step 321] neg-log-likelihood -1441.196916 stepsize 0.0001
# [step 322] neg-log-likelihood -1441.645275 stepsize 0.0001
# [step 323] neg-log-likelihood -1441.918835 stepsize 0.0001
# [step 324] neg-log-likelihood -1443.310454 stepsize 0.0001
# [step 325] neg-log-likelihood -1442.331530 stepsize 0.0001
# [step 326] neg-log-likelihood -1443.710644 stepsize 0.0001
# [step 327] neg-log-likelihood -1445.707839 stepsize 0.0001
# [step 328] neg-log-likelihood -1443.670197 stepsize 0.0001
# [step 329] neg-log-likelihood -1446.729806 stepsize 0.0001
# [step 330] neg-log-likelihood -1444.691629 stepsize 0.0001
# [step 331] neg-log-likelihood -1444.392919 stepsize 0.0001
# [step 332] neg-log-likelihood -1446.056611 stepsize 0.0001
# [step 333] neg-log-likelihood -1445.996665 stepsize 0.0001
# [step 334] neg-log-likelihood -1444.859803 stepsize 0.0001
# [step 335] neg-log-likelihood -1447.107877 stepsize 0.0001
# [step 336] neg-log-likelihood -1448.049696 stepsize 0.0001
# [step 337] neg-log-likelihood -1448.869858 stepsize 0.0001
# [step 338] neg-log-likelihood -1448.602956 stepsize 0.0001
# [step 339] neg-log-likelihood -1449.377977 stepsize 0.0001
# [step 340] neg-log-likelihood -1450.295811 stepsize 0.0001
# [step 341] neg-log-likelihood -1446.482413 stepsize 0.0001
# [step 342] neg-log-likelihood -1447.671912 stepsize 0.0001
# [step 343] neg-log-likelihood -1450.191589 stepsize 0.0001
# [step 344] neg-log-likelihood -1452.924510 stepsize 0.0001
# [step 345] neg-log-likelihood -1448.801446 stepsize 0.0001
# [step 346] neg-log-likelihood -1449.870424 stepsize 0.0001
# [step 347] neg-log-likelihood -1448.343348 stepsize 0.0001
# [step 348] neg-log-likelihood -1448.631539 stepsize 0.0001
# [step 349] neg-log-likelihood -1447.059714 stepsize 0.0001
# [step 350] neg-log-likelihood -1451.201716 stepsize 0.0001
# [step 351] neg-log-likelihood -1451.775796 stepsize 0.0001
# [step 352] neg-log-likelihood -1450.446152 stepsize 0.0001
# [step 353] neg-log-likelihood -1450.442240 stepsize 0.0001
# [step 354] neg-log-likelihood -1452.197694 stepsize 0.0001
# [step 355] neg-log-likelihood -1451.653795 stepsize 0.0001
# [step 356] neg-log-likelihood -1454.473006 stepsize 0.0001
# [step 357] neg-log-likelihood -1450.189830 stepsize 0.0001
# [step 358] neg-log-likelihood -1450.356821 stepsize 0.0001
# [step 359] neg-log-likelihood -1450.846091 stepsize 0.0001
# [step 360] neg-log-likelihood -1452.594998 stepsize 0.0001
# [step 361] neg-log-likelihood -1452.355112 stepsize 0.0001
# [step 362] neg-log-likelihood -1452.484998 stepsize 0.0001
# [step 363] neg-log-likelihood -1454.824928 stepsize 0.0001
# [step 364] neg-log-likelihood -1450.153550 stepsize 0.0001
# [step 365] neg-log-likelihood -1452.591625 stepsize 0.0001
# [step 366] neg-log-likelihood -1451.207201 stepsize 0.0001
# [step 367] neg-log-likelihood -1452.136475 stepsize 0.0001
# [step 368] neg-log-likelihood -1452.085134 stepsize 0.0001
# [step 369] neg-log-likelihood -1450.821097 stepsize 0.0001
# [step 370] neg-log-likelihood -1453.842401 stepsize 0.0001
# [step 371] neg-log-likelihood -1451.425350 stepsize 0.0001
# [step 372] neg-log-likelihood -1452.383704 stepsize 0.0001
# [step 373] neg-log-likelihood -1451.576548 stepsize 0.0001
# [step 374] neg-log-likelihood -1454.000887 stepsize 0.0001
# [step 375] neg-log-likelihood -1454.293399 stepsize 0.0001
# [step 376] neg-log-likelihood -1455.049545 stepsize 0.0001
# [step 377] neg-log-likelihood -1459.281118 stepsize 0.0001
# [step 378] neg-log-likelihood -1457.505892 stepsize 0.0001
# [step 379] neg-log-likelihood -1455.347448 stepsize 0.0001
# [step 380] neg-log-likelihood -1456.548301 stepsize 0.0001
# [step 381] neg-log-likelihood -1454.859524 stepsize 0.0001
# [step 382] neg-log-likelihood -1455.365039 stepsize 0.0001
# [step 383] neg-log-likelihood -1455.413040 stepsize 0.0001
# [step 384] neg-log-likelihood -1454.549142 stepsize 0.0001
# [step 385] neg-log-likelihood -1455.599218 stepsize 0.0001
# [step 386] neg-log-likelihood -1457.628723 stepsize 0.0001
# [step 387] neg-log-likelihood -1455.982912 stepsize 0.0001
# [step 388] neg-log-likelihood -1456.557582 stepsize 0.0001
# [step 389] neg-log-likelihood -1453.933398 stepsize 0.0001
# [step 390] neg-log-likelihood -1454.980215 stepsize 0.0001
# [step 391] neg-log-likelihood -1455.351532 stepsize 0.0001
# [step 392] neg-log-likelihood -1457.792804 stepsize 0.0001
# [step 393] neg-log-likelihood -1453.874232 stepsize 0.0001
# [step 394] neg-log-likelihood -1454.639339 stepsize 0.0001
# [step 395] neg-log-likelihood -1455.645755 stepsize 0.0001
# [step 396] neg-log-likelihood -1456.311218 stepsize 0.0001
# [step 397] neg-log-likelihood -1459.151675 stepsize 0.0001
# [step 398] neg-log-likelihood -1457.688057 stepsize 0.0001
# [step 399] neg-log-likelihood -1459.418564 stepsize 0.0001
# [step 400] neg-log-likelihood -1453.697163 stepsize 0.0001
# [step 401] neg-log-likelihood -1454.930984 stepsize 0.0001
# [step 402] neg-log-likelihood -1456.915110 stepsize 0.0001
# [step 403] neg-log-likelihood -1460.455950 stepsize 0.0001
# [step 404] neg-log-likelihood -1455.036669 stepsize 0.0001
# [step 405] neg-log-likelihood -1457.667681 stepsize 0.0001
# [step 406] neg-log-likelihood -1457.118523 stepsize 0.0001
# [step 407] neg-log-likelihood -1455.470069 stepsize 0.0001
# [step 408] neg-log-likelihood -1454.808443 stepsize 0.0001
# [step 409] neg-log-likelihood -1452.622263 stepsize 0.0001
# [step 410] neg-log-likelihood -1454.871765 stepsize 0.0001
# [step 411] neg-log-likelihood -1453.918573 stepsize 0.0001
# [step 412] neg-log-likelihood -1456.578386 stepsize 0.0001
# [step 413] neg-log-likelihood -1452.569390 stepsize 0.0001
# [step 414] neg-log-likelihood -1456.005413 stepsize 0.0001
# [step 415] neg-log-likelihood -1453.392976 stepsize 0.0001
# [step 416] neg-log-likelihood -1452.624441 stepsize 0.0001
# [step 417] neg-log-likelihood -1454.902207 stepsize 0.0001
# [step 418] neg-log-likelihood -1455.202698 stepsize 0.0001
# [step 419] neg-log-likelihood -1454.666445 stepsize 0.0001
# [step 420] neg-log-likelihood -1454.928800 stepsize 0.0001
# [step 421] neg-log-likelihood -1455.705860 stepsize 0.0001
# [step 422] neg-log-likelihood -1455.435338 stepsize 0.0001
# [step 423] neg-log-likelihood -1456.398474 stepsize 0.0001
# [step 424] neg-log-likelihood -1455.154484 stepsize 0.0001
# [step 425] neg-log-likelihood -1455.772385 stepsize 0.0001
# [step 426] neg-log-likelihood -1453.779209 stepsize 0.0001
# [step 427] neg-log-likelihood -1453.926210 stepsize 0.0001
# [step 428] neg-log-likelihood -1452.423732 stepsize 0.0001
# [step 429] neg-log-likelihood -1454.103860 stepsize 0.0001
# [step 430] neg-log-likelihood -1452.279252 stepsize 0.0001
# [step 431] neg-log-likelihood -1451.101786 stepsize 0.0001
# [step 432] neg-log-likelihood -1458.003404 stepsize 0.0001
# [step 433] neg-log-likelihood -1452.543480 stepsize 0.0001
# [step 434] neg-log-likelihood -1450.823450 stepsize 0.0001
# [step 435] neg-log-likelihood -1451.649861 stepsize 0.0001
# [step 436] neg-log-likelihood -1451.409301 stepsize 0.0001
# [step 437] neg-log-likelihood -1453.643408 stepsize 0.0001
# [step 438] neg-log-likelihood -1453.847354 stepsize 0.0001
# [step 439] neg-log-likelihood -1448.226600 stepsize 0.0001
# [step 440] neg-log-likelihood -1450.232936 stepsize 0.0001
# [step 441] neg-log-likelihood -1447.778875 stepsize 0.0001
# [step 442] neg-log-likelihood -1447.621011 stepsize 0.0001
# [step 443] neg-log-likelihood -1445.290349 stepsize 0.0001
# [step 444] neg-log-likelihood -1446.027062 stepsize 0.0001
# [step 445] neg-log-likelihood -1448.821522 stepsize 0.0001
# [step 446] neg-log-likelihood -1448.421337 stepsize 0.0001
# [step 447] neg-log-likelihood -1446.760309 stepsize 0.0001
# [step 448] neg-log-likelihood -1446.262458 stepsize 0.0001
# [step 449] neg-log-likelihood -1445.843704 stepsize 0.0001
# [step 450] neg-log-likelihood -1443.823733 stepsize 0.0001
# [step 451] neg-log-likelihood -1443.037613 stepsize 0.0001
# [step 452] neg-log-likelihood -1443.468802 stepsize 0.0001
# [step 453] neg-log-likelihood -1446.003089 stepsize 0.0001
# [step 454] neg-log-likelihood -1442.904617 stepsize 0.0001
# [step 455] neg-log-likelihood -1443.541076 stepsize 0.0001
# [step 456] neg-log-likelihood -1444.591663 stepsize 0.0001
# [step 457] neg-log-likelihood -1446.996379 stepsize 0.0001
# [step 458] neg-log-likelihood -1441.801429 stepsize 0.0001
# [step 459] neg-log-likelihood -1445.969499 stepsize 0.0001
# [step 460] neg-log-likelihood -1445.395538 stepsize 0.0001
# [step 461] neg-log-likelihood -1442.708115 stepsize 0.0001
# [step 462] neg-log-likelihood -1437.391205 stepsize 0.0001
# [step 463] neg-log-likelihood -1442.743186 stepsize 0.0001
# [step 464] neg-log-likelihood -1444.033331 stepsize 0.0001
# [step 465] neg-log-likelihood -1439.260131 stepsize 0.0001
# [step 466] neg-log-likelihood -1438.578029 stepsize 0.0001
# [step 467] neg-log-likelihood -1435.863975 stepsize 0.0001
# [step 468] neg-log-likelihood -1435.815342 stepsize 0.0001
# [step 469] neg-log-likelihood -1437.453436 stepsize 0.0001
# [step 470] neg-log-likelihood -1435.090937 stepsize 0.0001
# [step 471] neg-log-likelihood -1430.597546 stepsize 0.0001
# [step 472] neg-log-likelihood -1434.975976 stepsize 0.0001
# [step 473] neg-log-likelihood -1436.742546 stepsize 0.0001
# [step 474] neg-log-likelihood -1432.787591 stepsize 0.0001
# [step 475] neg-log-likelihood -1431.881013 stepsize 0.0001
# [step 476] neg-log-likelihood -1432.198860 stepsize 0.0001
# [step 477] neg-log-likelihood -1430.653453 stepsize 0.0001
# [step 478] neg-log-likelihood -1431.308203 stepsize 0.0001
# [step 479] neg-log-likelihood -1427.913772 stepsize 0.0001
# [step 480] neg-log-likelihood -1426.683301 stepsize 0.0001
# [step 481] neg-log-likelihood -1424.356466 stepsize 0.0001
# [step 482] neg-log-likelihood -1423.966615 stepsize 0.0001
# [step 483] neg-log-likelihood -1423.612492 stepsize 0.0001
# [step 484] neg-log-likelihood -1425.364714 stepsize 0.0001
# [step 485] neg-log-likelihood -1422.724135 stepsize 0.0001
# [step 486] neg-log-likelihood -1421.438893 stepsize 0.0001
# [step 487] neg-log-likelihood -1420.867058 stepsize 0.0001
# [step 488] neg-log-likelihood -1419.446362 stepsize 0.0001
# [step 489] neg-log-likelihood -1417.611891 stepsize 0.0001
# [step 490] neg-log-likelihood -1417.488867 stepsize 0.0001
# [step 491] neg-log-likelihood -1418.461641 stepsize 0.0001
# [step 492] neg-log-likelihood -1416.736967 stepsize 0.0001
# [step 493] neg-log-likelihood -1413.554485 stepsize 0.0001
# [step 494] neg-log-likelihood -1412.709296 stepsize 0.0001
# [step 495] neg-log-likelihood -1411.858218 stepsize 0.0001
# [step 496] neg-log-likelihood -1411.005364 stepsize 0.0001
# [step 497] neg-log-likelihood -1408.827817 stepsize 0.0001
# [step 498] neg-log-likelihood -1404.622211 stepsize 0.0001
# [step 499] neg-log-likelihood -1402.749340 stepsize 0.0001
# [step 500] neg-log-likelihood -1402.809830 stepsize 0.0001
# [step 501] neg-log-likelihood -1403.855892 stepsize 0.0001
# [step 502] neg-log-likelihood -1401.736777 stepsize 0.0001
# [step 503] neg-log-likelihood -1399.862097 stepsize 0.0001
# [step 504] neg-log-likelihood -1397.788956 stepsize 0.0001
# [step 505] neg-log-likelihood -1398.008060 stepsize 0.0001
# [step 506] neg-log-likelihood -1396.620486 stepsize 0.0001
# [step 507] neg-log-likelihood -1395.131128 stepsize 0.0001
# [step 508] neg-log-likelihood -1392.034647 stepsize 0.0001
# [step 509] neg-log-likelihood -1391.370268 stepsize 0.0001
# [step 510] neg-log-likelihood -1386.767133 stepsize 0.0001
# [step 511] neg-log-likelihood -1386.290033 stepsize 0.0001
# [step 512] neg-log-likelihood -1387.691777 stepsize 0.0001
# [step 513] neg-log-likelihood -1380.319530 stepsize 0.0001
# [step 514] neg-log-likelihood -1380.001418 stepsize 0.0001
# [step 515] neg-log-likelihood -1376.103636 stepsize 0.0001
# [step 516] neg-log-likelihood -1372.868167 stepsize 0.0001
# [step 517] neg-log-likelihood -1373.067279 stepsize 0.0001
# [step 518] neg-log-likelihood -1368.680546 stepsize 0.0001
# [step 519] neg-log-likelihood -1367.223238 stepsize 0.0001
# [step 520] neg-log-likelihood -1364.953641 stepsize 0.0001
# [step 521] neg-log-likelihood -1359.950265 stepsize 0.0001
# [step 522] neg-log-likelihood -1359.280245 stepsize 0.0001
# [step 523] neg-log-likelihood -1354.668525 stepsize 0.0001
# [step 524] neg-log-likelihood -1356.015904 stepsize 0.0001
# [step 525] neg-log-likelihood -1347.647905 stepsize 0.0001
# [step 526] neg-log-likelihood -1348.337815 stepsize 0.0001
# [step 527] neg-log-likelihood -1338.264372 stepsize 0.0001
# [step 528] neg-log-likelihood -1337.351789 stepsize 0.0001
# [step 529] neg-log-likelihood -1333.199778 stepsize 0.0001
# [step 530] neg-log-likelihood -1324.963601 stepsize 0.0001
# [step 531] neg-log-likelihood -1321.063468 stepsize 0.0001
# [step 532] neg-log-likelihood -1314.427741 stepsize 0.0001
# [step 533] neg-log-likelihood -1309.500002 stepsize 0.0001
# [step 534] neg-log-likelihood -1303.726937 stepsize 0.0001
# [step 535] neg-log-likelihood -1293.971728 stepsize 0.0001
# [step 536] neg-log-likelihood -1282.862910 stepsize 0.0001
# [step 537] neg-log-likelihood -1268.137552 stepsize 0.0001
# [step 538] neg-log-likelihood -1119.018187 stepsize 0.0001
# [step 539] neg-log-likelihood -1141.765717 stepsize 0.0001
# [step 540] neg-log-likelihood -1165.541458 stepsize 0.0001
# [step 541] neg-log-likelihood -1241.562017 stepsize 0.0001
# [step 542] neg-log-likelihood -1227.728678 stepsize 0.0001
# [step 543] neg-log-likelihood -1217.815339 stepsize 0.0001
# [step 544] neg-log-likelihood -1213.334901 stepsize 0.0001
# [step 545] neg-log-likelihood -1212.903343 stepsize 0.0001
# [step 546] neg-log-likelihood -1212.236928 stepsize 0.0001
# [step 547] neg-log-likelihood -1207.427538 stepsize 0.0001
# [step 548] neg-log-likelihood -1208.319316 stepsize 0.0001
# [step 549] neg-log-likelihood -1205.130521 stepsize 0.0001
# [step 550] neg-log-likelihood -1203.555452 stepsize 0.0001
# [step 551] neg-log-likelihood -1201.537284 stepsize 0.0001
# [step 552] neg-log-likelihood -1201.820723 stepsize 0.0001
# [step 553] neg-log-likelihood -1202.870271 stepsize 0.0001
# [step 554] neg-log-likelihood -1199.538033 stepsize 0.0001
# [step 555] neg-log-likelihood -1201.846567 stepsize 0.0001
# [step 556] neg-log-likelihood -1198.448420 stepsize 0.0001
# [step 557] neg-log-likelihood -1199.309849 stepsize 0.0001
# [step 558] neg-log-likelihood -1197.704913 stepsize 0.0001
# [step 559] neg-log-likelihood -1199.253237 stepsize 0.0001
# [step 560] neg-log-likelihood -1195.858798 stepsize 0.0001
# [step 561] neg-log-likelihood -1198.203821 stepsize 0.0001
# [step 562] neg-log-likelihood -1196.792531 stepsize 0.0001
# [step 563] neg-log-likelihood -1196.635513 stepsize 0.0001
# [step 564] neg-log-likelihood -1195.565645 stepsize 0.0001
# [step 565] neg-log-likelihood -1197.742072 stepsize 0.0001
# [step 566] neg-log-likelihood -1196.273197 stepsize 0.0001
# [step 567] neg-log-likelihood -1197.591228 stepsize 0.0001
# [step 568] neg-log-likelihood -1197.999959 stepsize 0.0001
# [step 569] neg-log-likelihood -1195.000087 stepsize 0.0001
# [step 570] neg-log-likelihood -1193.948856 stepsize 0.0001
# [step 571] neg-log-likelihood -1195.390112 stepsize 0.0001
# [step 572] neg-log-likelihood -1195.589163 stepsize 0.0001
# [step 573] neg-log-likelihood -1196.017670 stepsize 0.0001
# [step 574] neg-log-likelihood -1195.584567 stepsize 0.0001
# [step 575] neg-log-likelihood -1197.493519 stepsize 0.0001
# [step 576] neg-log-likelihood -1195.876131 stepsize 0.0001
# [step 577] neg-log-likelihood -1197.588825 stepsize 0.0001
# [step 578] neg-log-likelihood -1195.612526 stepsize 0.0001
# [step 579] neg-log-likelihood -1195.121178 stepsize 0.0001
# [step 580] neg-log-likelihood -1195.317803 stepsize 0.0001
# [step 581] neg-log-likelihood -1197.853190 stepsize 0.0001
# [step 582] neg-log-likelihood -1197.847985 stepsize 0.0001
# [step 583] neg-log-likelihood -1196.692946 stepsize 0.0001
# [step 584] neg-log-likelihood -1195.998775 stepsize 0.0001
# [step 585] neg-log-likelihood -1196.070319 stepsize 0.0001
# [step 586] neg-log-likelihood -1196.490692 stepsize 0.0001
# [step 587] neg-log-likelihood -1196.247666 stepsize 0.0001
# [step 588] neg-log-likelihood -1198.516158 stepsize 0.0001
# [step 589] neg-log-likelihood -1195.824196 stepsize 0.0001
# [step 590] neg-log-likelihood -1197.330370 stepsize 0.0001
# [step 591] neg-log-likelihood -1199.322006 stepsize 0.0001
# [step 592] neg-log-likelihood -1197.462662 stepsize 0.0001
# [step 593] neg-log-likelihood -1197.669852 stepsize 0.0001
# [step 594] neg-log-likelihood -1195.638820 stepsize 0.0001
# [step 595] neg-log-likelihood -1203.459396 stepsize 0.0001
# [step 596] neg-log-likelihood -1198.251888 stepsize 0.0001
# [step 597] neg-log-likelihood -1198.038844 stepsize 0.0001
# [step 598] neg-log-likelihood -1195.881944 stepsize 0.0001
# [step 599] neg-log-likelihood -1200.005023 stepsize 0.0001
# kernel initialization ...
# negative log-likelihood compute
# [step   0] neg-log-likelihood -550.491901 stepsize 0.0001
# The gradient of L w.r.t. U not been computed. Just compute it anyway.
# The gradient of L w.r.t K not been computed. Just compute it anyway.
# The gradient of K w.r.t. U not been computed. Just compute it anyway
# [step   1] neg-log-likelihood -561.221863 stepsize 0.0001
# [step   2] neg-log-likelihood -557.859178 stepsize 0.0001
# [step   3] neg-log-likelihood -545.345233 stepsize 0.0001
# [step   4] neg-log-likelihood -535.001129 stepsize 0.0001
# [step   5] neg-log-likelihood -532.696277 stepsize 0.0001
# [step   6] neg-log-likelihood -539.114530 stepsize 0.0001
# [step   7] neg-log-likelihood -552.230909 stepsize 0.0001
# [step   8] neg-log-likelihood -568.484578 stepsize 0.0001
# [step   9] neg-log-likelihood -582.646228 stepsize 0.0001
# [step  10] neg-log-likelihood -597.342091 stepsize 0.0001
# [step  11] neg-log-likelihood -613.333961 stepsize 0.0001
# [step  12] neg-log-likelihood -626.791492 stepsize 0.0001
# [step  13] neg-log-likelihood -642.667617 stepsize 0.0001
# [step  14] neg-log-likelihood -653.732418 stepsize 0.0001
# [step  15] neg-log-likelihood -667.093851 stepsize 0.0001
# [step  16] neg-log-likelihood -682.966760 stepsize 0.0001
# [step  17] neg-log-likelihood -700.621772 stepsize 0.0001
# [step  18] neg-log-likelihood -719.037819 stepsize 0.0001
# [step  19] neg-log-likelihood -736.973147 stepsize 0.0001
# [step  20] neg-log-likelihood -750.574792 stepsize 0.0001
# [step  21] neg-log-likelihood -764.791126 stepsize 0.0001
# [step  22] neg-log-likelihood -777.592113 stepsize 0.0001
# [step  23] neg-log-likelihood -789.150967 stepsize 0.0001
# [step  24] neg-log-likelihood -800.542403 stepsize 0.0001
# [step  25] neg-log-likelihood -811.932921 stepsize 0.0001
# [step  26] neg-log-likelihood -823.422434 stepsize 0.0001
# [step  27] neg-log-likelihood -835.050581 stepsize 0.0001
# [step  28] neg-log-likelihood -846.899766 stepsize 0.0001
# [step  29] neg-log-likelihood -859.018950 stepsize 0.0001
# [step  30] neg-log-likelihood -871.522370 stepsize 0.0001
# [step  31] neg-log-likelihood -884.690577 stepsize 0.0001
# [step  32] neg-log-likelihood -899.188874 stepsize 0.0001
# [step  33] neg-log-likelihood -909.340941 stepsize 0.0001
# [step  34] neg-log-likelihood -920.072795 stepsize 0.0001
# [step  35] neg-log-likelihood -931.509921 stepsize 0.0001
# [step  36] neg-log-likelihood -943.544124 stepsize 0.0001
# [step  37] neg-log-likelihood -952.774667 stepsize 0.0001
# [step  38] neg-log-likelihood -962.357366 stepsize 0.0001
# [step  39] neg-log-likelihood -971.850805 stepsize 0.0001
# [step  40] neg-log-likelihood -980.240363 stepsize 0.0001
# [step  41] neg-log-likelihood -988.760847 stepsize 0.0001
# [step  42] neg-log-likelihood -996.789570 stepsize 0.0001
# [step  43] neg-log-likelihood -1005.960574 stepsize 0.0001
# [step  44] neg-log-likelihood -1013.407598 stepsize 0.0001
# [step  45] neg-log-likelihood -1022.038845 stepsize 0.0001
# [step  46] neg-log-likelihood -1033.600627 stepsize 0.0001
# [step  47] neg-log-likelihood -1040.474686 stepsize 0.0001
# [step  48] neg-log-likelihood -1047.664551 stepsize 0.0001
# [step  49] neg-log-likelihood -1059.176971 stepsize 0.0001
# [step  50] neg-log-likelihood -1065.014671 stepsize 0.0001
# [step  51] neg-log-likelihood -1070.639356 stepsize 0.0001
# [step  52] neg-log-likelihood -1078.290777 stepsize 0.0001
# [step  53] neg-log-likelihood -1086.444344 stepsize 0.0001
# [step  54] neg-log-likelihood -1091.718050 stepsize 0.0001
# [step  55] neg-log-likelihood -1096.303659 stepsize 0.0001
# [step  56] neg-log-likelihood -1104.367792 stepsize 0.0001
# [step  57] neg-log-likelihood -1109.927124 stepsize 0.0001
# [step  58] neg-log-likelihood -1113.979856 stepsize 0.0001
# [step  59] neg-log-likelihood -1119.380139 stepsize 0.0001
# [step  60] neg-log-likelihood -1125.681961 stepsize 0.0001
# [step  61] neg-log-likelihood -1130.609077 stepsize 0.0001
# [step  62] neg-log-likelihood -1132.945326 stepsize 0.0001
# [step  63] neg-log-likelihood -1139.000421 stepsize 0.0001
# [step  64] neg-log-likelihood -1141.830327 stepsize 0.0001
# [step  65] neg-log-likelihood -1144.859123 stepsize 0.0001
# [step  66] neg-log-likelihood -1150.119197 stepsize 0.0001
# [step  67] neg-log-likelihood -1156.558399 stepsize 0.0001
# [step  68] neg-log-likelihood -1156.256979 stepsize 0.0001
# [step  69] neg-log-likelihood -1161.867665 stepsize 0.0001
# [step  70] neg-log-likelihood -1164.684834 stepsize 0.0001
# [step  71] neg-log-likelihood -1166.948700 stepsize 0.0001
# [step  72] neg-log-likelihood -1172.463132 stepsize 0.0001
# [step  73] neg-log-likelihood -1175.539893 stepsize 0.0001
# [step  74] neg-log-likelihood -1178.980360 stepsize 0.0001
# [step  75] neg-log-likelihood -1182.158709 stepsize 0.0001
# [step  76] neg-log-likelihood -1188.033815 stepsize 0.0001
# [step  77] neg-log-likelihood -1190.821616 stepsize 0.0001
# [step  78] neg-log-likelihood -1192.515793 stepsize 0.0001
# [step  79] neg-log-likelihood -1194.865578 stepsize 0.0001
# [step  80] neg-log-likelihood -1198.736775 stepsize 0.0001
# [step  81] neg-log-likelihood -1201.328332 stepsize 0.0001
# [step  82] neg-log-likelihood -1203.160559 stepsize 0.0001
# [step  83] neg-log-likelihood -1205.894261 stepsize 0.0001
# [step  84] neg-log-likelihood -1208.345848 stepsize 0.0001
# [step  85] neg-log-likelihood -1207.174909 stepsize 0.0001
# [step  86] neg-log-likelihood -1210.671940 stepsize 0.0001
# [step  87] neg-log-likelihood -1213.137802 stepsize 0.0001
# [step  88] neg-log-likelihood -1213.258464 stepsize 0.0001
# [step  89] neg-log-likelihood -1220.890080 stepsize 0.0001
# [step  90] neg-log-likelihood -1215.466771 stepsize 0.0001
# [step  91] neg-log-likelihood -1216.466404 stepsize 0.0001
# [step  92] neg-log-likelihood -1216.341686 stepsize 0.0001
# [step  93] neg-log-likelihood -1217.108436 stepsize 0.0001
# [step  94] neg-log-likelihood -1218.920963 stepsize 0.0001
# [step  95] neg-log-likelihood -1219.679801 stepsize 0.0001
# [step  96] neg-log-likelihood -1222.377843 stepsize 0.0001
# [step  97] neg-log-likelihood -1223.016819 stepsize 0.0001
# [step  98] neg-log-likelihood -1223.163824 stepsize 0.0001
# [step  99] neg-log-likelihood -1224.682725 stepsize 0.0001
# [step 100] neg-log-likelihood -1223.390171 stepsize 0.0001
# [step 101] neg-log-likelihood -1226.617976 stepsize 0.0001
# [step 102] neg-log-likelihood -1227.498046 stepsize 0.0001
# [step 103] neg-log-likelihood -1227.861425 stepsize 0.0001
# [step 104] neg-log-likelihood -1230.267811 stepsize 0.0001
# [step 105] neg-log-likelihood -1228.457434 stepsize 0.0001
# [step 106] neg-log-likelihood -1230.216880 stepsize 0.0001
# [step 107] neg-log-likelihood -1228.813426 stepsize 0.0001
# [step 108] neg-log-likelihood -1232.465029 stepsize 0.0001
# [step 109] neg-log-likelihood -1232.192059 stepsize 0.0001
# [step 110] neg-log-likelihood -1230.978592 stepsize 0.0001
# [step 111] neg-log-likelihood -1231.785075 stepsize 0.0001
# [step 112] neg-log-likelihood -1234.818500 stepsize 0.0001
# [step 113] neg-log-likelihood -1233.072770 stepsize 0.0001
# [step 114] neg-log-likelihood -1234.007335 stepsize 0.0001
# [step 115] neg-log-likelihood -1236.842179 stepsize 0.0001
# [step 116] neg-log-likelihood -1238.644224 stepsize 0.0001
# [step 117] neg-log-likelihood -1237.889951 stepsize 0.0001
# [step 118] neg-log-likelihood -1235.770283 stepsize 0.0001
# [step 119] neg-log-likelihood -1239.943912 stepsize 0.0001
# [step 120] neg-log-likelihood -1237.509239 stepsize 0.0001
# [step 121] neg-log-likelihood -1240.893625 stepsize 0.0001
# [step 122] neg-log-likelihood -1238.237652 stepsize 0.0001
# [step 123] neg-log-likelihood -1239.886565 stepsize 0.0001
# [step 124] neg-log-likelihood -1244.177367 stepsize 0.0001
# [step 125] neg-log-likelihood -1240.477917 stepsize 0.0001
# [step 126] neg-log-likelihood -1240.670654 stepsize 0.0001
# [step 127] neg-log-likelihood -1243.623451 stepsize 0.0001
# [step 128] neg-log-likelihood -1243.918666 stepsize 0.0001
# [step 129] neg-log-likelihood -1245.258353 stepsize 0.0001
# [step 130] neg-log-likelihood -1243.417958 stepsize 0.0001
# [step 131] neg-log-likelihood -1247.608431 stepsize 0.0001
# [step 132] neg-log-likelihood -1248.249165 stepsize 0.0001
# [step 133] neg-log-likelihood -1247.979115 stepsize 0.0001
# [step 134] neg-log-likelihood -1246.659919 stepsize 0.0001
# [step 135] neg-log-likelihood -1249.903879 stepsize 0.0001
# [step 136] neg-log-likelihood -1250.247377 stepsize 0.0001
# [step 137] neg-log-likelihood -1252.566629 stepsize 0.0001
# [step 138] neg-log-likelihood -1249.791785 stepsize 0.0001
# [step 139] neg-log-likelihood -1249.504585 stepsize 0.0001
# [step 140] neg-log-likelihood -1250.596099 stepsize 0.0001
# [step 141] neg-log-likelihood -1251.688098 stepsize 0.0001
# [step 142] neg-log-likelihood -1252.856766 stepsize 0.0001
# [step 143] neg-log-likelihood -1257.064639 stepsize 0.0001
# [step 144] neg-log-likelihood -1255.106411 stepsize 0.0001
# [step 145] neg-log-likelihood -1254.787099 stepsize 0.0001
# [step 146] neg-log-likelihood -1253.339054 stepsize 0.0001
# [step 147] neg-log-likelihood -1251.498971 stepsize 0.0001
# [step 148] neg-log-likelihood -1252.936959 stepsize 0.0001
# [step 149] neg-log-likelihood -1253.175521 stepsize 0.0001
# [step 150] neg-log-likelihood -1255.631186 stepsize 0.0001
# [step 151] neg-log-likelihood -1254.096084 stepsize 0.0001
# [step 152] neg-log-likelihood -1255.031064 stepsize 0.0001
# [step 153] neg-log-likelihood -1253.417038 stepsize 0.0001
# [step 154] neg-log-likelihood -1260.261888 stepsize 0.0001
# [step 155] neg-log-likelihood -1260.897490 stepsize 0.0001
# [step 156] neg-log-likelihood -1257.671672 stepsize 0.0001
# [step 157] neg-log-likelihood -1255.984609 stepsize 0.0001
# [step 158] neg-log-likelihood -1259.637972 stepsize 0.0001
# [step 159] neg-log-likelihood -1261.782948 stepsize 0.0001
# [step 160] neg-log-likelihood -1263.481626 stepsize 0.0001
# [step 161] neg-log-likelihood -1266.923966 stepsize 0.0001
# [step 162] neg-log-likelihood -1267.877196 stepsize 0.0001
# [step 163] neg-log-likelihood -1270.274179 stepsize 0.0001
# [step 164] neg-log-likelihood -1271.909028 stepsize 0.0001
# [step 165] neg-log-likelihood -1271.894343 stepsize 0.0001
# [step 166] neg-log-likelihood -1272.656314 stepsize 0.0001
# [step 167] neg-log-likelihood -1275.252154 stepsize 0.0001
# [step 168] neg-log-likelihood -1276.944467 stepsize 0.0001
# [step 169] neg-log-likelihood -1281.614036 stepsize 0.0001
# [step 170] neg-log-likelihood -1281.372655 stepsize 0.0001
# [step 171] neg-log-likelihood -1283.946575 stepsize 0.0001
# [step 172] neg-log-likelihood -1285.657790 stepsize 0.0001
# [step 173] neg-log-likelihood -1287.859143 stepsize 0.0001
# [step 174] neg-log-likelihood -1287.601389 stepsize 0.0001
# [step 175] neg-log-likelihood -1290.991985 stepsize 0.0001
# [step 176] neg-log-likelihood -1295.696897 stepsize 0.0001
# [step 177] neg-log-likelihood -1297.788245 stepsize 0.0001
# [step 178] neg-log-likelihood -1297.927563 stepsize 0.0001
# [step 179] neg-log-likelihood -1299.388697 stepsize 0.0001
# [step 180] neg-log-likelihood -1302.728066 stepsize 0.0001
# [step 181] neg-log-likelihood -1304.592101 stepsize 0.0001
# [step 182] neg-log-likelihood -1308.299439 stepsize 0.0001
# [step 183] neg-log-likelihood -1307.756693 stepsize 0.0001
# [step 184] neg-log-likelihood -1312.266016 stepsize 0.0001
# [step 185] neg-log-likelihood -1312.561648 stepsize 0.0001
# [step 186] neg-log-likelihood -1315.526812 stepsize 0.0001
# [step 187] neg-log-likelihood -1317.546086 stepsize 0.0001
# [step 188] neg-log-likelihood -1320.935714 stepsize 0.0001
# [step 189] neg-log-likelihood -1326.607520 stepsize 0.0001
# [step 190] neg-log-likelihood -1329.507626 stepsize 0.0001
# [step 191] neg-log-likelihood -1328.452077 stepsize 0.0001
# [step 192] neg-log-likelihood -1330.606485 stepsize 0.0001
# [step 193] neg-log-likelihood -1331.132898 stepsize 0.0001
# [step 194] neg-log-likelihood -1332.657039 stepsize 0.0001
# [step 195] neg-log-likelihood -1336.998912 stepsize 0.0001
# [step 196] neg-log-likelihood -1335.200617 stepsize 0.0001
# [step 197] neg-log-likelihood -1337.724095 stepsize 0.0001
# [step 198] neg-log-likelihood -1341.140540 stepsize 0.0001
# [step 199] neg-log-likelihood -1340.951618 stepsize 0.0001
# [step 200] neg-log-likelihood -1342.940910 stepsize 0.0001
# [step 201] neg-log-likelihood -1342.977966 stepsize 0.0001
# [step 202] neg-log-likelihood -1344.538123 stepsize 0.0001
# [step 203] neg-log-likelihood -1347.994664 stepsize 0.0001
# [step 204] neg-log-likelihood -1345.806481 stepsize 0.0001
# ...
# [step 329] neg-log-likelihood -1425.514677 stepsize 0.0001
# [step 330] neg-log-likelihood -1427.567097 stepsize 0.0001
# [step 331] neg-log-likelihood -1426.102899 stepsize 0.0001
# [step 332] neg-log-likelihood -1427.385438 stepsize 0.0001
# [step 333] neg-log-likelihood -1424.084567 stepsize 0.0001
# [step 334] neg-log-likelihood -1425.652849 stepsize 0.0001
# [step 335] neg-log-likelihood -1428.932655 stepsize 0.0001
# [step 336] neg-log-likelihood -1429.971450 stepsize 0.0001
# [step 337] neg-log-likelihood -1428.964389 stepsize 0.0001
# [step 338] neg-log-likelihood -1429.626217 stepsize 0.0001
# [step 339] neg-log-likelihood -1430.348147 stepsize 0.0001
# [step 340] neg-log-likelihood -1429.557561 stepsize 0.0001
# [step 341] neg-log-likelihood -1429.866804 stepsize 0.0001
# [step 342] neg-log-likelihood -1430.581417 stepsize 0.0001
# [step 343] neg-log-likelihood -1428.194893 stepsize 0.0001
# [step 344] neg-log-likelihood -1431.083699 stepsize 0.0001
# [step 345] neg-log-likelihood -1431.507153 stepsize 0.0001
# [step 346] neg-log-likelihood -1428.579301 stepsize 0.0001
# [step 347] neg-log-likelihood -1431.467354 stepsize 0.0001
# [step 348] neg-log-likelihood -1429.547579 stepsize 0.0001
# [step 349] neg-log-likelihood -1431.631525 stepsize 0.0001
# [step 350] neg-log-likelihood -1434.757640 stepsize 0.0001
# [step 351] neg-log-likelihood -1433.855131 stepsize 0.0001
# [step 352] neg-log-likelihood -1433.765235 stepsize 0.0001
# [step 353] neg-log-likelihood -1432.445386 stepsize 0.0001
# [step 354] neg-log-likelihood -1432.516048 stepsize 0.0001
# [step 355] neg-log-likelihood -1434.630600 stepsize 0.0001
# [step 356] neg-log-likelihood -1434.838413 stepsize 0.0001
# [step 357] neg-log-likelihood -1436.984039 stepsize 0.0001
# [step 358] neg-log-likelihood -1435.432325 stepsize 0.0001
# [step 359] neg-log-likelihood -1439.563780 stepsize 0.0001
# [step 360] neg-log-likelihood -1431.542452 stepsize 0.0001
# [step 361] neg-log-likelihood -1440.540996 stepsize 0.0001
# [step 362] neg-log-likelihood -1434.304303 stepsize 0.0001
# [step 363] neg-log-likelihood -1434.389386 stepsize 0.0001
# [step 364] neg-log-likelihood -1435.952773 stepsize 0.0001
# [step 365] neg-log-likelihood -1434.327537 stepsize 0.0001
# [step 366] neg-log-likelihood -1439.502567 stepsize 0.0001
# [step 367] neg-log-likelihood -1438.361047 stepsize 0.0001
# [step 368] neg-log-likelihood -1435.622401 stepsize 0.0001
# [step 369] neg-log-likelihood -1436.186331 stepsize 0.0001
# [step 370] neg-log-likelihood -1437.935356 stepsize 0.0001
# [step 371] neg-log-likelihood -1435.423613 stepsize 0.0001
# [step 372] neg-log-likelihood -1438.936072 stepsize 0.0001
# [step 373] neg-log-likelihood -1438.276574 stepsize 0.0001
# [step 374] neg-log-likelihood -1440.140271 stepsize 0.0001
# [step 375] neg-log-likelihood -1436.478358 stepsize 0.0001
# [step 376] neg-log-likelihood -1438.586798 stepsize 0.0001
# [step 377] neg-log-likelihood -1439.755680 stepsize 0.0001
# [step 378] neg-log-likelihood -1439.758201 stepsize 0.0001
# [step 379] neg-log-likelihood -1440.597323 stepsize 0.0001
# [step 380] neg-log-likelihood -1440.319018 stepsize 0.0001
# [step 381] neg-log-likelihood -1443.030431 stepsize 0.0001
# [step 382] neg-log-likelihood -1440.578963 stepsize 0.0001
# [step 383] neg-log-likelihood -1443.169534 stepsize 0.0001
# [step 384] neg-log-likelihood -1442.779072 stepsize 0.0001
# [step 385] neg-log-likelihood -1443.001507 stepsize 0.0001
# [step 386] neg-log-likelihood -1440.800053 stepsize 0.0001
# [step 387] neg-log-likelihood -1443.371636 stepsize 0.0001
# [step 388] neg-log-likelihood -1443.686670 stepsize 0.0001
# [step 389] neg-log-likelihood -1445.330257 stepsize 0.0001
# [step 390] neg-log-likelihood -1444.129503 stepsize 0.0001
# [step 391] neg-log-likelihood -1443.390077 stepsize 0.0001
# [step 392] neg-log-likelihood -1443.975242 stepsize 0.0001
# [step 393] neg-log-likelihood -1448.226518 stepsize 0.0001
# [step 394] neg-log-likelihood -1442.075409 stepsize 0.0001
# [step 395] neg-log-likelihood -1445.130542 stepsize 0.0001
# [step 396] neg-log-likelihood -1445.266312 stepsize 0.0001
# [step 397] neg-log-likelihood -1446.689877 stepsize 0.0001
# [step 398] neg-log-likelihood -1444.876516 stepsize 0.0001
# [step 399] neg-log-likelihood -1445.379528 stepsize 0.0001
# [step 400] neg-log-likelihood -1445.486113 stepsize 0.0001
# [step 401] neg-log-likelihood -1448.769354 stepsize 0.0001
# [step 402] neg-log-likelihood -1448.694141 stepsize 0.0001
# [step 403] neg-log-likelihood -1446.068419 stepsize 0.0001
# [step 404] neg-log-likelihood -1448.191644 stepsize 0.0001
# [step 405] neg-log-likelihood -1446.084052 stepsize 0.0001
# [step 406] neg-log-likelihood -1447.342574 stepsize 0.0001
# [step 407] neg-log-likelihood -1445.792200 stepsize 0.0001
# [step 408] neg-log-likelihood -1448.806598 stepsize 0.0001
# [step 409] neg-log-likelihood -1448.693130 stepsize 0.0001
# [step 410] neg-log-likelihood -1446.775351 stepsize 0.0001
# [step 411] neg-log-likelihood -1447.828658 stepsize 0.0001
# [step 412] neg-log-likelihood -1449.193099 stepsize 0.0001
# [step 413] neg-log-likelihood -1447.981644 stepsize 0.0001
# [step 414] neg-log-likelihood -1447.416757 stepsize 0.0001
# [step 415] neg-log-likelihood -1446.950155 stepsize 0.0001
# [step 416] neg-log-likelihood -1449.872509 stepsize 0.0001
# [step 417] neg-log-likelihood -1449.944113 stepsize 0.0001
# [step 418] neg-log-likelihood -1450.401414 stepsize 0.0001
# [step 419] neg-log-likelihood -1450.942594 stepsize 0.0001
# [step 420] neg-log-likelihood -1451.437604 stepsize 0.0001
# [step 421] neg-log-likelihood -1449.899250 stepsize 0.0001
# [step 422] neg-log-likelihood -1449.198467 stepsize 0.0001
# [step 423] neg-log-likelihood -1451.883098 stepsize 0.0001
# [step 424] neg-log-likelihood -1450.105478 stepsize 0.0001
# [step 425] neg-log-likelihood -1450.875207 stepsize 0.0001
# [step 426] neg-log-likelihood -1451.184010 stepsize 0.0001
# [step 427] neg-log-likelihood -1452.478750 stepsize 0.0001
# [step 428] neg-log-likelihood -1454.114025 stepsize 0.0001
# [step 429] neg-log-likelihood -1452.679641 stepsize 0.0001
# [step 430] neg-log-likelihood -1450.962505 stepsize 0.0001
# [step 431] neg-log-likelihood -1455.791201 stepsize 0.0001
# [step 432] neg-log-likelihood -1455.073262 stepsize 0.0001
# [step 433] neg-log-likelihood -1453.393260 stepsize 0.0001
# [step 434] neg-log-likelihood -1452.840085 stepsize 0.0001
# [step 435] neg-log-likelihood -1454.222980 stepsize 0.0001
# [step 436] neg-log-likelihood -1451.991390 stepsize 0.0001
# [step 437] neg-log-likelihood -1454.640392 stepsize 0.0001
# [step 438] neg-log-likelihood -1456.054366 stepsize 0.0001
# [step 439] neg-log-likelihood -1450.449161 stepsize 0.0001
# [step 440] neg-log-likelihood -1455.710007 stepsize 0.0001
# [step 441] neg-log-likelihood -1454.884319 stepsize 0.0001
# [step 442] neg-log-likelihood -1451.029367 stepsize 0.0001
# [step 443] neg-log-likelihood -1455.424712 stepsize 0.0001
# [step 444] neg-log-likelihood -1454.218715 stepsize 0.0001
# [step 445] neg-log-likelihood -1453.402959 stepsize 0.0001
# [step 446] neg-log-likelihood -1455.284800 stepsize 0.0001
# [step 447] neg-log-likelihood -1458.991438 stepsize 0.0001
# [step 448] neg-log-likelihood -1454.726045 stepsize 0.0001
# [step 449] neg-log-likelihood -1456.364924 stepsize 0.0001
# [step 450] neg-log-likelihood -1458.021323 stepsize 0.0001
# [step 451] neg-log-likelihood -1454.499287 stepsize 0.0001
# [step 452] neg-log-likelihood -1457.613551 stepsize 0.0001
# [step 453] neg-log-likelihood -1452.258717 stepsize 0.0001
# [step 454] neg-log-likelihood -1455.803990 stepsize 0.0001
# [step 455] neg-log-likelihood -1455.535912 stepsize 0.0001
# [step 456] neg-log-likelihood -1457.960805 stepsize 0.0001
# [step 457] neg-log-likelihood -1457.954868 stepsize 0.0001
# [step 458] neg-log-likelihood -1456.213078 stepsize 0.0001
# [step 459] neg-log-likelihood -1458.228277 stepsize 0.0001
# [step 460] neg-log-likelihood -1455.492536 stepsize 0.0001
# [step 461] neg-log-likelihood -1455.712012 stepsize 0.0001
# [step 462] neg-log-likelihood -1457.506440 stepsize 0.0001
# [step 463] neg-log-likelihood -1454.624943 stepsize 0.0001
# [step 464] neg-log-likelihood -1459.897029 stepsize 0.0001
# [step 465] neg-log-likelihood -1455.534589 stepsize 0.0001
# [step 466] neg-log-likelihood -1457.545472 stepsize 0.0001
# [step 467] neg-log-likelihood -1456.043881 stepsize 0.0001
# [step 468] neg-log-likelihood -1459.902538 stepsize 0.0001
# [step 469] neg-log-likelihood -1458.398391 stepsize 0.0001
# [step 470] neg-log-likelihood -1458.267948 stepsize 0.0001
# [step 471] neg-log-likelihood -1457.140348 stepsize 0.0001
# [step 472] neg-log-likelihood -1458.763971 stepsize 0.0001
# [step 473] neg-log-likelihood -1462.609504 stepsize 0.0001
# [step 474] neg-log-likelihood -1457.686949 stepsize 0.0001
# [step 475] neg-log-likelihood -1458.857501 stepsize 0.0001
# [step 476] neg-log-likelihood -1456.452774 stepsize 0.0001
# [step 477] neg-log-likelihood -1459.999171 stepsize 0.0001
# [step 478] neg-log-likelihood -1456.065289 stepsize 0.0001
# [step 479] neg-log-likelihood -1457.266771 stepsize 0.0001
# [step 480] neg-log-likelihood -1461.152355 stepsize 0.0001
# [step 481] neg-log-likelihood -1459.909546 stepsize 0.0001
# [step 482] neg-log-likelihood -1458.995789 stepsize 0.0001
# [step 483] neg-log-likelihood -1458.011556 stepsize 0.0001
# [step 484] neg-log-likelihood -1459.172772 stepsize 0.0001
# [step 485] neg-log-likelihood -1460.972692 stepsize 0.0001
# [step 486] neg-log-likelihood -1459.044970 stepsize 0.0001
# [step 487] neg-log-likelihood -1458.226145 stepsize 0.0001
# [step 488] neg-log-likelihood -1459.097313 stepsize 0.0001
# [step 489] neg-log-likelihood -1458.113030 stepsize 0.0001
# [step 490] neg-log-likelihood -1461.553057 stepsize 0.0001
# [step 491] neg-log-likelihood -1458.499657 stepsize 0.0001
# [step 492] neg-log-likelihood -1461.089863 stepsize 0.0001
# [step 493] neg-log-likelihood -1458.039120 stepsize 0.0001
# [step 494] neg-log-likelihood -1459.504873 stepsize 0.0001
# [step 495] neg-log-likelihood -1462.874383 stepsize 0.0001
# [step 496] neg-log-likelihood -1464.356082 stepsize 0.0001
# [step 497] neg-log-likelihood -1459.278102 stepsize 0.0001
# [step 498] neg-log-likelihood -1464.896543 stepsize 0.0001
# [step 499] neg-log-likelihood -1457.963955 stepsize 0.0001
# [step 500] neg-log-likelihood -1460.500349 stepsize 0.0001
# [step 501] neg-log-likelihood -1461.723420 stepsize 0.0001
# [step 502] neg-log-likelihood -1457.912452 stepsize 0.0001
# [step 503] neg-log-likelihood -1464.755808 stepsize 0.0001
# [step 504] neg-log-likelihood -1458.306711 stepsize 0.0001
# [step 505] neg-log-likelihood -1464.531869 stepsize 0.0001
# [step 506] neg-log-likelihood -1464.990685 stepsize 0.0001
# [step 507] neg-log-likelihood -1460.184842 stepsize 0.0001
# [step 508] neg-log-likelihood -1459.238925 stepsize 0.0001
# [step 509] neg-log-likelihood -1458.584020 stepsize 0.0001
# [step 510] neg-log-likelihood -1458.870614 stepsize 0.0001
# [step 511] neg-log-likelihood -1462.361594 stepsize 0.0001
# [step 512] neg-log-likelihood -1463.283949 stepsize 0.0001
# [step 513] neg-log-likelihood -1462.748855 stepsize 0.0001
# [step 514] neg-log-likelihood -1461.135747 stepsize 0.0001
# [step 515] neg-log-likelihood -1462.395252 stepsize 0.0001
# [step 516] neg-log-likelihood -1459.690118 stepsize 0.0001
# [step 517] neg-log-likelihood -1460.294460 stepsize 0.0001
# [step 518] neg-log-likelihood -1460.314992 stepsize 0.0001
# [step 519] neg-log-likelihood -1459.678660 stepsize 0.0001
# [step 520] neg-log-likelihood -1460.977581 stepsize 0.0001
# [step 521] neg-log-likelihood -1460.392499 stepsize 0.0001
# [step 522] neg-log-likelihood -1461.287722 stepsize 0.0001
# [step 523] neg-log-likelihood -1460.646318 stepsize 0.0001
# [step 524] neg-log-likelihood -1459.337314 stepsize 0.0001
# [step 525] neg-log-likelihood -1458.525321 stepsize 0.0001
# [step 526] neg-log-likelihood -1461.800744 stepsize 0.0001
# [step 527] neg-log-likelihood -1467.749657 stepsize 0.0001
# [step 528] neg-log-likelihood -1459.192304 stepsize 0.0001
# [step 529] neg-log-likelihood -1460.262644 stepsize 0.0001
# [step 530] neg-log-likelihood -1461.716717 stepsize 0.0001
# [step 531] neg-log-likelihood -1459.864671 stepsize 0.0001
# [step 532] neg-log-likelihood -1463.569544 stepsize 0.0001
# [step 533] neg-log-likelihood -1459.597305 stepsize 0.0001
# [step 534] neg-log-likelihood -1458.852721 stepsize 0.0001
# [step 535] neg-log-likelihood -1462.418670 stepsize 0.0001
# [step 536] neg-log-likelihood -1462.196968 stepsize 0.0001
# [step 537] neg-log-likelihood -1460.774211 stepsize 0.0001
# [step 538] neg-log-likelihood -1461.702351 stepsize 0.0001
# [step 539] neg-log-likelihood -1461.182845 stepsize 0.0001
# [step 540] neg-log-likelihood -1459.556005 stepsize 0.0001
# [step 541] neg-log-likelihood -1459.879346 stepsize 0.0001
# [step 542] neg-log-likelihood -1461.120705 stepsize 0.0001
# [step 543] neg-log-likelihood -1458.546190 stepsize 0.0001
# [step 544] neg-log-likelihood -1462.739156 stepsize 0.0001
# [step 545] neg-log-likelihood -1460.132170 stepsize 0.0001
# [step 546] neg-log-likelihood -1460.990117 stepsize 0.0001
# [step 547] neg-log-likelihood -1461.089121 stepsize 0.0001
# [step 548] neg-log-likelihood -1459.564218 stepsize 0.0001
# [step 549] neg-log-likelihood -1463.558479 stepsize 0.0001
# [step 550] neg-log-likelihood -1459.808915 stepsize 0.0001
# [step 551] neg-log-likelihood -1461.101197 stepsize 0.0001
# [step 552] neg-log-likelihood -1458.522272 stepsize 0.0001
# [step 553] neg-log-likelihood -1461.247885 stepsize 0.0001
# [step 554] neg-log-likelihood -1458.703875 stepsize 0.0001
# [step 555] neg-log-likelihood -1459.843947 stepsize 0.0001
# [step 556] neg-log-likelihood -1459.003779 stepsize 0.0001
# [step 557] neg-log-likelihood -1458.243780 stepsize 0.0001
# [step 558] neg-log-likelihood -1457.880110 stepsize 0.0001
# [step 559] neg-log-likelihood -1459.696231 stepsize 0.0001
# [step 560] neg-log-likelihood -1459.655370 stepsize 0.0001
# [step 561] neg-log-likelihood -1460.839044 stepsize 0.0001
# [step 562] neg-log-likelihood -1458.954471 stepsize 0.0001
# [step 563] neg-log-likelihood -1459.355938 stepsize 0.0001
# [step 564] neg-log-likelihood -1461.980726 stepsize 0.0001
# [step 565] neg-log-likelihood -1457.521579 stepsize 0.0001
# [step 566] neg-log-likelihood -1460.990646 stepsize 0.0001
# [step 567] neg-log-likelihood -1461.334928 stepsize 0.0001
# [step 568] neg-log-likelihood -1459.410083 stepsize 0.0001
# [step 569] neg-log-likelihood -1459.148997 stepsize 0.0001
# [step 570] neg-log-likelihood -1457.033985 stepsize 0.0001
# [step 571] neg-log-likelihood -1461.296239 stepsize 0.0001
# [step 572] neg-log-likelihood -1461.571700 stepsize 0.0001
# [step 573] neg-log-likelihood -1456.790380 stepsize 0.0001
# [step 574] neg-log-likelihood -1457.088486 stepsize 0.0001
# [step 575] neg-log-likelihood -1458.177077 stepsize 0.0001
# [step 576] neg-log-likelihood -1460.471658 stepsize 0.0001
# [step 577] neg-log-likelihood -1454.945481 stepsize 0.0001
# [step 578] neg-log-likelihood -1457.082718 stepsize 0.0001
# [step 579] neg-log-likelihood -1455.940520 stepsize 0.0001
# [step 580] neg-log-likelihood -1457.904611 stepsize 0.0001
# [step 581] neg-log-likelihood -1453.851125 stepsize 0.0001
# [step 582] neg-log-likelihood -1458.767995 stepsize 0.0001
# [step 583] neg-log-likelihood -1457.981471 stepsize 0.0001
# [step 584] neg-log-likelihood -1457.341955 stepsize 0.0001
# [step 585] neg-log-likelihood -1461.207832 stepsize 0.0001
# [step 586] neg-log-likelihood -1462.439750 stepsize 0.0001
# [step 587] neg-log-likelihood -1460.296672 stepsize 0.0001
# [step 588] neg-log-likelihood -1455.763644 stepsize 0.0001
# [step 589] neg-log-likelihood -1456.678060 stepsize 0.0001
# [step 590] neg-log-likelihood -1454.999426 stepsize 0.0001
# [step 591] neg-log-likelihood -1454.872148 stepsize 0.0001
# [step 592] neg-log-likelihood -1457.156878 stepsize 0.0001
# [step 593] neg-log-likelihood -1456.267838 stepsize 0.0001
# [step 594] neg-log-likelihood -1453.544110 stepsize 0.0001
# [step 595] neg-log-likelihood -1459.696172 stepsize 0.0001
# [step 596] neg-log-likelihood -1454.077220 stepsize 0.0001
# [step 597] neg-log-likelihood -1452.850584 stepsize 0.0001
# [step 598] neg-log-likelihood -1452.551355 stepsize 0.0001
# [step 599] neg-log-likelihood -1451.938635 stepsize 0.0001

# %%
fig= plt.figure(1)
fig.set_size_inches(12.0, 6.0*len(lambda_array))
plt.style.use('seaborn-white')

for i in np.arange(len(lambda_array)):
    ax = plt.subplot(len(lambda_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_nll_eu_array[i], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_nll_grass_array[i], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
                             r"Grassmann ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
                             fontsize = 15, loc='upper center', frameon=True)
    else:    
        ax.legend([h1, h2], [r"Euclidean ($\eta$ = {0:5.4f})".format(eta), r"Grassmann ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper center', frameon=True)
    plt.grid(1)
    plt.ylabel('negative log-likelihood', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_01_16_" + str(trail) + "_"
    file_tail = "_nll_iters_Grass_Eu.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %% [markdown]
# These plots show the comparison of learning trajectories for different regularization paramters $\lambda$. We see that the larger $\lambda$, the smoother the curve is. However, it introduces more biases.
# <img src="../figures/03_31_16_nll_iters_Grass_Eu_1_nearReg.png">

# %%
fig= plt.figure(2)
fig.set_size_inches(12.0, 6.0*len(lambda_array))
plt.style.use('seaborn-white')

for i in np.arange(len(lambda_array)):
    ax = plt.subplot(len(lambda_array),1,i+1)
    h1, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,0], 'b')
    h2, = plt.plot(np.arange(max_iters), hist_Hsig_array[i][:,1], 'r')
    if add_reg:
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i]), \
                             r"2nd singular value ($\eta$ = {0:5.4f}, $\lambda$ = {1:5.3f})".format(eta, lambda_array[i])], \
                             fontsize = 15, loc='upper right', frameon=True)
    else:    
        ax.legend([h1, h2], [r"1st singular value ($\eta$ = {0:5.4f})".format(eta), r"2nd singular value ($\eta$ = {0:5.4f})".format(eta)], \
                             fontsize = 15, loc='upper right', frameon=True)
    plt.grid(1)
    plt.ylabel('singular value', fontsize = 15)
    plt.xlabel('iterations', fontsize = 15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
plt.show    
if Ifsavefig:
    file_org = "../figures/04_01_16_" + str(trail) + "_"
    file_tail = "_sig_iters_Grass_Eu.eps"
    if choice == "random":
        file_comment = "rand"
    elif choice == "near":
        file_comment = "near"
        
    if add_reg:
        file_comment = file_comment +'Reg'
        
    fig.savefig(file_org + file_comment + file_tail )

# %%
Ifsavefig = True
